# %%
import pandas as pd
import os

# %% [markdown]
# # Cluster based on additional tags, see top divergences

# %%
metadata_fpath = '/usr0/home/mamille2/erebor/fanfiction-project/data/ao3/harrypotter/au_dataset/metadata_train.csv'
metadata = pd.read_csv(metadata_fpath, index_col=0)
print(len(metadata))
print(metadata.index.name)
metadata.columns
# Out:
# 12570
# fic_id
# Index(['title', 'author', 'author_key', 'rating', 'category', 'fandom',
#        'relationship', 'character', 'additional tags', 'language', 'published',
#        'status', 'status date', 'words', 'comments', 'kudos', 'bookmarks',
#        'hits', 'chapter_count', 'series', 'seriespart', 'seriesid', 'summary',
#        'preface_notes', 'afterword_notes', 'selected_tags'],
#       dtype='object')

# %%
from collections import Counter

# Get vectors for tags

all_tags = [t.lower() for l in metadata['additional tags'] for t in eval(l)]
tag_ctr = Counter(all_tags)
print(len(all_tags))
threshold = 5
top_tag_ctr = [(tag,count) for (tag,count) in tag_ctr.most_common() if count >= threshold]
print(len(top_tag_ctr))
top_tags = [el[0] for el in top_tag_ctr]
# Out:
# 97159
# 2344

# %%
from tqdm import tqdm_notebook as tqdm

for tag, count in tqdm(top_tag_ctr):
    metadata[tag] = metadata['additional tags'].map(lambda x: tag in [t.lower() for t in eval(x)])
#     print(sum(metadata[tag]))
# Out:
# HBox(children=(IntProgress(value=0, max=2344), HTML(value='')))

# %%
import numpy as np
# tag_vectors = metadata.set_index('fic_id').loc[:, top_tags].to_dict()
# tag_vectors = metadata.set_index('fic_id').loc[:, top_tags].to_dict(orient='index')
tag_vectors = np.array(metadata.loc[:, top_tags].values)
print(tag_vectors.shape)
tag_vectors[:2]
# Out:
# (12570, 2344)
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %% [markdown]
# ## Run PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=.7, svd_solver='full')

# %%
reduced = pca.fit_transform(tag_vectors)
print(pca.explained_variance_[:10])
print(pca.n_components_)
# Out:
# [0.18700258 0.12319356 0.11022768 0.09911675 0.09382891 0.06295342
#  0.05988378 0.05430083 0.04819833 0.04617006]
# 368

# %%
# Look at factor loadings on tags
def feats_for_factors(feature_names, pca, n_factors=20, n_feats=40):
    top = np.flip(np.argsort(pca.components_)[:n_factors, -1*n_feats:], axis=1)
    vec = np.vectorize(lambda x: feature_names[x])
    return vec(top)

# %%
factor_feats = feats_for_factors(top_tags, pca, n_feats=5)
print(feats_for_factors(top_tags, pca, n_feats=5))
# Out:
# [['alternate universe' 'romance' 'angst' 'explicit language'
#   'sexual content']
#  ['fluff' 'romance' 'angst' 'humor' 'established relationship']
#  ['angst' 'alternate universe - canon divergence' 'hurt/comfort'
#   'tragedy' 'drama']
#  ['alternate universe' 'fluff' 'angst'
#   'alternate universe - canon divergence' 'fluff and angst']
#  ['alternate universe - canon divergence' 'romance' 'humor' 'fluff'
#   'established relationship']
#  ['sexual content' 'explicit language' 'plot what plot/porn without plot'
#   'anal sex' 'fluff']
#  ['humor' 'parody' 'angst' 'crack' 'explicit language']
#  ['anal sex' 'established relationship' 'oral sex' 'smut'
#   'plot what plot/porn without plot']
#  ['au' 'crossover' 'one shot' 'anal sex'
#   'plot what plot/porn without plot']
#  ['hurt/comfort' 'friendship' 'established relationship' 'au' 'anal sex']
#  ['alternate universe - modern setting' 'au'
#   'alternate universe - non-magical' 'hurt/comfort'
#   'alternate universe - muggle']
#  ['friendship' 'drama' 'one shot' 'alternate universe - modern setting'
#   "marauders' era"]
#  ['established relationship' 'drama' 'hp: ewe' 'tragedy' 'post-hogwarts']
#  ['one shot' 'smut' 'hurt/comfort' 'hp: ewe' 'emotional hurt/comfort']
#  ['established relationship' "marauders' era" 'friendship'
#   'sexual content' 'explicit language']
#  ['crossover' 'alternate universe - hogwarts' 'established relationship'
#   'alternate universe - modern setting' 'hogwarts']
#  ["marauders' era" 'marauders' 'anal sex' 'first time' 'drama']
#  ['explicit sexual content' "marauders' era" 'crossover' 'drama' 'slash']
#  ['alternate universe - hogwarts' 'hogwarts'
#   'plot what plot/porn without plot'
#   'alternate universe - harry potter setting' 'magic']
#  ['slash' 'hogwarts' 'alternate universe - hogwarts' 'one shot'
#   'established relationship']]

# %%
from IPython.core.debugger import set_trace

# Look at factor loadings on examples
def examples_for_factors(data, reduced, n_factors=20, n_examples=20):
    """ Returns n_factors x n_examples """
    
    top = np.argsort(reduced, axis=0)[-1*n_examples:, :n_factors][::-1].T
    vec = np.vectorize(lambda x: data.index[x])
    return vec(top)

# %%
top_factor_examples = examples_for_factors(metadata, reduced, n_factors=10, n_examples=10)
top_factor_examples.shape
# Out:
# (10, 10)

# %% [markdown]
# ## Load fic divergence distances

# %%
from IPython.core.debugger import set_trace

dist_dirpath = '/usr0/home/jfiacco/Research/fanfic/language_model/vocab_dists/train/'

factor_word_dists = []
for factor_examples in top_factor_examples:
    
    word_dists = {}
    
    for fic_id in factor_examples:
        dist_fpath = os.path.join(dist_dirpath, f"{fic_id}.txt.vocab.dists")
        dist = pd.read_csv(dist_fpath, sep='\t', header=None, names=['word', 'distance', 'frequency'], index_col=0)
        dist = dist[dist['frequency'] >= 3]
        word_dists.update(dist['distance'].to_dict())
        
    factor_word_dists.append(word_dists)
    
len(factor_word_dists)
# Out:
# 10

# %%
from pprint import pprint

for i in range(len(factor_word_dists)):
    print(factor_feats[i])
    print(top_factor_examples[i])
    pprint([metadata.loc[fic_id, 'additional tags'] for fic_id in top_factor_examples[i]])
    factor_word_dist = factor_word_dists[i]
    sorted_dist = sorted(factor_word_dist.items(), key=lambda x: x[1], reverse=True)
    pprint(sorted_dist[:10])
    print()
# Out:
# ['alternate universe' 'romance' 'angst' 'explicit language'
#  'sexual content']
# [10095980  9892973 10026635 10095860 10050935 10026620 10162880  9894131
#  10180253 10063406]
# ["['Explicit Language', 'Chan', 'Heterosexual Sex', 'Slash sex', 'Mpreg', 'Out "
#  "of Character', 'Self-Harm', 'Sexual Content', 'Spoilers', 'Threesome', "
#  "'Action/Adventure', 'Alternate Universe', 'Angst', 'Tragedy', 'Crossover', "
#  "'Drama', 'First Time', 'Horror', 'Supernatural - Freeform', 'Hurt/Comfort', "
#  "'Mystery', 'Suspense', 'Pre-Slash', 'Romance']",
#  "['Explicit Language', 'BDSM', 'Slash sex', 'Drug Use', 'Mpreg', 'Out of "
#  "Character', 'Self-Harm', 'Sexual Content', 'Spoilers', 'Threesome', "
#  "'Voyeurism', 'Alternate Universe', 'Angst', 'Tragedy', 'Bonding', 'Drama', "
#  "'First Time', 'Horror', 'Supernatural - Freeform', 'Hurt/Comfort', "
#  "'Pre-Slash', 'Romance']",
#  "['Slash', 'Explicit Language', 'Slash sex', 'Incest', 'Mpreg', 'Out of "
#  "Character', 'Sexual Content', 'Action/Adventure', 'Alternate Universe', "
#  "'Angst', 'Tragedy', 'Drama', 'Horror', 'Supernatural - Freeform', "
#  "'Hurt/Comfort', 'Mystery', 'Suspense', 'Romance']",
#  "['Explicit Language', 'Heterosexual Sex', 'Slash sex', 'Mpreg', 'Out of "
#  "Character', 'Sexual Content', 'Threesome', 'Action/Adventure', 'Alternate "
#  "Universe', 'Angst', 'Tragedy', 'Drama', 'Horror', 'Supernatural - Freeform', "
#  "'Hurt/Comfort', 'Mystery', 'Suspense', 'Romance']",
#  "['Slash', 'Explicit Language', 'BDSM', 'Chan', 'Incest', 'Out of Character', "
#  "'Self-Harm', 'Sexual Content', 'Spoilers', 'Threesome', 'Voyeurism', "
#  "'Action/Adventure', 'Alternate Universe', 'Angst', 'Tragedy', 'Drama', "
#  "'First Time', 'Horror', 'Supernatural - Freeform', 'Mystery', 'Suspense', "
#  "'Romance']",
#  "['Explicit Language', 'Heterosexual Sex', 'Slash sex', 'Incest', 'Mpreg', "
#  "'Out of Character', 'Sexual Content', 'Action/Adventure', 'Alternate "
#  "Universe', 'Angst', 'Tragedy', 'Drama', 'Horror', 'Supernatural - Freeform', "
#  "'Hurt/Comfort', 'Mystery', 'Suspense', 'Romance']",
#  "['Explicit Language', 'Slash sex', 'Out of Character', 'Self-Harm', 'Sexual "
#  "Content', 'Action/Adventure', 'Alternate Universe', 'Angst', 'Tragedy', "
#  "'Bonding', 'Drama', 'First Time', 'Hurt/Comfort', 'Mystery', 'Suspense', "
#  "'Romance']",
#  "['Explicit Language', 'Heterosexual Sex', 'Slash sex', 'Out of Character', "
#  "'Sexual Content', 'Spoilers', 'Threesome', 'Action/Adventure', 'Alternate "
#  "Universe', 'Angst', 'Tragedy', 'Bonding', 'Crossover', 'Drama', 'First "
#  "Time', 'Mystery', 'Suspense', 'Romance']",
#  "['Explicit Language', 'Bestiality', 'Heterosexual Sex', 'Out of Character', "
#  "'Self-Harm', 'Sexual Content', 'Spoilers', 'Action/Adventure', 'Alternate "
#  "Universe', 'Angst', 'Tragedy', 'Drama', 'First Time', 'Hurt/Comfort', "
#  "'Mystery', 'Suspense', 'Romance', 'Science Fiction & Fantasy']",
#  "['Explicit Language', 'Chan', 'Slash sex', 'Gender Change', 'Out of "
#  "Character', 'Sexual Content', 'Spoilers', 'Alternate Universe', 'Angst', "
#  "'Tragedy', 'Drama', 'First Time', 'Hurt/Comfort', 'Mystery', 'Suspense', "
#  "'Pre-Slash', 'Romance']"]
# [('internal', 2.3869599999999997),
#  ('ethereal', 2.339594),
#  ('author', 2.319328),
#  ('civil', 2.0461150000000004),
#  ('warrior', 2.021574),
#  ('location', 1.983491),
#  ('blah', 1.900396),
#  ('birth', 1.886832),
#  ('demonic', 1.885227),
#  ('books', 1.856643)]
#
# ['fluff' 'romance' 'angst' 'humor' 'established relationship']
# [13447413 14206446  8218099  4412690 14219061  8819329  3725170  1530842
#   8203721  8015266]
# ['["Marauders\' Era", \'Marauders\', \'Get Together\', \'First Kiss\', '
#  "'Friends to Lovers', 'Pining', 'Pining Sirius Black', 'Sharing Clothes', "
#  "'Clothes Kink', 'Hogwarts', 'kiss', 'Sweet', 'I love these sweet sweet "
#  "boys', 'peter is barely there because he sucks', 'James is a Dork', 'Gay', "
#  "'wolfstar', 'who let me internet?', 'this is total trash', 'lots of fluff', "
#  "'Fluff', 'Romance', 'Flirting', 'Sexy', 'Remus Lupin is sneaky', 'LGBTQ', "
#  "'Friendship', 'Humor', 'Relationship(s)', 'Consensual', 'Kinks', 'not really "
#  "kinky', 'Kissing', 'Light-Hearted', 'Love', 'Falling In Love', 'Getting "
#  "Together', 'Firsts', 'Pre-Canon', 'Happy Ending', 'Slash']",
#  "['Angst', 'Harry Potter - Freeform', 'Draco Malfoy - Freeform', 'Humor', "
#  "'Fiction', 'Double Life', 'Secret Identity', 'soulmate', 'Soulmate AU', "
#  "'AU', 'Romance', 'Love', 'Drarry', 'Idiots in Love', 'Reincarnation', "
#  "'second life', 'new life', 'Fluff', 'Drabble', 'One Shot', 'Cute', 'm/m - "
#  "Freeform', 'birthday fic', 'Identity Reveal']",
#  "['Angst', 'Fluff', 'Humor', 'One Shot', 'Romance', 'Songfic', 'Squee', 'Book "
#  "7: Harry Potter and the Deathly Hallows', 'Spoilers']",
#  "['Romance', 'Angst', 'Humor', 'Fluff', 'Drabble Collection', 'Established "
#  "Relationship', 'Mild Sexual Content']",
#  "['Minor Hermione Granger/Ron Weasley', 'Minor Pansy Parkinson/Blaise "
#  "Zabini', 'Minor Luna Lovegood/Ginny Weasley', 'Angst', 'Fluff', 'Fluff and "
#  "Angst', 'Smut', 'Eventual Smut', 'Angst with a Happy Ending', 'Angst and "
#  "Fluff and Smut', 'Hurt/Comfort', 'Blind Draco Malfoy', 'Disability', 'Anal "
#  "Sex', 'Anal Fingering', 'Oral Sex', 'Rimming', 'Powerful Harry', 'Magically "
#  "Powerful Harry Potter', 'Powerful Harry Potter', 'Auror Harry Potter', "
#  "'Auror Ron Weasley', 'Ministry worker Hermione Granger', 'Hermione Granger & "
#  "Draco Malfoy Friendship', 'Ginny Weasley & Harry Potter Friendship', "
#  "'Astoria Greengrass & Draco Malfoy Friendship', 'and many other "
#  "friendships', 'wow i have a lot of tags', 'Angst and Humor', 'Romance', "
#  "'Angst and Romance', 'Not Epilogue Compliant', 'Post Hogwarts AU', 'Draco "
#  "Malfoy in the Muggle World', 'Humor']",
#  "['Fluff', 'Domestic', 'Romance', 'Drabble', 'Drabble Collection', 'Probably "
#  "going to be some light angst', 'Light Angst', 'some could take place in a AU "
#  "where Grindelwald never impersonated Graves', 'insecure!Newt', 'Newt has "
#  "scars from his beasts and is self-conscious about them', 'Protective Tina "
#  "Goldstein', 'Angst', 'Original Percival Graves Has PTSD - Post-Traumatic "
#  "Stress Disorder', 'Graves has trauma from Grindlewald', 'Original Percival "
#  "Graves is a Softie', 'Post-Traumatic Stress Disorder - PTSD', "
#  "'Hurt/Comfort', 'Emotional Hurt/Comfort', 'Established Relationship', "
#  "'Developing Relationship', 'Falling In Love', 'Aurors']",
#  "['Romance', 'Fluff', 'Domestic Fluff', 'Angst', 'Humor', 'I Solemnly Swear "
#  "That I Am Up To No Good', 'Adventure']",
#  "['Hogwarts Eighth Year', 'after the war', 'Some alive characters', 'OC "
#  'Snape\', \'This fanfic is about you will find out soon\', "I don\'t know '
#  'what I am doing..really", \'Drarry all the way\', \'Competition\', '
#  "'Fluff', 'Angst', 'Humor', 'Romance']",
#  "['Angst', 'Challenge Response', 'Fluff', 'Humor', 'One Shot', 'Romance', "
#  "'Explicit Language', 'Book 7: Harry Potter and the Deathly Hallows', 'Sexual "
#  "Content', 'Spoilers', 'Voyeurism', 'Exhibitionism']",
#  "['POV Third Person Limited', 'Romance', 'Friends to Lovers', 'Possibly "
#  "Unrequited Love', 'Not Actually Unrequited Love', 'Angst', 'Light Angst', "
#  "'Happy Ending', 'Angst with a Happy Ending', 'Fluff', 'Fluff and Angst', "
#  "'written for hpshipweeks', 'this is barely proof-read and probably full of "
#  "filler words rip']"]
# [('jumpers', 2.381894),
#  ('tick', 1.977582),
#  ('books', 1.910032),
#  ('blaise', 1.8580729999999999),
#  ('silver', 1.7933419999999998),
#  ('replies', 1.6807509999999999),
#  ('folks', 1.6632810000000002),
#  ('hot', 1.526151),
#  ('felt', 1.514041),
#  ('opposite', 1.480159)]
#
# ['angst' 'alternate universe - canon divergence' 'hurt/comfort' 'tragedy'
#  'drama']
# [15736098 10065767  1048104 16163366 16255241 13258383 12398943 16255685
#   9893531  9900953]
# ["['Dark Lord Harry Potter', 'Master of Death', 'Master of Death Harry "
#  "Potter', 'Mod', 'Book 7: Harry Potter and the Deathly Hallows', 'Post-Battle "
#  "of Hogwarts', 'Hurt/Comfort', 'Emotional Hurt/Comfort', 'Angst', 'Fluff and "
#  "Angst', 'Powerful Harry', 'Magically Powerful Harry Potter', 'harry knows "
#  'things\', \'the voices told him\', "Don\'t worry", "the voices know what '
#  'they\'re doing", \'seriously\', \'Powerful Characters\', \'The Deathly '
#  "Hallows', 'Death (Character) - Freeform', 'this is a fix-it fic', 'AU', "
#  "'Alternate Universe - Canon Divergence', 'How Do I Tag', 'more to be added - "
#  "Freeform', 'totally self indulgent writing', 'Blood', 'Violence', 'things "
#  "might get dark later', 'but not TOO dark', 'hopefully']",
#  "['Angst', 'Hurt/Comfort', 'Horror', 'dark!fic', 'Unbeta-ed', 'One Thousand "
#  'and One Nights\', \'Pre-ship\', "This is the darkest thing I\'ve ever '
#  'written", "I Can\'t Believe I Wrote This", \'Alternate Universe - Canon '
#  "Divergence', 'Trigger Warnings Alphabetized for Your Convenience:', 'Abuse', "
#  "'Blood', 'Body Horror', 'Bondage', 'Claustrophobia', 'Depression', 'Fire', "
#  "'Forced Drugs Usage', 'Forced Pregnancy', 'Forced Public Sex', "
#  "'Humiliation', 'Mpreg', 'Pregnancy', 'Psychological Torture', 'Public Sex', "
#  "'Rape', 'Slurs', 'Torture', 'Violence', 'Vomit', 'voyerisum']",
#  "['Alternate Universe - Canon Divergence', 'Book 3: Harry Potter and the "
#  "Prisoner of Azkaban', 'Family', 'Hurt/Comfort', 'Angst', 'Friendship', "
#  "'Grief/Mourning', 'Werewolves', 'Alternate Universe - Werewolf', 'Werewolf "
#  "Biology', 'Werewolf Culture', 'Adoption', 'Parenthood', 'Remus-centric - "
#  "Freeform', 'POV Remus Lupin', 'POV First Person']",
#  "['Alternate Universe - Canon Divergence', 'Hogwarts Fifth Year', 'Potions "
#  "Accident', 'Body Switching of Sorts', 'Angst', 'Eventual Fluff', 'Eventual "
#  "Smut', 'Eventual Romance', 'Angst with a Happy Ending', 'Depressed Draco "
#  "Malfoy', 'Hurt/Comfort', 'Self-Harm', 'Other Additional Tags to Be Added', "
#  "'Tags May Change', 'WIP']",
#  "['Weasley Family', 'Hurt/Comfort', 'Emotional Hurt/Comfort', 'Angst', 'Light "
#  "Angst', 'Light-Hearted', 'Eventual Romance', 'Friendship', 'Redemption', "
#  "'Inspiration', 'Snow', 'Alternate Universe - Canon Divergence', 'The Burrow "
#  "(Harry Potter)']",
#  '["Book 1: Harry Potter and the Philosopher\'s Stone", \'Alternate Universe - '
#  "Canon Divergence', 'Hurt/Comfort', 'Angst', 'James Bond AU', 'Romance', "
#  "'Older Woman/Younger Man', 'Drama', 'Sister-Sister Relationship']",
#  "['Alternate Universe - Canon Divergence', 'Angst', 'Hurt/Comfort', 'First "
#  "War with Voldemort', 'Violence']",
#  "['Friendship', 'Bromance', 'Hurt/Comfort', 'Angst', 'Post-War', 'Alternate "
#  "Universe - Canon Divergence', 'a friend in need', 'Drinking', 'Comforting']",
#  "['Explicit Language', 'Angst', 'Tragedy', 'Drama', 'Hurt/Comfort']",
#  "['Out of Character', 'Spoilers', 'Angst', 'Tragedy', 'Drama', "
#  "'Hurt/Comfort']"]
# [('kisses', 2.636417),
#  ('books', 2.101666),
#  ('grey', 1.934886),
#  ('beer', 1.8002779999999998),
#  ('beg', 1.715512),
#  ('own', 1.670395),
#  ('sherry', 1.655704),
#  ('murmurs', 1.6450080000000002),
#  ('am', 1.6148129999999998),
#  ('-', 1.533367)]
#
# ['alternate universe' 'fluff' 'angst'
#  'alternate universe - canon divergence' 'fluff and angst']
# [12958827  5015104 16463237 16010408  5504573 13409112  8699341  4072942
#   1386646 12883182]
# ["['Angst', 'Fluff', 'Fluff and Angst', 'Angst with a Happy Ending', "
#  "'Alternate Universe', 'Alternate Universe - Canon Divergence', 'One Shot "
#  "Collection', 'Drabble Collection', 'Ficlet Collection', 'mix bag', 'stories "
#  "I may never finish', 'Canonical Character Death', 'With A Twist', 'Original "
#  "Percival Graves is a Softie', 'Original Percival Graves Needs a Hug', "
#  "'Samhain', 'Grief/Mourning', 'Mail Order Brides', 'crispy cinnamon roll', "
#  "'Credence Barebone Needs a Hug', 'Tooth-Rotting Fluff', 'Awkwardness', "
#  "'Awkward Romance', 'Smitten Original Percival Graves', 'Crispy Cinnamon Roll "
#  "Credence']",
#  "['Alternate Universe', 'Alternate Universe - Hogwarts', 'Potterlock', "
#  "'Potter!Lock', 'Magical Sherlock', 'Muggle John', 'Muggle/Wizard Relations', "
#  "'Angst', 'Fluff and Angst', 'Falling In Love', 'Friendship/Love', 'Friends "
#  "to Lovers', 'Magic Revealed', 'Unrequited Love', 'Requited Love', 'Sherlock "
#  "Holmes and Feelings', 'That lead to magical outbursts', 'Fluff', 'Johnlock "
#  "Roulette', 'Alternate Universe - Harry Potter Setting', 'Magic', 'First "
#  "Kiss', 'Domestic Fluff', 'Winter']",
#  "['Angst with a Happy Ending', 'Angst', 'Fluff', 'Hurt/Comfort', 'Emotional "
#  "Hurt/Comfort', 'Alternate Universe', 'Alternate Universe - Canon "
#  'Divergence\', \'Sonorus AU\', \'Established Relationship\', "Mentions of '
#  'Remus\' Scars from Transformations", "Marauders\' Era"]',
#  "['Original Character(s)', 'Death', 'A Lot of Death', 'Homosexuality', "
#  "'Implied homophobia', 'Referenced Death', 'Angst with a Happy Ending', "
#  "'Sharing a Bed', 'Alternate Universe - Hogwarts', 'Hogwarts', 'Bottom "
#  "Scorpius Malfoy', 'Top Fang Octavius', 'Fang is an OC', 'Awkward Flirting', "
#  "'Shyness', 'Shy Gazing', 'Fluff', 'Cute', 'Blushing', 'hand holding', 'Butt "
#  'Squeezing\', \'Scary rooms\', \'why am i like this\', "honestly don\'t '
#  'expect this to be a porn-fest", \'Voldemort?\', \'Delphi is still alive\', '
#  '"Albus doesn\'t date Scorpius", \'Or does he\', \'Fang is jealous\', '
#  "'Revenge', 'Pranking', 'Revenge Sex', 'Anger', 'Angst', 'Anxiety', 'Social "
#  'Anxiety\', \'Abuse\', \'Muggleborn\', \'Being called "mudblood"\', \'Black '
#  "Hermione Granger', 'Rose is annoying', 'The time-turner makes a return', "
#  "'Time Travel', 'Alternate Universe', 'Underage Sex', 'Underage Kissing', "
#  "'Underage Dating?', 'Dating', 'Male Homosexuality', 'Female Homosexuality', "
#  "'Scorpius is bisexual', 'Albus is bicurious', 'Fang is questioning', "
#  '"pls don\'t hate on fangus", \'fang is precious\', \'more fang octavius '
#  "details later']",
#  '[\'First Kiss\', \'Friends to Lovers\', \'Celestial Bodies\', "Marauders\' '
#  'Era", \'Angst\', \'Stargazing\', \'post-OotP\', \'Fluff\', '
#  "'Comfort/Angst', 'Canon Compliant', 'Canon Divergent', 'Alternate Universe', "
#  "'Alternate Universe - Modern Setting', 'band au', 'Alternate Universe - "
#  "Non-Magical', 'Alternate Universe - Space', 'Pining', 'Anthropomorphism - "
#  "Freeform']",
#  "['Alternate Universe', 'Time Travel', 'Voldemort is dead', 'Nobody else is "
#  "though', 'Harry hugs everyone', 'sort of', 'Angst', 'Fluff', 'Hugs', "
#  "'Drarry', 'Falling In Love', 'One Shot', 'Alternate Universe - Time Travel', "
#  "'Time Travel Fix-It', 'Emotional Hurt/Comfort', 'Feels', 'Bittersweet', 'POV "
#  "Outsider']",
#  "['Alternate Universe', 'Past Relationship(s)', 'Past Lives', 'Friendship', "
#  "'Magic', 'Wizards', 'Wizarding World', 'Muggles', 'Muggle/Wizard Relations', "
#  "'Angst', 'Fluff', 'Fluff and Angst', 'Mythical Beings & Creatures']",
#  "['Alternate Universe', 'Dark Ginny Weasley', 'Murder Mystery', 'Alternate "
#  "Universe - Historical', 'Alternate Universe - 1920s', 'Other Additional Tags "
#  "to Be Added', 'Angst', 'Fluff', 'Some Humor', 'Plot Twists', 'Smut', "
#  "'References to Clue | Cluedo', 'Hogwarts Express', 'Disturbing Themes', "
#  "'Love at First Sight', 'Complicated Relationships', 'Doomed Relationship', "
#  "'Tragedy']",
#  "['Abuse', 'Angst', 'mild mentions of rape-non graphic', 'Pregnancy', "
#  "'Mpreg', 'Violence', 'D/s', 'Hurt/Comfort', 'Lemons', 'gender swap', "
#  "'Alternate Universe', 'B-Mod', 'Fluff', 'creaturefic', 'Knotting', 'Het and "
#  "Slash', 'Toys', 'Work In Progress', 'Character "
#  "bashing-Dumbledore/Molly/Ron/Ginny']",
#  '[\'Vampires\', \'vampire Sirius\', \'Alternate Universe\', "Marauders\' '
#  'Era", \'Violence\', \'Hurt/Comfort\', \'Angst\', \'Fluff\', \'Humor as a '
#  "coping mechanism', 'Mystery', 'First War with Voldemort', 'Swearing']"]
# [('evan', 2.2042759999999997),
#  ('octavius', 1.985184),
#  ("'s", 1.7708849999999998),
#  ('holes', 1.7171740000000002),
#  ('bloodthirsty', 1.6950180000000001),
#  ('sickles', 1.633692),
#  ('catches', 1.565418),
#  ('values', 1.456652),
#  ('hugs', 1.397845),
#  ('dark', 1.395225)]
#
# ['alternate universe - canon divergence' 'romance' 'humor' 'fluff'
#  'established relationship']
# [   23405    23227  9920975 12378879    23277    23223    23222   309751
#     23410   200241]
# ["['Romance', 'Established Relationship', 'Humor', 'Family', 'Holidays', "
#  "'Domestic', 'Alternate Canon', 'Alternate Universe - Canon Divergence', "
#  "'Post-Canon', 'Female Characters']",
#  "['Alternate Universe - Canon Divergence', 'Post-Canon', 'Established "
#  "Relationship', 'Humor', 'Romance', 'Exhibitionism', 'Plot What Plot', "
#  "'Family', 'Gay Male Character', 'Challenge Response']",
#  "['Alternate Universe - Canon Divergence', 'Fluff', 'Romance', 'Humor', 'Post "
#  "Hogwarts AU']",
#  "['Alternate Universe - Canon Divergence', 'Fluff', 'Romance', 'Humor']",
#  "['Alternate Universe - Canon Divergence', 'Established Relationship', "
#  "'Humor', 'Romance', 'Friendship', 'LGBTQ Character', 'LGBTQ Character of "
#  "Color', 'Character of Color', 'Chromatic Character', 'Rare Pairing', "
#  "'Male-Female Friendship', 'Gay Male Character', 'Male Character of Color']",
#  "['Alternate Canon', 'Alternate Universe - Canon Divergence', 'Established "
#  "Relationship', 'Pegging', 'Female Characters', 'Romance', 'Post-Canon', "
#  "'Humor', 'Plot What Plot']",
#  "['Alternate Universe - Canon Divergence', 'Post-Canon', 'Romance', 'Humor', "
#  "'Established Relationship', 'Female Character of Color', 'Holidays', 'Plot "
#  "What Plot', 'Rare Pairing', 'Challenge Response']",
#  "['Families of Choice', 'Kid Fic', 'Holidays', 'Shopping', 'Alternate "
#  "Universe - Canon Divergence', 'Post-Canon', 'Established Relationship', "
#  "'Romance', 'Humor', 'Lesbian Character of Color']",
#  "['Alternate Canon', 'Alternate Universe - Canon Divergence', 'Humor', "
#  "'Romance', 'Holidays', 'Family', 'Established Relationship', 'Female "
#  "Characters']",
#  "['Alternate Universe - Canon Divergence', 'Post-Canon', 'Lesbian Character "
#  "of Color', 'Community: kink_bingo', 'Temperature Play', 'Established "
#  "Relationship', 'Humor', 'Romance', 'Plot What Plot']"]
# [('cube', 2.052866),
#  ('gilbert', 2.036038),
#  ('arse', 1.9879669999999998),
#  ('tease', 1.772805),
#  ('cock', 1.726802),
#  ('unpacking', 1.709687),
#  ("'s", 1.6577400000000002),
#  ('entrance', 1.6538099999999998),
#  ('loud', 1.618659),
#  ('flat', 1.605612)]
#
# ['sexual content' 'explicit language' 'plot what plot/porn without plot'
#  'anal sex' 'fluff']
# [10064414 10141175 10052201  9892973 10057376 10095980  9913556 10050935
#   8203525  9893855]
# ["['Explicit Language', 'BDSM', 'Chan', 'Heterosexual Sex', 'Slash sex', "
#  "'Incest', 'Mpreg', 'Out of Character', 'Sexual Content', 'Spoilers', "
#  "'Threesome', 'Bonding']",
#  "['Explicit Language', 'BDSM', 'Chan', 'Heterosexual Sex', 'Slash sex', "
#  "'Incest', 'Out of Character', 'Sexual Content', 'Alternate Universe', "
#  "'Angst', 'Tragedy', 'Drama', 'First Time', 'Hurt/Comfort', 'Pre-Slash']",
#  "['Explicit Language', 'Slash sex', 'Out of Character', 'Sexual Content', "
#  "'Alternate Universe', 'Bonding', 'Drama', 'First Time', 'Horror', "
#  "'Supernatural - Freeform', 'Plot What Plot/Porn Without Plot']",
#  "['Explicit Language', 'BDSM', 'Slash sex', 'Drug Use', 'Mpreg', 'Out of "
#  "Character', 'Self-Harm', 'Sexual Content', 'Spoilers', 'Threesome', "
#  "'Voyeurism', 'Alternate Universe', 'Angst', 'Tragedy', 'Bonding', 'Drama', "
#  "'First Time', 'Horror', 'Supernatural - Freeform', 'Hurt/Comfort', "
#  "'Pre-Slash', 'Romance']",
#  "['Explicit Language', 'BDSM', 'Slash sex', 'Incest', 'Sexual Content', "
#  "'Threesome', 'Voyeurism', 'Plot What Plot/Porn Without Plot']",
#  "['Explicit Language', 'Chan', 'Heterosexual Sex', 'Slash sex', 'Mpreg', 'Out "
#  "of Character', 'Self-Harm', 'Sexual Content', 'Spoilers', 'Threesome', "
#  "'Action/Adventure', 'Alternate Universe', 'Angst', 'Tragedy', 'Crossover', "
#  "'Drama', 'First Time', 'Horror', 'Supernatural - Freeform', 'Hurt/Comfort', "
#  "'Mystery', 'Suspense', 'Pre-Slash', 'Romance']",
#  "['Explicit Language', 'Slash sex', 'Out of Character', 'Sexual Content', "
#  "'First Time', 'Plot What Plot/Porn Without Plot']",
#  "['Slash', 'Explicit Language', 'BDSM', 'Chan', 'Incest', 'Out of Character', "
#  "'Self-Harm', 'Sexual Content', 'Spoilers', 'Threesome', 'Voyeurism', "
#  "'Action/Adventure', 'Alternate Universe', 'Angst', 'Tragedy', 'Drama', "
#  "'First Time', 'Horror', 'Supernatural - Freeform', 'Mystery', 'Suspense', "
#  "'Romance']",
#  "['Alternate Universe', 'Fluff', 'One Shot', 'Plot What Plot/Porn Without "
#  "Plot', 'Smut', 'Alternate Universe - Non-Magical', 'Explicit Language', 'Out "
#  "of Character', 'Sexual Content']",
#  "['Explicit Language', 'BDSM', 'Drug Use', 'Incest', 'Mpreg', 'Out of "
#  "Character', 'Self-Harm', 'Sexual Content', 'Threesome', 'Voyeurism', "
#  "'Alternate Universe', 'Angst', 'Tragedy', 'Drama', 'First Time', 'Horror', "
#  "'Supernatural - Freeform', 'Hurt/Comfort', 'Pre-Slash', 'Romance']"]
# [('guy', 2.37765),
#  ('wiggly', 2.303692),
#  ('arse', 2.0777330000000003),
#  ('warrior', 2.021574),
#  ('location', 1.983491),
#  ('books', 1.910032),
#  ('dick', 1.907932),
#  ('author', 1.8923880000000002),
#  ('birth', 1.886832),
#  ('demonic', 1.885227)]
#
# ['humor' 'parody' 'angst' 'crack' 'explicit language']
# [ 8190152  8201900 10177805  8218219 10076936 10181231 10056488 10076843
#  10032383  9901028]
# ["['BDSM', 'Humor', 'One Shot', 'Parody', 'Plot What Plot/Porn Without Plot', "
#  "'Smut', 'Explicit Language', 'Dom/sub', 'Fetish', 'Sexual Content', 'Crack']",
#  "['Alternate Universe', 'Crossover', 'Humor', 'One Shot', 'Parody', 'Crack', "
#  "'Out of Character', 'Sexual Content']",
#  "['Slash', 'Explicit Language', 'BDSM', 'Slash sex', 'Sexual Content', "
#  "'Action/Adventure', 'Angst', 'Tragedy', 'Drama', 'Humor', 'Parody', "
#  "'Hurt/Comfort']",
#  "['Action/Adventure', 'Alternate Universe', 'Drama', 'Fluff', 'Humor', 'One "
#  "Shot', 'Parody', 'Squee', 'Crack', 'Explicit Language', 'Out of Character']",
#  "['Explicit Language', 'BDSM', 'Out of Character', 'Sexual Content', "
#  "'Voyeurism', 'Humor', 'Parody']",
#  "['Explicit Language', 'Out of Character', 'Sexual Content', 'Humor', "
#  "'Parody', 'Plot What Plot/Porn Without Plot']",
#  "['Explicit Language', 'Out of Character', 'Sexual Content', 'Alternate "
#  "Universe', 'Bonding', 'Crossover', 'First Time', 'Humor', 'Parody', 'Science "
#  "Fiction & Fantasy']",
#  "['Slash', 'Explicit Language', 'Out of Character', 'Sexual Content', "
#  "'Alternate Universe', 'Humor', 'Parody']",
#  "['Slash', 'Explicit Language', 'Chan', 'Out of Character', 'Sexual Content', "
#  "'Voyeurism', 'Alternate Universe', 'Humor', 'Parody', 'Plot What Plot/Porn "
#  "Without Plot']",
#  "['Explicit Language', 'Slash sex', 'Mpreg', 'Out of Character', 'Sexual "
#  "Content', 'Alternate Universe', 'Humor', 'Parody']"]
# [('arse', 2.289158),
#  ('witnessed', 2.107007),
#  ('shag', 2.0360650000000002),
#  ('spike', 2.03503),
#  ('chorus', 1.937513),
#  ('crisis', 1.7906090000000001),
#  ('lyrics', 1.704004),
#  ('skirt', 1.675391),
#  ('ducks', 1.628284),
#  ('outfit', 1.6152799999999998)]
#
# ['anal sex' 'established relationship' 'oral sex' 'smut'
#  'plot what plot/porn without plot']
# [ 9460391  6075483 11174763 13920426 16399421 13066140  6803056  7147427
#  15641634 14347083]
# ["['Established Relationship', 'Plot What Plot/Porn Without Plot', 'Porn', "
#  "'Porn with Feelings', 'Smut', 'Shameless Smut', 'Masturbation', 'Lube', "
#  "'Hand Jobs', 'Anal Fingering', 'Anal Sex', 'Multiple Orgasms', 'POV Draco "
#  "Malfoy', 'Frottage', 'Blow Jobs', 'Face-Fucking', 'Facials', 'Comeplay', "
#  "'Tender Sex', 'Rough Sex', 'Dirty Talk', 'Sex', 'Fluff and Smut']",
#  "['Remix', 'Smut', 'Porn With Plot', 'Porn with Feelings', 'First Time', "
#  "'Loss of Virginity', 'Established Relationship', 'Engagement', "
#  "'Misunderstandings', 'Bottom Draco', 'Top Charlie Weasley', 'Rimming', "
#  "'Dirty Talk', 'Anal Sex', 'Anal Fingering', 'Hand Jobs', 'Face-Fucking', "
#  "'Blow Jobs']",
#  "['Hate Sex', 'Smut', 'Shameless Smut', 'Gratuitous Smut', 'Angst and Porn', "
#  "'Kissing', 'Bathroom Sex', 'Anal Sex', 'Choking', 'Oral Sex', 'Rough Oral "
#  "Sex', 'Rough Kissing', 'Anal Fingering', 'Finger Sucking', 'Self-Hatred', "
#  "'Self-Esteem Issues', 'Self Confidence Issues', 'Forced Orgasm', "
#  "'Drunkenness', 'Drunk Sex', 'Angst', 'Heavy Angst', 'Crying', 'Angst and "
#  "Hurt/Comfort', 'Enemies', 'Death', 'Character Death', 'Grief/Mourning', "
#  "'Switch Harry', 'Top Harry', 'Bottom Harry', 'Top Draco Malfoy', 'Bottom "
#  "Draco']",
#  "['Office Sex', 'Anal Sex', 'Anal Fingering', 'Age Difference', 'Dirty Talk', "
#  "'Dominance', 'Desk Sex', 'Blow Jobs', 'Rough Sex', 'Kissing', 'Plot What "
#  "Plot/Porn Without Plot', 'One Shot', 'Smut', 'Friends With Benefits', 'Top "
#  "Percival Graves', 'Bottom Newt Scamander', 'Clothed Sex', 'Semi-Public Sex', "
#  "'Hair-pulling', 'Suit Sex']",
#  '[\'Sleepovers\', \'Potter Manor\', "Marauders\' Era", \'Marauders\', '
#  "'MWPP', 'wolfstar', 'jilly - Freeform', 'Summer', 'Hogwarts Seventh Year', "
#  "'Hogwarts', 'Fluff', 'Eventual Smut', 'Sirius puns', 'First Time Bottoming', "
#  "'First Time Topping', 'Bottom Sirius Black', 'Top Remus Lupin', 'Anal Sex', "
#  "'Anal Fingering', 'Oral Sex', 'Blow Jobs', 'hold the moan', 'Smut', 'Fluff "
#  "and Smut', 'Shameless Smut', 'PWP', 'Plot What Plot/Porn Without Plot', 'Gay "
#  "Sex']",
#  "['Inappropriate use of mirrors', 'Plot What Plot/Porn Without Plot', 'Porn "
#  "with Feelings', 'Established Relationship', 'Post-Hogwarts', 'Muggle "
#  "London', 'VERY light bondage', 'Rimming', 'Anal Fingering', 'Anal Sex', 'Top "
#  "Draco Malfoy', 'Bottom Harry Potter', 'Kissing', 'Alternate Universe', 'Out "
#  "of Character Draco Malfoy']",
#  "['Anal Sex', 'Anal Fingering', 'Morning Sex', 'Morning Wood', 'Dirty Talk', "
#  "'Established Relationship', 'Fluff and Smut', 'Smut', 'Plot What Plot/Porn "
#  "Without Plot', 'Fluff', 'Happy Ending', 'No Lube', 'Bottom Harry', 'Top "
#  "Draco Malfoy', 'wand in a knot', '24 hour porn challenge']",
#  "['Plot What Plot/Porn Without Plot', 'Explicit Sexual Content', 'Gay Sex', "
#  "'implied PTSD', 'implied trauma', 'Nightmares', 'Boyfriends', 'Fluff and "
#  "Smut', 'Implied/Referenced Suicide', 'Crying', 'Top Theodore', 'Boys "
#  "Kissing', 'French Kissing', 'Making Love', 'Rutting', 'Frottage', 'Blow "
#  "Jobs', 'Rimming', 'Anal Fingering', 'Spit As Lube', 'Anal Sex', 'Gentle "
#  "Sex', 'Mentioned therapy', 'Coming Untouched', 'Naked Cuddling', 'Spooning', "
#  "'Little Spoon Harry', 'Post-Coital Cuddling', 'Emotional Hurt/Comfort', "
#  "'Comfort Sex', 'Boys In Love', 'Bottom Harry Potter', 'Making Out', 'Hand "
#  "Jobs']",
#  "['Incest', 'Parent/Child Incest', 'No Plot/Plotless', 'Plot What Plot/Porn "
#  "Without Plot', 'Porn', 'Bondage', 'Malfoy Manor', 'Abusive Parents', "
#  "'Explicit Sexual Content', 'Sexual Punishment', 'Oral Sex', 'Anal "
#  "Fingering', 'Anal Sex', 'Vaginal Sex', 'Multiple Orgasms', 'Dubious "
#  "Consent', 'Threesome - F/M/M', 'Sex Toys', 'Femdom', 'Strap-Ons', "
#  "'Rape/Non-con Elements']",
#  "['Alternate Universe - Muggle', 'Alternate Universe - Historical', "
#  "'Alternate Universe - Non-Magical', 'Non magic AU', 'Sexual Tension', "
#  "'Smut', 'Angst', 'Fluff', 'Romance', 'flangst', 'Songfic', 'Inspired by "
#  "Music', 'Top Harry Potter', 'Bottom Draco Malfoy', 'Rimming', 'Blow Jobs', "
#  "'Anal Sex', 'Anal Fingering', 'Period-Typical Homophobia', 'Internalized "
#  "Homophobia', 'Closeted Character', 'Master/Servant', 'Servant Harry', "
#  "'Butler Harry', 'Inspired by The Greatest Showman (2017)', 'Hermione Granger "
#  "& Draco Malfoy Friendship', 'Lucius Malfoy Being an Asshole', 'Alternate "
#  "Universe - Victorian', 'Victorian era', 'Pining Harry Potter', 'Virgin Draco "
#  "Malfoy']"]
# [('arse', 2.324063),
#  ('mutters', 2.3196),
#  ('dick', 2.205962),
#  ('builds', 2.133527),
#  ('butt', 2.029687),
#  ('tender', 1.8856669999999998),
#  ('pre', 1.86845),
#  ('wormy', 1.843278),
#  ('grips', 1.794605),
#  ('cock', 1.7782939999999998)]
#
# ['au' 'crossover' 'one shot' 'anal sex' 'plot what plot/porn without plot']
# [ 9278135  5825332 10385655  1774519  2176812  4193868 16505483 14206446
#   3985804   611527]
# ["['Top Draco Malfoy', 'top!draco', 'Bottom Harry Potter', 'Top Draco', "
#  "'Bottom Harry', 'bareback', 'Rimming', 'Fingering', 'Begging', 'smol Harry', "
#  "'Fluff', 'Smut', 'AU', 'Alternate Universe - Harry Potter Setting', 'One "
#  "Shot', 'Muggle Life']",
#  "['Crossover', 'Female Doctor (Doctor Who)', 'Ginny Weasley is a companion', "
#  "'Luna is the Doctor', 'One Shot', 'Good Dumbledore', 'Well this was fun', "
#  "'Sorry Not Sorry', 'TARDIS - Freeform', 'CoS AU', 'Chamber of Secrets AU', "
#  "'AU', 'Salazar Slytherin - Freeform', 'Godric Gryffindor - Freeform', "
#  "'Basilisk - Freeform', 'Hogwarts', 'Tardis in Hogwarts', 'sort of drabbly', "
#  "'Drabble', 'wibbly wobbly']",
#  "['Top Harry Potter', 'Bottom Draco', 'AU', 'Muggle Life', 'Muggle Harry', "
#  "'Muggle Draco', 'Feminine Draco', 'Light Dom/sub', 'Dom Harry', 'Sub Draco "
#  "Malfoy', 'Cheating', 'Fingering', 'Barebacking', 'Plot What Plot/Porn "
#  "Without Plot', 'Size Kink', 'Alternate Universe', 'Accidental Voyeurism', "
#  "'Blow Jobs', 'Bathroom Sex', 'No Lube', 'Smut', 'Kissing', 'Boys Kissing', "
#  "'Fluff and Smut', 'Established Relationship', 'Bisexual Harry Potter', "
#  "'Closeted Harry', 'One Shot', 'Coming Out']",
#  "['Magic', 'frozen', 'Arrow - Freeform', 'Harry Potter - Freeform', 'Olicity "
#  "if you squint', 'Crossover', 'AU', 'One Shot']",
#  "['Potter!Lock', 'Potterlock', 'Crossover', 'sherlock crossover', "
#  "'Sherlock/Harry Potter', 'AU', 'Hogwarts AU', 'Wet Dream', 'Johnlock - "
#  "Freeform', 'Christmas', 'Christmas Fluff', 'Angst', 'Fluff', 'Fluff and "
#  "Angst', 'Unresolved Sexual Tension', 'Unresolved Romantic Tension', "
#  "'Mistletoe']",
#  "['fem!Harry Potter - Freeform', 'Cannon Divergent', 'Might Get A Sequel', "
#  '\'AU\', \'Crossover\', \'Somebody dies\', "but then they don\'t", \'The '
#  "Deathly Hallows', 'Crossover Pairings', 'Mentions of Sex', 'Russian terms of "
#  "endearment', 'Genderbend', 'Mention of OC', 'Bless the Broken Road by Rascal "
#  "Flatts', 'One Shot', 'Spoilers', 'music lyrics', 'Post-Avengers: Age of "
#  "Ultron (Movie)', 'Avengers: Age of Ultron (Movie) Spoilers', 'inspired by a "
#  "song', 'Ignores everything after AoU', 'Everything is Beautiful and Nothing "
#  "Hurts']",
#  "['Drarry', 'Kissing', 'Fluff', 'Hogwarts Eighth Year', 'Hogwarts', 'The "
#  "Golden Trio', 'Pansmione - Freeform', 'First Kiss', 'Soulmate-Identifying "
#  "Marks', 'Magical Tattoos', 'Alternate Universe - Soulmates', 'AU', "
#  "'Alternate Universe', 'Alternate Universe - Canon Divergence', 'Alternate "
#  "Universe - Everyone Lives/Nobody Dies', 'One Shot', 'Short One Shot', "
#  "'Love', 'Romance', 'Flirting', 'Oblivious Harry Potter', 'pansy is so done "
#  "with their shit', 'So is Hermione', 'No Smut', 'for once', 'Why Did I Write "
#  "This?', 'because I wanted to post', 'this is shit', 'but keep reading "
#  "please', 'Gay Draco Malfoy', 'POV Draco Malfoy', 'POV Harry Potter', 'POV "
#  "Third Person', 'Gay Harry Potter']",
#  "['Angst', 'Harry Potter - Freeform', 'Draco Malfoy - Freeform', 'Humor', "
#  "'Fiction', 'Double Life', 'Secret Identity', 'soulmate', 'Soulmate AU', "
#  "'AU', 'Romance', 'Love', 'Drarry', 'Idiots in Love', 'Reincarnation', "
#  "'second life', 'new life', 'Fluff', 'Drabble', 'One Shot', 'Cute', 'm/m - "
#  "Freeform', 'birthday fic', 'Identity Reveal']",
#  "['Slash', 'Angst', 'Het', 'bad weasleys', 'Good Weasleys', 'Character "
#  "Bashing', 'Bad Dumbledore', 'Good Voldemort', 'Evil Lucius', 'Good Lucius', "
#  "'Fluff', 'Future Fic', 'AU', 'Mpreg', 'Pregnancy', 'allusions to rape', "
#  "'Mind Control', 'Badass characters', 'Character Death', 'everyone dies', "
#  '\'Everyone lives\', \'Murder\', \'kidnappings\', \'Crack\', "Not Beta\'d", '
#  "'Ficlet Collection', 'No Unsolicited Beta Welcome', 'GFY', 'Polyamory', "
#  "'Threesomes', 'Moresomes', 'Bisexuality', 'crossovers', 'Kidfic', 'good "
#  "ginny', 'Evil Ginny', 'Evil Weasley Women', 'Kid Fic', 'Evil Molly', 'Good "
#  "Molly', 'Evil Ron Weasley', 'Good Ron Weasley', 'Badass Draco', 'Badass "
#  'Neville\', \'Badass Harry\', \'Rita Skeeter is an Evil Bitch\', "Rita is why '
#  'we can\'t have nice things", \'Slytherin Ron\', \'Gryffindor Draco Malfoy\', '
#  "'Sad Harry Potter', 'Sad Jack Frost']",
#  '[\'Potterlock\', \'Crossover\', \'AU\', \'Fluff\', \'Dementors\', "John is '
#  'basically Sherlock\'s real-life patronus", \'Teenlock\', \'Established '
#  "Relationship']"]
# [('guy', 2.314821),
#  ('dick', 2.086478),
#  ('stark', 1.795814),
#  ('hedgehog', 1.642666),
#  ('doctor', 1.632925),
#  ('text', 1.618342),
#  ('magick', 1.596649),
#  ('mrs', 1.5955979999999998),
#  ('pixie', 1.590806),
#  ('blessed', 1.536186)]
#
# ['hurt/comfort' 'friendship' 'established relationship' 'au' 'anal sex']
# [13402062  1152881  1152853  4037536  4921912  5535647 11395380  1153035
#  11525430  1068483]
# ["['Female Harry Potter', 'Alternate Universe', 'Child Abuse', "
#  "'Implied/Referenced Rape/Non-con', 'Rape/Non-con Elements', 'Rape', "
#  "'Infidelity', 'Consensual Infidelity', 'Arranged Marriage', 'Mistress', "
#  "'Female Friendship', 'Female Characters', 'Romance', 'Magic', 'Emotional "
#  "Hurt/Comfort', 'Emotional/Psychological Abuse', 'Emotional Baggage', "
#  "'Hurt/Comfort', 'Child Marriage', 'Abuse', 'Friendship', 'Friendship/Love', "
#  "'Implied/Referenced Child Abuse', 'Crossover', 'Crossover Pairings', 'Het']",
#  "['Family', 'Friendship', 'Romance', 'Drama', 'Hurt/Comfort', 'AU', "
#  "'Alternate Universe']",
#  "['Friendship', 'Future Fic', 'Pre-Relationship', 'Drama', 'Hurt/Comfort', "
#  "'AU', 'Alternate Universe']",
#  "['Hermione Granger & Harry Potter Friendship', 'hermione granger - "
#  "Freeform', 'Harry Potter - Freeform', 'Skinny Dipping', 'nude', 'Nudity', "
#  "'Touch', 'Touching', 'Swim', 'Swimming', 'swimming lessons', 'Teaching', "
#  "'Friendship', 'Friendship/Love', 'Male-Female Friendship', 'Unresolved "
#  "Sexual Tension', 'Deathly Hallows AU', 'One Shot', 'lake', 'Fluff', 'Fluff "
#  "and Angst', 'Alternate Universe - Canon Divergence', 'Water', "
#  "'Hurt/Comfort', 'Emotional Hurt/Comfort', 'Comfort', 'Comfort/Angst', 'Mild "
#  "Hurt/Comfort', 'Angst and Hurt/Comfort', 'Fluff and Hurt/Comfort', "
#  "'Voyeurism', 'Mild Voyerurism', 'wank', 'wanking', 'Masturbate', "
#  "'Masturbating', 'Orgasm Denial', 'Grasp', 'Uncircumcised Penis', 'penis - "
#  "Freeform', 'Pee', 'peeing', 'Urination', 'Breasts', 'tits', 'Underwater', "
#  "'Floating - Freeform', 'float', 'Masturbation Interruptus', 'Underage - "
#  "Freeform', 'Underage Character(s)']",
#  "['Friendship', 'Humour', 'Alternate Universe', 'AU', 'Hurt/Comfort']",
#  "['Friendship', 'Christmas', 'Fluff', 'Hurt/Comfort', 'my first ever festive "
#  'fic\', "Marauders\' Era", \'Established Relationship\']',
#  "['Sex', 'Smut', 'Fluff and Smut', 'Shameless Smut', 'Gay Sex', 'Anal Sex', "
#  "'Oral Sex', 'Rough Sex', 'Rough Kissing', 'Love/Hate', 'Enemies to Lovers', "
#  "'Slytherin', 'Hogwarts', 'Potions', 'Hurt/Comfort', 'Emotional "
#  "Hurt/Comfort', 'Hate Sex', 'Emotional Sex', 'Emotional Roller Coaster', "
#  "'Denial']",
#  "['Angst', 'Friendship', 'Character Death', 'Tragedy', 'Hurt/Comfort', "
#  "'Drama', 'Family', 'AU', 'Alternate Universe']",
#  "['Book 7: Harry Potter and the Deathly Hallows', 'Missing Scene', 'Canon "
#  "Compliant', 'Friendship', 'Emotional Hurt/Comfort', 'Hurt/Comfort', "
#  "'Nightmares', 'Crying']",
#  "['Post-Hogwarts', 'Post War Society', 'Cruising', 'One-Sided Attraction', "
#  "'Misunderstandings', 'Bittersweet', 'Bittersweet Ending', 'Illness', "
#  "'Chronic Illness', 'Friendship', 'dependance', 'Minimum Wage', 'Poverty', "
#  "'Caretaking', 'Kindness', 'Bars and Pubs', 'Auror Training', 'Not Canon "
#  "Compliant - Harry Potter and the Deathly Hallows', 'Not Epilogue Compliant', "
#  "'Alternate Universe - Canon Divergence', 'Challenge: helmet_fest2008', "
#  "'Community: ronsexuals', 'POV Ron Weasley', 'Hurt/Comfort', 'Emotional "
#  "Hurt/Comfort']"]
# [('woollen', 3.2806330000000004),
#  ('flannel', 2.340977),
#  ('dock', 1.863535),
#  ('organ', 1.815969),
#  ('re', 1.6515950000000001),
#  ('cane', 1.641415),
#  ('pint', 1.633518),
#  ('sharply', 1.561589),
#  ('gifts', 1.511866),
#  ('quick', 1.486127)]
