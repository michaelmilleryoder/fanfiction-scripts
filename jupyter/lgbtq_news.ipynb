# %% [markdown]
# # Build LGBTQ corpus texts

# %%
# Load article IDs
fpath = '/data/news/now2010-2021/lgbtq/article_ids.txt'
with open(fpath) as f:
    article_ids = [int(aid) for aid in f.read().splitlines()]
len(article_ids)
# Out:
# 218809

# %% [markdown]
# ## Assemble articles

# %%
# Strip out articles that don't match
text_dirpath = '/data/news/now2010-2021/lgbtq/article_ids.txt'
for fname in sorted(os.listdir(text_dirpath), )

# %% [markdown]
# ## Determine which month/country files to search for articles in (more trouble than its worth)

# %%
import csv
source_dirpath = '/data/news/now2010-2021/sources/'
month_countries = []
for fname in tqdm(sorted(os.listdir(source_dirpath))):
    fpath = os.path.join(source_dirpath, fname)
    sources = pd.read_csv(fpath, sep='\t', header=None, names=['article_id', 'word_count', 'date', 'country', 'source', 'url', 'title'], 
                          index_col='article_id', engine='c', error_bad_lines=False, quoting=csv.QUOTE_NONE)
    matching_sources = sources.loc[sources.index.isin(article_ids)]
    matching_sources.loc[:, 'month'] = matching_sources.date.str.slice(0, 5)
    month_countries += list(matching_sources[['month', 'country']].itertuples(index=False, name=None))
month_countries = set(month_countries)
len(month_countries)
# Out:
#   0%|          | 0/53 [00:00<?, ?it/s]
# /usr0/home/mamille2/anaconda/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# 2318

# %%
list(month_countries)[:10]
# Out:
# [('11-09', 'PK'),
#  ('13-04', 'MY'),
#  ('18-12', 'CA'),
#  ('15-12', 'JM'),
#  ('19-11', 'AU'),
#  ('11-01', 'IN'),
#  ('10-05', 'JM'),
#  ('17-11', 'HK'),
#  ('17-04', 'BD'),
#  ('15-10', 'GB')]

# %%
# formatted = [f'{month}-{country}'.lower() for month, country in month_countries]
formatted = [(month.split('-')[0], month.split('-')[1], country) for month, country in month_countries]
formatted[:20]
# Out:
# [('11', '09', 'PK'),
#  ('13', '04', 'MY'),
#  ('18', '12', 'CA'),
#  ('15', '12', 'JM'),
#  ('19', '11', 'AU'),
#  ('11', '01', 'IN'),
#  ('10', '05', 'JM'),
#  ('17', '11', 'HK'),
#  ('17', '04', 'BD'),
#  ('15', '10', 'GB'),
#  ('17', '02', 'BD'),
#  ('14', '06', 'ZA'),
#  ('12', '05', 'SG'),
#  ('13', '07', 'KE'),
#  ('20', '01', 'TZ'),
#  ('20', '12', 'LK'),
#  ('13', '11', 'GH'),
#  ('12', '06', 'PH'),
#  ('16', '10', 'AU'),
#  ('14', '03', 'KE')]

# %%
text_fnames = os.listdir('/data/news/now2010-2021/text')
selected_fnames = []
for f in formatted:
    for fname in text_fnames:
        if f[0] in fname.lower() and f[1] in fname.lower() and f[2].lower() in fname.lower():
            selected_fnames.append(fname)
            break
    else:
        print(f)
len(selected_fnames)
# Out:
# ('20', '07', '??')
# ('19', '07', 'y ')
# ('20', '02', '??')
# ('19', '12', '??')
# ('20', '06', '??')
# ('20', '03', '??')
# ('19', '07', '? ')
# ('19', '08', '??')
# ('19', '09', '??')
# ('19', '07', '  ')
# ('19', '10', '??')
# ('19', '11', '??')
# ('20', '01', '??')
# ('19', '12', 'ZA')
# 2304

# %%
[name for name in text_fnames if '20-06' in name]
# Out:
# []

# %% [markdown]
# # Filter NOW corpus to articles that mention LGBTQ issues

# %% [markdown]
# ## Load, check terms for presence

# %%
# Load lexicons, get term IDs
import os
import pandas as pd

# Load old lexicon
lex_dirpath = '/data/news/now2010-2021/lexicon'
fname = 'now_dic.txt'
old_lex = pd.read_csv(os.path.join(lex_dirpath, fname), sep='\t', skiprows=[0,1], index_col='wID', names=['wID', 'word', 'lemma', 'PoS'],
                     keep_default_na=False)

# Load specific lexica
import pdb
from tqdm.notebook import tqdm
lexica = [old_lex]
for fname in sorted(tqdm(os.listdir(lex_dirpath))):
    if not fname.startswith('lexicon'): continue
    fpath = os.path.join(lex_dirpath, fname)
    current_lex = pd.read_csv(fpath, sep='\t', header=None, index_col=0, names=['wID', 'word', 'lemma', 'PoS'], keep_default_na=False,
                             dtype={'wID': int, 'word': str})
    lexica.append(current_lex)

lex = pd.concat(lexica)
lex.sort_index(inplace=True)
lex
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
#                        word lemma          PoS
# wID
# 1                       the   the           at
# 2                         ,                  ,
# 3                         .                  .
# 4                        q!    q!           q!
# 5                        of    of           io
# ...                     ...   ...          ...
# 63471367       torso--minus             jj_nn1
# 63471368          LIPBUBBLE        np1_nn1_vv0
# 63471369  **40;3671;TOOLONG                 fu
# 63471370         @@42681482                 fo
# 63471371            2,065mm                nnu
#
# [55140388 rows x 3 columns]

# %%
# LGBTQ terms
mendelsohn_terms = [
    'gay',
    'gays',
    'lesbian',
    'lesbians',
    'bisexual',
    'bisexuals',
    'homosexual',
    'homosexuals',
    'transgender',
    'transgenders',
    'transsexual',
    'transsexuals',
    'transexual',
#     'transexuals',
    'transvestite',
    'transvestites',
    'transgendered',
    'asexual',
    'agender',
    'aromantic',
    'lgb',
    'lgbt',
    'lgbtq',
    'lgbtqia',
    'glbt',
    'lgbtqqia',
    'genderqueer',
    'genderfluid',
    'intersex',
    'pansexual',
]
added_terms = [
    'nonbinary',
    'non-binary', 
    'demisexual',
    'demi-sexual',
    'gender-expansive',
    'homophobia',
    'homophobic',
    'transphobia',
    'transphobic',
    'queerphobia',
#     'queerphobic',
    'heteronormativity',
    'heterosexism',
    'heterosexist',
#     'cissexism',
#     'cissexist',
    'transmisogyny',
    'bi-sexual',
#     'bi-sexuals',
    'pan-sexual',
#     'pan-sexuals',
    'pansexuals'
]
terms = mendelsohn_terms + added_terms
# len(terms) 

# Check for presence in lexicon
matches = lex[(lex.word.str.lower().isin(terms)) | (lex.lemma.str.lower().isin(terms))]
matches
# Out:
#                  word        lemma         PoS
# wID
# 2275              gay          gay          jj
# 9616             LGBT         lgbt         np1
# 15177     transgender  transgender         nn1
# 17204            gays          gay         nn2
# 18119         lesbian      lesbian      jj_nn1
# ...               ...          ...         ...
# 61709097  TRANSPHOBIA                      nn1
# 61946145  TRANSGENDER                      vvi
# 62280693    Nonbinary               nn1_np1_jj
# 62614837  Genderfluid               np1_jj_nn1
# 63014455      ASEXUAL                      np1
#
# [230 rows x 3 columns]

# %%
# See which terms did not occur
[w for w in terms if w not in matches.word.str.lower().unique()]
# Out:
# []

# %% [markdown]
# ## Find articles that contain keywords (build LGBTQ news corpus)

# %%
lgbtq_wids = matches.index.tolist()
len(lgbtq_wids)
# Out:
# 230

# %%
# Search articles for matches
from tqdm.notebook import tqdm
from multiprocessing import Pool
import pdb

db_dirpath = '/data/news/now2010-2021/db'
out_dirpath = '/data/news/now2010-2021/lgbtq/text_ids/'
# n_files = len(os.listdir(db_dirpath)) #2687
            
def search_file(fname):
    fpath = os.path.join(db_dirpath, fname)
    outpath = os.path.join(out_dirpath, f'{fname[:-4]}_text_ids.txt')
    if os.path.exists(outpath):
        return
    try:
        data = pd.read_csv(fpath, sep='\t', header=None, names=['textID',  'ID', 'wID'], index_col='ID', 
                           error_bad_lines=False, low_memory=False)
        # Convert to int datatypes
        data.wID = pd.to_numeric(data.wID, errors='coerce')
        data.textID = pd.to_numeric(data.textID, errors='coerce')
        data = data[data.wID.notnull()]
        data.wID = data.wID.astype(int)
        data.textID = data.textID.astype(int)
    except:
        tqdm.write(fname)
#         pdb.set_trace()
        return
    matches = set(data.loc[data.wID.isin(lgbtq_wids), 'textID'].unique())
    with open(outpath, 'w') as f:
        for tid in matches:
            f.write(f'{tid}\n')
            

fnames = sorted(os.listdir(db_dirpath))
# list(tqdm(map(search_file, fnames), total=len(fnames))) # debug
with Pool(15) as p:
    list(tqdm(p.imap(search_file, fnames), total=len(fnames)))
# Out:
#   0%|          | 0/2687 [00:00<?, ?it/s]
# /usr0/home/mamille2/anaconda/lib/python3.7/multiprocessing/process.py:297: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   self.run()
# /usr0/home/mamille2/anaconda/lib/python3.7/multiprocessing/process.py:297: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   self.run()
# /usr0/home/mamille2/anaconda/lib/python3.7/multiprocessing/process.py:297: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   self.run()
# /usr0/home/mamille2/anaconda/lib/python3.7/multiprocessing/process.py:297: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   self.run()
# /usr0/home/mamille2/anaconda/lib/python3.7/multiprocessing/process.py:297: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   self.run()
# /usr0/home/mamille2/anaconda/lib/python3.7/multiprocessing/process.py:297: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   self.run()
# /usr0/home/mamille2/anaconda/lib/python3.7/multiprocessing/process.py:297: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   self.run()
# /usr0/home/mamille2/anaconda/lib/python3.7/multiprocessing/process.py:297: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   self.run()
# /usr0/home/mamille2/anaconda/lib/python3.7/multiprocessing/process.py:297: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   self.run()
# /usr0/home/mamille2/anaconda/lib/python3.7/multiprocessing/process.py:297: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   self.run()
# /usr0/home/mamille2/anaconda/lib/python3.7/multiprocessing/process.py:297: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   self.run()
# /usr0/home/mamille2/anaconda/lib/python3.7/multiprocessing/process.py:297: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   self.run()
# /usr0/home/mamille2/anaconda/lib/python3.7/multiprocessing/process.py:297: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   self.run()
# /usr0/home/mamille2/anaconda/lib/python3.7/multiprocessing/process.py:297: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   self.run()
# /usr0/home/mamille2/anaconda/lib/python3.7/multiprocessing/process.py:297: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   self.run()

# %%
# Concatenate all article ID matches
parts = []
out_dirpath = '/data/news/now2010-2021/lgbtq/text_ids/'
for fname in tqdm(sorted(os.listdir(out_dirpath))):
    fpath = os.path.join(out_dirpath, fname)
    with open(fpath) as f:
        parts.append(f.read().splitlines())
all_parts = [int(p) for part in parts for p in part]
len(all_parts)
# Out:
#   0%|          | 0/2687 [00:00<?, ?it/s]
# 218809

# %%
# Save out
outpath = '/data/news/now2010-2021/lgbtq/article_ids.txt'
with open(outpath, 'w') as f:
    for aid in all_parts:
        f.write(f'{aid}\n')

# %% [markdown]
# # Download NOW corpus

# %%
# Extract all txt links, save to a file for wget
from bs4 import BeautifulSoup
import urllib

html = urllib.request.urlopen('https://www.corpusdata.org/a3047_now/x.asp?e=yoder@cs.cmu.edu').read()
soup = BeautifulSoup(html, 'html.parser')
links = soup.find_all('a')
len(links)
# Out:
# 508

# %%
links[:10]
# Out:
# [<a href="https://www.english-corpora.org/now/" target="_blank">NOW</a>,
#  <a href="https://www.corpusdata.org/restrictions.asp?r=y">Restrictions on use</a>,
#  <a href="mailto:corpus@byu.edu">please email us</a>,
#  <a href="https://www.corpusdata.org/formats.asp">
#  <font color="#0000FF">Format</font></a>,
#  <a href="https://www.corpusdata.org/a3047_now/db/db_10-01-kus.zip">10-01</a>,
#  <a href="https://www.corpusdata.org/a3047_now/db/db_10-02-kvz.zip">10-02</a>,
#  <a href="https://www.corpusdata.org/a3047_now/db/db_10-03-ovi.zip">10-03</a>,
#  <a href="https://www.corpusdata.org/a3047_now/db/db_10-04-laq.zip">10-04</a>,
#  <a href="https://www.corpusdata.org/a3047_now/db/db_10-05-wbb.zip">10-05</a>,
#  <a href="https://www.corpusdata.org/a3047_now/db/db_10-06-bwq.zip">10-06</a>]

# %%
links = [link['href'] for link in links]
links[:10]
# Out:
# ['https://www.english-corpora.org/now/',
#  'https://www.corpusdata.org/restrictions.asp?r=y',
#  'mailto:corpus@byu.edu',
#  'https://www.corpusdata.org/formats.asp',
#  'https://www.corpusdata.org/a3047_now/db/db_10-01-kus.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_10-02-kvz.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_10-03-ovi.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_10-04-laq.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_10-05-wbb.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_10-06-bwq.zip']

# %%
text_links = [link for link in links if 'text' in link]
len(text_links)
# Out:
# 133

# %%
text_links
# Out:
# ['http://www.corpusdata.org/a3047_now/text/text_10-01-kus.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_10-02-kvz.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_10-03-ovi.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_10-04-laq.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_10-05-wbb.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_10-06-bwq.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_10-07-uek.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_10-08-lqd.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_10-09-udn.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_10-10-nln.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_10-11-weq.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_10-12-ixv.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_11-01-pct.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_11-02-keb.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_11-03-lup.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_11-04-fpt.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_11-05-gbc.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_11-06-hld.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_11-07-mpk.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_11-08-lag.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_11-09-ptj.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_11-10-qsy.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_11-11-rst.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_11-12-dxg.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_12-01-jgs.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_12-02-eig.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_12-03-hge.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_12-04-qzl.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_12-05-qvg.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_12-06-ury.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_12-07-jbh.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_12-08-apx.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_12-09-qxc.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_12-10-fim.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_12-11-ysq.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_12-12-fbe.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_13-01-lii.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_13-02-fwy.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_13-03-zxv.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_13-04-vzr.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_13-05-skm.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_13-06-rak.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_13-07-mht.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_13-08-ofo.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_13-09-ibd.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_13-10-zpv.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_13-11-vwg.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_13-12-yny.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_14-01-jhx.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_14-02-fbh.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_14-03-mps.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_14-04-oki.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_14-05-cwh.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_14-06-glg.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_14-07-oul.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_14-08-gri.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_14-09-hkl.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_14-10-alo.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_14-11-tlv.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_14-12-dik.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_15-01-oam.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_15-02-xnd.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_15-03-dhu.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_15-04-qci.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_15-05-xzr.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_15-06-jhb.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_15-07-ztm.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_15-08-orq.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_15-09-dhp.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_15-10-fxo.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_15-11-xje.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_15-12-bjr.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_16-01-yxh.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_16-02-iuq.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_16-03-sls.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_16-04-ovb.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_16-05-bvk.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_16-06-uda.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_16-07-qxx.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_16-08-pcg.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_16-09-bmb.zip',
#  'http://www.corpusdata.org/a3047_now/text/text_16-10-ykw.zip',
#  'http://www.corpusdata.org/a3047_now/16-11-hsk/text-16-11.zip',
#  'http://www.corpusdata.org/a3047_now/16-12-kds/text-16-12.zip',
#  'http://www.corpusdata.org/a3047_now/17-01-ske/text-17-01.zip',
#  'http://www.corpusdata.org/a3047_now/17-02-skr/text-17-02.zip',
#  'http://www.corpusdata.org/a3047_now/17-03-wwt/text-17-03.zip',
#  'http://www.corpusdata.org/a3047_now/17-04-mks/text-17-04.zip',
#  'http://www.corpusdata.org/a3047_now/17-05-lop/text-17-05.zip',
#  'http://www.corpusdata.org/a3047_now/17-06-lei/text-17-06.zip',
#  'http://www.corpusdata.org/a3047_now/17-07-jjr/text-17-07.zip',
#  'http://www.corpusdata.org/a3047_now/17-08-nsi/text-17-08.zip',
#  'http://www.corpusdata.org/a3047_now/17-09-isn/text-17-09.zip',
#  'http://www.corpusdata.org/a3047_now/17-10-kll/text-17-10.zip',
#  'http://www.corpusdata.org/a3047_now/17-11-mmm/text-17-11.zip',
#  'http://www.corpusdata.org/a3047_now/17-12-usu/text-17-12.zip',
#  'http://www.corpusdata.org/a3047_now/18-01-wie/text-18-01.zip',
#  'http://www.corpusdata.org/a3047_now/18-02-jje/text-18-02.zip',
#  'http://www.corpusdata.org/a3047_now/18-03-kek/text-18-03.zip',
#  'http://www.corpusdata.org/a3047_now/18-04-pvp/text-18-04.zip',
#  'http://www.corpusdata.org/a3047_now/18-05-kwe/text-18-05.zip',
#  'http://www.corpusdata.org/a3047_now/18-06-uuw/text-18-06.zip',
#  'http://www.corpusdata.org/a3047_now/18-07-niw/text-18-07.zip',
#  'http://www.corpusdata.org/a3047_now/18-08-min/text-18-08.zip',
#  'http://www.corpusdata.org/a3047_now/18-09-hdu/text-18-09.zip',
#  'http://www.corpusdata.org/a3047_now/18-10-uus/text-18-10.zip',
#  'http://www.corpusdata.org/a3047_now/18-11-coo/text-18-11.zip',
#  'http://www.corpusdata.org/a3047_now/18-12-lgl/text-18-12.zip',
#  'http://www.corpusdata.org/a3047_now/19-01-lij/text-19-01.zip',
#  'http://www.corpusdata.org/a3047_now/19-02-khk/text-19-02.zip',
#  'http://www.corpusdata.org/a3047_now/19-03-leo/text-19-03.zip',
#  'http://www.corpusdata.org/a3047_now/19-04-hys/text-19-04.zip',
#  'http://www.corpusdata.org/a3047_now/19-05-his/text-19-05.zip',
#  'http://www.corpusdata.org/a3047_now/19-06-nvq/text-19-06.zip',
#  'http://www.corpusdata.org/a3047_now/19-07-kds/text-19-07.zip',
#  'http://www.corpusdata.org/a3047_now/19-08-ssi/text-19-08.zip',
#  'http://www.corpusdata.org/a3047_now/19-09-tyt/text-19-09.zip',
#  'http://www.corpusdata.org/a3047_now/19-10-nkq/text-19-10.zip',
#  'http://www.corpusdata.org/a3047_now/19-11-kep/text-19-11.zip',
#  'http://www.corpusdata.org/a3047_now/19-12-xio/text-19-12.zip',
#  'http://www.corpusdata.org/a3047_now/20-01-iwi/text-20-01.zip',
#  'http://www.corpusdata.org/a3047_now/20-02-bow/text-20-02.zip',
#  'http://www.corpusdata.org/a3047_now/20-03-fur/text-20-03.zip',
#  'http://www.corpusdata.org/a3047_now/20-04-mnb/text-20-04.zip',
#  'http://www.corpusdata.org/a3047_now/20-05-iwo/text-20-05.zip',
#  'http://www.corpusdata.org/a3047_now/20-06-kwk/text-20-06.zip',
#  'http://www.corpusdata.org/a3047_now/20-07-nss/text-20-07.zip',
#  'http://www.corpusdata.org/a3047_now/20-08-wks/text-20-08.zip',
#  'http://www.corpusdata.org/a3047_now/20-09-akr/text-20-09.zip',
#  'http://www.corpusdata.org/a3047_now/20-10-hnw/text-20-10.zip',
#  'http://www.corpusdata.org/a3047_now/20-11-hwt/text-20-11.zip',
#  'http://www.corpusdata.org/a3047_now/20-12-zio/text-20-12.zip',
#  'http://www.corpusdata.org/a3047_now/21-01-hhd/text-21-01.zip']

# %%
# Save out
with open('/data/news/now_urls_text.txt', 'w') as f:
    for url in text_links:
        f.write(f'{url}\n')

# %%
# Download sources
sources = [link for link in links if 'source' in link]
print(len(sources))
sources
# Out:
# 53
# ['http://www.corpusdata.org/a3047_now/shared/now_sources_pt1.zip',
#  'http://www.corpusdata.org/a3047_now/shared/now_sources_pt2.zip',
#  'http://www.corpusdata.org/a3047_now/16-11-hsk/sources-16-11.zip',
#  'http://www.corpusdata.org/a3047_now/16-12-kds/sources-16-12.zip',
#  'http://www.corpusdata.org/a3047_now/17-01-ske/sources-17-01.zip',
#  'http://www.corpusdata.org/a3047_now/17-02-skr/sources-17-02.zip',
#  'http://www.corpusdata.org/a3047_now/17-03-wwt/sources-17-03.zip',
#  'http://www.corpusdata.org/a3047_now/17-04-mks/sources-17-04.zip',
#  'http://www.corpusdata.org/a3047_now/17-05-lop/sources-17-05.zip',
#  'http://www.corpusdata.org/a3047_now/17-06-lei/sources-17-06.zip',
#  'http://www.corpusdata.org/a3047_now/17-07-jjr/sources-17-07.zip',
#  'http://www.corpusdata.org/a3047_now/17-08-nsi/sources-17-08.zip',
#  'http://www.corpusdata.org/a3047_now/17-09-isn/sources-17-09.zip',
#  'http://www.corpusdata.org/a3047_now/17-10-kll/sources-17-10.zip',
#  'http://www.corpusdata.org/a3047_now/17-11-mmm/sources-17-11.zip',
#  'http://www.corpusdata.org/a3047_now/17-12-usu/sources-17-12.zip',
#  'http://www.corpusdata.org/a3047_now/18-01-wie/sources-18-01.zip',
#  'http://www.corpusdata.org/a3047_now/18-02-jje/sources-18-02.zip',
#  'http://www.corpusdata.org/a3047_now/18-03-kek/sources-18-03.zip',
#  'http://www.corpusdata.org/a3047_now/18-04-pvp/sources-18-04.zip',
#  'http://www.corpusdata.org/a3047_now/18-05-kwe/sources-18-05.zip',
#  'http://www.corpusdata.org/a3047_now/18-06-uuw/sources-18-06.zip',
#  'http://www.corpusdata.org/a3047_now/18-07-niw/sources-18-07.zip',
#  'http://www.corpusdata.org/a3047_now/18-08-min/sources-18-08.zip',
#  'http://www.corpusdata.org/a3047_now/18-09-hdu/sources-18-09.zip',
#  'http://www.corpusdata.org/a3047_now/18-10-uus/sources-18-10.zip',
#  'http://www.corpusdata.org/a3047_now/18-11-coo/sources-18-11.zip',
#  'http://www.corpusdata.org/a3047_now/18-12-lgl/sources-18-12.zip',
#  'http://www.corpusdata.org/a3047_now/19-01-lij/sources-19-01.zip',
#  'http://www.corpusdata.org/a3047_now/19-02-khk/sources-19-02.zip',
#  'http://www.corpusdata.org/a3047_now/19-03-leo/sources-19-03.zip',
#  'http://www.corpusdata.org/a3047_now/19-04-hys/sources-19-04.zip',
#  'http://www.corpusdata.org/a3047_now/19-05-his/sources-19-05.zip',
#  'http://www.corpusdata.org/a3047_now/19-06-nvq/sources-19-06.zip',
#  'http://www.corpusdata.org/a3047_now/19-07-kds/sources-19-07.zip',
#  'http://www.corpusdata.org/a3047_now/19-08-ssi/sources-19-08.zip',
#  'http://www.corpusdata.org/a3047_now/19-09-tyt/sources-19-09.zip',
#  'http://www.corpusdata.org/a3047_now/19-10-nkq/sources-19-10.zip',
#  'http://www.corpusdata.org/a3047_now/19-11-kep/sources-19-11.zip',
#  'http://www.corpusdata.org/a3047_now/19-12-xio/sources-19-12.zip',
#  'http://www.corpusdata.org/a3047_now/20-01-iwi/sources-20-01.zip',
#  'http://www.corpusdata.org/a3047_now/20-02-bow/sources-20-02.zip',
#  'http://www.corpusdata.org/a3047_now/20-03-fur/sources-20-03.zip',
#  'http://www.corpusdata.org/a3047_now/20-04-mnb/sources-20-04.zip',
#  'http://www.corpusdata.org/a3047_now/20-05-iwo/sources-20-05.zip',
#  'http://www.corpusdata.org/a3047_now/20-06-kwk/sources-20-06.zip',
#  'http://www.corpusdata.org/a3047_now/20-07-nss/sources-20-07.zip',
#  'http://www.corpusdata.org/a3047_now/20-08-wks/sources-20-08.zip',
#  'http://www.corpusdata.org/a3047_now/20-09-akr/sources-20-09.zip',
#  'http://www.corpusdata.org/a3047_now/20-10-hnw/sources-20-10.zip',
#  'http://www.corpusdata.org/a3047_now/20-11-hwt/sources-20-11.zip',
#  'http://www.corpusdata.org/a3047_now/20-12-zio/sources-20-12.zip',
#  'http://www.corpusdata.org/a3047_now/21-01-hhd/sources-21-01.zip']

# %%
# Save out
with open('/data/news/now_urls_sources.txt', 'w') as f:
    for url in sources:
        f.write(f'{url}\n')

# %%
# Download sources
dbs = [link for link in links if 'db' in link]
print(len(dbs))
dbs
# Out:
# 133
# ['https://www.corpusdata.org/a3047_now/db/db_10-01-kus.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_10-02-kvz.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_10-03-ovi.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_10-04-laq.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_10-05-wbb.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_10-06-bwq.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_10-07-uek.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_10-08-lqd.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_10-09-udn.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_10-10-nln.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_10-11-weq.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_10-12-ixv.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_11-01-pct.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_11-02-keb.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_11-03-lup.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_11-04-fpt.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_11-05-gbc.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_11-06-hld.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_11-07-mpk.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_11-08-lag.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_11-09-ptj.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_11-10-qsy.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_11-11-rst.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_11-12-dxg.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_12-01-jgs.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_12-02-eig.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_12-03-hge.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_12-04-qzl.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_12-05-qvg.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_12-06-ury.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_12-07-jbh.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_12-08-apx.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_12-09-qxc.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_12-10-fim.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_12-11-ysq.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_12-12-fbe.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_13-01-lii.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_13-02-fwy.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_13-03-zxv.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_13-04-vzr.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_13-05-skm.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_13-06-rak.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_13-07-mht.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_13-08-ofo.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_13-09-ibd.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_13-10-zpv.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_13-11-vwg.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_13-12-yny.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_14-01-jhx.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_14-02-fbh.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_14-03-mps.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_14-04-oki.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_14-05-cwh.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_14-06-glg.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_14-07-oul.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_14-08-gri.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_14-09-hkl.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_14-10-alo.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_14-11-tlv.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_14-12-dik.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_15-01-oam.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_15-02-xnd.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_15-03-dhu.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_15-04-qci.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_15-05-xzr.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_15-06-jhb.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_15-07-ztm.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_15-08-orq.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_15-09-hwa.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_15-10-fxo.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_15-11-xje.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_15-12-bjr.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_16-01-yxh.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_16-02-iuq.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_16-03-sls.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_16-04-ovb.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_16-05-bvk.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_16-06-uda.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_16-07-qxx.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_16-08-pcg.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_16-09-bmb.zip',
#  'https://www.corpusdata.org/a3047_now/db/db_16-10-ykw.zip',
#  'https://www.corpusdata.org/a3047_now/16-11-hsk/db-16-11.zip',
#  'https://www.corpusdata.org/a3047_now/16-12-kds/db-16-12.zip',
#  'https://www.corpusdata.org/a3047_now/17-01-ske/db-17-01.zip',
#  'https://www.corpusdata.org/a3047_now/17-02-skr/db-17-02.zip',
#  'https://www.corpusdata.org/a3047_now/17-03-wwt/db-17-03.zip',
#  'https://www.corpusdata.org/a3047_now/17-04-mks/db-17-04.zip',
#  'https://www.corpusdata.org/a3047_now/17-05-lop/db-17-05.zip',
#  'https://www.corpusdata.org/a3047_now/17-06-lei/db-17-06.zip',
#  'https://www.corpusdata.org/a3047_now/17-07-jjr/db-17-07.zip',
#  'https://www.corpusdata.org/a3047_now/17-08-nsi/db-17-08.zip',
#  'https://www.corpusdata.org/a3047_now/17-09-isn/db-17-09.zip',
#  'https://www.corpusdata.org/a3047_now/17-10-kll/db-17-10.zip',
#  'https://www.corpusdata.org/a3047_now/17-11-mmm/db-17-11.zip',
#  'https://www.corpusdata.org/a3047_now/17-12-usu/db-17-12.zip',
#  'https://www.corpusdata.org/a3047_now/18-01-wie/db-18-01.zip',
#  'https://www.corpusdata.org/a3047_now/18-02-jje/db-18-02.zip',
#  'https://www.corpusdata.org/a3047_now/18-03-kek/db-18-03.zip',
#  'https://www.corpusdata.org/a3047_now/18-04-pvp/db-18-04.zip',
#  'https://www.corpusdata.org/a3047_now/18-05-kwe/db-18-05.zip',
#  'https://www.corpusdata.org/a3047_now/18-06-uuw/db-18-06.zip',
#  'https://www.corpusdata.org/a3047_now/18-07-niw/db-18-07.zip',
#  'https://www.corpusdata.org/a3047_now/18-08-min/db-18-08.zip',
#  'https://www.corpusdata.org/a3047_now/18-09-hdu/db-18-09.zip',
#  'https://www.corpusdata.org/a3047_now/18-10-uus/db-18-10.zip',
#  'https://www.corpusdata.org/a3047_now/18-11-coo/db-18-11.zip',
#  'https://www.corpusdata.org/a3047_now/18-12-lgl/db-18-12.zip',
#  'https://www.corpusdata.org/a3047_now/19-01-lij/db-19-01.zip',
#  'https://www.corpusdata.org/a3047_now/19-02-khk/db-19-02.zip',
#  'https://www.corpusdata.org/a3047_now/19-03-leo/db-19-03.zip',
#  'https://www.corpusdata.org/a3047_now/19-04-hys/db-19-04.zip',
#  'https://www.corpusdata.org/a3047_now/19-05-his/db-19-05.zip',
#  'https://www.corpusdata.org/a3047_now/19-06-nvq/db-19-06.zip',
#  'https://www.corpusdata.org/a3047_now/19-07-kds/db-19-07.zip',
#  'https://www.corpusdata.org/a3047_now/19-08-ssi/db-19-08.zip',
#  'https://www.corpusdata.org/a3047_now/19-09-tyt/db-19-09.zip',
#  'https://www.corpusdata.org/a3047_now/19-10-nkq/db-19-10.zip',
#  'https://www.corpusdata.org/a3047_now/19-11-kep/db-19-11.zip',
#  'https://www.corpusdata.org/a3047_now/19-12-xio/db-19-12.zip',
#  'https://www.corpusdata.org/a3047_now/20-01-iwi/db-20-01.zip',
#  'https://www.corpusdata.org/a3047_now/20-02-bow/db-20-02.zip',
#  'https://www.corpusdata.org/a3047_now/20-03-fur/db-20-03.zip',
#  'https://www.corpusdata.org/a3047_now/20-04-mnb/db-20-04.zip',
#  'https://www.corpusdata.org/a3047_now/20-05-iwo/db-20-05.zip',
#  'https://www.corpusdata.org/a3047_now/20-06-kwk/db-20-06.zip',
#  'https://www.corpusdata.org/a3047_now/20-07-nss/db-20-07.zip',
#  'https://www.corpusdata.org/a3047_now/20-08-wks/db-20-08.zip',
#  'https://www.corpusdata.org/a3047_now/20-09-akr/db-20-09.zip',
#  'https://www.corpusdata.org/a3047_now/20-10-hnw/db-20-10.zip',
#  'https://www.corpusdata.org/a3047_now/20-11-hwt/db-20-11.zip',
#  'https://www.corpusdata.org/a3047_now/20-12-zio/db-20-12.zip',
#  'https://www.corpusdata.org/a3047_now/21-01-hhd/db-21-01.zip']

# %%
# Save out
with open('/data/news/now_urls_db.txt', 'w') as f:
    for url in dbs:
        f.write(f'{url}\n')

# %%
# Download lexicon
lex = [link for link in links if 'lexicon' in link]
print(len(lex))
lex
# Out:
# 52
# ['http://www.corpusdata.org/a3047_now/shared/now_lexicon.zip',
#  'http://www.corpusdata.org/a3047_now/16-11-hsk/lexicon-16-11.zip',
#  'http://www.corpusdata.org/a3047_now/16-12-kds/lexicon-16-12.zip',
#  'http://www.corpusdata.org/a3047_now/17-01-ske/lexicon-17-01.zip',
#  'http://www.corpusdata.org/a3047_now/17-02-skr/lexicon-17-02.zip',
#  'http://www.corpusdata.org/a3047_now/17-03-wwt/lexicon-17-03.zip',
#  'http://www.corpusdata.org/a3047_now/17-04-mks/lexicon-17-04.zip',
#  'http://www.corpusdata.org/a3047_now/17-05-lop/lexicon-17-05.zip',
#  'http://www.corpusdata.org/a3047_now/17-06-lei/lexicon-17-06.zip',
#  'http://www.corpusdata.org/a3047_now/17-07-jjr/lexicon-17-07.zip',
#  'http://www.corpusdata.org/a3047_now/17-08-nsi/lexicon-17-08.zip',
#  'http://www.corpusdata.org/a3047_now/17-09-isn/lexicon-17-09.zip',
#  'http://www.corpusdata.org/a3047_now/17-10-kll/lexicon-17-10.zip',
#  'http://www.corpusdata.org/a3047_now/17-11-mmm/lexicon-17-11.zip',
#  'http://www.corpusdata.org/a3047_now/17-12-usu/lexicon-17-12.zip',
#  'http://www.corpusdata.org/a3047_now/18-01-wie/lexicon-18-01.zip',
#  'http://www.corpusdata.org/a3047_now/18-02-jje/lexicon-18-02.zip',
#  'http://www.corpusdata.org/a3047_now/18-03-kek/lexicon-18-03.zip',
#  'http://www.corpusdata.org/a3047_now/18-04-pvp/lexicon-18-04.zip',
#  'http://www.corpusdata.org/a3047_now/18-05-kwe/lexicon-18-05.zip',
#  'http://www.corpusdata.org/a3047_now/18-06-uuw/lexicon-18-06.zip',
#  'http://www.corpusdata.org/a3047_now/18-07-niw/lexicon-18-07.zip',
#  'http://www.corpusdata.org/a3047_now/18-08-min/lexicon-18-08.zip',
#  'http://www.corpusdata.org/a3047_now/18-09-hdu/lexicon-18-09.zip',
#  'http://www.corpusdata.org/a3047_now/18-10-uus/lexicon-18-10.zip',
#  'http://www.corpusdata.org/a3047_now/18-11-coo/lexicon-18-11.zip',
#  'http://www.corpusdata.org/a3047_now/18-12-lgl/lexicon-18-12.zip',
#  'http://www.corpusdata.org/a3047_now/19-01-lij/lexicon-19-01.zip',
#  'http://www.corpusdata.org/a3047_now/19-02-khk/lexicon-19-02.zip',
#  'http://www.corpusdata.org/a3047_now/19-03-leo/lexicon-19-03.zip',
#  'http://www.corpusdata.org/a3047_now/19-04-hys/lexicon-19-04.zip',
#  'http://www.corpusdata.org/a3047_now/19-05-his/lexicon-19-05.zip',
#  'http://www.corpusdata.org/a3047_now/19-06-nvq/lexicon-19-06.zip',
#  'http://www.corpusdata.org/a3047_now/19-07-kds/lexicon-19-07.zip',
#  'http://www.corpusdata.org/a3047_now/19-08-ssi/lexicon-19-08.zip',
#  'http://www.corpusdata.org/a3047_now/19-09-tyt/lexicon-19-09.zip',
#  'http://www.corpusdata.org/a3047_now/19-10-nkq/lexicon-19-10.zip',
#  'http://www.corpusdata.org/a3047_now/19-11-kep/lexicon-19-11.zip',
#  'http://www.corpusdata.org/a3047_now/19-12-xio/lexicon-19-12.zip',
#  'http://www.corpusdata.org/a3047_now/20-01-iwi/lexicon-20-01.zip',
#  'http://www.corpusdata.org/a3047_now/20-02-bow/lexicon-20-02.zip',
#  'http://www.corpusdata.org/a3047_now/20-03-fur/lexicon-20-03.zip',
#  'http://www.corpusdata.org/a3047_now/20-04-mnb/lexicon-20-04.zip',
#  'http://www.corpusdata.org/a3047_now/20-05-iwo/lexicon-20-05.zip',
#  'http://www.corpusdata.org/a3047_now/20-06-kwk/lexicon-20-06.zip',
#  'http://www.corpusdata.org/a3047_now/20-07-nss/lexicon-20-07.zip',
#  'http://www.corpusdata.org/a3047_now/20-08-wks/lexicon-20-08.zip',
#  'http://www.corpusdata.org/a3047_now/20-09-akr/lexicon-20-09.zip',
#  'http://www.corpusdata.org/a3047_now/20-10-hnw/lexicon-20-10.zip',
#  'http://www.corpusdata.org/a3047_now/20-11-hwt/lexicon-20-11.zip',
#  'http://www.corpusdata.org/a3047_now/20-12-zio/lexicon-20-12.zip',
#  'http://www.corpusdata.org/a3047_now/21-01-hhd/lexicon-21-01.zip']

# %%
# Save out
with open('/data/news/now_urls_lexicon.txt', 'w') as f:
    for url in lex:
        f.write(f'{url}\n')

# %% [markdown]
# # Investigate All the News 1 corpus

# %%
import pandas as pd
import sqlite3

datapath = '/data/news/all-the-news.db'
with sqlite3.connect(datapath) as con:
    cursor = con.cursor()
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    tables = cursor.fetchall()
    cursor.close()
tables
# Out:
# [('longform',)]

# %%
with sqlite3.connect(datapath) as con:
    data = pd.read_sql_query('SELECT * from longform', con)
data
# Out:
#             id                                              title  \
# 0            1  Agent Cooper in Twin Peaks is the audience: on...
# 1            2                                  AI, the humanity!
# 2            3                                  The Viral Machine
# 3            4  How Anker is beating Apple and Samsung at thei...
# 4            5  Tour Black Panther’s reimagined homeland with ...
# ...        ...                                                ...
# 204130  271689  Opinion | The West’s Schism Over Liberal Value...
# 204131  271690  Sammy Stewart, Pitcher Whose Life Took a Downt...
# 204132  271692  California Today: Down to the Wire in Hollywoo...
# 204133  271697  An Export From Sweden: Art Treasures Collected...
# 204134  271698  Taking a Knee and Taking Down a Monument - Vid...
#
#                      author        date  \
# 0        \nTasha Robinson\n  2017-05-31
# 1            \nSam Byford\n  2017-05-30
# 2       \nKaitlyn Tiffany\n  2017-05-25
# 3            \nNick Statt\n  2017-05-22
# 4            \nKwame Opam\n  2017-05-15
# ...                     ...         ...
# 204130                 None        None
# 204131     Richard Sandomir  2018-03-07
# 204132         Mike McPhate  2017-05-01
# 204133                 None        None
# 204134       BRENT McDONALD        None
#
#                                                   content  year month  \
# 0             And never more so than in Showtime’s new...  2017     5
# 1             AlphaGo’s victory isn’t a defeat for hum...  2017     5
# 2             Super Deluxe built a weird internet empi...  2017     5
# 3             Steven Yang quit his job at Google in th...  2017     5
# 4             Ahead of Black Panther’s 2018 theatrical...  2017     5
# ...                                                   ...   ...   ...
# 204130                                               None  None  None
# 204131  Sammy Stewart, who set a record when he struck...  2018     3
# 204132  Good morning. (Want to get California Today by...  2017     5
# 204133                                               None  None  None
# 204134                                                     None  None
#
#            publication   category  digital section   url
# 0                Verge   Longform      1.0    None  None
# 1                Verge   Longform      1.0    None  None
# 2                Verge   Longform      1.0    None  None
# 3                Verge   Longform      1.0    None  None
# 4                Verge   Longform      1.0    None  None
# ...                ...        ...      ...     ...   ...
# 204130            None       None      NaN    None  None
# 204131  New York Times  newspaper      0.0    None  None
# 204132  New York Times  newspaper      0.0    None  None
# 204133            None       None      NaN    None  None
# 204134            None       None      NaN    None  None
#
# [204135 rows x 12 columns]

# %%
data.year.value_counts()
# Out:
# 2016    95997
# 2017    75034
# 2015     9838
# 2018     4966
# 2014     3362
# 2013     1142
# 2012      948
# 2011      163
# 2010       65
# 2008        3
# 2009        3
# 2005        2
# 2004        2
# 2003        2
#             2
# 2007        1
# 2006        1
# 2000        1
# Name: year, dtype: int64

# %%
data.publication.value_counts()
# Out:
# New York Times         30257
# Breitbart              23791
# New York Post          18144
# Reuters                15055
# CNN                    14288
# Washington Post        12051
# NPR                    12001
# Buzzfeed News          10699
# Guardian                9920
# Los Angeles Times       9036
# Business Insider        8344
# Atlantic                7386
# National Review         6258
# Talking Points Memo     5323
# Vox                     4953
# Fox News                4384
# New Inquiry             3305
# Verge                   1225
# Name: publication, dtype: int64

# %% [markdown]
# # Investigate All the News 2 corpus

# %%
import pandas as pd

datapath = '/data/news/all-the-news-2-1.csv'
chunked = pd.read_csv(datapath, iterator=True)
sample = chunked.get_chunk(200)
sample
# Out:
#      Unnamed: 0  Unnamed: 0.1                 date  year  month  day  \
# 0             0             0  2016-12-09 18:31:00  2016   12.0    9
# 1             1             1  2016-10-07 21:26:46  2016   10.0    7
# 2             2             2  2018-01-26 00:00:00  2018    1.0   26
# 3             3             3  2019-06-27 00:00:00  2019    6.0   27
# 4             4             4  2016-01-27 00:00:00  2016    1.0   27
# ..          ...           ...                  ...   ...    ...  ...
# 195         195           195  2018-03-24 00:00:00  2018    3.0   24
# 196         196           196  2016-12-03 00:00:00  2016   12.0    3
# 197         197           197  2018-03-18 00:00:00  2018    3.0   18
# 198         198           198  2019-06-25 00:00:00  2019    6.0   25
# 199         199           199  2018-04-16 19:20:01  2018    4.0   16
#
#             author                                              title  \
# 0      Lee Drutman  We should take concerns about the health of li...
# 1      Scott Davis  Colts GM Ryan Grigson says Andrew Luck's contr...
# 2              NaN       Trump denies report he ordered Mueller fired
# 3              NaN  France's Sarkozy reveals his 'Passions' but in...
# 4              NaN  Paris Hilton: Woman In Black For Uncle Monty's...
# ..             ...                                                ...
# 195     Perry Bard                 The Places Rex Tillerson Didn’t Go
# 196            NaN  White House: no change to 'one China' policy a...
# 197            NaN  Putin says 'nonsense' to think Russia would po...
# 198  Melissa Fares  Wayfair employee walkout called over alleged f...
# 199    Dylan Scott  3 red states could put Medicaid expansion on t...
#
#                                                article  \
# 0    This post is part of Polyarchy, an independent...
# 1     The Indianapolis Colts made Andrew Luck the h...
# 2    DAVOS, Switzerland (Reuters) - U.S. President ...
# 3    PARIS (Reuters) - Former French president Nico...
# 4    Paris Hilton arrived at LAX Wednesday dressed ...
# ..                                                 ...
# 195  Trump’s Secretary of State, ex-CEO of ExxonMob...
# 196  WASHINGTON (Reuters) - The White House on Frid...
# 197  MOSCOW (Reuters) - Russian President Vladimir ...
# 198  (Reuters) - Wayfair Inc came under pressure on...
# 199  Medicaid expansion is back on the ballot. Orga...
#
#                                                    url     section  \
# 0    https://www.vox.com/polyarchy/2016/12/9/138983...         NaN
# 1    https://www.businessinsider.com/colts-gm-ryan-...         NaN
# 2    https://www.reuters.com/article/us-davos-meeti...       Davos
# 3    https://www.reuters.com/article/france-politic...  World News
# 4    https://www.tmz.com/2016/01/27/paris-hilton-mo...         NaN
# ..                                                 ...         ...
# 195  https://hyperallergic.com/433978/perry-bard-th...         NaN
# 196  https://www.reuters.com/article/us-usa-trump-t...  World News
# 197  https://www.reuters.com/article/us-britain-rus...  World News
# 198  https://www.reuters.com/article/us-usa-immigra...        U.S.
# 199  https://www.vox.com/policy-and-politics/2018/4...         NaN
#
#           publication
# 0                 Vox
# 1    Business Insider
# 2             Reuters
# 3             Reuters
# 4                 TMZ
# ..                ...
# 195     Hyperallergic
# 196           Reuters
# 197           Reuters
# 198           Reuters
# 199               Vox
#
# [200 rows x 12 columns]

# %%
# Publication and year metadata
from tqdm.notebook import tqdm
from IPython.display import display

data = pd.DataFrame(columns=['publication', 'year'])
chunksize = 10**5
pbar = tqdm(total=2.7e6)
vals = []
for chunk in pd.read_csv(datapath, chunksize=chunksize):
    vals.append(chunk.loc[:, ['publication', 'year']].values)
    pbar.update(chunksize)
pbar.close()
len(vals)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=2700000.0), HTML(value='')))
# 27

# %%
import numpy as np
data = pd.DataFrame(np.concatenate(vals), columns=['publication', 'year'])
data
# Out:
#               publication  year
# 0                     Vox  2016
# 1        Business Insider  2016
# 2                 Reuters  2018
# 3                 Reuters  2019
# 4                     TMZ  2016
# ...                   ...   ...
# 2688874               TMZ  2020
# 2688875               TMZ  2020
# 2688876               TMZ  2020
# 2688877               TMZ  2020
# 2688878               TMZ  2020
#
# [2688879 rows x 2 columns]

# %%
pd.crosstab(data.publication, data.year, margins=True)
# Out:
# year                  2016    2017    2018    2019    2020  2016  2017  2018  \
# publication
# Axios                    7   15659   16543   15605       1     0     0     0
# Business Insider      3243    2874    2204    7067   15903     0     0     0
# Buzzfeed News         8459    9706    8194    5068    1392     0     0     0
# CNBC                 36562   45065   42964   85878   23266     0     0     1
# CNN                  23546   25315   29736   38332   10673     0     0     0
# Economist             6819    6182    5942    5684    1380     0     0     0
# Fox News                56    2464   17624       0       0     0     0     0
# Gizmodo               9755    6345    6590    4537       0     0     0     1
# Hyperallergic         3363    3259    3045    2972     736     0     0     0
# Mashable             33120   27459   15958   13757    3063     2    21    21
# New Republic          4899    2828    2381    1237     403     0     0     0
# New Yorker            1233    1197    1148     997      81     0     0     0
# People               32705   34875   34346   32233       0     0     0     0
# Politico             12234   12105    9983    9585    2469     0     0     0
# Refinery 29          23265   31501   17302   27272   12093     0     0     0
# Reuters             188283  215300  162196  178285   85373     5     0     0
# TMZ                  12082   12407   12293    9704    2606     0     0     0
# TechCrunch           12898   12973   11955   11325    2770     0     0     0
# The Hill             42736   50381   50616   48830   13003     0     0     1
# The New York Times   70017   57006   54456   52427   16094     0     0     0
# The Verge            15238   12837   11139   10314    2896     0     0     0
# Vice                 39526   31965   17342    9104    2525     0     0     0
# Vice News             5136    3989    4271    2143       0     0     0     0
# Vox                  13206   12145   11072    8715    2134     0     0     0
# Washington Post          5      22     106    4825   34866     1    83     1
# Wired                 6110    4530    4157    4162    1103     0     0     0
# All                 604503  640389  553563  590058  234830     8   104    25
#
# year                 2019      All
# publication
# Axios                   0    47815
# Business Insider    26662    57953
# Buzzfeed News           0    32819
# CNBC                 4360   238096
# CNN                     0   127602
# Economist             220    26227
# Fox News                0    20144
# Gizmodo                 0    27228
# Hyperallergic         176    13551
# Mashable              706    94107
# New Republic           61    11809
# New Yorker             45     4701
# People               2329   136488
# Politico                1    46377
# Refinery 29             0   111433
# Reuters             10652   840094
# TMZ                   503    49595
# TechCrunch            174    52095
# The Hill             2844   208411
# The New York Times   2259   252259
# The Verge               0    52424
# Vice                  675   101137
# Vice News               0    15539
# Vox                     0    47272
# Washington Post       973    40882
# Wired                 181    20243
# All                 52821  2676301

# %%
# Overview of publications and years
from tqdm.notebook import tqdm
from IPython.display import display

# pubs = set()
# years = set()
pubs = pd.Series(dtype=int)
years = pd.Series(dtype=int)
chunksize = 10**5
pbar = tqdm(total=2.7e6)
for chunk in pd.read_csv(datapath, chunksize=chunksize):
#     pubs |= set(chunk['publication'].unique())
#     years |= set(chunk['year'].unique())
    pubs = pubs.add(chunk.publication.value_counts(), fill_value=0)
    years = years.add(chunk.year.value_counts(), fill_value=0)
    pbar.update(chunksize)
pbar.close()
display(pubs)
display(years)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=2700000.0), HTML(value='')))
# Axios                  47815.0
# Business Insider       57953.0
# Buzzfeed News          32819.0
# CNBC                  238096.0
# CNN                   127602.0
# Economist              26227.0
# Fox News               20144.0
# Gizmodo                27228.0
# Hyperallergic          13551.0
# Mashable               94107.0
# New Republic           11809.0
# New Yorker              4701.0
# People                136488.0
# Politico               46377.0
# Refinery 29           111433.0
# Reuters               840094.0
# TMZ                    49595.0
# TechCrunch             52095.0
# The Hill              208411.0
# The New York Times    252259.0
# The Verge              52424.0
# Vice                  101137.0
# Vice News              15539.0
# Vox                    47272.0
# Washington Post        40882.0
# Wired                  20243.0
# dtype: float64
# 2016                                                                                                                                                                                  604503.0
# 2017                                                                                                                                                                                  640389.0
# 2018                                                                                                                                                                                  553563.0
# 2019                                                                                                                                                                                  590058.0
# 2020                                                                                                                                                                                  234830.0
# 2016                                                                                                                                                                                       8.0
# 2017                                                                                                                                                                                     104.0
# 2018                                                                                                                                                                                      25.0
# 2019                                                                                                                                                                                   65398.0
# https://www.washingtonpost.com/outlook/tale-of-a-woman-who-died-and-a-woman-who-killed-in-the-northern-ireland-conflict/2019/03/08/59e75dd4-2ecd-11e9-8ad3-9a5b113ecd3c_story.html         1.0
# dtype: float64

# %%
import plotly.express as px

# %% [markdown]
# # Investigate existing LGBT news corpus (used by Mendelsohn et al 2020)

# %%
# Load corpus
import pandas as pd

background_fpath = '/data/fanfiction_ao3/lgbt_news/background_news_corpus.csv'
bg = pd.read_csv(background_fpath, encoding='latin-1')
bg
# Out:
#                                                     Text  \
# 0      UNION TOWNSHIP The Karl and Helen Burger Galle...
# 1      In his view, the European Union ÛÓ for all it...
# 2      Potential overseas researchers and teachers fa...
# 3      Perhaps, however, it is time to look at demand...
# 4      It is also east of Church Street, on the outsk...
# ...                                                  ...
# 34615  Disney officials promised that if the roads be...
# 34616  Adopting such a model will again restrict cash...
# 34617  \"Your letter,\" Fortas said to Wolfson, \"and...
# 34618  Last week, in the busy, final days of budget n...
# 34619  Petitioner challenges the decision of the Oreg...
#
#                                                    Title  \
# 0                                   Events in New Jersey
# 1            Quest for Balance in Joining European Union
# 2             Simplifying Italy to Lure Global Graduates
# 3                    Oil Spurt: A Rally That Few Believe
# 4                     Big Ticket | Sold for $9.5 Million
# ...                                                  ...
# 34615  A New Battle of Manassas Is Under Way in the S...
# 34616    In Death of Rain Forests, We're All Accomplices
# 34617                                 Masterful Meltdown
# 34618  A Reconditioned East Side G. O. P. Flexes Its ...
# 34619  Excerpts From Court Ruling Limiting Government...
#
#                              Id  Count                  Date  \
# 0      53f8952d7988105a42595735     87  2012-07-08T00:00:00Z
# 1      51fbd80e79881007d5901216      3  2013-08-03T17:45:00Z
# 2      53f9b77b79881001aab76f02      5  2012-08-13T14:00:00Z
# 3      4fd1d2e58eb7c8105d70e775      5  1996-03-24T00:00:00Z
# 4      4fd3a2b18eb7c8105d8eae60      6  2012-01-20T13:01:31Z
# ...                         ...    ...                   ...
# 34615  4fd1dbfd8eb7c8105d71d2bc     15  1994-06-22T00:00:00Z
# 34616  4fd1b5e98eb7c8105d6dbcd2      4  1994-06-20T00:00:00Z
# 34617  4fd1be1f8eb7c8105d6eb220     11  1994-06-05T00:00:00Z
# 34618  4fd1e45f8eb7c8105d72ecfb      0  1994-06-26T00:00:00Z
# 34619  4fd1e45b8eb7c8105d72e9b6      2  1994-06-25T00:00:00Z
#
#                   Category
# 0            N.Y. / Region
# 1                    World
# 2                    World
# 3                 Business
# 4            N.Y. / Region
# ...                    ...
# 34615                 U.S.
# 34616              Opinion
# 34617             Magazine
# 34618  New York and Region
# 34619                 U.S.
#
# [34620 rows x 6 columns]

# %%
lgbt_articles = pd.read_csv('/data/fanfiction_ao3/lgbt_news/lgbt_news_corpus.csv', encoding='latin-1')
lgbt_articles # each row is a paragraph with a term from their list in it
# Out:
# /usr0/home/mamille2/anaconda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3147: DtypeWarning: Columns (7,8,10,14,18) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                                     Text  \
# 0      Re ÛÏObama Alters Hospital Rules for Gay Righ...
# 1      You cannot have people who have no expertise i...
# 2      In an interview with Tracy Clark-Flory on Salo...
# 3      After we filed back out into the Tennessee sun...
# 4      ''Gays and lesbians are a very good group of p...
# ...                                                  ...
# 34615  Infection data are sparse. Estimates of the nu...
# 34616  The Council notes that throughout the history ...
# 34617  Another reason throws light on C.D.C. reluctan...
# 34618  The executive director of the National Gay and...
# 34619  The other complaint was prompted by the broadc...
#
#                                                    Title  \
# 0         Hospital Visiting Rights for Same-Sex Partners
# 1      For Police Union Head, Review Board Proposal I...
# 2      Why Asexuals DonÛªt Want to Be Invisible Anymore
# 3      Dollywood: A Little Bit Country, a Little Bit Gay
# 4                      San Francisco Toasts Gay Weddings
# ...                                                  ...
# 34615     HETEROSEXUALS AND AIDS: THE CONCERN IS GROWING
# 34616                            TEXT OF NEW RIGHTS BILL
# 34617                       The Mysteries Of Belle Glade
# 34618  CITY'S HOMOSEXUALS PROTEST HIGH COURT SODOMY R...
# 34619                F.C.C. STUDIES 'INDECENCY' ON RADIO
#
#                              Id  Count                  Date  \
# 0      54457293798810347c1a843e      1  2010-04-26T00:00:00Z
# 1      4fd1d13d8eb7c8105d70bb37      3  1992-06-28T00:00:00Z
# 2      54232178798810604c505435      4  2014-09-24T15:44:50Z
# 3      53f782e67988105a42594f8f     28  2014-08-24T00:00:00Z
# 4      4fd24bb98eb7c8105d7eacb6     20  2004-02-29T00:00:00Z
# ...                         ...    ...                   ...
# 34615  4fd170d58eb7c8105d663f0a      5  1986-10-28T00:00:00Z
# 34616  4fd14a698eb7c8105d627e7c      2  1986-01-23T00:00:00Z
# 34617  4fd155988eb7c8105d6398da      3  1986-06-11T00:00:00Z
# 34618  4fd1662a8eb7c8105d653865      7  1986-07-03T00:00:00Z
# 34619  4fd169008eb7c8105d65895c     20  1986-11-22T00:00:00Z
#
#                   Category  Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9  \
# 0                  Opinion         NaN        NaN        NaN         NaN
# 1      New York and Region         NaN        NaN        NaN         NaN
# 2                  Unknown         NaN        NaN        NaN         NaN
# 3                   Travel         NaN        NaN        NaN         NaN
# 4                  Unknown         NaN        NaN        NaN         NaN
# ...                    ...         ...        ...        ...         ...
# 34615      Science; Health         NaN        NaN        NaN         NaN
# 34616  New York and Region         NaN        NaN        NaN         NaN
# 34617              Opinion         NaN        NaN        NaN         NaN
# 34618  New York and Region         NaN        NaN        NaN         NaN
# 34619                 U.S.         NaN        NaN        NaN         NaN
#
#       Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13 Unnamed: 14  \
# 0             NaN          NaN          NaN          NaN         NaN
# 1             NaN          NaN          NaN          NaN         NaN
# 2             NaN          NaN          NaN          NaN         NaN
# 3             NaN          NaN          NaN          NaN         NaN
# 4             NaN          NaN          NaN          NaN         NaN
# ...           ...          ...          ...          ...         ...
# 34615         NaN          NaN          NaN          NaN         NaN
# 34616         NaN          NaN          NaN          NaN         NaN
# 34617         NaN          NaN          NaN          NaN         NaN
# 34618         NaN          NaN          NaN          NaN         NaN
# 34619         NaN          NaN          NaN          NaN         NaN
#
#        Unnamed: 15  Unnamed: 16  Unnamed: 17 Unnamed: 18
# 0              NaN          NaN          NaN         NaN
# 1              NaN          NaN          NaN         NaN
# 2              NaN          NaN          NaN         NaN
# 3              NaN          NaN          NaN         NaN
# 4              NaN          NaN          NaN         NaN
# ...            ...          ...          ...         ...
# 34615          NaN          NaN          NaN         NaN
# 34616          NaN          NaN          NaN         NaN
# 34617          NaN          NaN          NaN         NaN
# 34618          NaN          NaN          NaN         NaN
# 34619          NaN          NaN          NaN         NaN
#
# [34620 rows x 19 columns]

# %%
len(lgbt_articles['Title'].unique())
# Out:
# 17820

# %%
vc = lgbt_articles['Title'].value_counts()
vc[vc>1]
# Out:
# NEWS SUMMARY                                                            640
# INSIDE                                                                  128
# Corrections                                                             110
# METRO DIGEST                                                             77
# News Summary                                                             71
#                                                                        ...
# New Top Cop to Keep an Eye on How Hollywood Depicts Homosexuality         2
# Fugitive in Gay Bar Attacks Dies After Shootout With Arkansas Police      2
# SOUTHWARD GOES RIVER OF FINANCE                                           2
# Gay Users of Internet Play Down Concerns Over New Strain of AIDS          2
# Name America's Most Liberal City                                          2
# Name: Title, Length: 6450, dtype: int64

# %%
pd.set_option('display.max_colwidth', None)
lgbt_articles.loc[lgbt_articles['Title'] == 'New Top Cop to Keep an Eye on How Hollywood Depicts Homosexuality', ['Text', 'Title', 'Id', 'Count', 'Date']]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Text  \
# 9671   In recent years, the organization has shown a reluctance to battle Hollywood too publicly, opting instead to work back channels. Its public approach seems built more around praising positive depictions of gay men and lesbians (ÛÏMilkÛ) than decrying negative ones (ÛÏI Now Pronounce You Chuck & LarryÛ). In its reaction to the forthcoming film ÛÏBruno,Û which stars Sacha Baron Cohen as a flamboyantly gay fashion journalist, G.L.A.A.D. has taken more of a middle-of-the-road tack, saying that some people would very likely find the stereotypes in the movie funny and others would find them offensive.
# 12431                                                                                                                                                                                                                                                        The organization that polices how Hollywood depicts homosexuality has a new top cop. The Gay & Lesbian Alliance Against Defamation on Wednesday hired Jarrett T. Barrios, a former state senator from Massachusetts, as its president. The question for moviemakers and television networks is: How loudly will his G.L.A.A.D. complain when it spots problematic treatment?
#
#                                                                    Title  \
# 9671   New Top Cop to Keep an Eye on How Hollywood Depicts Homosexuality
# 12431  New Top Cop to Keep an Eye on How Hollywood Depicts Homosexuality
#
#                              Id  Count                  Date
# 9671   4fd3960f8eb7c8105d8ccc45      5  2009-06-18T15:53:44Z
# 12431  4fd3960f8eb7c8105d8ccc45      0  2009-06-18T15:53:44Z

# %%
lgbt_articles.loc[1,'Text']
# Out:
# "You cannot have people who have no expertise in police work sit in judgment of police officers, because police work by its very nature is esoteric. When you have to have represented on that board every segment of the community, the gay segment, black, the Hispanic and so on, they tend to pursue a political agenda as opposed to looking at police behavior in an objective and fair fashion. So they can't be coming down with decisions that are fair."
