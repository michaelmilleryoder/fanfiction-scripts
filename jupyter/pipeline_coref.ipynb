# %% [markdown]
# # Try to figure LEA discrepancies

# %%
gold_clusters = [
    ['a', 'b', 'c'],
    ['d', 'e', 'f', 'g']
]
sys_clusters = [
    ['a', 'b'],
    ['c', 'd'],
    ['f', 'g', 'h', 'i']
]
sys_mention_gold_cluster = {
    'a': 0,
    'b': 0,
    'c': 0,
    'd': 1,
    'f': 1,
    'g': 1,
}
gold_mention_sys_cluster = {
    'a': 0,
    'b': 0,
    'c': 1,
    'd': 1,
    'f': 2,
    'g': 2,
}

# %%
import pdb

def lea_internal(input_clusters, output_clusters, mention_to_gold):
    num, den = 0, 0

    for c in input_clusters:
#         if len(c) == 4: pdb.set_trace()
        if len(c) == 1:
            all_links = 1
            if c[0] in mention_to_gold and len(
                    output_clusters[mention_to_gold[c[0]]]) == 1:
                common_links = 1
            else:
                common_links = 0
        else:
            common_links = 0
            all_links = len(c) * (len(c) - 1) / 2.0
            for i, m in enumerate(c):
                if m in mention_to_gold:
                    for m2 in c[i + 1:]:
                        if m2 in mention_to_gold and mention_to_gold[
                                m] == mention_to_gold[m2]:
                            common_links += 1

        num += len(c) * common_links / float(all_links)
        den += len(c)

    return num, den

def lea_actual(sys_clusters, gold_clusters, sys_mention_gold_cluster, gold_mention_sys_cluster):
    pn, pd = lea_internal(sys_clusters, gold_clusters, sys_mention_gold_cluster)
    rn, rd = lea_internal(gold_clusters, sys_clusters, gold_mention_sys_cluster)
    
    precision = 0 if pn == 0 else pn/pd
    recall = 0 if rn == 0 else rn/rd
    print(f'Precision {precision}')
    print(f'Recall {recall}')

# %%
# Pipeline implementation
import pdb
import itertools

def links(mention_cluster):
    """ Returns a set of all the links in an entity between lists of AnnotatedSpans
        Links are tuples (chap_id, start_token_id, end_token_id)
    """

    if len(mention_cluster) == 1: # self-link
        links = {mention_cluster[0], mention_cluster[0]}

    else:
        links = set([(mention1, mention2) for mention1,     
                     mention2 in itertools.combinations(mention_cluster, 2)])
    n_mentions = len(mention_cluster)
    if len(mention_cluster) != 1:
        if len(links) != (n_mentions * (n_mentions-1))/2:
            pdb.set_trace()
    return links


def lea(clusters, ref_clusters):
    """ Generic LEA calculcation between 2 sets of clusters..
        Input clusters are of form {'annotation': [AnnotatedSpan, ...]}
        Returns a numerator and denominator to be used for recall and precision.
    """

    cluster_resolutions = {}
    cluster_sizes = {}

    for ref_cluster_name, ref_mentions in enumerate(ref_clusters):
        ref_links = links(ref_mentions)
        cluster_resolution = 0
        for cluster, mentions in enumerate(clusters):
            cluster_links = links(mentions)
            cluster_resolution += len(cluster_links.intersection(ref_links))

        cluster_resolution = cluster_resolution/len(ref_links)
        cluster_resolutions[ref_cluster_name] = cluster_resolution
        cluster_sizes[ref_cluster_name] = len(ref_mentions)

    num = sum([cluster_sizes[c] * cluster_resolutions[c] for c in range(len(ref_clusters))])
    den = sum(cluster_sizes.values())

    return num, den


def lea_pipeline_recall(predicted_clusters, gold_clusters):
    """ Calculates LEA recall between predicted mention clusters and gold mention
        clusters for a fic.
        Input clusters are of form {'annotation': [AnnotatedSpan, ...]}
    """
    if len(predicted_clusters) == 0:
        return 0
    else:
        num, den = lea(predicted_clusters, gold_clusters)
        return num/den


def lea_pipeline_precision(predicted_clusters, gold_clusters):
    """ Calculates LEA precision between predicted mention clusters and gold mention
        clusters for a fic.
        Input clusters are of form {'annotation': [AnnotatedSpan, ...]}
    """
    if len(predicted_clusters) == 0:
        return 0
    else:
        num, den = lea(gold_clusters, predicted_clusters)
        return num/den

# %%
print('Actual:')
lea_actual(sys_clusters, gold_clusters, sys_mention_gold_cluster, gold_mention_sys_cluster)
print()
# Out:
# Actual:
# Precision 0.3333333333333333
# Recall 0.23809523809523808

# %%
pipeline_r = lea_pipeline_recall(sys_clusters, gold_clusters)
pipeline_p = lea_pipeline_precision(sys_clusters, gold_clusters)
print('Pipeline:')
print(f'Precision: {pipeline_p}')
print(f'Recall: {pipeline_r}')
# Out:
# Pipeline:
# Precision: 0.3333333333333333
# Recall: 0.23809523809523808

# %% [markdown]
# # Load SpanBERT coref
# For placement in fanfiction_nlp_evaluation/annotation.py

# %%
import json
import os

clusters = {}
# dirpath = '/projects/presidio_analysis/Patient_Doctor_Conversations/COREF_RESOLUTION/fanfiction_coref/data/output_spl_lit'
dirpath = '/projects/presidio_analysis/Patient_Doctor_Conversations/COREF_RESOLUTION/fanfiction_coref/data/output_spb_lit'
for fname in sorted(os.listdir(dirpath)):
    fpath = os.path.join(dirpath, fname)
    with open(fpath) as f:
        clusters[fname[:-5]] = json.load(f)

# %%
clusters.keys()
# Out:
# dict_keys(['allmarvel_606106', 'dcu_16369049', 'dragonage_4305894', 'drwho_8333365', 'harrypotter_2287736', 'sherlock_1296961', 'starwars_6082176', 'supernatural_1813147', 'teenwolf_3150806', 'tolkien_2185500'])

# %%
clusters['allmarvel_606106'].keys()
# Out:
# dict_keys(['document', 'doc_tokens', 'subtoken_map', 'tokenized_doc', 'clusters'])

# %%
len(clusters['allmarvel_606106']['document'].split())
# Out:
# 4176

# %%
len(clusters['allmarvel_606106']['doc_tokens'])
# Out:
# 4176

# %%
clusters['allmarvel_606106']['clusters']
# Out:
# [[[1, 3],
#   [20, 20],
#   [23, 23],
#   [32, 32],
#   [40, 40],
#   [45, 45],
#   [50, 50],
#   [56, 56],
#   [88, 88],
#   [93, 93],
#   [114, 114],
#   [116, 116],
#   [135, 135],
#   [145, 145],
#   [155, 155],
#   [158, 158],
#   [184, 184],
#   [212, 213],
#   [215, 215],
#   [220, 220],
#   [224, 224],
#   [236, 236],
#   [258, 258],
#   [261, 261],
#   [277, 277],
#   [285, 285],
#   [297, 297],
#   [312, 312],
#   [324, 324],
#   [358, 358],
#   [398, 398],
#   [405, 405],
#   [433, 433],
#   [452, 452],
#   [462, 462],
#   [468, 468],
#   [505, 505],
#   [529, 529],
#   [537, 537],
#   [585, 586],
#   [591, 591],
#   [608, 608],
#   [616, 616],
#   [625, 625],
#   [641, 641],
#   [648, 648],
#   [669, 669],
#   [690, 690],
#   [697, 697],
#   [716, 716],
#   [718, 718],
#   [732, 732],
#   [759, 759],
#   [762, 762],
#   [775, 775],
#   [788, 788],
#   [793, 793],
#   [813, 813],
#   [840, 840],
#   [890, 890],
#   [916, 916],
#   [922, 922],
#   [938, 938],
#   [953, 953],
#   [969, 969],
#   [984, 984],
#   [1006, 1006],
#   [1056, 1056],
#   [1062, 1062],
#   [1103, 1103],
#   [1120, 1120],
#   [1135, 1135],
#   [1155, 1155],
#   [1159, 1159],
#   [1167, 1167],
#   [1179, 1179],
#   [1194, 1194],
#   [1198, 1198],
#   [1208, 1208],
#   [1264, 1264],
#   [1299, 1299],
#   [1304, 1304],
#   [1321, 1321],
#   [1333, 1333],
#   [1464, 1464],
#   [1475, 1475],
#   [1510, 1510],
#   [1514, 1514],
#   [1516, 1516],
#   [1523, 1523],
#   [1528, 1528],
#   [1531, 1531],
#   [1543, 1543],
#   [1556, 1556],
#   [1597, 1597],
#   [1604, 1604],
#   [1618, 1618],
#   [1626, 1626],
#   [1645, 1645],
#   [1658, 1658],
#   [1692, 1692],
#   [1698, 1698],
#   [1709, 1709],
#   [1732, 1732],
#   [1734, 1734],
#   [1742, 1742],
#   [1747, 1747],
#   [1750, 1750],
#   [1753, 1753],
#   [1758, 1758],
#   [1765, 1765],
#   [1778, 1778],
#   [1781, 1781],
#   [1806, 1806],
#   [1812, 1812],
#   [1823, 1823],
#   [1827, 1827],
#   [1835, 1835],
#   [1842, 1842],
#   [1864, 1864],
#   [1868, 1868],
#   [1878, 1878],
#   [1903, 1903],
#   [1907, 1907],
#   [1929, 1929],
#   [1941, 1941],
#   [1965, 1965],
#   [1980, 1980],
#   [1985, 1985],
#   [1989, 1989],
#   [1997, 1997],
#   [2002, 2002],
#   [2008, 2008],
#   [2023, 2023],
#   [2027, 2027],
#   [2034, 2034],
#   [2048, 2048],
#   [2085, 2085],
#   [2094, 2094],
#   [2105, 2105],
#   [2118, 2118],
#   [2123, 2123],
#   [2145, 2145],
#   [2150, 2150],
#   [2153, 2153],
#   [2176, 2176],
#   [2195, 2195],
#   [2396, 2396],
#   [2411, 2411],
#   [2418, 2418],
#   [2420, 2420],
#   [2425, 2425],
#   [2637, 2637],
#   [2643, 2643],
#   [2650, 2650],
#   [2657, 2657],
#   [2666, 2666],
#   [2682, 2682],
#   [2692, 2692],
#   [2724, 2724],
#   [2736, 2736],
#   [2743, 2743],
#   [2753, 2753],
#   [2968, 2968],
#   [2976, 2976],
#   [2990, 2990],
#   [3001, 3001],
#   [3005, 3005],
#   [3017, 3017],
#   [3021, 3021],
#   [3034, 3034],
#   [3042, 3042],
#   [3055, 3055],
#   [3066, 3066],
#   [3073, 3073],
#   [3084, 3084],
#   [3091, 3091],
#   [3100, 3100],
#   [3104, 3104],
#   [3114, 3114],
#   [3118, 3118],
#   [3125, 3125],
#   [3130, 3130],
#   [3149, 3149],
#   [3155, 3155],
#   [3165, 3165],
#   [3169, 3169],
#   [3179, 3179],
#   [3191, 3191],
#   [3214, 3214],
#   [3217, 3217],
#   [3222, 3222],
#   [3242, 3242],
#   [3246, 3246],
#   [3255, 3255],
#   [3264, 3264],
#   [3299, 3299],
#   [3304, 3304],
#   [3311, 3311],
#   [3318, 3318],
#   [3335, 3335],
#   [3337, 3337],
#   [3406, 3406],
#   [3410, 3410],
#   [3425, 3425],
#   [3434, 3434],
#   [3452, 3452],
#   [3469, 3469],
#   [3477, 3477],
#   [3559, 3559],
#   [3567, 3567],
#   [3689, 3689],
#   [3708, 3708],
#   [3746, 3746],
#   [3763, 3763],
#   [3769, 3769],
#   [3806, 3806],
#   [3810, 3810],
#   [3817, 3817],
#   [3823, 3823],
#   [3827, 3827],
#   [3831, 3831],
#   [3833, 3833],
#   [3890, 3890],
#   [3902, 3903],
#   [3914, 3914],
#   [3931, 3931],
#   [3978, 3978],
#   [3993, 3993],
#   [4013, 4013],
#   [4054, 4054],
#   [4107, 4107],
#   [4133, 4133],
#   [4135, 4135],
#   [4165, 4165],
#   [4185, 4185],
#   [4188, 4188],
#   [4195, 4195],
#   [4214, 4214],
#   [4237, 4237],
#   [4246, 4246],
#   [4289, 4289],
#   [4291, 4292],
#   [4353, 4353],
#   [4380, 4380],
#   [4391, 4391],
#   [4421, 4421],
#   [4425, 4425],
#   [4486, 4486],
#   [4495, 4495],
#   [4529, 4529],
#   [4531, 4531],
#   [4535, 4535],
#   [4561, 4561],
#   [4568, 4568],
#   [4598, 4598],
#   [4605, 4605],
#   [4617, 4617],
#   [4623, 4623]],
#  [[93, 94],
#   [277, 278],
#   [1062, 1063],
#   [1384, 1385],
#   [1510, 1511],
#   [1750, 1751],
#   [1765, 1766],
#   [2799, 2800],
#   [2833, 2834]],
#  [[335, 336], [343, 343], [349, 349], [365, 366], [376, 376]],
#  [[407, 407],
#   [410, 410],
#   [421, 422],
#   [438, 438],
#   [1876, 1876],
#   [1978, 1978],
#   [2317, 2317],
#   [2435, 2435],
#   [2493, 2493],
#   [2497, 2497],
#   [2663, 2663],
#   [2985, 2985],
#   [2997, 2997],
#   [3003, 3003],
#   [3014, 3014],
#   [3078, 3080],
#   [3080, 3080],
#   [3147, 3147],
#   [3179, 3182],
#   [3193, 3193],
#   [3208, 3208],
#   [3282, 3282],
#   [3429, 3429],
#   [3606, 3606],
#   [3704, 3704],
#   [3710, 3710],
#   [3863, 3863],
#   [3990, 3990],
#   [4429, 4429],
#   [4437, 4437],
#   [4611, 4611]],
#  [[591, 592], [751, 752], [802, 803], [1270, 1271]],
#  [[783, 785],
#   [799, 799],
#   [808, 808],
#   [831, 831],
#   [835, 835],
#   [877, 878],
#   [920, 920],
#   [928, 929],
#   [958, 958],
#   [965, 965],
#   [970, 970],
#   [991, 992],
#   [1019, 1019],
#   [1027, 1027],
#   [1029, 1029],
#   [1050, 1050],
#   [1071, 1071],
#   [1086, 1086],
#   [1090, 1090],
#   [1130, 1130],
#   [1451, 1454],
#   [1676, 1676],
#   [1724, 1724],
#   [1737, 1737],
#   [1859, 1859],
#   [2299, 2299],
#   [2501, 2501],
#   [2503, 2503],
#   [2531, 2531],
#   [2536, 2536],
#   [2549, 2549],
#   [2560, 2560],
#   [2566, 2566],
#   [2571, 2571],
#   [2575, 2575],
#   [2588, 2588],
#   [2592, 2592],
#   [2598, 2598],
#   [2603, 2603],
#   [2620, 2620],
#   [2632, 2632],
#   [3624, 3624],
#   [3637, 3637],
#   [3643, 3643],
#   [4403, 4403],
#   [4414, 4414],
#   [4424, 4424],
#   [4432, 4432],
#   [4602, 4602]],
#  [[1073, 1073], [1109, 1109], [2544, 2544]],
#  [[1248, 1248], [1252, 1252]],
#  [[1354, 1359], [1370, 1370]],
#  [[1373, 1375], [1384, 1384], [2451, 2451]],
#  [[1396, 1396],
#   [1404, 1404],
#   [1422, 1422],
#   [1422, 1424],
#   [1552, 1552],
#   [3296, 3296],
#   [3360, 3360],
#   [3362, 3362],
#   [3375, 3375],
#   [3382, 3382],
#   [3385, 3385],
#   [3391, 3391],
#   [4168, 4168]],
#  [[1412, 1412], [1440, 1440], [1443, 1443]],
#  [[1560, 1560], [1565, 1565]],
#  [[1306, 1306],
#   [1588, 1588],
#   [2070, 2070],
#   [2892, 2892],
#   [2908, 2908],
#   [2921, 2921],
#   [2924, 2924],
#   [3048, 3048],
#   [3061, 3061],
#   [3440, 3440],
#   [4266, 4266],
#   [4315, 4315],
#   [4319, 4319],
#   [4335, 4335],
#   [4365, 4369],
#   [4393, 4393],
#   [4498, 4498],
#   [4572, 4572],
#   [4579, 4579],
#   [4590, 4590]],
#  [[1221, 1221], [1776, 1776]],
#  [[542, 543], [2077, 2078], [2083, 2083], [4462, 4463]],
#  [[2101, 2102], [2109, 2109], [2130, 2130]],
#  [[2166, 2166], [2185, 2185]],
#  [[2188, 2191], [2199, 2199]],
#  [[2181, 2181],
#   [2202, 2202],
#   [2211, 2211],
#   [2220, 2220],
#   [2225, 2225],
#   [2247, 2247],
#   [2264, 2264],
#   [2277, 2277],
#   [2286, 2286],
#   [2296, 2296],
#   [2320, 2320],
#   [2352, 2352],
#   [2367, 2367],
#   [2384, 2384],
#   [2393, 2393],
#   [2758, 2758],
#   [2769, 2769],
#   [2793, 2793],
#   [2799, 2799],
#   [2829, 2829],
#   [2833, 2833],
#   [2842, 2842],
#   [2853, 2853],
#   [2878, 2878],
#   [2901, 2901],
#   [2910, 2910],
#   [2913, 2913],
#   [3572, 3572],
#   [3615, 3615],
#   [3850, 3850],
#   [3852, 3852],
#   [3861, 3861],
#   [3911, 3911],
#   [3922, 3922],
#   [3933, 3933],
#   [3936, 3936],
#   [3944, 3944],
#   [3951, 3951],
#   [3953, 3953],
#   [3965, 3965],
#   [3973, 3973],
#   [4005, 4005],
#   [4218, 4218],
#   [4451, 4451]],
#  [[2188, 2190], [2251, 2253]],
#  [[2288, 2289], [2302, 2302]],
#  [[2459, 2459],
#   [2469, 2469],
#   [3587, 3587],
#   [3881, 3881],
#   [3896, 3896],
#   [4355, 4355],
#   [4360, 4360],
#   [4506, 4506],
#   [4513, 4513]],
#  [[2479, 2479], [2481, 2481]],
#  [[2517, 2517], [2534, 2534]],
#  [[2614, 2619], [2618, 2619]],
#  [[2546, 2546], [2761, 2761]],
#  [[2809, 2815], [2826, 2826]],
#  [[2851, 2856], [2872, 2872]],
#  [[3204, 3205], [3292, 3293]],
#  [[3377, 3377], [3408, 3408], [3414, 3414]],
#  [[3443, 3444], [3450, 3450]],
#  [[3505, 3506], [3564, 3564], [4026, 4026]],
#  [[3651, 3653], [3657, 3659], [3667, 3667], [3682, 3682], [4348, 4350]],
#  [[3785, 3786], [3795, 3795]],
#  [[3500, 3502], [4112, 4114]],
#  [[4230, 4231], [4241, 4241], [4443, 4444], [4453, 4453]]]

# %%
clusters['allmarvel_606106']['clusters']
# Out:
# [[[1, 3],
#   [20, 20],
#   [23, 23],
#   [32, 32],
#   [40, 40],
#   [45, 45],
#   [50, 50],
#   [56, 56],
#   [88, 88],
#   [93, 93],
#   [114, 114],
#   [116, 116],
#   [135, 135],
#   [145, 145],
#   [155, 155],
#   [158, 158],
#   [184, 184],
#   [212, 213],
#   [215, 215],
#   [220, 220],
#   [224, 224],
#   [236, 236],
#   [258, 258],
#   [261, 261],
#   [277, 277],
#   [285, 285],
#   [297, 297],
#   [312, 312],
#   [324, 324],
#   [358, 358],
#   [398, 398],
#   [405, 405],
#   [433, 433],
#   [452, 452],
#   [462, 462],
#   [468, 468],
#   [505, 505],
#   [529, 529],
#   [537, 537],
#   [585, 586],
#   [591, 591],
#   [608, 608],
#   [616, 616],
#   [625, 625],
#   [641, 641],
#   [648, 648],
#   [669, 669],
#   [690, 690],
#   [697, 697],
#   [716, 716],
#   [718, 718],
#   [732, 732],
#   [759, 759],
#   [762, 762],
#   [775, 775],
#   [788, 788],
#   [793, 793],
#   [813, 813],
#   [840, 840],
#   [890, 890],
#   [916, 916],
#   [922, 922],
#   [938, 938],
#   [953, 953],
#   [969, 969],
#   [984, 984],
#   [1006, 1006],
#   [1056, 1056],
#   [1062, 1062],
#   [1103, 1103],
#   [1120, 1120],
#   [1135, 1135],
#   [1155, 1155],
#   [1159, 1159],
#   [1167, 1167],
#   [1179, 1179],
#   [1194, 1194],
#   [1198, 1198],
#   [1208, 1208],
#   [1264, 1264],
#   [1299, 1299],
#   [1304, 1304],
#   [1321, 1321],
#   [1333, 1333],
#   [1464, 1464],
#   [1475, 1475],
#   [1510, 1510],
#   [1514, 1514],
#   [1516, 1516],
#   [1523, 1523],
#   [1528, 1528],
#   [1531, 1531],
#   [1543, 1543],
#   [1556, 1556],
#   [1597, 1597],
#   [1604, 1604],
#   [1618, 1618],
#   [1626, 1626],
#   [1645, 1645],
#   [1658, 1658],
#   [1692, 1692],
#   [1698, 1698],
#   [1709, 1709],
#   [1732, 1732],
#   [1734, 1734],
#   [1742, 1742],
#   [1747, 1747],
#   [1750, 1750],
#   [1753, 1753],
#   [1758, 1758],
#   [1765, 1765],
#   [1778, 1778],
#   [1781, 1781],
#   [1806, 1806],
#   [1812, 1812],
#   [1823, 1823],
#   [1827, 1827],
#   [1835, 1835],
#   [1842, 1842],
#   [1864, 1864],
#   [1868, 1868],
#   [1878, 1878],
#   [1903, 1903],
#   [1907, 1907],
#   [1929, 1929],
#   [1941, 1941],
#   [1965, 1965],
#   [1980, 1980],
#   [1985, 1985],
#   [1989, 1989],
#   [1997, 1997],
#   [2002, 2002],
#   [2008, 2008],
#   [2023, 2023],
#   [2027, 2027],
#   [2034, 2034],
#   [2048, 2048],
#   [2085, 2085],
#   [2094, 2094],
#   [2105, 2105],
#   [2118, 2118],
#   [2123, 2123],
#   [2145, 2145],
#   [2150, 2150],
#   [2153, 2153],
#   [2176, 2176],
#   [2195, 2195],
#   [2396, 2396],
#   [2411, 2411],
#   [2418, 2418],
#   [2420, 2420],
#   [2425, 2425],
#   [2637, 2637],
#   [2643, 2643],
#   [2650, 2650],
#   [2657, 2657],
#   [2666, 2666],
#   [2682, 2682],
#   [2692, 2692],
#   [2724, 2724],
#   [2736, 2736],
#   [2743, 2743],
#   [2753, 2753],
#   [2968, 2968],
#   [2976, 2976],
#   [2990, 2990],
#   [3001, 3001],
#   [3005, 3005],
#   [3017, 3017],
#   [3021, 3021],
#   [3034, 3034],
#   [3042, 3042],
#   [3055, 3055],
#   [3066, 3066],
#   [3073, 3073],
#   [3084, 3084],
#   [3091, 3091],
#   [3100, 3100],
#   [3104, 3104],
#   [3114, 3114],
#   [3118, 3118],
#   [3125, 3125],
#   [3130, 3130],
#   [3149, 3149],
#   [3155, 3155],
#   [3165, 3165],
#   [3169, 3169],
#   [3179, 3179],
#   [3191, 3191],
#   [3214, 3214],
#   [3217, 3217],
#   [3222, 3222],
#   [3242, 3242],
#   [3246, 3246],
#   [3255, 3255],
#   [3264, 3264],
#   [3299, 3299],
#   [3304, 3304],
#   [3311, 3311],
#   [3318, 3318],
#   [3335, 3335],
#   [3337, 3337],
#   [3406, 3406],
#   [3410, 3410],
#   [3425, 3425],
#   [3434, 3434],
#   [3452, 3452],
#   [3469, 3469],
#   [3477, 3477],
#   [3559, 3559],
#   [3567, 3567],
#   [3689, 3689],
#   [3708, 3708],
#   [3746, 3746],
#   [3763, 3763],
#   [3769, 3769],
#   [3806, 3806],
#   [3810, 3810],
#   [3817, 3817],
#   [3823, 3823],
#   [3827, 3827],
#   [3831, 3831],
#   [3833, 3833],
#   [3890, 3890],
#   [3902, 3903],
#   [3914, 3914],
#   [3931, 3931],
#   [3978, 3978],
#   [3993, 3993],
#   [4013, 4013],
#   [4054, 4054],
#   [4107, 4107],
#   [4133, 4133],
#   [4135, 4135],
#   [4165, 4165],
#   [4185, 4185],
#   [4188, 4188],
#   [4195, 4195],
#   [4214, 4214],
#   [4237, 4237],
#   [4246, 4246],
#   [4289, 4289],
#   [4291, 4292],
#   [4353, 4353],
#   [4380, 4380],
#   [4391, 4391],
#   [4421, 4421],
#   [4425, 4425],
#   [4486, 4486],
#   [4495, 4495],
#   [4529, 4529],
#   [4531, 4531],
#   [4535, 4535],
#   [4561, 4561],
#   [4568, 4568],
#   [4598, 4598],
#   [4605, 4605],
#   [4617, 4617],
#   [4623, 4623]],
#  [[93, 94],
#   [277, 278],
#   [1062, 1063],
#   [1384, 1385],
#   [1510, 1511],
#   [1750, 1751],
#   [1765, 1766],
#   [2799, 2800],
#   [2833, 2834]],
#  [[335, 336], [343, 343], [349, 349], [365, 366], [376, 376]],
#  [[407, 407],
#   [410, 410],
#   [421, 422],
#   [438, 438],
#   [1876, 1876],
#   [1978, 1978],
#   [2317, 2317],
#   [2435, 2435],
#   [2493, 2493],
#   [2497, 2497],
#   [2663, 2663],
#   [2985, 2985],
#   [2997, 2997],
#   [3003, 3003],
#   [3014, 3014],
#   [3078, 3080],
#   [3080, 3080],
#   [3147, 3147],
#   [3179, 3182],
#   [3193, 3193],
#   [3208, 3208],
#   [3282, 3282],
#   [3429, 3429],
#   [3606, 3606],
#   [3704, 3704],
#   [3710, 3710],
#   [3863, 3863],
#   [3990, 3990],
#   [4429, 4429],
#   [4437, 4437],
#   [4611, 4611]],
#  [[591, 592], [751, 752], [802, 803], [1270, 1271]],
#  [[783, 785],
#   [799, 799],
#   [808, 808],
#   [831, 831],
#   [835, 835],
#   [877, 878],
#   [920, 920],
#   [928, 929],
#   [958, 958],
#   [965, 965],
#   [970, 970],
#   [991, 992],
#   [1019, 1019],
#   [1027, 1027],
#   [1029, 1029],
#   [1050, 1050],
#   [1071, 1071],
#   [1086, 1086],
#   [1090, 1090],
#   [1130, 1130],
#   [1451, 1454],
#   [1676, 1676],
#   [1724, 1724],
#   [1737, 1737],
#   [1859, 1859],
#   [2299, 2299],
#   [2501, 2501],
#   [2503, 2503],
#   [2531, 2531],
#   [2536, 2536],
#   [2549, 2549],
#   [2560, 2560],
#   [2566, 2566],
#   [2571, 2571],
#   [2575, 2575],
#   [2588, 2588],
#   [2592, 2592],
#   [2598, 2598],
#   [2603, 2603],
#   [2620, 2620],
#   [2632, 2632],
#   [3624, 3624],
#   [3637, 3637],
#   [3643, 3643],
#   [4403, 4403],
#   [4414, 4414],
#   [4424, 4424],
#   [4432, 4432],
#   [4602, 4602]],
#  [[1073, 1073], [1109, 1109], [2544, 2544]],
#  [[1248, 1248], [1252, 1252]],
#  [[1354, 1359], [1370, 1370]],
#  [[1373, 1375], [1384, 1384], [2451, 2451]],
#  [[1396, 1396],
#   [1404, 1404],
#   [1422, 1422],
#   [1422, 1424],
#   [1552, 1552],
#   [3296, 3296],
#   [3360, 3360],
#   [3362, 3362],
#   [3375, 3375],
#   [3382, 3382],
#   [3385, 3385],
#   [3391, 3391],
#   [4168, 4168]],
#  [[1412, 1412], [1440, 1440], [1443, 1443]],
#  [[1560, 1560], [1565, 1565]],
#  [[1306, 1306],
#   [1588, 1588],
#   [2070, 2070],
#   [2892, 2892],
#   [2908, 2908],
#   [2921, 2921],
#   [2924, 2924],
#   [3048, 3048],
#   [3061, 3061],
#   [3440, 3440],
#   [4266, 4266],
#   [4315, 4315],
#   [4319, 4319],
#   [4335, 4335],
#   [4365, 4369],
#   [4393, 4393],
#   [4498, 4498],
#   [4572, 4572],
#   [4579, 4579],
#   [4590, 4590]],
#  [[1221, 1221], [1776, 1776]],
#  [[542, 543], [2077, 2078], [2083, 2083], [4462, 4463]],
#  [[2101, 2102], [2109, 2109], [2130, 2130]],
#  [[2166, 2166], [2185, 2185]],
#  [[2188, 2191], [2199, 2199]],
#  [[2181, 2181],
#   [2202, 2202],
#   [2211, 2211],
#   [2220, 2220],
#   [2225, 2225],
#   [2247, 2247],
#   [2264, 2264],
#   [2277, 2277],
#   [2286, 2286],
#   [2296, 2296],
#   [2320, 2320],
#   [2352, 2352],
#   [2367, 2367],
#   [2384, 2384],
#   [2393, 2393],
#   [2758, 2758],
#   [2769, 2769],
#   [2793, 2793],
#   [2799, 2799],
#   [2829, 2829],
#   [2833, 2833],
#   [2842, 2842],
#   [2853, 2853],
#   [2878, 2878],
#   [2901, 2901],
#   [2910, 2910],
#   [2913, 2913],
#   [3572, 3572],
#   [3615, 3615],
#   [3850, 3850],
#   [3852, 3852],
#   [3861, 3861],
#   [3911, 3911],
#   [3922, 3922],
#   [3933, 3933],
#   [3936, 3936],
#   [3944, 3944],
#   [3951, 3951],
#   [3953, 3953],
#   [3965, 3965],
#   [3973, 3973],
#   [4005, 4005],
#   [4218, 4218],
#   [4451, 4451]],
#  [[2188, 2190], [2251, 2253]],
#  [[2288, 2289], [2302, 2302]],
#  [[2459, 2459],
#   [2469, 2469],
#   [3587, 3587],
#   [3881, 3881],
#   [3896, 3896],
#   [4355, 4355],
#   [4360, 4360],
#   [4506, 4506],
#   [4513, 4513]],
#  [[2479, 2479], [2481, 2481]],
#  [[2517, 2517], [2534, 2534]],
#  [[2614, 2619], [2618, 2619]],
#  [[2546, 2546], [2761, 2761]],
#  [[2809, 2815], [2826, 2826]],
#  [[2851, 2856], [2872, 2872]],
#  [[3204, 3205], [3292, 3293]],
#  [[3377, 3377], [3408, 3408], [3414, 3414]],
#  [[3443, 3444], [3450, 3450]],
#  [[3505, 3506], [3564, 3564], [4026, 4026]],
#  [[3651, 3653], [3657, 3659], [3667, 3667], [3682, 3682], [4348, 4350]],
#  [[3785, 3786], [3795, 3795]],
#  [[3500, 3502], [4112, 4114]],
#  [[4230, 4231], [4241, 4241], [4443, 4444], [4453, 4453]]]

# %%
len([tag for taglist in clusters['allmarvel_606106']['clusters'] for tag in taglist])
# Out:
# 574

# %%
# Convert Bert-tokenized spans to chapter_id, para_id, token_ids
import pdb
from tqdm.notebook import tqdm

matches = []
gold_tok_clusters = {}
for fandom_fname in tqdm(clusters):
    print(fandom_fname)
    gold_toks = load_gold_toks(fandom_fname)
    bert_toks = load_bert_toks(fandom_fname)
    gold_tok_clusters[fandom_fname] = []
    for cluster in clusters[fandom_fname]['clusters']:
        cluster_gold_toks = set()
        for entry in cluster:
            bert_beg_tok = entry[0][0]
            bert_end_tok = entry[0][1]
            bert_text = entry[1]
            if bert_beg_tok == bert_end_tok: continue
            gold_start_tok, gold_end_tok, gold_text = bert2gold(bert_beg_tok, bert_end_tok, bert_toks, gold_toks)
            cluster_gold_toks.add((gold_start_tok, gold_end_tok))
            gold_tok_clusters[fandom_fname].append(cluster_gold_toks)
            matches.append([fandom_fname, bert_text, gold_text, bert_beg_tok, bert_end_tok, gold_start_tok, gold_end_tok])
            
matches = pd.DataFrame(matches, columns=['fandom_fname', 'bert_text', 'gold_text', 'bert_beg_tok', 'bert_end_tok', 
                                        'gold_start_tok', 'gold_end_tok'])
pd.set_option('display.max_colwidth', None)
mismatches = matches.loc[matches['bert_text']!= matches['gold_text']]
mismatches
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# allmarvel_606106
# dcu_16369049
# dragonage_4305894
# drwho_8333365
# harrypotter_2287736
# sherlock_1296961
# starwars_6082176
# supernatural_1813147
# teenwolf_3150806
# tolkien_2185500
#            fandom_fname  \
# 17     allmarvel_606106
# 367    allmarvel_606106
# 453    allmarvel_606106
# 579        dcu_16369049
# 600        dcu_16369049
# 624        dcu_16369049
# 626        dcu_16369049
# 769        dcu_16369049
# 954        dcu_16369049
# 955        dcu_16369049
# 1332  dragonage_4305894
# 1340  dragonage_4305894
# 1744      drwho_8333365
# 2096   sherlock_1296961
# 2292   sherlock_1296961
# 2363   starwars_6082176
# 3131   teenwolf_3150806
# 3136   teenwolf_3150806
# 3204   teenwolf_3150806
# 3313    tolkien_2185500
# 3342    tolkien_2185500
# 3350    tolkien_2185500
#
#                                                                                       bert_text  \
# 17                                                                                          you
# 367                                                                    the family he ' s chosen
# 453                                                                                           I
# 579   a species of mobster fish people stealing humans who all seem to have sea - diving skills
# 600                                                                                   Merpeople
# 624                                                                               the Merpeople
# 626                                                                                   merpeople
# 769                                                                           The . . . Bretans
# 954                                                                                           I
# 955                                                                                           I
# 1332                                                           someone that was n ’ t even real
# 1340                                                                      Lavellan ’ s chambers
# 1744                                                                                       Miss
# 2096                                                                          the P . E teacher
# 2292                                                      the virgin who ' s never dated anyone
# 2363                                     Booster Terrik ’ s Star Destroyer , the Errant Venture
# 3131                                                                a big ol ’ softy cat person
# 3136                                                                           he ’ s neighbors
# 3204                                                                        the sheriff ’ s son
# 3313                                                                     female Bilbo ’ s uncle
# 3342                                                                        male Bilbo ’ s aunt
# 3350                                                                                     ##self
#
#                                                                                gold_text  \
# 17                                                                                 /you/
# 367                                                              the family he 's chosen
# 453                                                                                   I-
# 579   a species of mobster fish people stealing humans who all seem to have sea - diving
# 600                                                                           —Merpeople
# 624                                                                       the Merpeople—
# 626                                                                           merpeople—
# 769                                                                      The ... Bretans
# 954                                                                                  I’m
# 955                                                                                  I’m
# 1332                                                      someone that was n’t even real
# 1340                                                                Lavellan ’s chambers
# 1744                                                                               Miss.
# 2096                                                                     the P.E teacher
# 2292                                                the virgin who 's never dated anyone
# 2363                               Booster Terrik ’s Star Destroyer , the Errant Venture
# 3131                                                           a big ol’softy cat person
# 3136                                                                     he ’s neighbors
# 3204                                                                  the sheriff ’s son
# 3313                                                               female Bilbo ’s uncle
# 3342                                                                  male Bilbo ’s aunt
# 3350                                                                             Herself
#
#       bert_beg_tok  bert_end_tok gold_start_tok  gold_end_tok
# 17            1192          1193    (1, 10, 46)   (1, 10, 46)
# 367           2752          2758    (1, 31, 86)   (1, 31, 90)
# 453           2544          2545     (1, 30, 2)    (1, 30, 2)
# 579             10            27      (1, 1, 9)    (1, 1, 24)
# 600             31            32      (1, 2, 2)     (1, 2, 2)
# 624           1354          1356     (1, 47, 7)    (1, 47, 8)
# 626           1449          1450    (1, 51, 22)   (1, 51, 22)
# 769            129           134     (1, 6, 22)    (1, 6, 24)
# 954           3035          3036   (1, 114, 12)  (1, 114, 12)
# 955           3039          3040   (1, 114, 14)  (1, 114, 14)
# 1332           161           169     (1, 4, 10)    (1, 4, 15)
# 1340          1243          1247    (1, 35, 16)   (1, 35, 18)
# 1744          1361          1362     (1, 41, 9)    (1, 41, 9)
# 2096           655           660    (1, 30, 16)   (1, 30, 18)
# 2292           455           463     (1, 20, 3)    (1, 20, 9)
# 2363          1947          1957      (1, 3, 8)    (1, 3, 16)
# 3131          1385          1392     (1, 27, 6)   (1, 27, 10)
# 3136          1711          1715    (1, 32, 40)   (1, 32, 42)
# 3204          1730          1735    (1, 32, 58)   (1, 32, 61)
# 3313           944           949   (1, 19, 115)  (1, 19, 118)
# 3342           938           943   (1, 19, 110)  (1, 19, 113)
# 3350           373           374    (1, 7, 117)   (1, 7, 117)

# %%
# Load bert and gold tokenizations
import pandas as pd
import pdb

def add_nospace_boundaries(df, colname):
    df['token_len'] = df[colname].map(len)
    boundaries = []
    ptr = 0
    for length in df['token_len']:
        boundaries.append((ptr, ptr+length))
        ptr += length
    df[['beg_nospace', 'end_nospace']] = pd.DataFrame(boundaries, index=df.index)
    return df

# Build gold df
def load_gold_toks(fandom_fname):
    fpath = f'/data/fanfiction_ao3/annotated_10fandom/test/fics/{fandom_fname}.csv'
    gold = pd.read_csv(fpath)
    s = gold['text_tokenized'].str.split().apply(pd.Series, 1).stack()
    gt = pd.DataFrame(s, columns=['token'])
    gt['token_id'] = gt.index.get_level_values(1) + 1
    gt.index = gt.index.droplevel(-1)
    gold_toks = gt.merge(gold, left_index=True, right_index=True)[['token', 'chapter_id', 'para_id', 'token_id']]
    gold_toks = gold_toks.reset_index(drop=True)
    gold_toks = add_nospace_boundaries(gold_toks, 'token')
    return gold_toks

# Build bert df
def load_bert_toks(fandom_fname):
    bert_toks = pd.DataFrame(clusters[fandom_fname]['document'].split(), columns=['token'])
    bert_toks = add_nospace_boundaries(bert_toks, 'token')
    return bert_toks

def bert2gold(beg_tok, end_tok, bert_toks, gold_toks):
#     if beg_tok == 1354 and end_tok == 1356:
#         pdb.set_trace()
    beg_nospace = bert_toks.loc[beg_tok, 'beg_nospace']
    end_nospace = bert_toks.loc[end_tok-1, 'end_nospace']
    selected = gold_toks.loc[(gold_toks['beg_nospace']>=beg_nospace) & (gold_toks['end_nospace']<=end_nospace)]
    spread = 1
    while len(selected) == 0 or ' '.join(selected['token'].tolist()) == 'the':
        selected = gold_toks.loc[(gold_toks['beg_nospace']>=beg_nospace-spread) & (gold_toks['end_nospace']<=end_nospace+spread)]
        # Remove any rows with only punctuation
        selected = selected.loc[selected['token'].str.contains(r'\w')]
        spread +=1 
        if spread == 10:
            pdb.set_trace()

    # Look up in gold_toks
    start_gold_tok = tuple(selected.iloc[0][['chapter_id', 'para_id', 'token_id']])
    end_gold_tok = tuple(selected.iloc[-1][['chapter_id', 'para_id', 'token_id']])
    gold_text = ' '.join(selected.token.tolist())
    return (start_gold_tok, end_gold_tok, gold_text)

# %% [markdown]
# # Post-process CoreNLP server output

# %%
# Load JSON output
import os
import json

server_output_dirpath = '/data/fanfiction_ao3/allmarvel/complete_en_1k-50k/fics_proc'
fname = '2114373.csv'
fpath = os.path.join(server_output_dirpath, fname)

with open(fpath) as f:
    data = [json.loads(line) for line in f.read().splitlines()]
    
data
# Out:
# [{'fic_id': '2114373',
#   'chapter_id': '1',
#   'para_id': '1',
#   'text': 'Their relationship, right from the start, was unconventional, to say the least. They both worked for Daily Bugle, or at least that’s what Wade had told him. He was handsome and flirty, if a little bit odd. They’ve talked a few times and Peter liked him just fine.',
#   'text_tokenized': 'Their relationship , right from the start , was unconventional , to say the least . They both worked for Daily Bugle , or at least that ’s what Wade had told him . He was handsome and flirty , if a little bit odd . They ’ve talked a few times and Peter liked him just fine .',
#   'corenlp': {'sentences': [{'index': 0,
#      'parse': '(ROOT\n  (S\n    (NP\n      (NP (PRP$ Their) (NN relationship))\n      (, ,)\n      (ADVP (RB right)\n        (PP (IN from)\n          (NP (DT the) (NN start))))\n      (, ,))\n    (VP (VBD was)\n      (ADJP (JJ unconventional))\n      (, ,)\n      (S\n        (VP (TO to)\n          (VP (VB say)\n            (NP (DT the) (JJS least))))))\n    (. .)))',
#      'basicDependencies': [{'dep': 'ROOT',
#        'governor': 0,
#        'governorGloss': 'ROOT',
#        'dependent': 10,
#        'dependentGloss': 'unconventional'},
#       {'dep': 'nmod:poss',
#        'governor': 2,
#        'governorGloss': 'relationship',
#        'dependent': 1,
#        'dependentGloss': 'Their'},
#       {'dep': 'nsubj',
#        'governor': 10,
#        'governorGloss': 'unconventional',
#        'dependent': 2,
#        'dependentGloss': 'relationship'},
#       {'dep': 'punct',
#        'governor': 2,
#        'governorGloss': 'relationship',
#        'dependent': 3,
#        'dependentGloss': ','},
#       {'dep': 'advmod',
#        'governor': 2,
#        'governorGloss': 'relationship',
#        'dependent': 4,
#        'dependentGloss': 'right'},
#       {'dep': 'case',
#        'governor': 7,
#        'governorGloss': 'start',
#        'dependent': 5,
#        'dependentGloss': 'from'},
#       {'dep': 'det',
#        'governor': 7,
#        'governorGloss': 'start',
#        'dependent': 6,
#        'dependentGloss': 'the'},
#       {'dep': 'nmod',
#        'governor': 4,
#        'governorGloss': 'right',
#        'dependent': 7,
#        'dependentGloss': 'start'},
#       {'dep': 'punct',
#        'governor': 2,
#        'governorGloss': 'relationship',
#        'dependent': 8,
#        'dependentGloss': ','},
#       {'dep': 'cop',
#        'governor': 10,
#        'governorGloss': 'unconventional',
#        'dependent': 9,
#        'dependentGloss': 'was'},
#       {'dep': 'punct',
#        'governor': 10,
#        'governorGloss': 'unconventional',
#        'dependent': 11,
#        'dependentGloss': ','},
#       {'dep': 'mark',
#        'governor': 13,
#        'governorGloss': 'say',
#        'dependent': 12,
#        'dependentGloss': 'to'},
#       {'dep': 'xcomp',
#        'governor': 10,
#        'governorGloss': 'unconventional',
#        'dependent': 13,
#        'dependentGloss': 'say'},
#       {'dep': 'det',
#        'governor': 15,
#        'governorGloss': 'least',
#        'dependent': 14,
#        'dependentGloss': 'the'},
#       {'dep': 'dobj',
#        'governor': 13,
#        'governorGloss': 'say',
#        'dependent': 15,
#        'dependentGloss': 'least'},
#       {'dep': 'punct',
#        'governor': 10,
#        'governorGloss': 'unconventional',
#        'dependent': 16,
#        'dependentGloss': '.'}],
#      'enhancedDependencies': [{'dep': 'ROOT',
#        'governor': 0,
#        'governorGloss': 'ROOT',
#        'dependent': 10,
#        'dependentGloss': 'unconventional'},
#       {'dep': 'nmod:poss',
#        'governor': 2,
#        'governorGloss': 'relationship',
#        'dependent': 1,
#        'dependentGloss': 'Their'},
#       {'dep': 'nsubj',
#        'governor': 10,
#        'governorGloss': 'unconventional',
#        'dependent': 2,
#        'dependentGloss': 'relationship'},
#       {'dep': 'nsubj:xsubj',
#        'governor': 13,
#        'governorGloss': 'say',
#        'dependent': 2,
#        'dependentGloss': 'relationship'},
#       {'dep': 'punct',
#        'governor': 2,
#        'governorGloss': 'relationship',
#        'dependent': 3,
#        'dependentGloss': ','},
#       {'dep': 'advmod',
#        'governor': 2,
#        'governorGloss': 'relationship',
#        'dependent': 4,
#        'dependentGloss': 'right'},
#       {'dep': 'case',
#        'governor': 7,
#        'governorGloss': 'start',
#        'dependent': 5,
#        'dependentGloss': 'from'},
#       {'dep': 'det',
#        'governor': 7,
#        'governorGloss': 'start',
#        'dependent': 6,
#        'dependentGloss': 'the'},
#       {'dep': 'nmod:from',
#        'governor': 4,
#        'governorGloss': 'right',
#        'dependent': 7,
#        'dependentGloss': 'start'},
#       {'dep': 'punct',
#        'governor': 2,
#        'governorGloss': 'relationship',
#        'dependent': 8,
#        'dependentGloss': ','},
#       {'dep': 'cop',
#        'governor': 10,
#        'governorGloss': 'unconventional',
#        'dependent': 9,
#        'dependentGloss': 'was'},
#       {'dep': 'punct',
#        'governor': 10,
#        'governorGloss': 'unconventional',
#        'dependent': 11,
#        'dependentGloss': ','},
#       {'dep': 'mark',
#        'governor': 13,
#        'governorGloss': 'say',
#        'dependent': 12,
#        'dependentGloss': 'to'},
#       {'dep': 'xcomp',
#        'governor': 10,
#        'governorGloss': 'unconventional',
#        'dependent': 13,
#        'dependentGloss': 'say'},
#       {'dep': 'det',
#        'governor': 15,
#        'governorGloss': 'least',
#        'dependent': 14,
#        'dependentGloss': 'the'},
#       {'dep': 'dobj',
#        'governor': 13,
#        'governorGloss': 'say',
#        'dependent': 15,
#        'dependentGloss': 'least'},
#       {'dep': 'punct',
#        'governor': 10,
#        'governorGloss': 'unconventional',
#        'dependent': 16,
#        'dependentGloss': '.'}],
#      'enhancedPlusPlusDependencies': [{'dep': 'ROOT',
#        'governor': 0,
#        'governorGloss': 'ROOT',
#        'dependent': 10,
#        'dependentGloss': 'unconventional'},
#       {'dep': 'nmod:poss',
#        'governor': 2,
#        'governorGloss': 'relationship',
#        'dependent': 1,
#        'dependentGloss': 'Their'},
#       {'dep': 'nsubj',
#        'governor': 10,
#        'governorGloss': 'unconventional',
#        'dependent': 2,
#        'dependentGloss': 'relationship'},
#       {'dep': 'nsubj:xsubj',
#        'governor': 13,
#        'governorGloss': 'say',
#        'dependent': 2,
#        'dependentGloss': 'relationship'},
#       {'dep': 'punct',
#        'governor': 2,
#        'governorGloss': 'relationship',
#        'dependent': 3,
#        'dependentGloss': ','},
#       {'dep': 'advmod',
#        'governor': 2,
#        'governorGloss': 'relationship',
#        'dependent': 4,
#        'dependentGloss': 'right'},
#       {'dep': 'case',
#        'governor': 7,
#        'governorGloss': 'start',
#        'dependent': 5,
#        'dependentGloss': 'from'},
#       {'dep': 'det',
#        'governor': 7,
#        'governorGloss': 'start',
#        'dependent': 6,
#        'dependentGloss': 'the'},
#       {'dep': 'nmod:from',
#        'governor': 4,
#        'governorGloss': 'right',
#        'dependent': 7,
#        'dependentGloss': 'start'},
#       {'dep': 'punct',
#        'governor': 2,
#        'governorGloss': 'relationship',
#        'dependent': 8,
#        'dependentGloss': ','},
#       {'dep': 'cop',
#        'governor': 10,
#        'governorGloss': 'unconventional',
#        'dependent': 9,
#        'dependentGloss': 'was'},
#       {'dep': 'punct',
#        'governor': 10,
#        'governorGloss': 'unconventional',
#        'dependent': 11,
#        'dependentGloss': ','},
#       {'dep': 'mark',
#        'governor': 13,
#        'governorGloss': 'say',
#        'dependent': 12,
#        'dependentGloss': 'to'},
#       {'dep': 'xcomp',
#        'governor': 10,
#        'governorGloss': 'unconventional',
#        'dependent': 13,
#        'dependentGloss': 'say'},
#       {'dep': 'det',
#        'governor': 15,
#        'governorGloss': 'least',
#        'dependent': 14,
#        'dependentGloss': 'the'},
#       {'dep': 'dobj',
#        'governor': 13,
#        'governorGloss': 'say',
#        'dependent': 15,
#        'dependentGloss': 'least'},
#       {'dep': 'punct',
#        'governor': 10,
#        'governorGloss': 'unconventional',
#        'dependent': 16,
#        'dependentGloss': '.'}],
#      'entitymentions': [],
#      'tokens': [{'index': 1,
#        'word': 'Their',
#        'originalText': 'Their',
#        'lemma': 'they',
#        'characterOffsetBegin': 0,
#        'characterOffsetEnd': 5,
#        'pos': 'PRP$',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': '',
#        'after': ' '},
#       {'index': 2,
#        'word': 'relationship',
#        'originalText': 'relationship',
#        'lemma': 'relationship',
#        'characterOffsetBegin': 6,
#        'characterOffsetEnd': 18,
#        'pos': 'NN',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 3,
#        'word': ',',
#        'originalText': ',',
#        'lemma': ',',
#        'characterOffsetBegin': 19,
#        'characterOffsetEnd': 20,
#        'pos': ',',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 4,
#        'word': 'right',
#        'originalText': 'right',
#        'lemma': 'right',
#        'characterOffsetBegin': 21,
#        'characterOffsetEnd': 26,
#        'pos': 'RB',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 5,
#        'word': 'from',
#        'originalText': 'from',
#        'lemma': 'from',
#        'characterOffsetBegin': 27,
#        'characterOffsetEnd': 31,
#        'pos': 'IN',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 6,
#        'word': 'the',
#        'originalText': 'the',
#        'lemma': 'the',
#        'characterOffsetBegin': 32,
#        'characterOffsetEnd': 35,
#        'pos': 'DT',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 7,
#        'word': 'start',
#        'originalText': 'start',
#        'lemma': 'start',
#        'characterOffsetBegin': 36,
#        'characterOffsetEnd': 41,
#        'pos': 'NN',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 8,
#        'word': ',',
#        'originalText': ',',
#        'lemma': ',',
#        'characterOffsetBegin': 42,
#        'characterOffsetEnd': 43,
#        'pos': ',',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 9,
#        'word': 'was',
#        'originalText': 'was',
#        'lemma': 'be',
#        'characterOffsetBegin': 44,
#        'characterOffsetEnd': 47,
#        'pos': 'VBD',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 10,
#        'word': 'unconventional',
#        'originalText': 'unconventional',
#        'lemma': 'unconventional',
#        'characterOffsetBegin': 48,
#        'characterOffsetEnd': 62,
#        'pos': 'JJ',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 11,
#        'word': ',',
#        'originalText': ',',
#        'lemma': ',',
#        'characterOffsetBegin': 63,
#        'characterOffsetEnd': 64,
#        'pos': ',',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 12,
#        'word': 'to',
#        'originalText': 'to',
#        'lemma': 'to',
#        'characterOffsetBegin': 65,
#        'characterOffsetEnd': 67,
#        'pos': 'TO',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 13,
#        'word': 'say',
#        'originalText': 'say',
#        'lemma': 'say',
#        'characterOffsetBegin': 68,
#        'characterOffsetEnd': 71,
#        'pos': 'VB',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 14,
#        'word': 'the',
#        'originalText': 'the',
#        'lemma': 'the',
#        'characterOffsetBegin': 72,
#        'characterOffsetEnd': 75,
#        'pos': 'DT',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 15,
#        'word': 'least',
#        'originalText': 'least',
#        'lemma': 'least',
#        'characterOffsetBegin': 76,
#        'characterOffsetEnd': 81,
#        'pos': 'JJS',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 16,
#        'word': '.',
#        'originalText': '.',
#        'lemma': '.',
#        'characterOffsetBegin': 82,
#        'characterOffsetEnd': 83,
#        'pos': '.',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '}]},
#     {'index': 1,
#      'parse': "(ROOT\n  (S\n    (NP (PRP They))\n    (DT both)\n    (VP (VBD worked)\n      (SBAR (IN for)\n        (S\n          (NP\n            (NP (NNP Daily) (NNP Bugle))\n            (, ,)\n            (CC or)\n            (ADVP (IN at) (JJS least))\n            (NP (DT that)))\n          (VP (VBZ 's)\n            (SBAR\n              (WHNP (WP what))\n              (S\n                (NP (NNP Wade))\n                (VP (VBD had)\n                  (VP (VBN told)\n                    (NP (PRP him))))))))))\n    (. .)))",
#      'basicDependencies': [{'dep': 'ROOT',
#        'governor': 0,
#        'governorGloss': 'ROOT',
#        'dependent': 3,
#        'dependentGloss': 'worked'},
#       {'dep': 'nsubj',
#        'governor': 3,
#        'governorGloss': 'worked',
#        'dependent': 1,
#        'dependentGloss': 'They'},
#       {'dep': 'dep',
#        'governor': 3,
#        'governorGloss': 'worked',
#        'dependent': 2,
#        'dependentGloss': 'both'},
#       {'dep': 'mark',
#        'governor': 12,
#        'governorGloss': "'s",
#        'dependent': 4,
#        'dependentGloss': 'for'},
#       {'dep': 'compound',
#        'governor': 6,
#        'governorGloss': 'Bugle',
#        'dependent': 5,
#        'dependentGloss': 'Daily'},
#       {'dep': 'nsubj',
#        'governor': 12,
#        'governorGloss': "'s",
#        'dependent': 6,
#        'dependentGloss': 'Bugle'},
#       {'dep': 'punct',
#        'governor': 6,
#        'governorGloss': 'Bugle',
#        'dependent': 7,
#        'dependentGloss': ','},
#       {'dep': 'cc',
#        'governor': 6,
#        'governorGloss': 'Bugle',
#        'dependent': 8,
#        'dependentGloss': 'or'},
#       {'dep': 'case',
#        'governor': 10,
#        'governorGloss': 'least',
#        'dependent': 9,
#        'dependentGloss': 'at'},
#       {'dep': 'advmod',
#        'governor': 6,
#        'governorGloss': 'Bugle',
#        'dependent': 10,
#        'dependentGloss': 'least'},
#       {'dep': 'conj',
#        'governor': 6,
#        'governorGloss': 'Bugle',
#        'dependent': 11,
#        'dependentGloss': 'that'},
#       {'dep': 'advcl',
#        'governor': 3,
#        'governorGloss': 'worked',
#        'dependent': 12,
#        'dependentGloss': "'s"},
#       {'dep': 'dobj',
#        'governor': 16,
#        'governorGloss': 'told',
#        'dependent': 13,
#        'dependentGloss': 'what'},
#       {'dep': 'nsubj',
#        'governor': 16,
#        'governorGloss': 'told',
#        'dependent': 14,
#        'dependentGloss': 'Wade'},
#       {'dep': 'aux',
#        'governor': 16,
#        'governorGloss': 'told',
#        'dependent': 15,
#        'dependentGloss': 'had'},
#       {'dep': 'ccomp',
#        'governor': 12,
#        'governorGloss': "'s",
#        'dependent': 16,
#        'dependentGloss': 'told'},
#       {'dep': 'dobj',
#        'governor': 16,
#        'governorGloss': 'told',
#        'dependent': 17,
#        'dependentGloss': 'him'},
#       {'dep': 'punct',
#        'governor': 3,
#        'governorGloss': 'worked',
#        'dependent': 18,
#        'dependentGloss': '.'}],
#      'enhancedDependencies': [{'dep': 'ROOT',
#        'governor': 0,
#        'governorGloss': 'ROOT',
#        'dependent': 3,
#        'dependentGloss': 'worked'},
#       {'dep': 'nsubj',
#        'governor': 3,
#        'governorGloss': 'worked',
#        'dependent': 1,
#        'dependentGloss': 'They'},
#       {'dep': 'dep',
#        'governor': 3,
#        'governorGloss': 'worked',
#        'dependent': 2,
#        'dependentGloss': 'both'},
#       {'dep': 'mark',
#        'governor': 12,
#        'governorGloss': "'s",
#        'dependent': 4,
#        'dependentGloss': 'for'},
#       {'dep': 'compound',
#        'governor': 6,
#        'governorGloss': 'Bugle',
#        'dependent': 5,
#        'dependentGloss': 'Daily'},
#       {'dep': 'nsubj',
#        'governor': 12,
#        'governorGloss': "'s",
#        'dependent': 6,
#        'dependentGloss': 'Bugle'},
#       {'dep': 'punct',
#        'governor': 6,
#        'governorGloss': 'Bugle',
#        'dependent': 7,
#        'dependentGloss': ','},
#       {'dep': 'cc',
#        'governor': 6,
#        'governorGloss': 'Bugle',
#        'dependent': 8,
#        'dependentGloss': 'or'},
#       {'dep': 'case',
#        'governor': 10,
#        'governorGloss': 'least',
#        'dependent': 9,
#        'dependentGloss': 'at'},
#       {'dep': 'advmod',
#        'governor': 6,
#        'governorGloss': 'Bugle',
#        'dependent': 10,
#        'dependentGloss': 'least'},
#       {'dep': 'conj:or',
#        'governor': 6,
#        'governorGloss': 'Bugle',
#        'dependent': 11,
#        'dependentGloss': 'that'},
#       {'dep': 'nsubj',
#        'governor': 12,
#        'governorGloss': "'s",
#        'dependent': 11,
#        'dependentGloss': 'that'},
#       {'dep': 'advcl:for',
#        'governor': 3,
#        'governorGloss': 'worked',
#        'dependent': 12,
#        'dependentGloss': "'s"},
#       {'dep': 'dobj',
#        'governor': 16,
#        'governorGloss': 'told',
#        'dependent': 13,
#        'dependentGloss': 'what'},
#       {'dep': 'nsubj',
#        'governor': 16,
#        'governorGloss': 'told',
#        'dependent': 14,
#        'dependentGloss': 'Wade'},
#       {'dep': 'aux',
#        'governor': 16,
#        'governorGloss': 'told',
#        'dependent': 15,
#        'dependentGloss': 'had'},
#       {'dep': 'ccomp',
#        'governor': 12,
#        'governorGloss': "'s",
#        'dependent': 16,
#        'dependentGloss': 'told'},
#       {'dep': 'dobj',
#        'governor': 16,
#        'governorGloss': 'told',
#        'dependent': 17,
#        'dependentGloss': 'him'},
#       {'dep': 'punct',
#        'governor': 3,
#        'governorGloss': 'worked',
#        'dependent': 18,
#        'dependentGloss': '.'}],
#      'enhancedPlusPlusDependencies': [{'dep': 'ROOT',
#        'governor': 0,
#        'governorGloss': 'ROOT',
#        'dependent': 3,
#        'dependentGloss': 'worked'},
#       {'dep': 'nsubj',
#        'governor': 3,
#        'governorGloss': 'worked',
#        'dependent': 1,
#        'dependentGloss': 'They'},
#       {'dep': 'dep',
#        'governor': 3,
#        'governorGloss': 'worked',
#        'dependent': 2,
#        'dependentGloss': 'both'},
#       {'dep': 'mark',
#        'governor': 12,
#        'governorGloss': "'s",
#        'dependent': 4,
#        'dependentGloss': 'for'},
#       {'dep': 'compound',
#        'governor': 6,
#        'governorGloss': 'Bugle',
#        'dependent': 5,
#        'dependentGloss': 'Daily'},
#       {'dep': 'nsubj',
#        'governor': 12,
#        'governorGloss': "'s",
#        'dependent': 6,
#        'dependentGloss': 'Bugle'},
#       {'dep': 'punct',
#        'governor': 6,
#        'governorGloss': 'Bugle',
#        'dependent': 7,
#        'dependentGloss': ','},
#       {'dep': 'cc',
#        'governor': 6,
#        'governorGloss': 'Bugle',
#        'dependent': 8,
#        'dependentGloss': 'or'},
#       {'dep': 'case',
#        'governor': 10,
#        'governorGloss': 'least',
#        'dependent': 9,
#        'dependentGloss': 'at'},
#       {'dep': 'advmod',
#        'governor': 6,
#        'governorGloss': 'Bugle',
#        'dependent': 10,
#        'dependentGloss': 'least'},
#       {'dep': 'conj:or',
#        'governor': 6,
#        'governorGloss': 'Bugle',
#        'dependent': 11,
#        'dependentGloss': 'that'},
#       {'dep': 'nsubj',
#        'governor': 12,
#        'governorGloss': "'s",
#        'dependent': 11,
#        'dependentGloss': 'that'},
#       {'dep': 'advcl:for',
#        'governor': 3,
#        'governorGloss': 'worked',
#        'dependent': 12,
#        'dependentGloss': "'s"},
#       {'dep': 'dobj',
#        'governor': 16,
#        'governorGloss': 'told',
#        'dependent': 13,
#        'dependentGloss': 'what'},
#       {'dep': 'nsubj',
#        'governor': 16,
#        'governorGloss': 'told',
#        'dependent': 14,
#        'dependentGloss': 'Wade'},
#       {'dep': 'aux',
#        'governor': 16,
#        'governorGloss': 'told',
#        'dependent': 15,
#        'dependentGloss': 'had'},
#       {'dep': 'ccomp',
#        'governor': 12,
#        'governorGloss': "'s",
#        'dependent': 16,
#        'dependentGloss': 'told'},
#       {'dep': 'dobj',
#        'governor': 16,
#        'governorGloss': 'told',
#        'dependent': 17,
#        'dependentGloss': 'him'},
#       {'dep': 'punct',
#        'governor': 3,
#        'governorGloss': 'worked',
#        'dependent': 18,
#        'dependentGloss': '.'}],
#      'entitymentions': [{'docTokenBegin': 29,
#        'docTokenEnd': 30,
#        'tokenBegin': 13,
#        'tokenEnd': 14,
#        'text': 'Wade',
#        'characterOffsetBegin': 144,
#        'characterOffsetEnd': 148,
#        'ner': 'PERSON'},
#       {'docTokenBegin': 32,
#        'docTokenEnd': 33,
#        'tokenBegin': 16,
#        'tokenEnd': 17,
#        'text': 'him',
#        'characterOffsetBegin': 158,
#        'characterOffsetEnd': 161,
#        'ner': 'PERSON'}],
#      'tokens': [{'index': 1,
#        'word': 'They',
#        'originalText': 'They',
#        'lemma': 'they',
#        'characterOffsetBegin': 84,
#        'characterOffsetEnd': 88,
#        'pos': 'PRP',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 2,
#        'word': 'both',
#        'originalText': 'both',
#        'lemma': 'both',
#        'characterOffsetBegin': 89,
#        'characterOffsetEnd': 93,
#        'pos': 'DT',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 3,
#        'word': 'worked',
#        'originalText': 'worked',
#        'lemma': 'work',
#        'characterOffsetBegin': 94,
#        'characterOffsetEnd': 100,
#        'pos': 'VBD',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 4,
#        'word': 'for',
#        'originalText': 'for',
#        'lemma': 'for',
#        'characterOffsetBegin': 101,
#        'characterOffsetEnd': 104,
#        'pos': 'IN',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 5,
#        'word': 'Daily',
#        'originalText': 'Daily',
#        'lemma': 'Daily',
#        'characterOffsetBegin': 105,
#        'characterOffsetEnd': 110,
#        'pos': 'NNP',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 6,
#        'word': 'Bugle',
#        'originalText': 'Bugle',
#        'lemma': 'Bugle',
#        'characterOffsetBegin': 111,
#        'characterOffsetEnd': 116,
#        'pos': 'NNP',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 7,
#        'word': ',',
#        'originalText': ',',
#        'lemma': ',',
#        'characterOffsetBegin': 117,
#        'characterOffsetEnd': 118,
#        'pos': ',',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 8,
#        'word': 'or',
#        'originalText': 'or',
#        'lemma': 'or',
#        'characterOffsetBegin': 119,
#        'characterOffsetEnd': 121,
#        'pos': 'CC',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 9,
#        'word': 'at',
#        'originalText': 'at',
#        'lemma': 'at',
#        'characterOffsetBegin': 122,
#        'characterOffsetEnd': 124,
#        'pos': 'IN',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 10,
#        'word': 'least',
#        'originalText': 'least',
#        'lemma': 'least',
#        'characterOffsetBegin': 125,
#        'characterOffsetEnd': 130,
#        'pos': 'JJS',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 11,
#        'word': 'that',
#        'originalText': 'that',
#        'lemma': 'that',
#        'characterOffsetBegin': 131,
#        'characterOffsetEnd': 135,
#        'pos': 'DT',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 12,
#        'word': "'s",
#        'originalText': '’s',
#        'lemma': 'be',
#        'characterOffsetBegin': 136,
#        'characterOffsetEnd': 138,
#        'pos': 'VBZ',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 13,
#        'word': 'what',
#        'originalText': 'what',
#        'lemma': 'what',
#        'characterOffsetBegin': 139,
#        'characterOffsetEnd': 143,
#        'pos': 'WP',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 14,
#        'word': 'Wade',
#        'originalText': 'Wade',
#        'lemma': 'Wade',
#        'characterOffsetBegin': 144,
#        'characterOffsetEnd': 148,
#        'pos': 'NNP',
#        'ner': 'PERSON',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 15,
#        'word': 'had',
#        'originalText': 'had',
#        'lemma': 'have',
#        'characterOffsetBegin': 149,
#        'characterOffsetEnd': 152,
#        'pos': 'VBD',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 16,
#        'word': 'told',
#        'originalText': 'told',
#        'lemma': 'tell',
#        'characterOffsetBegin': 153,
#        'characterOffsetEnd': 157,
#        'pos': 'VBN',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 17,
#        'word': 'him',
#        'originalText': 'him',
#        'lemma': 'he',
#        'characterOffsetBegin': 158,
#        'characterOffsetEnd': 161,
#        'pos': 'PRP',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 18,
#        'word': '.',
#        'originalText': '.',
#        'lemma': '.',
#        'characterOffsetBegin': 162,
#        'characterOffsetEnd': 163,
#        'pos': '.',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '}]},
#     {'index': 2,
#      'parse': '(ROOT\n  (S\n    (NP (PRP He))\n    (VP (VBD was)\n      (ADJP (JJ handsome)\n        (CC and)\n        (JJ flirty))\n      (, ,)\n      (SBAR (IN if)\n        (S\n          (NP (DT a) (JJ little) (NN bit))\n          (ADJP (JJ odd)))))\n    (. .)))',
#      'basicDependencies': [{'dep': 'ROOT',
#        'governor': 0,
#        'governorGloss': 'ROOT',
#        'dependent': 3,
#        'dependentGloss': 'handsome'},
#       {'dep': 'nsubj',
#        'governor': 3,
#        'governorGloss': 'handsome',
#        'dependent': 1,
#        'dependentGloss': 'He'},
#       {'dep': 'cop',
#        'governor': 3,
#        'governorGloss': 'handsome',
#        'dependent': 2,
#        'dependentGloss': 'was'},
#       {'dep': 'cc',
#        'governor': 3,
#        'governorGloss': 'handsome',
#        'dependent': 4,
#        'dependentGloss': 'and'},
#       {'dep': 'conj',
#        'governor': 3,
#        'governorGloss': 'handsome',
#        'dependent': 5,
#        'dependentGloss': 'flirty'},
#       {'dep': 'punct',
#        'governor': 3,
#        'governorGloss': 'handsome',
#        'dependent': 6,
#        'dependentGloss': ','},
#       {'dep': 'mark',
#        'governor': 11,
#        'governorGloss': 'odd',
#        'dependent': 7,
#        'dependentGloss': 'if'},
#       {'dep': 'det',
#        'governor': 10,
#        'governorGloss': 'bit',
#        'dependent': 8,
#        'dependentGloss': 'a'},
#       {'dep': 'amod',
#        'governor': 10,
#        'governorGloss': 'bit',
#        'dependent': 9,
#        'dependentGloss': 'little'},
#       {'dep': 'dep',
#        'governor': 11,
#        'governorGloss': 'odd',
#        'dependent': 10,
#        'dependentGloss': 'bit'},
#       {'dep': 'advcl',
#        'governor': 3,
#        'governorGloss': 'handsome',
#        'dependent': 11,
#        'dependentGloss': 'odd'},
#       {'dep': 'punct',
#        'governor': 3,
#        'governorGloss': 'handsome',
#        'dependent': 12,
#        'dependentGloss': '.'}],
#      'enhancedDependencies': [{'dep': 'ROOT',
#        'governor': 0,
#        'governorGloss': 'ROOT',
#        'dependent': 3,
#        'dependentGloss': 'handsome'},
#       {'dep': 'nsubj',
#        'governor': 3,
#        'governorGloss': 'handsome',
#        'dependent': 1,
#        'dependentGloss': 'He'},
#       {'dep': 'nsubj',
#        'governor': 5,
#        'governorGloss': 'flirty',
#        'dependent': 1,
#        'dependentGloss': 'He'},
#       {'dep': 'cop',
#        'governor': 3,
#        'governorGloss': 'handsome',
#        'dependent': 2,
#        'dependentGloss': 'was'},
#       {'dep': 'cc',
#        'governor': 3,
#        'governorGloss': 'handsome',
#        'dependent': 4,
#        'dependentGloss': 'and'},
#       {'dep': 'conj:and',
#        'governor': 3,
#        'governorGloss': 'handsome',
#        'dependent': 5,
#        'dependentGloss': 'flirty'},
#       {'dep': 'punct',
#        'governor': 3,
#        'governorGloss': 'handsome',
#        'dependent': 6,
#        'dependentGloss': ','},
#       {'dep': 'mark',
#        'governor': 11,
#        'governorGloss': 'odd',
#        'dependent': 7,
#        'dependentGloss': 'if'},
#       {'dep': 'det',
#        'governor': 10,
#        'governorGloss': 'bit',
#        'dependent': 8,
#        'dependentGloss': 'a'},
#       {'dep': 'amod',
#        'governor': 10,
#        'governorGloss': 'bit',
#        'dependent': 9,
#        'dependentGloss': 'little'},
#       {'dep': 'dep',
#        'governor': 11,
#        'governorGloss': 'odd',
#        'dependent': 10,
#        'dependentGloss': 'bit'},
#       {'dep': 'advcl:if',
#        'governor': 3,
#        'governorGloss': 'handsome',
#        'dependent': 11,
#        'dependentGloss': 'odd'},
#       {'dep': 'punct',
#        'governor': 3,
#        'governorGloss': 'handsome',
#        'dependent': 12,
#        'dependentGloss': '.'}],
#      'enhancedPlusPlusDependencies': [{'dep': 'ROOT',
#        'governor': 0,
#        'governorGloss': 'ROOT',
#        'dependent': 3,
#        'dependentGloss': 'handsome'},
#       {'dep': 'nsubj',
#        'governor': 3,
#        'governorGloss': 'handsome',
#        'dependent': 1,
#        'dependentGloss': 'He'},
#       {'dep': 'nsubj',
#        'governor': 5,
#        'governorGloss': 'flirty',
#        'dependent': 1,
#        'dependentGloss': 'He'},
#       {'dep': 'cop',
#        'governor': 3,
#        'governorGloss': 'handsome',
#        'dependent': 2,
#        'dependentGloss': 'was'},
#       {'dep': 'cc',
#        'governor': 3,
#        'governorGloss': 'handsome',
#        'dependent': 4,
#        'dependentGloss': 'and'},
#       {'dep': 'conj:and',
#        'governor': 3,
#        'governorGloss': 'handsome',
#        'dependent': 5,
#        'dependentGloss': 'flirty'},
#       {'dep': 'punct',
#        'governor': 3,
#        'governorGloss': 'handsome',
#        'dependent': 6,
#        'dependentGloss': ','},
#       {'dep': 'mark',
#        'governor': 11,
#        'governorGloss': 'odd',
#        'dependent': 7,
#        'dependentGloss': 'if'},
#       {'dep': 'det',
#        'governor': 10,
#        'governorGloss': 'bit',
#        'dependent': 8,
#        'dependentGloss': 'a'},
#       {'dep': 'amod',
#        'governor': 10,
#        'governorGloss': 'bit',
#        'dependent': 9,
#        'dependentGloss': 'little'},
#       {'dep': 'dep',
#        'governor': 11,
#        'governorGloss': 'odd',
#        'dependent': 10,
#        'dependentGloss': 'bit'},
#       {'dep': 'advcl:if',
#        'governor': 3,
#        'governorGloss': 'handsome',
#        'dependent': 11,
#        'dependentGloss': 'odd'},
#       {'dep': 'punct',
#        'governor': 3,
#        'governorGloss': 'handsome',
#        'dependent': 12,
#        'dependentGloss': '.'}],
#      'entitymentions': [{'docTokenBegin': 34,
#        'docTokenEnd': 35,
#        'tokenBegin': 0,
#        'tokenEnd': 1,
#        'text': 'He',
#        'characterOffsetBegin': 164,
#        'characterOffsetEnd': 166,
#        'ner': 'PERSON'}],
#      'tokens': [{'index': 1,
#        'word': 'He',
#        'originalText': 'He',
#        'lemma': 'he',
#        'characterOffsetBegin': 164,
#        'characterOffsetEnd': 166,
#        'pos': 'PRP',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 2,
#        'word': 'was',
#        'originalText': 'was',
#        'lemma': 'be',
#        'characterOffsetBegin': 167,
#        'characterOffsetEnd': 170,
#        'pos': 'VBD',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 3,
#        'word': 'handsome',
#        'originalText': 'handsome',
#        'lemma': 'handsome',
#        'characterOffsetBegin': 171,
#        'characterOffsetEnd': 179,
#        'pos': 'JJ',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 4,
#        'word': 'and',
#        'originalText': 'and',
#        'lemma': 'and',
#        'characterOffsetBegin': 180,
#        'characterOffsetEnd': 183,
#        'pos': 'CC',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 5,
#        'word': 'flirty',
#        'originalText': 'flirty',
#        'lemma': 'flirty',
#        'characterOffsetBegin': 184,
#        'characterOffsetEnd': 190,
#        'pos': 'JJ',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 6,
#        'word': ',',
#        'originalText': ',',
#        'lemma': ',',
#        'characterOffsetBegin': 191,
#        'characterOffsetEnd': 192,
#        'pos': ',',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 7,
#        'word': 'if',
#        'originalText': 'if',
#        'lemma': 'if',
#        'characterOffsetBegin': 193,
#        'characterOffsetEnd': 195,
#        'pos': 'IN',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 8,
#        'word': 'a',
#        'originalText': 'a',
#        'lemma': 'a',
#        'characterOffsetBegin': 196,
#        'characterOffsetEnd': 197,
#        'pos': 'DT',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 9,
#        'word': 'little',
#        'originalText': 'little',
#        'lemma': 'little',
#        'characterOffsetBegin': 198,
#        'characterOffsetEnd': 204,
#        'pos': 'JJ',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 10,
#        'word': 'bit',
#        'originalText': 'bit',
#        'lemma': 'bit',
#        'characterOffsetBegin': 205,
#        'characterOffsetEnd': 208,
#        'pos': 'NN',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 11,
#        'word': 'odd',
#        'originalText': 'odd',
#        'lemma': 'odd',
#        'characterOffsetBegin': 209,
#        'characterOffsetEnd': 212,
#        'pos': 'JJ',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 12,
#        'word': '.',
#        'originalText': '.',
#        'lemma': '.',
#        'characterOffsetBegin': 213,
#        'characterOffsetEnd': 214,
#        'pos': '.',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '}]},
#     {'index': 3,
#      'parse': "(ROOT\n  (S\n    (S\n      (NP (PRP They))\n      (VP (VBP 've)\n        (VP (VBN talked)\n          (NP-TMP (DT a) (JJ few) (NNS times)))))\n    (CC and)\n    (S\n      (NP (NNP Peter))\n      (VP (VBD liked)\n        (NP (PRP him))\n        (PP (RB just)\n          (NP (NN fine)))))\n    (. .)))",
#      'basicDependencies': [{'dep': 'ROOT',
#        'governor': 0,
#        'governorGloss': 'ROOT',
#        'dependent': 3,
#        'dependentGloss': 'talked'},
#       {'dep': 'nsubj',
#        'governor': 3,
#        'governorGloss': 'talked',
#        'dependent': 1,
#        'dependentGloss': 'They'},
#       {'dep': 'aux',
#        'governor': 3,
#        'governorGloss': 'talked',
#        'dependent': 2,
#        'dependentGloss': "'ve"},
#       {'dep': 'det',
#        'governor': 6,
#        'governorGloss': 'times',
#        'dependent': 4,
#        'dependentGloss': 'a'},
#       {'dep': 'amod',
#        'governor': 6,
#        'governorGloss': 'times',
#        'dependent': 5,
#        'dependentGloss': 'few'},
#       {'dep': 'nmod:tmod',
#        'governor': 3,
#        'governorGloss': 'talked',
#        'dependent': 6,
#        'dependentGloss': 'times'},
#       {'dep': 'cc',
#        'governor': 3,
#        'governorGloss': 'talked',
#        'dependent': 7,
#        'dependentGloss': 'and'},
#       {'dep': 'nsubj',
#        'governor': 9,
#        'governorGloss': 'liked',
#        'dependent': 8,
#        'dependentGloss': 'Peter'},
#       {'dep': 'conj',
#        'governor': 3,
#        'governorGloss': 'talked',
#        'dependent': 9,
#        'dependentGloss': 'liked'},
#       {'dep': 'dobj',
#        'governor': 9,
#        'governorGloss': 'liked',
#        'dependent': 10,
#        'dependentGloss': 'him'},
#       {'dep': 'advmod',
#        'governor': 12,
#        'governorGloss': 'fine',
#        'dependent': 11,
#        'dependentGloss': 'just'},
#       {'dep': 'nmod',
#        'governor': 9,
#        'governorGloss': 'liked',
#        'dependent': 12,
#        'dependentGloss': 'fine'},
#       {'dep': 'punct',
#        'governor': 3,
#        'governorGloss': 'talked',
#        'dependent': 13,
#        'dependentGloss': '.'}],
#      'enhancedDependencies': [{'dep': 'ROOT',
#        'governor': 0,
#        'governorGloss': 'ROOT',
#        'dependent': 3,
#        'dependentGloss': 'talked'},
#       {'dep': 'nsubj',
#        'governor': 3,
#        'governorGloss': 'talked',
#        'dependent': 1,
#        'dependentGloss': 'They'},
#       {'dep': 'aux',
#        'governor': 3,
#        'governorGloss': 'talked',
#        'dependent': 2,
#        'dependentGloss': "'ve"},
#       {'dep': 'det',
#        'governor': 6,
#        'governorGloss': 'times',
#        'dependent': 4,
#        'dependentGloss': 'a'},
#       {'dep': 'amod',
#        'governor': 6,
#        'governorGloss': 'times',
#        'dependent': 5,
#        'dependentGloss': 'few'},
#       {'dep': 'nmod:tmod',
#        'governor': 3,
#        'governorGloss': 'talked',
#        'dependent': 6,
#        'dependentGloss': 'times'},
#       {'dep': 'cc',
#        'governor': 3,
#        'governorGloss': 'talked',
#        'dependent': 7,
#        'dependentGloss': 'and'},
#       {'dep': 'nsubj',
#        'governor': 9,
#        'governorGloss': 'liked',
#        'dependent': 8,
#        'dependentGloss': 'Peter'},
#       {'dep': 'conj:and',
#        'governor': 3,
#        'governorGloss': 'talked',
#        'dependent': 9,
#        'dependentGloss': 'liked'},
#       {'dep': 'dobj',
#        'governor': 9,
#        'governorGloss': 'liked',
#        'dependent': 10,
#        'dependentGloss': 'him'},
#       {'dep': 'advmod',
#        'governor': 12,
#        'governorGloss': 'fine',
#        'dependent': 11,
#        'dependentGloss': 'just'},
#       {'dep': 'nmod',
#        'governor': 9,
#        'governorGloss': 'liked',
#        'dependent': 12,
#        'dependentGloss': 'fine'},
#       {'dep': 'punct',
#        'governor': 3,
#        'governorGloss': 'talked',
#        'dependent': 13,
#        'dependentGloss': '.'}],
#      'enhancedPlusPlusDependencies': [{'dep': 'ROOT',
#        'governor': 0,
#        'governorGloss': 'ROOT',
#        'dependent': 3,
#        'dependentGloss': 'talked'},
#       {'dep': 'nsubj',
#        'governor': 3,
#        'governorGloss': 'talked',
#        'dependent': 1,
#        'dependentGloss': 'They'},
#       {'dep': 'aux',
#        'governor': 3,
#        'governorGloss': 'talked',
#        'dependent': 2,
#        'dependentGloss': "'ve"},
#       {'dep': 'det',
#        'governor': 6,
#        'governorGloss': 'times',
#        'dependent': 4,
#        'dependentGloss': 'a'},
#       {'dep': 'amod',
#        'governor': 6,
#        'governorGloss': 'times',
#        'dependent': 5,
#        'dependentGloss': 'few'},
#       {'dep': 'nmod:tmod',
#        'governor': 3,
#        'governorGloss': 'talked',
#        'dependent': 6,
#        'dependentGloss': 'times'},
#       {'dep': 'cc',
#        'governor': 3,
#        'governorGloss': 'talked',
#        'dependent': 7,
#        'dependentGloss': 'and'},
#       {'dep': 'nsubj',
#        'governor': 9,
#        'governorGloss': 'liked',
#        'dependent': 8,
#        'dependentGloss': 'Peter'},
#       {'dep': 'conj:and',
#        'governor': 3,
#        'governorGloss': 'talked',
#        'dependent': 9,
#        'dependentGloss': 'liked'},
#       {'dep': 'dobj',
#        'governor': 9,
#        'governorGloss': 'liked',
#        'dependent': 10,
#        'dependentGloss': 'him'},
#       {'dep': 'advmod',
#        'governor': 12,
#        'governorGloss': 'fine',
#        'dependent': 11,
#        'dependentGloss': 'just'},
#       {'dep': 'nmod',
#        'governor': 9,
#        'governorGloss': 'liked',
#        'dependent': 12,
#        'dependentGloss': 'fine'},
#       {'dep': 'punct',
#        'governor': 3,
#        'governorGloss': 'talked',
#        'dependent': 13,
#        'dependentGloss': '.'}],
#      'entitymentions': [{'docTokenBegin': 53,
#        'docTokenEnd': 54,
#        'tokenBegin': 7,
#        'tokenEnd': 8,
#        'text': 'Peter',
#        'characterOffsetBegin': 247,
#        'characterOffsetEnd': 252,
#        'ner': 'PERSON'},
#       {'docTokenBegin': 55,
#        'docTokenEnd': 56,
#        'tokenBegin': 9,
#        'tokenEnd': 10,
#        'text': 'him',
#        'characterOffsetBegin': 259,
#        'characterOffsetEnd': 262,
#        'ner': 'PERSON'}],
#      'tokens': [{'index': 1,
#        'word': 'They',
#        'originalText': 'They',
#        'lemma': 'they',
#        'characterOffsetBegin': 215,
#        'characterOffsetEnd': 219,
#        'pos': 'PRP',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 2,
#        'word': "'ve",
#        'originalText': '’ve',
#        'lemma': 'have',
#        'characterOffsetBegin': 220,
#        'characterOffsetEnd': 223,
#        'pos': 'VBP',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 3,
#        'word': 'talked',
#        'originalText': 'talked',
#        'lemma': 'talk',
#        'characterOffsetBegin': 224,
#        'characterOffsetEnd': 230,
#        'pos': 'VBN',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 4,
#        'word': 'a',
#        'originalText': 'a',
#        'lemma': 'a',
#        'characterOffsetBegin': 231,
#        'characterOffsetEnd': 232,
#        'pos': 'DT',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 5,
#        'word': 'few',
#        'originalText': 'few',
#        'lemma': 'few',
#        'characterOffsetBegin': 233,
#        'characterOffsetEnd': 236,
#        'pos': 'JJ',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 6,
#        'word': 'times',
#        'originalText': 'times',
#        'lemma': 'time',
#        'characterOffsetBegin': 237,
#        'characterOffsetEnd': 242,
#        'pos': 'NNS',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 7,
#        'word': 'and',
#        'originalText': 'and',
#        'lemma': 'and',
#        'characterOffsetBegin': 243,
#        'characterOffsetEnd': 246,
#        'pos': 'CC',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 8,
#        'word': 'Peter',
#        'originalText': 'Peter',
#        'lemma': 'Peter',
#        'characterOffsetBegin': 247,
#        'characterOffsetEnd': 252,
#        'pos': 'NNP',
#        'ner': 'PERSON',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 9,
#        'word': 'liked',
#        'originalText': 'liked',
#        'lemma': 'like',
#        'characterOffsetBegin': 253,
#        'characterOffsetEnd': 258,
#        'pos': 'VBD',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 10,
#        'word': 'him',
#        'originalText': 'him',
#        'lemma': 'he',
#        'characterOffsetBegin': 259,
#        'characterOffsetEnd': 262,
#        'pos': 'PRP',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 11,
#        'word': 'just',
#        'originalText': 'just',
#        'lemma': 'just',
#        'characterOffsetBegin': 263,
#        'characterOffsetEnd': 267,
#        'pos': 'RB',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 12,
#        'word': 'fine',
#        'originalText': 'fine',
#        'lemma': 'fine',
#        'characterOffsetBegin': 268,
#        'characterOffsetEnd': 272,
#        'pos': 'NN',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 13,
#        'word': '.',
#        'originalText': '.',
#        'lemma': '.',
#        'characterOffsetBegin': 273,
#        'characterOffsetEnd': 274,
#        'pos': '.',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ''}]}],
#    'corefs': {'10': [{'id': 4,
#       'text': 'him',
#       'type': 'PRONOMINAL',
#       'number': 'SINGULAR',
#       'gender': 'MALE',
#       'animacy': 'ANIMATE',
#       'startIndex': 17,
#       'endIndex': 18,
#       'headIndex': 17,
#       'sentNum': 2,
#       'position': [2, 3],
#       'isRepresentativeMention': True},
#      {'id': 8,
#       'text': 'He',
#       'type': 'PRONOMINAL',
#       'number': 'SINGULAR',
#       'gender': 'MALE',
#       'animacy': 'ANIMATE',
#       'startIndex': 1,
#       'endIndex': 2,
#       'headIndex': 1,
#       'sentNum': 3,
#       'position': [3, 2],
#       'isRepresentativeMention': False},
#      {'id': 10,
#       'text': 'him',
#       'type': 'PRONOMINAL',
#       'number': 'SINGULAR',
#       'gender': 'MALE',
#       'animacy': 'ANIMATE',
#       'startIndex': 10,
#       'endIndex': 11,
#       'headIndex': 10,
#       'sentNum': 4,
#       'position': [4, 2],
#       'isRepresentativeMention': False}],
#     '12': [{'id': 0,
#       'text': 'Their',
#       'type': 'PRONOMINAL',
#       'number': 'PLURAL',
#       'gender': 'UNKNOWN',
#       'animacy': 'ANIMATE',
#       'startIndex': 1,
#       'endIndex': 2,
#       'headIndex': 1,
#       'sentNum': 1,
#       'position': [1, 1],
#       'isRepresentativeMention': True},
#      {'id': 5,
#       'text': 'They',
#       'type': 'PRONOMINAL',
#       'number': 'PLURAL',
#       'gender': 'UNKNOWN',
#       'animacy': 'ANIMATE',
#       'startIndex': 1,
#       'endIndex': 2,
#       'headIndex': 1,
#       'sentNum': 2,
#       'position': [2, 4],
#       'isRepresentativeMention': False},
#      {'id': 12,
#       'text': 'They',
#       'type': 'PRONOMINAL',
#       'number': 'PLURAL',
#       'gender': 'UNKNOWN',
#       'animacy': 'ANIMATE',
#       'startIndex': 1,
#       'endIndex': 2,
#       'headIndex': 1,
#       'sentNum': 4,
#       'position': [4, 4],
#       'isRepresentativeMention': False}]}}},
#  {'fic_id': '2114373',
#   'chapter_id': '1',
#   'para_id': '2',
#   'text': 'Then, one day, there was a huge explosion in the building that Peter survived more or less unscathed – a few cracked ribs, concussion, several bruises, broken leg, oh, and partial loss of hearing. It took some time to adjust, obviously, but all things considered, he could have ended up much worse than a cast and a hearing aid.',
#   'text_tokenized': 'Then , one day , there was a huge explosion in the building that Peter survived more or less unscathed – a few cracked ribs , concussion , several bruises , broken leg , oh , and partial loss of hearing . It took some time to adjust , obviously , but all things considered , he could have ended up much worse than a cast and a hearing aid .',
#   'corenlp': {'sentences': [{'index': 0,
# ...
#      'tokens': [{'index': 1,
#        'word': '``',
#        'originalText': '“',
#        'lemma': '``',
#        'characterOffsetBegin': 71,
#        'characterOffsetEnd': 72,
#        'pos': '``',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 2,
#        'word': 'But',
#        'originalText': 'But',
#        'lemma': 'but',
#        'characterOffsetBegin': 73,
#        'characterOffsetEnd': 76,
#        'pos': 'CC',
#        'ner': 'O',
#        'speaker': 'PER1',
#        'before': ' ',
#        'after': ' '},
#       {'index': 3,
#        'word': 'I',
#        'originalText': 'I',
#        'lemma': 'I',
#        'characterOffsetBegin': 77,
#        'characterOffsetEnd': 78,
#        'pos': 'PRP',
#        'ner': 'O',
#        'speaker': 'PER1',
#        'before': ' ',
#        'after': ' '},
#       {'index': 4,
#        'word': "'m",
#        'originalText': '’m',
#        'lemma': 'be',
#        'characterOffsetBegin': 79,
#        'characterOffsetEnd': 81,
#        'pos': 'VBP',
#        'ner': 'O',
#        'speaker': 'PER1',
#        'before': ' ',
#        'after': ' '},
#       {'index': 5,
#        'word': 'the',
#        'originalText': 'the',
#        'lemma': 'the',
#        'characterOffsetBegin': 82,
#        'characterOffsetEnd': 85,
#        'pos': 'DT',
#        'ner': 'O',
#        'speaker': 'PER1',
#        'before': ' ',
#        'after': ' '},
#       {'index': 6,
#        'word': 'wife',
#        'originalText': 'wife',
#        'lemma': 'wife',
#        'characterOffsetBegin': 86,
#        'characterOffsetEnd': 90,
#        'pos': 'NN',
#        'ner': 'O',
#        'speaker': 'PER1',
#        'before': ' ',
#        'after': ' '},
#       {'index': 7,
#        'word': ',',
#        'originalText': ',',
#        'lemma': ',',
#        'characterOffsetBegin': 91,
#        'characterOffsetEnd': 92,
#        'pos': ',',
#        'ner': 'O',
#        'speaker': 'PER1',
#        'before': ' ',
#        'after': ' '},
#       {'index': 8,
#        'word': 'right',
#        'originalText': 'right',
#        'lemma': 'right',
#        'characterOffsetBegin': 93,
#        'characterOffsetEnd': 98,
#        'pos': 'NN',
#        'ner': 'O',
#        'speaker': 'PER1',
#        'before': ' ',
#        'after': ' '},
#       {'index': 9,
#        'word': '?',
#        'originalText': '?',
#        'lemma': '?',
#        'characterOffsetBegin': 99,
#        'characterOffsetEnd': 100,
#        'pos': '.',
#        'ner': 'O',
#        'speaker': 'PER1',
#        'before': ' ',
#        'after': ' '},
#       {'index': 10,
#        'word': "''",
#        'originalText': '”',
#        'lemma': "''",
#        'characterOffsetBegin': 101,
#        'characterOffsetEnd': 102,
#        'pos': "''",
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ''}]}],
#    'corefs': {'4': [{'id': 0,
#       'text': 'Wade',
#       'type': 'PROPER',
#       'number': 'SINGULAR',
#       'gender': 'MALE',
#       'animacy': 'ANIMATE',
#       'startIndex': 3,
#       'endIndex': 4,
#       'headIndex': 3,
#       'sentNum': 1,
#       'position': [1, 1],
#       'isRepresentativeMention': True},
#      {'id': 4,
#       'text': 'I',
#       'type': 'PRONOMINAL',
#       'number': 'SINGULAR',
#       'gender': 'UNKNOWN',
#       'animacy': 'ANIMATE',
#       'startIndex': 3,
#       'endIndex': 4,
#       'headIndex': 3,
#       'sentNum': 2,
#       'position': [2, 1],
#       'isRepresentativeMention': False}]}}},
#  {'fic_id': '2114373',
#   'chapter_id': '1',
#   'para_id': '27',
#   'text': 'Peter laughed happily and kissed him again. And this time Wade kissed back.',
#   'text_tokenized': 'Peter laughed happily and kissed him again . And this time Wade kissed back .',
#   'corenlp': {'sentences': [{'index': 0,
#      'parse': '(ROOT\n  (S\n    (NP (NNP Peter))\n    (VP\n      (VP (VBD laughed)\n        (ADVP (RB happily)))\n      (CC and)\n      (VP (VBD kissed)\n        (NP (PRP him))\n        (ADVP (RB again))))\n    (. .)))',
#      'basicDependencies': [{'dep': 'ROOT',
#        'governor': 0,
#        'governorGloss': 'ROOT',
#        'dependent': 2,
#        'dependentGloss': 'laughed'},
#       {'dep': 'nsubj',
#        'governor': 2,
#        'governorGloss': 'laughed',
#        'dependent': 1,
#        'dependentGloss': 'Peter'},
#       {'dep': 'advmod',
#        'governor': 2,
#        'governorGloss': 'laughed',
#        'dependent': 3,
#        'dependentGloss': 'happily'},
#       {'dep': 'cc',
#        'governor': 2,
#        'governorGloss': 'laughed',
#        'dependent': 4,
#        'dependentGloss': 'and'},
#       {'dep': 'conj',
#        'governor': 2,
#        'governorGloss': 'laughed',
#        'dependent': 5,
#        'dependentGloss': 'kissed'},
#       {'dep': 'dobj',
#        'governor': 5,
#        'governorGloss': 'kissed',
#        'dependent': 6,
#        'dependentGloss': 'him'},
#       {'dep': 'advmod',
#        'governor': 5,
#        'governorGloss': 'kissed',
#        'dependent': 7,
#        'dependentGloss': 'again'},
#       {'dep': 'punct',
#        'governor': 2,
#        'governorGloss': 'laughed',
#        'dependent': 8,
#        'dependentGloss': '.'}],
#      'enhancedDependencies': [{'dep': 'ROOT',
#        'governor': 0,
#        'governorGloss': 'ROOT',
#        'dependent': 2,
#        'dependentGloss': 'laughed'},
#       {'dep': 'nsubj',
#        'governor': 2,
#        'governorGloss': 'laughed',
#        'dependent': 1,
#        'dependentGloss': 'Peter'},
#       {'dep': 'nsubj',
#        'governor': 5,
#        'governorGloss': 'kissed',
#        'dependent': 1,
#        'dependentGloss': 'Peter'},
#       {'dep': 'advmod',
#        'governor': 2,
#        'governorGloss': 'laughed',
#        'dependent': 3,
#        'dependentGloss': 'happily'},
#       {'dep': 'cc',
#        'governor': 2,
#        'governorGloss': 'laughed',
#        'dependent': 4,
#        'dependentGloss': 'and'},
#       {'dep': 'conj:and',
#        'governor': 2,
#        'governorGloss': 'laughed',
#        'dependent': 5,
#        'dependentGloss': 'kissed'},
#       {'dep': 'dobj',
#        'governor': 5,
#        'governorGloss': 'kissed',
#        'dependent': 6,
#        'dependentGloss': 'him'},
#       {'dep': 'advmod',
#        'governor': 5,
#        'governorGloss': 'kissed',
#        'dependent': 7,
#        'dependentGloss': 'again'},
#       {'dep': 'punct',
#        'governor': 2,
#        'governorGloss': 'laughed',
#        'dependent': 8,
#        'dependentGloss': '.'}],
#      'enhancedPlusPlusDependencies': [{'dep': 'ROOT',
#        'governor': 0,
#        'governorGloss': 'ROOT',
#        'dependent': 2,
#        'dependentGloss': 'laughed'},
#       {'dep': 'nsubj',
#        'governor': 2,
#        'governorGloss': 'laughed',
#        'dependent': 1,
#        'dependentGloss': 'Peter'},
#       {'dep': 'nsubj',
#        'governor': 5,
#        'governorGloss': 'kissed',
#        'dependent': 1,
#        'dependentGloss': 'Peter'},
#       {'dep': 'advmod',
#        'governor': 2,
#        'governorGloss': 'laughed',
#        'dependent': 3,
#        'dependentGloss': 'happily'},
#       {'dep': 'cc',
#        'governor': 2,
#        'governorGloss': 'laughed',
#        'dependent': 4,
#        'dependentGloss': 'and'},
#       {'dep': 'conj:and',
#        'governor': 2,
#        'governorGloss': 'laughed',
#        'dependent': 5,
#        'dependentGloss': 'kissed'},
#       {'dep': 'dobj',
#        'governor': 5,
#        'governorGloss': 'kissed',
#        'dependent': 6,
#        'dependentGloss': 'him'},
#       {'dep': 'advmod',
#        'governor': 5,
#        'governorGloss': 'kissed',
#        'dependent': 7,
#        'dependentGloss': 'again'},
#       {'dep': 'punct',
#        'governor': 2,
#        'governorGloss': 'laughed',
#        'dependent': 8,
#        'dependentGloss': '.'}],
#      'entitymentions': [{'docTokenBegin': 0,
#        'docTokenEnd': 1,
#        'tokenBegin': 0,
#        'tokenEnd': 1,
#        'text': 'Peter',
#        'characterOffsetBegin': 0,
#        'characterOffsetEnd': 5,
#        'ner': 'PERSON'},
#       {'docTokenBegin': 5,
#        'docTokenEnd': 6,
#        'tokenBegin': 5,
#        'tokenEnd': 6,
#        'text': 'him',
#        'characterOffsetBegin': 33,
#        'characterOffsetEnd': 36,
#        'ner': 'PERSON'}],
#      'tokens': [{'index': 1,
#        'word': 'Peter',
#        'originalText': 'Peter',
#        'lemma': 'Peter',
#        'characterOffsetBegin': 0,
#        'characterOffsetEnd': 5,
#        'pos': 'NNP',
#        'ner': 'PERSON',
#        'speaker': 'PER0',
#        'before': '',
#        'after': ' '},
#       {'index': 2,
#        'word': 'laughed',
#        'originalText': 'laughed',
#        'lemma': 'laugh',
#        'characterOffsetBegin': 6,
#        'characterOffsetEnd': 13,
#        'pos': 'VBD',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 3,
#        'word': 'happily',
#        'originalText': 'happily',
#        'lemma': 'happily',
#        'characterOffsetBegin': 14,
#        'characterOffsetEnd': 21,
#        'pos': 'RB',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 4,
#        'word': 'and',
#        'originalText': 'and',
#        'lemma': 'and',
#        'characterOffsetBegin': 22,
#        'characterOffsetEnd': 25,
#        'pos': 'CC',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 5,
#        'word': 'kissed',
#        'originalText': 'kissed',
#        'lemma': 'kiss',
#        'characterOffsetBegin': 26,
#        'characterOffsetEnd': 32,
#        'pos': 'VBD',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 6,
#        'word': 'him',
#        'originalText': 'him',
#        'lemma': 'he',
#        'characterOffsetBegin': 33,
#        'characterOffsetEnd': 36,
#        'pos': 'PRP',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 7,
#        'word': 'again',
#        'originalText': 'again',
#        'lemma': 'again',
#        'characterOffsetBegin': 37,
#        'characterOffsetEnd': 42,
#        'pos': 'RB',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 8,
#        'word': '.',
#        'originalText': '.',
#        'lemma': '.',
#        'characterOffsetBegin': 43,
#        'characterOffsetEnd': 44,
#        'pos': '.',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '}]},
#     {'index': 1,
#      'parse': '(ROOT\n  (S (CC And)\n    (NP-TMP (DT this) (NN time))\n    (NP (NNP Wade))\n    (VP (VBD kissed)\n      (ADVP (RB back)))\n    (. .)))',
#      'basicDependencies': [{'dep': 'ROOT',
#        'governor': 0,
#        'governorGloss': 'ROOT',
#        'dependent': 5,
#        'dependentGloss': 'kissed'},
#       {'dep': 'cc',
#        'governor': 5,
#        'governorGloss': 'kissed',
#        'dependent': 1,
#        'dependentGloss': 'And'},
#       {'dep': 'det',
#        'governor': 3,
#        'governorGloss': 'time',
#        'dependent': 2,
#        'dependentGloss': 'this'},
#       {'dep': 'nmod:tmod',
#        'governor': 5,
#        'governorGloss': 'kissed',
#        'dependent': 3,
#        'dependentGloss': 'time'},
#       {'dep': 'nsubj',
#        'governor': 5,
#        'governorGloss': 'kissed',
#        'dependent': 4,
#        'dependentGloss': 'Wade'},
#       {'dep': 'advmod',
#        'governor': 5,
#        'governorGloss': 'kissed',
#        'dependent': 6,
#        'dependentGloss': 'back'},
#       {'dep': 'punct',
#        'governor': 5,
#        'governorGloss': 'kissed',
#        'dependent': 7,
#        'dependentGloss': '.'}],
#      'enhancedDependencies': [{'dep': 'ROOT',
#        'governor': 0,
#        'governorGloss': 'ROOT',
#        'dependent': 5,
#        'dependentGloss': 'kissed'},
#       {'dep': 'cc',
#        'governor': 5,
#        'governorGloss': 'kissed',
#        'dependent': 1,
#        'dependentGloss': 'And'},
#       {'dep': 'det',
#        'governor': 3,
#        'governorGloss': 'time',
#        'dependent': 2,
#        'dependentGloss': 'this'},
#       {'dep': 'nmod:tmod',
#        'governor': 5,
#        'governorGloss': 'kissed',
#        'dependent': 3,
#        'dependentGloss': 'time'},
#       {'dep': 'nsubj',
#        'governor': 5,
#        'governorGloss': 'kissed',
#        'dependent': 4,
#        'dependentGloss': 'Wade'},
#       {'dep': 'advmod',
#        'governor': 5,
#        'governorGloss': 'kissed',
#        'dependent': 6,
#        'dependentGloss': 'back'},
#       {'dep': 'punct',
#        'governor': 5,
#        'governorGloss': 'kissed',
#        'dependent': 7,
#        'dependentGloss': '.'}],
#      'enhancedPlusPlusDependencies': [{'dep': 'ROOT',
#        'governor': 0,
#        'governorGloss': 'ROOT',
#        'dependent': 5,
#        'dependentGloss': 'kissed'},
#       {'dep': 'cc',
#        'governor': 5,
#        'governorGloss': 'kissed',
#        'dependent': 1,
#        'dependentGloss': 'And'},
#       {'dep': 'det',
#        'governor': 3,
#        'governorGloss': 'time',
#        'dependent': 2,
#        'dependentGloss': 'this'},
#       {'dep': 'nmod:tmod',
#        'governor': 5,
#        'governorGloss': 'kissed',
#        'dependent': 3,
#        'dependentGloss': 'time'},
#       {'dep': 'nsubj',
#        'governor': 5,
#        'governorGloss': 'kissed',
#        'dependent': 4,
#        'dependentGloss': 'Wade'},
#       {'dep': 'advmod',
#        'governor': 5,
#        'governorGloss': 'kissed',
#        'dependent': 6,
#        'dependentGloss': 'back'},
#       {'dep': 'punct',
#        'governor': 5,
#        'governorGloss': 'kissed',
#        'dependent': 7,
#        'dependentGloss': '.'}],
#      'entitymentions': [{'docTokenBegin': 11,
#        'docTokenEnd': 12,
#        'tokenBegin': 3,
#        'tokenEnd': 4,
#        'text': 'Wade',
#        'characterOffsetBegin': 59,
#        'characterOffsetEnd': 63,
#        'ner': 'PERSON'}],
#      'tokens': [{'index': 1,
#        'word': 'And',
#        'originalText': 'And',
#        'lemma': 'and',
#        'characterOffsetBegin': 45,
#        'characterOffsetEnd': 48,
#        'pos': 'CC',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 2,
#        'word': 'this',
#        'originalText': 'this',
#        'lemma': 'this',
#        'characterOffsetBegin': 49,
#        'characterOffsetEnd': 53,
#        'pos': 'DT',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 3,
#        'word': 'time',
#        'originalText': 'time',
#        'lemma': 'time',
#        'characterOffsetBegin': 54,
#        'characterOffsetEnd': 58,
#        'pos': 'NN',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 4,
#        'word': 'Wade',
#        'originalText': 'Wade',
#        'lemma': 'Wade',
#        'characterOffsetBegin': 59,
#        'characterOffsetEnd': 63,
#        'pos': 'NNP',
#        'ner': 'PERSON',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 5,
#        'word': 'kissed',
#        'originalText': 'kissed',
#        'lemma': 'kiss',
#        'characterOffsetBegin': 64,
#        'characterOffsetEnd': 70,
#        'pos': 'VBD',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 6,
#        'word': 'back',
#        'originalText': 'back',
#        'lemma': 'back',
#        'characterOffsetBegin': 71,
#        'characterOffsetEnd': 75,
#        'pos': 'RB',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ' '},
#       {'index': 7,
#        'word': '.',
#        'originalText': '.',
#        'lemma': '.',
#        'characterOffsetBegin': 76,
#        'characterOffsetEnd': 77,
#        'pos': '.',
#        'ner': 'O',
#        'speaker': 'PER0',
#        'before': ' ',
#        'after': ''}]}],
#    'corefs': {'2': [{'id': 1,
#       'text': 'him',
#       'type': 'PRONOMINAL',
#       'number': 'SINGULAR',
#       'gender': 'MALE',
#       'animacy': 'ANIMATE',
#       'startIndex': 6,
#       'endIndex': 7,
#       'headIndex': 6,
#       'sentNum': 1,
#       'position': [1, 2],
#       'isRepresentativeMention': False},
#      {'id': 2,
#       'text': 'Wade',
#       'type': 'PROPER',
#       'number': 'SINGULAR',
#       'gender': 'MALE',
#       'animacy': 'ANIMATE',
#       'startIndex': 4,
#       'endIndex': 5,
#       'headIndex': 4,
#       'sentNum': 2,
#       'position': [2, 1],
#       'isRepresentativeMention': True}]}}}]
