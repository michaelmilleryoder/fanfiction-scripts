# %% [markdown]
# # Create character feature dataset for STM

# %% [markdown]
# ## Fix gender footnote issue

# %%
path = f'/data/fanfiction_gender_roles/harrypotter_ao3/{dataset_name}/output/character_relationship_features.csv'
feats = pd.read_csv(path)
feats.columns
# Out:
# Index(['fic_id', 'character_original', 'character_canonical',
#        'character_gender', 'character_features', 'title', 'author',
#        'author_key', 'rating', 'category', 'fandom', 'relationship',
#        'character', 'additional tags', 'language', 'published', 'status',
#        'status date', 'words', 'comments', 'kudos', 'bookmarks', 'hits',
#        'chapter_count', 'series', 'seriespart', 'seriesid', 'summary',
#        'preface_notes', 'afterword_notes', 'character_in_relationship',
#        'character_in_relationship_type'],
#       dtype='object')

# %%
feats['character_gender'].value_counts()
# Out:
# male         195246
# female       71526
# male[5]      3539
# male[2]      2745
# male[1]      2430
# male[4]      1749
# male[3]      595
# female[5]    375
# female[3]    313
# female[2]    274
# female[4]    227
# male[6]      147
# Name: character_gender, dtype: int64

# %%
feats['character_gender'] = feats['character_gender'].map(lambda x: re.match(r'\w+', x).group())
feats['character_gender'].value_counts()
# Out:
# male      206451
# female    72715
# Name: character_gender, dtype: int64

# %%
# Save out annotated data
outpath = f'/data/fanfiction_gender_roles/harrypotter_ao3/{dataset_name}/output/character_relationship_features.csv'
feats.to_csv(outpath, index=False)

# %%
feats['character_in_relationship_type'].value_counts()
# Out:
# character_not_in_relationship    186089
# queer                            56580
# straight                         32448
# unknown                          4049
# Name: character_in_relationship_type, dtype: int64

# %% [markdown]
# ## Annotate fic relationship type

# %%
# Load current character/fic features
import pandas as pd

dataset_name = 'complete_en_1k-50k'
path = f'/data/fanfiction_gender_roles/harrypotter_ao3/{dataset_name}/output/character_gender_features.csv'
char_fic_feats = pd.read_csv(path)
char_fic_feats
# Out:
#           fic_id character_original character_canonical character_gender  \
# 0        5888698              Remus               Remus             male
# 1        5888698            Padfoot             Padfoot             male
# 2          10199              Draco               Draco             male
# 3        5355224           Hermione            Hermione           female
# 4        5355224              Draco               Draco             male
# 5        5355224              Ginny               Ginny           female
# 6        5355224               Luna                Luna           female
# 7        5355224            Salazar             Salazar          male[5]
# 8       10838292              Remus               Remus             male
# 9       10838292            Marlene             Marlene          male[5]
# 10      10838292             Sirius              Sirius             male
# 11      10838292              James      James Potter I             male
# 12      15522078          Voldemort           Voldemort             male
# 13      15522078              Patil               Patil             male
# 14      15522078           Hermione            Hermione           female
# 15      15522078              Harry               Harry             male
# 16      15522078              Draco               Draco             male
# 17      15522078             Blaise              Blaise             male
# 18      15522078             Zabini              Zabini           female
# 19      15522078               Dean                Dean             male
# 20      15522078         Dumbledore          Dumbledore             male
# 21      15522078              Snape               Snape             male
# 22      15522078            Severus             Severus             male
# 23      15522078               Lord           Voldemort             male
# 24      15522078              Dobby               Dobby             male
# 25      15522078               Lily      Lily J. Potter           female
# 26       9525716            Michael             Michael             male
# 27       9525716              Terry               Terry           female
# 28       9525716            Anthony             Anthony           female
# 29       9525716             Ariana              Ariana           female
# ...          ...                ...                 ...              ...
# 279136  10786131            Severus             Severus             male
# 279137  10786131         Dumbledore          Dumbledore             male
# 279138  10786131          Voldemort           Voldemort             male
# 279139  10786131               Lily      Lily J. Potter           female
# 279140  14829977            Severus             Severus             male
# 279141  14829977            Minerva             Minerva           female
# 279142  14829977            Granger             Granger             male
# 279143  14829977            Regulus     Regulus Black I          male[1]
# 279144  14829977          Voldemort           Voldemort             male
# 279145  14829977             Hagrid              Hagrid             male
# 279146  14829977           Kingsley            Kingsley          male[5]
# 279147  14829977            Padfoot             Padfoot             male
# 279148  14829977              James      James Potter I             male
# 279149   7881532              Lupin               Lupin             male
# 279150   7881532              Remus               Remus             male
# 279151  10076291              Harry               Harry             male
# 279152  10076291             Potter        Harry Potter             male
# 279153  10076291                Ron                 Ron             male
# 279154  10076291              Goyle               Goyle             male
# 279155  10076291             Crabbe              Crabbe             male
# 279156   9182275             Graves              Graves             male
# 279157   8703775               Newt    Newton Scamander          male[2]
# 279158   8703775              Percy               Percy             male
# 279159   8703775            Queenie             Queenie           female
# 279160   8703775               Tina                Tina           female
# 279161   8485216          Voldemort           Voldemort             male
# 279162   8485216              Harry               Harry             male
# 279163   8485216             Sirius              Sirius             male
# 279164   8485216              Snape               Snape             male
# 279165   2789771            Granger             Granger             male
#
#                                        character_features
# 0       carries cherished carried carried was been wan...
# 1                                                      by
# 2       responded hinted is walked knew question sat c...
# 3       was felt growled let doing read gotten going r...
# 4       find like pouted gripped smirked joked drawled...
# 5       said snapped said said snickered getting think...
# 6       's said seemed imagine said said smiled asked ...
# 7                                                  damned
# 8       considered thought asked doing pulled going op...
# 9       liked tell trying mean mind mind touch said kn...
# 10      said get try sleep go have had staring tasted ...
# 11      said sound dropped said said was said get said...
# 12      know coming used met am had talking thought am...
# 13      was was had blamed friends took smiled could s...
# 14      thinking interject rolled answered smiled said...
# 15      at for at hiding tell fucking scowled be turni...
# 16      seemed threw have chocked scrubbed breaking go...
# 17      spoke spoke did lost sat realised murmured gon...
# 18                                     was gone patronize
# 19                                               answered
# 20                                         was as flicked
# 21      wearing shaking through as lifting into decidi...
# 22      swore was be looked read was whimpered spread ...
# 23                                 following with sneered
# 24                                            found as as
# 25                                             had folded
# 26      sitting hates dropping glances mean crying lau...
# 27      put goes trails turns says says wants says mea...
# 28      says says thinks standing gives closes mean sa...
# 29                                               comes be
# ...                                                   ...
# 279136  looked stumbled getting fell tried moaned bega...
# 279137                                 achieve son person
# 279138                                             is one
# 279139                                        haunt about
# 279140  knew imagine realised do grabbed got had knew ...
# 279141                                did attract was did
# 279142  hated knelt submitted given been took bend sla...
# 279143                                was like marked man
# 279144                                               with
# 279145                                               walk
# 279146                            requested spoke droning
# 279147                                       trotted into
# 279148  was raged threw picked created knew took tore ...
# 279149                  kept was was be have relationship
# 279150                                            replied
# 279151  sighed pointed jerked lunged cast pointed aske...
# 279152                                          detention
# 279153  grumbled walked snarled 're humiliated be chuc...
# 279154                                                 on
# 279155  come do was do was licked said kiss wish thoug...
# 279156  smell missed said reached continued pulled rei...
# 279157  suffer asked asked locked looked think stood l...
# 279158     went took have said said to pushed followed at
# 279159  knew looked has loved met gave started correct...
# 279160  grumbled followed looked change got sunken hea...
# 279161  blames dealing 's make 's going going making b...
# 279162  is starts doing stuffs pets pick turns want sn...
# 279163                   make than good beautiful good us
# 279164  tipped fall open slipped reach hang manages gl...
# 279165                                             showed
#
# [279166 rows x 5 columns]

# %%
# Load fic metadata

metadata_fpath = '/data/fanfiction_gender_roles/harrypotter_ao3/story_metadata.csv'
metadata = pd.read_csv(metadata_fpath)
metadata
# Out:
#           fic_id                                     title  \
# 0            100                          A Strong Defense
# 1        1000039  Laocoon's Children: The End Of The Story
# 2        1000044           Sing, For The Sea Belongs To Me
# 3       10000460                              Grim's child
# 4       10000490  (the Girl Standing) In the Blush of Dawn
# 5        1000053                          The World Burned
# 6        1000059                           Take Half Of Me
# 7        1000060                 An Interlude with Potions
# 8        1000061        Everybody Knows (Your Sister Does)
# 9          10001                                   Remorse
# 10      10001006                                Resolution
# 11       1000109                                Gryffindor
# 12       1000123                              Unforgivable
# 13      10001231                                Feel, love
# 14       1000138                 Being Expendable [PODFIC]
# 15       1000154                            Demon Dealings
# 16      10001672                             Vision Quest!
# 17      10002215                A Good Deed Gone Unnoticed
# 18      10002266                   Streets of Philadelphia
# 19      10002536                                    Relief
# 20        100026                                Homecoming
# 21      10002731                         One Year Of Snark
# 22      10002920                  Those Three Little Words
# 23       1000329                               Live It Out
# 24       1000353                              Night Patrol
# 25       1000414                     Crazy things for love
# 26       1000455                                   The Fae
# 27       1000515                              storytelling
# 28      10005209              The Untitled Shannon Project
# 29      10005212                            Exire Aeternum
# ...          ...                                       ...
# 179377    999681                Slash-tastic Drabble-athon
# 179378   9996896                             Harry N Draco
# 179379     99969                              Not a Number
# 179380   9996932                           Beyond the Veil
# 179381   9997727                       it seems like years
# 179382   9997754                                    Caught
# 179383   9997760                                  Innocent
# 179384   9997820                           A Brand New Day
# 179385    999797                      The Unlikely Visitor
# 179386   9998033                                     Sable
# 179387   9998039                                     Later
# 179388    999830                        For Those in Peril
# 179389    999850                    The First and the Last
# 179390    999853                            A Single Flame
# 179391    999862                               Dark Master
# 179392   9998621                        The Silver Soldier
# 179393    999866                       Tom Riddle's Ghost.
# 179394    999867               In the Shack, After Moonset
# 179395     99989                   The Just and the Unjust
# 179396   9999032                                      Rain
# 179397   9999194                    Salty Sweet - Book Two
# 179398    999925                   Malfoy Sensibilities II
# 179399   9999338                               Canis Major
# 179400    999934            Life and Times of Harry Hibiki
# 179401    999938                                 Halloween
# 179402     99995                                 Incarnate
# 179403    999981  And that's how Harry got rid of Volemort
# 179404    999989                                Inevitable
# 179405     99999                                 Dreamtime
# 179406   9999935                                 Aftermath
#
#                     author           author_key                     rating  \
# 0           ellen_fremedon       ellen_fremedon               ["Explicit"]
# 1              copperbadge          copperbadge  ["Teen And Up Audiences"]
# 2                 leontina             Leontina  ["Teen And Up Audiences"]
# 3             Willofhounds         Willofhounds  ["Teen And Up Audiences"]
# 4        writing_as_tracey    writing_as_tracey  ["Teen And Up Audiences"]
# 5                Lillielle            Lillielle  ["Teen And Up Audiences"]
# 6                 leontina             Leontina                 ["Mature"]
# 7                Lillielle            Lillielle                 ["Mature"]
# 8                Neon_Opal            Neon_Opal                 ["Mature"]
# 9         Mairi%20Nathaira                 Tara  ["Teen And Up Audiences"]
# 10        SlytherinsDragon     SlytherinsDragon  ["Teen And Up Audiences"]
# 11           Lady_Rougarou        Lady_Rougarou      ["General Audiences"]
# 12                   Musyc                Musyc               ["Explicit"]
# 13                Time_out         Key_Mahogany  ["Teen And Up Audiences"]
# 14              codeswitch           codeswitch                 ["Mature"]
# 15               PitchGold            PitchGold               ["Explicit"]
# 16          TheFandomIdjit       TheFandomIdjit      ["General Audiences"]
# 17            PseudoLeigha         PseudoLeigha  ["Teen And Up Audiences"]
# 18      HPFandom_archivist   HPFandom_archivist                 ["Mature"]
# 19      HPFandom_archivist   HPFandom_archivist               ["Explicit"]
# 20                MiraMira             MiraMira      ["General Audiences"]
# 21      HPFandom_archivist   HPFandom_archivist               ["Explicit"]
# 22      HPFandom_archivist   HPFandom_archivist                 ["Mature"]
# 23         SunseticMonster      SunseticMonster                 ["Mature"]
# 24             sheltie1987          sheltie1987              ["Not Rated"]
# 25                Betsal55             Betsal55                 ["Mature"]
# 26                Betsal55             Betsal55                 ["Mature"]
# 27                  phirsh               phirsh      ["General Audiences"]
# 28      HPFandom_archivist   HPFandom_archivist               ["Explicit"]
# 29            ShimizuBlack         ShimizuBlack                 ["Mature"]
# ...                    ...                  ...                        ...
# 179377    BrianJustin4Ever     BrianJustin4Ever              ["Not Rated"]
# 179378  HPFandom_archivist   HPFandom_archivist               ["Explicit"]
# 179379           Vipersweb             Rhianona  ["Teen And Up Audiences"]
# 179380  HPFandom_archivist   HPFandom_archivist                 ["Mature"]
# 179381            haymitch  noblydonedonnanoble      ["General Audiences"]
# 179382  HPFandom_archivist   HPFandom_archivist               ["Explicit"]
# 179383           SBluemoon            SBluemoon                 ["Mature"]
# 179384  HPFandom_archivist   HPFandom_archivist               ["Explicit"]
# 179385      Quantumphysica       Quantumphysica  ["Teen And Up Audiences"]
# 179386  HPFandom_archivist   HPFandom_archivist               ["Explicit"]
# 179387        sinwithagrin         sinwithagrin      ["General Audiences"]
# 179388              tofsla               tofsla      ["General Audiences"]
# 179389             Crimbob              Crimbob      ["General Audiences"]
# 179390           Lillielle            Lillielle                 ["Mature"]
# 179391               undun                undun      ["General Audiences"]
# 179392  HPFandom_archivist   HPFandom_archivist      ["General Audiences"]
# 179393     smilingcrescent      smilingcrescent  ["Teen And Up Audiences"]
# 179394               undun                undun                 ["Mature"]
# 179395            cleodoxa             cleodoxa               ["Explicit"]
# 179396    heartbreakholmes     heartbreakholmes      ["General Audiences"]
# 179397              Nugiha               Nugiha                 ["Mature"]
# 179398          PaolaAdara           PaolaAdara              ["Not Rated"]
# 179399           SleepGlue            SleepGlue  ["Teen And Up Audiences"]
# 179400           USA_Tiger            USA_Tiger  ["Teen And Up Audiences"]
# 179401          kaosbabe16           kaosbabe16               ["Explicit"]
# 179402            cleodoxa             cleodoxa               ["Explicit"]
# 179403          jeanette9a           jeanette9a                 ["Mature"]
# 179404        writeonclara         writeonclara  ["Teen And Up Audiences"]
# 179405            cleodoxa             cleodoxa               ["Explicit"]
# 179406  HPFandom_archivist   HPFandom_archivist                 ["Mature"]
#
#                               category  \
# 0                              ["M/M"]
# 1                              ["Gen"]
# 2                              ["M/M"]
# 3                              ["Gen"]
# 4                       ["F/M", "Gen"]
# 5                              ["M/M"]
# 6                              ["M/M"]
# 7                              ["F/M"]
# 8                            ["Multi"]
# 9                              ["M/M"]
# 10                             ["F/M"]
# 11                             ["Gen"]
# 12                             ["F/M"]
# 13                           ["Other"]
# 14                             ["F/M"]
# 15                             ["M/M"]
# 16                             ["F/M"]
# 17                                  []
# 18                             ["M/M"]
# 19                             ["M/M"]
# 20                             ["Gen"]
# 21                             ["M/M"]
# 22                             ["M/M"]
# 23                             ["M/M"]
# 24             ["F/M", "F/F", "Multi"]
# 25                             ["M/M"]
# 26                             ["M/M"]
# 27                             ["Gen"]
# 28                             ["M/M"]
# 29               ["F/F", "F/M", "M/M"]
# ...                                ...
# 179377                  ["M/M", "F/F"]
# 179378                  ["M/M", "F/M"]
# 179379                         ["Gen"]
# 179380                         ["M/M"]
# 179381                         ["F/M"]
# 179382                         ["M/M"]
# 179383                         ["F/M"]
# 179384                         ["M/M"]
# 179385                         ["F/M"]
# 179386                         ["M/M"]
# 179387                  ["F/M", "M/M"]
# 179388                         ["F/F"]
# 179389                       ["Multi"]
# 179390                         ["Gen"]
# 179391                         ["Gen"]
# 179392                       ["Multi"]
# 179393                         ["Gen"]
# 179394                       ["Other"]
# 179395                  ["F/M", "Gen"]
# 179396                         ["M/M"]
# 179397                         ["Gen"]
# 179398                ["Gen", "Other"]
# 179399                  ["F/M", "M/M"]
# 179400  ["F/M", "M/M", "F/F", "Multi"]
# 179401                         ["F/M"]
# 179402                         ["M/M"]
# 179403                         ["Gen"]
# 179404                         ["M/M"]
# 179405                         ["M/M"]
# 179406                         ["M/M"]
#
#                                                    fandom  \
# 0                              ["Harry Potter - Rowling"]
# 1                        ["Harry Potter - J. K. Rowling"]
# 2                        ["Harry Potter - J. K. Rowling"]
# 3                ["RWBY", "Harry Potter - J. K. Rowling"]
# 4                        ["Harry Potter - J. K. Rowling"]
# 5                        ["Harry Potter - J. K. Rowling"]
# 6                        ["Harry Potter - J. K. Rowling"]
# 7                        ["Harry Potter - J. K. Rowling"]
# 8                        ["Harry Potter - J. K. Rowling"]
# 9                              ["Harry Potter - Rowling"]
# 10                       ["Harry Potter - J. K. Rowling"]
# 11                       ["Harry Potter - J. K. Rowling"]
# 12                              ["Harry Potter - Fandom"]
# 13                       ["Harry Potter - J. K. Rowling"]
# 14                       ["Harry Potter - J. K. Rowling"]
# 15       ["Harry Potter - J. K. Rowling", "Supernatural"]
# 16                       ["Harry Potter - J. K. Rowling"]
# 17                       ["Harry Potter - J. K. Rowling"]
# 18                       ["Harry Potter - J. K. Rowling"]
# 19                       ["Harry Potter - J. K. Rowling"]
# 20                             ["Harry Potter - Rowling"]
# 21                       ["Harry Potter - J. K. Rowling"]
# 22                       ["Harry Potter - J. K. Rowling"]
# 23                       ["Harry Potter - J. K. Rowling"]
# 24                       ["Harry Potter - J. K. Rowling"]
# 25                       ["Harry Potter - J. K. Rowling"]
# 26                       ["Harry Potter - J. K. Rowling"]
# 27      ["Merlin (TV)", "Sherlock Holmes & Related Fan...
# 28                       ["Harry Potter - J. K. Rowling"]
# 29                       ["Harry Potter - J. K. Rowling"]
# ...                                                   ...
# 179377                   ["Harry Potter - J. K. Rowling"]
# 179378                   ["Harry Potter - J. K. Rowling"]
# 179379  ["Harry Potter - Rowling", "The Prisoner (1967)"]
# 179380                   ["Harry Potter - J. K. Rowling"]
# 179381                   ["Harry Potter - J. K. Rowling"]
# 179382                   ["Harry Potter - J. K. Rowling"]
# 179383                   ["Harry Potter - J. K. Rowling"]
# 179384                   ["Harry Potter - J. K. Rowling"]
# 179385  ["TOLKIEN J. R. R. - Works", "Harry Potter - J...
# 179386                   ["Harry Potter - J. K. Rowling"]
# 179387  ["Harry Potter - J. K. Rowling", "Harry Potter...
# 179388                   ["Harry Potter - J. K. Rowling"]
# 179389                   ["Harry Potter - J. K. Rowling"]
# 179390                   ["Harry Potter - J. K. Rowling"]
# 179391                   ["Harry Potter - J. K. Rowling"]
# 179392                   ["Harry Potter - J. K. Rowling"]
# 179393                   ["Harry Potter - J. K. Rowling"]
# 179394                   ["Harry Potter - J. K. Rowling"]
# 179395                   ["Harry Potter - J. K. Rowling"]
# 179396                   ["Harry Potter - J. K. Rowling"]
# 179397  ["Harry Potter - J. K. Rowling", "One Tree Hill"]
# 179398                   ["Harry Potter - J. K. Rowling"]
# 179399                   ["Harry Potter - J. K. Rowling"]
# 179400      ["Harry Potter - J. K. Rowling", "Ranma 1/2"]
# 179401                   ["Harry Potter - J. K. Rowling"]
# 179402                   ["Harry Potter - J. K. Rowling"]
# 179403                   ["Harry Potter - J. K. Rowling"]
# 179404                   ["Harry Potter - J. K. Rowling"]
# 179405                   ["Harry Potter - J. K. Rowling"]
# 179406                   ["Harry Potter - J. K. Rowling"]
#
#                                              relationship  \
# 0                           ["Remus Lupin/Severus Snape"]
# 1                                                      []
# 2                           ["Draco Malfoy/Harry Potter"]
# 3        ["Ozpin/Harry Potter", "Harry Potter/Voldemort"]
# 4       ["Hermione Granger/Cormac McLaggen", "Sirius B...
# 5                ["Albus Dumbledore/Gellert Grindelwald"]
# 6       ["Draco Malfoy/Harry Potter", "Astoria Greengr...
# 7                      ["Hermione Granger/Severus Snape"]
# 8       ["Harry Potter/Ginny Weasley", "and whoever Ha...
# 9                            ["Sirius Black/Remus Lupin"]
# 10                                                     []
# 11                                                     []
# 12                   ["Bellatrix Lestrange/Draco Malfoy"]
# 13                                 ["Draco Malfoy/Apple"]
# 14                   ["Alastor Moody/Minerva McGonagall"]
# 15                          ["Draco Malfoy/Harry Potter"]
# 16                                                     []
# 17      ["Luna Lovegood & Fate", "Luna Lovegood & Seve...
# 18      ["Draco Malfoy/Harry Potter", "Harry Potter/Se...
# 19                                                     []
# 20                                                     []
# 21                         ["Harry Potter/Severus Snape"]
# 22                           ["Harry Potter/Ron Weasley"]
# 23                          ["Draco Malfoy/Harry Potter"]
# 24      ["Hermione Granger/Harry Potter", "Harry Potte...
# 25      ["Draco Malfoy/Harry Potter", "Severus Snape/S...
# 26      ["Lucius Malfoy/Harry Potter", "Draco Malfoy H...
# 27                                                     []
# 28                              ["Harry Potter/Other(s)"]
# 29      ["Draco Malfoy & Harry Potter", "Sirius Black ...
# ...                                                   ...
# 179377  ["Lavender Brown/Parvati Patil", "Harry Potter...
# 179378  ["Draco Malfoy/Harry Potter", "Hermione Grange...
# 179379                                                 []
# 179380                                                 []
# 179381  ["Hermione Granger/Remus Lupin", "Remus Lupin/...
# 179382                                                 []
# 179383                                                 []
# 179384                      ["Draco Malfoy/Harry Potter"]
# 179385  ["Harry Potter/Ginny Weasley", "Sauron/Aurora ...
# 179386                     ["Harry Potter/Severus Snape"]
# 179387  ["Scorpius Malfoy/Albus Severus Potter", "Scor...
# 179388               ["Minerva McGonagall/Poppy Pomfrey"]
# 179389                       ["Sirius Black/Remus Lupin"]
# 179390                                                 []
# 179391                                                 []
# 179392                                                 []
# 179393                                                 []
# 179394                                                 []
# 179395                                ["Draco/Bellatrix"]
# 179396  ["wolfstar - Relationship", "Sirius Black & Re...
# 179397                                                 []
# 179398                      ["Draco Malfoy/Harry Potter"]
# 179399  ["Sirius Black/Remus Lupin", "Remus Lupin/Nymp...
# 179400  ["Hibiki Ryouga/Kuonji Ukyou", "Saotome Ranma/...
# 179401                  ["Hermione Granger/Draco Malfoy"]
# 179402                                    ["Harry/Draco"]
# 179403                                                 []
# 179404           ["Scorpius Malfoy/Albus Severus Potter"]
# 179405  ["Teddy Lupin/Scorpius Malfoy/Albus Severus Po...
# 179406                     ["Harry Potter/Severus Snape"]
#
#                                                 character  \
# 0                        ["Remus Lupin", "Severus Snape"]
# 1                                                      []
# 2         ["Draco Malfoy", "Harry Potter", "Teddy Lupin"]
# 3       ["Harry Potter", "Voldemort", "Ozpin", "Roman ...
# 4       ["Hermione Granger", "King Perseus - OC", "Sir...
# 5       ["Albus Dumbledore", "Gellert Grindelwald", "A...
# 6       ["Harry Potter", "Draco Malfoy", "Luna Lovegoo...
# 7                   ["Hermione Granger", "Severus Snape"]
# 8       ["Harry Potter", "Ron Weasley", "mentions of.....
# 9         ["Sirius Black", "Remus Lupin", "James Potter"]
# 10      ["Harry Potter", "Blaise Zabini", "Severus Sna...
# 11                  ["Neville Longbottom", "Sorting Hat"]
# 12                ["Bellatrix Lestrange", "Draco Malfoy"]
# 13                              ["Draco Malfoy", "Apple"]
# 14      ["Alastor Moody", "Minerva McGonagall", "Albus...
# 15                       ["Harry Potter", "Draco Malfoy"]
# 16      ["Harry Potter", "Ron Weasley", "Hermione Gran...
# 17                     ["Luna Lovegood", "Severus Snape"]
# 18      ["Harry Potter", "Severus Snape", "Draco Malfo...
# 19                               ["Dobby (Harry Potter)"]
# 20                      ["Bill Weasley", "Molly Weasley"]
# 21                      ["Harry Potter", "Severus Snape"]
# 22                                                     []
# 23      ["Harry Potter", "Draco Malfoy", "Luna Lovegood"]
# 24      ["Harry Potter", "Hermione Granger", "Susan Bo...
# 25      ["Harry Potter", "Draco Malfoy", "Severus Snap...
# 26      ["Lucius Malfoy", "Harry Potter", "Draco Malfoy"]
# 27      ["Arthur Pendragon (Merlin)", "Merlin (Merlin)...
# 28                                                     []
# 29      ["Draco Malfoy", "Harry Potter", "Sirius Black...
# ...                                                   ...
# 179377                                                 []
# 179378  ["Harry Potter", "Hermione Granger", "Pansy Pa...
# 179379  ["Harry Potter", "Number Six (The Prisoner)", ...
# 179380                   ["Harry Potter", "Sirius Black"]
# 179381  ["Hermione Granger", "Remus Lupin", "Lily Evans"]
# 179382                 ["Fred Weasley", "George Weasley"]
# 179383  ["Harry Potter", "Sirius Black", "Remus Lupin"...
# 179384  ["Harry Potter", "Hermione Granger", "Blaise Z...
# 179385  ["Sauron", "Ginny Weasley", "The Weasley Famil...
# 179386  ["Harry Potter", "Hermione Granger", "Ron Weas...
# 179387  ["Albus Severus Potter", "Scorpius Malfoy", "H...
# 179388                                                 []
# 179389                    ["Sirius Black", "Remus Lupin"]
# 179390              ["Neville Longbottom", "Argus Filch"]
# 179391                                  ["Severus Snape"]
# 179392  ["Vernon Dursley", "Harry Potter", "Original C...
# 179393  ["Harry Potter", "Tom Marvolo Riddle", "Voldem...
# 179394                                    ["Remus Lupin"]
# 179395              ["Lucius Malfoy", "Hermione Granger"]
# 179396  ["Remus Lupin", "Sirius Black", "Marauders (Ha...
# 179397  ["Lily Evans Potter", "Lucas Scott", "Nathan S...
# 179398                   ["Harry Potter", "Draco Malfoy"]
# 179399  ["Remus Lupin", "Sirius Black", "Nymphadora To...
# 179400  ["Harry Potter", "Hibiki Ryouga", "Saotome Ran...
# 179401               ["Hermione Granger", "Draco Malfoy"]
# 179402                   ["Harry Potter", "Draco Malfoy"]
# 179403  ["Tom Riddle | Voldemort", "Harry Potter", "Ro...
# 179404  ["Albus Severus Potter", "Scorpius Malfoy", "L...
# 179405  ["Albus Potter", "Teddy Lupin", "Scorpius Malf...
# 179406                  ["Harry Potter", "Severus Snape"]
#
#                                           additional tags  ...   kudos  \
# 0                                             ["pre-HBP"]  ...   109.0
# 1       ["Alternate Universe", "Alternate Universe - C...  ...  1773.0
# 2                                     ["Suicide Attempt"]  ...   321.0
# 3       ["Harry Potter is Voldemort's Child", "Harry i...  ...   139.0
# 4       ["Yona of the Dawn retelling", "High Fantasy",...  ...     8.0
# 5       ["Slash", "Justification", "Unhealthy Relation...  ...    21.0
# 6            ["Infidelity", "Background Het", "Anal Sex"]  ...    98.0
# 7       ["Potions", "Potions Accident", "unapologetic ...  ...    21.0
# 8       ["Best Friends", "Implied Sexual Content", "ar...  ...     1.0
# 9                            ["Ficlet", "Angst", "Drama"]  ...    25.0
# 10                   ["Alternate Universe - Time Travel"]  ...    41.0
# 11      ["Book 7: Harry Potter and the Deathly Hallows...  ...    13.0
# 12      ["Community: deflower_draco", "Blackcest", "In...  ...    43.0
# 13                        ["Nonsense", "Love", "Secrets"]  ...     6.0
# 14      ["Canon-Typical Violence", "Character Death", ...  ...     2.0
# 15      ["Cross Over", "Harry potter characters insert...  ...   124.0
# 16                               ["Harry Potter mystery"]  ...     NaN
# 17      ["The future is terrifying", "After the third ...  ...    18.0
# 18      ["Slash sex", "Sexual Content", "Alternate Uni...  ...     NaN
# 19                       ["Slash sex", "Humor", "Parody"]  ...     NaN
# 20         ["Family", "One Shot", "Wordcount: 100-1.000"]  ...    11.0
# 21      ["Slash sex", "Sexual Content", "Angst", "Trag...  ...     1.0
# 22                ["Slash", "Humor", "Parody", "Romance"]  ...     4.0
# 23      ["Torture", "Romance", "Angst", "Friendship", ...  ...   440.0
# 24      ["Explicit Sexual Content", "Explicit Language...  ...   588.0
# 25      ["possible light side bashing", "not much thou...  ...    39.0
# 26      ["Dumbledore Bashing", "Ron Bashing", "Hermion...  ...   512.0
# 27      ["Reincarnation", "POV First Person", "Doctor ...  ...    12.0
# 28      ["Slash", "Explicit Language", "Out of Charact...  ...     1.0
# 29      ["Drarry", "Guardianes del Tiempo", "Cambios e...  ...     4.0
# ...                                                   ...  ...     ...
# 179377  ["Hermione Bashing", "Ginny Bashing", "Ron Bas...  ...   216.0
# 179378  ["Slash sex", "Out of Character", "Sexual Cont...  ...     5.0
# 179379                                                 []  ...    39.0
# 179380  ["Explicit Language", "Slash sex", "Drug Use",...  ...     NaN
# 179381  ["Not Canon Compliant", "including a non-canon...  ...    44.0
# 179382  ["Slash sex", "Incest", "Out of Character", "S...  ...     2.0
# 179383  ["Alternate Universe - Canon Divergence", "Min...  ...    16.0
# 179384  ["Slash", "Explicit Language", "Out of Charact...  ...    17.0
# 179385  ["Adventure", "Romance", "Unexpected Friendshi...  ...   100.0
# 179386  ["Slash", "Explicit Language", "Sexual Content...  ...    21.0
# 179387  ["Angst", "I'm Sorry", "The Author Regrets Eve...  ...   179.0
# 179388                                                 []  ...    40.0
# 179389  ["Pansexual Remus", "Mention of misgendering",...  ...   187.0
# 179390  ["Canonical Character Death", "Dark Arts", "Sq...  ...    11.0
# 179391   ["Art", "Portraiture", "Drawing", "Mixed Media"]  ...    34.0
# 179392  ["Explicit Language", "Drug Use", "Self-Harm",...  ...     1.0
# 179393  ["School Life", "ghost story", "Gothic", "wint...  ...    21.0
# 179394      ["Art", "Pencil", "Figure Drawing", "Nudity"]  ...    14.0
# 179395                                        ["Darkfic"]  ...     3.0
# 179396  ["remus is sad but his whole life was sad so",...  ...    14.0
# 179397  ["Alternate Universe - Harry Potter Setting", ...  ...     2.0
# 179398  ["Humor", "Friendship", "Possibly Pre-Slash", ...  ...    14.0
# 179399  ["Fluff and Angst", "Magical Tattoos", "Canoni...  ...    73.0
# 179400  ["One Shot Collection", "Alternate Universe", ...  ...    34.0
# 179401                                                 []  ...    19.0
# 179402                                                 []  ...    23.0
# 179403                                ["Angst and Humor"]  ...    15.0
# 179404  ["Humor", "Angst", "Slash", "Boys Will Be Boys...  ...  1777.0
# 179405  ["Threesome - M/M/M", "Harry Potter Next Gener...  ...     3.0
# 179406                    ["Angst", "Tragedy", "Romance"]  ...     5.0
#
#        bookmarks      hits chapter_count  \
# 0           10.0    2773.0             1
# 1           61.0   27154.0             1
# 2           57.0    4880.0             1
# 3           27.0    6690.0            21
# 4            2.0     279.0             1
# 5            1.0     816.0             1
# 6           17.0    2517.0             1
# 7            NaN    1323.0             1
# 8            1.0     272.0             1
# 9            6.0     731.0             1
# 10          28.0    1141.0            21
# 11           1.0     206.0             1
# 12           5.0    4991.0             1
# 13           NaN      86.0             1
# 14           NaN     205.0             1
# 15          19.0    2894.0             1
# 16           NaN      47.0             1
# 17           1.0     292.0             1
# 18           NaN      52.0             1
# 19           1.0      99.0             1
# 20           NaN     286.0             1
# 21           NaN     173.0             1
# 22           2.0     113.0             1
# 23          99.0    4383.0             3
# 24          94.0  104814.0             6
# 25           8.0    1916.0             6
# 26         108.0   25743.0            11
# 27           1.0     354.0             1
# 28           NaN      19.0             1
# 29           NaN      73.0             1
# ...          ...       ...           ...
# 179377      20.0    7784.0            21
# 179378       NaN     379.0             6
# 179379      14.0     779.0             3
# 179380       NaN      81.0             2
# 179381       6.0     620.0             1
# 179382       NaN      89.0             3
# 179383       3.0     503.0            80
# 179384       2.0     403.0             3
# 179385      23.0    2497.0            25
# 179386       4.0     450.0             1
# 179387      14.0    2880.0             1
# 179388       3.0     584.0             1
# 179389      12.0    2730.0             1
# 179390       1.0     116.0             1
# 179391       1.0     564.0             1
# 179392       NaN      18.0             1
# 179393       9.0   13652.0             6
# 179394       NaN     606.0             1
# 179395       2.0     278.0             2
# 179396       1.0     297.0             1
# 179397       NaN      31.0             1
# 179398       NaN     523.0             1
# 179399       6.0     816.0             1
# 179400       9.0    1521.0             6
# 179401       1.0    3429.0             1
# 179402       3.0    1541.0             2
# 179403       2.0     216.0             1
# 179404     369.0   26338.0             2
# 179405       2.0     801.0             2
# 179406       2.0      86.0             1
#
#                                          series  seriespart  seriesid  \
# 0                                           NaN         NaN       NaN
# 1                           Stealing Harryverse        12.0   58157.0
# 2                                           NaN         NaN       NaN
# 3                              Children of Grim         1.0  810846.0
# 4                                           NaN         NaN       NaN
# 5       A Breath of Romance, A Twist of Despair         1.0   59048.0
# 6                                           NaN         NaN       NaN
# 7       A Breath of Romance, A Twist of Despair         2.0   59048.0
# 8                                           NaN         NaN       NaN
# 9                                           NaN         NaN       NaN
# 10                                          NaN         NaN       NaN
# 11                                          NaN         NaN       NaN
# 12                                          NaN         NaN       NaN
# 13                                          NaN         NaN       NaN
# 14                                          NaN         NaN       NaN
# 15                                          NaN         NaN       NaN
# 16                                          NaN         NaN       NaN
# 17                Mary Potter Shorts/Background        12.0  442555.0
# 18                                          NaN         NaN       NaN
# 19                                          NaN         NaN       NaN
# 20                           genhp_ldws entries         6.0    3639.0
# 21                                          NaN         NaN       NaN
# 22                                          NaN         NaN       NaN
# 23                                          NaN         NaN       NaN
# 24                                          NaN         NaN       NaN
# 25                                          NaN         NaN       NaN
# 26                                          NaN         NaN       NaN
# 27                                          NaN         NaN       NaN
# 28                                          NaN         NaN       NaN
# 29                                          NaN         NaN       NaN
# ...                                         ...         ...       ...
# 179377                                      NaN         NaN       NaN
# 179378                                      NaN         NaN       NaN
# 179379                                      NaN         NaN       NaN
# 179380                                      NaN         NaN       NaN
# 179381                                      NaN         NaN       NaN
# 179382                                      NaN         NaN       NaN
# 179383                                 Innocent         1.0  669584.0
# 179384                                      NaN         NaN       NaN
# 179385         Tales From The Unlikely Universe         1.0   59019.0
# 179386                                      NaN         NaN       NaN
# 179387                The Chronicles of Scorbus         2.0  656570.0
# 179388                                      NaN         NaN       NaN
# 179389                                      NaN         NaN       NaN
# 179390                                      NaN         NaN       NaN
# 179391                                      NaN         NaN       NaN
# 179392                                      NaN         NaN       NaN
# 179393                                      NaN         NaN       NaN
# 179394                                      NaN         NaN       NaN
# 179395                                      NaN         NaN       NaN
# 179396                                      NaN         NaN       NaN
# 179397                              Salty Sweet         2.0  673373.0
# 179398                     Malfoy Sensibilities         2.0   58728.0
# 179399                                      NaN         NaN       NaN
# 179400                             Harry Hibiki         2.0   44397.0
# 179401                                      NaN         NaN       NaN
# 179402                                      NaN         NaN       NaN
# 179403                                      NaN         NaN       NaN
# 179404                                      NaN         NaN       NaN
# 179405                                      NaN         NaN       NaN
# 179406                                      NaN         NaN       NaN
#
#                                                   summary  \
# 0       After the battle, the survivors regroup.\nWrit...
# 1       My notes and fic excerpts for the end of Laoco...
# 2       An unfortunate circumstance means that Harry g...
# 3       Voldemort and Bellatrix had a set of triplets ...
# 4       On the eve of her 17th birthday, she confesses...
# 5       Disclaimer: I own nothing.\nAgainst the world,...
# 6       When Harry joins Luna and Rolf on an expeditio...
# 7       Disclaimer: I own nothing.\n"Use your mind," h...
# 8       Ron is listening to a muggle rock band on an o...
# 9       What would've happened if James didn't rescue ...
# 10      In 2013, Harry and Blaise travel to the past (...
# 11      What secret conversation went on inside the ha...
# 12      Now, I can put a name to my crimes and curses....
# 13          Mankind can fall for the strangest of desires
# 14                                                    NaN
# 15      DMHP. Slash. Supernatural AU. Harry is a Hunte...
# 16      Harry has a vision of a man who needs help, af...
# 17      Luna Lovegood does what she can to ensure that...
# 18            What if Harry's life begins with his death?
# 19         Oneshot... Dobby gives Dumbledore some relief.
# 20      An unexpected reaction to an unexpected moment...
# 21      After gracefully punching one of the Ministry'...
# 22          Ron and Harry find what they are looking for.
# 23      Draco is home for Easter during his 7th year a...
# 24      This is a series that has Harry on patrol as a...
# 25      I might have said it before, but love makes yo...
# 26                Harry and Lucius are mates. How? Magic.
# 27      In the space between lives, there is a lot of ...
# 28      random fic about my half vampire character sha...
# 29      Nadie, ni siquiera el mago más poderoso del mu...
# ...                                                   ...
# 179377  All drabbles based on various prompts, mostly ...
# 179378  As much as they don't want it to be, something...
# 179379  Number 6 moves next door to Harry Potter, and ...
# 179380  In Harry's 5th year when Sirius fell through t...
# 179381  Remus detects many similarities between Hermio...
# 179382  A response to a challenge posted by Mirrorhany...
# 179383  [TRADUÇÃO] O Sr. e a Sr. Dursley, da rua dos A...
# 179384  Harry and Hermonie show up at Hogwarts with a ...
# 179385  Thrown into the Void as a bodiless fëa, Sauron...
# 179386  Sable is a cross-dressing prostitute. Severus ...
# 179387  Albus can see that she isn't right for Scorpiu...
# 179388  When Minerva retires, years from now, she will...
# 179389  Remus Lupin has many crushes. But in the end, ...
# 179390  Disclaimer: I own nothing.\nArgus Filch's hear...
# 179391  Tinted gesso on wood for background. Charcoal ...
# 179392  A new girl, Silver King, moves onto Harry's bl...
# 179393  Harry should have been concentrating on Sirius...
# 179394               Remus has a lie-in after The Change.
# 179395  AU set four years after HBP.  Cut off from the...
# 179396  Remus first notices the rain at age five and c...
# 179397  Several fourth to seventh years are found slau...
# 179398  Because the second time around is so much swee...
# 179399  Remus agrees to get a tattoo on one condition:...
# 179400  A series of one-shots detailing the years of H...
# 179401     A smutty one-shot. AU. Adult, rated for lemon.
# 179402  Death is away on his honeymoon and Harry is fo...
# 179403  My creative insane and horrendous take on how ...
# 179404  Scorpius figured that turning down Albus Sever...
# 179405  When Teddy, Scorpius and Albus embark on a lif...
# 179406  The war is over and so much was lost.  What co...
#
#                                             preface_notes  \
# 0       Thanks to Louise Lux for her thorough and thou...
# 1                                                     NaN
# 2       This was written for the Dracotops_Harry Fest ...
# 3                                                     NaN
# 4       This HP AU follows a similar, but still diverg...
# 5                                                     NaN
# 6       This was written for the HD-Tropes fest, and t...
# 7                                                     NaN
# 8                                                     NaN
# 9       Another one of those "What if" fics . . . anot...
# 10      Time Travel Story!\nPremise: Harry and Blaise,...
# 11                  Originally written on August 3, 2007.
# 12                                                    NaN
# 13                                                    NaN
# 14                                                    NaN
# 15                                                    NaN
# 16                                                    NaN
# 17                                                    NaN
# 18      Note from SeparatriX, the archivist: this stor...
# 19      Note from SeparatriX, the archivist: this stor...
# 20      Written for the HP Gen Last Drabble Writer Sta...
# 21      Note from SeparatriX, the archivist: this stor...
# 22      Note from SeparatriX, the archivist: this stor...
# 23                                                    NaN
# 24                                                    NaN
# 25      Disclaimer:\nI am not getting paid to write th...
# 26      I am in the process of editing and reposting t...
# 27      Merlin's P.O.V. in first person\nAlso, un-beta...
# 28      Note from SeparatriX, the archivist: this stor...
# 29      Disclaimer: He de aclarar desde un principio q...
# ...                                                   ...
# 179377  Notes: The collection is going to be either sl...
# 179378  Note from SeparatriX, the archivist: this stor...
# 179379  Disclaimer: [Insert witty comment here] Neithe...
# 179380  Note from SeparatriX, the archivist: this stor...
# 179381                                                NaN
# 179382  Note from SeparatriX, the archivist: this stor...
# 179383  Eu já estou postando essa tradução em outro si...
# 179384  Note from SeparatriX, the archivist: this stor...
# 179385                                                NaN
# 179386  Note from SeparatriX, the archivist: this stor...
# 179387                                                NaN
# 179388  While I freely disregard pottermore, I'm entir...
# 179389                                                NaN
# 179390                                                NaN
# 179391                                                NaN
# 179392  Note from SeparatriX, the archivist: this stor...
# 179393                                                NaN
# 179394                                                NaN
# 179395  Thanks to Youroctober for beta reading.  Writt...
# 179396                my first fic here so be nice please
# 179397  Title: Salty Sweet - Book Two\nA/N: AU fic, st...
# 179398  Disclaimer: Malfoy Sensibilities II is based o...
# 179399                                                NaN
# 179400                                                NaN
# 179401                                                NaN
# 179402                                                NaN
# 179403  A/N this is a crack fic, this was made purely ...
# 179404                                                NaN
# 179405                                                NaN
# 179406  Note from SeparatriX, the archivist: this stor...
#
#                                           afterword_notes
# 0                                                     NaN
# 1       And that's the end. Thanks for reading, everyo...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# 6                                                     NaN
# 7                                                     NaN
# 8       The song is real called "Your Sister Does" fro...
# 9                                                     NaN
# 10                                                    NaN
# 11                                                    NaN
# 12                                                    NaN
# 13                                                    NaN
# 14                                                    NaN
# 15      So there might be a sequel. There might not. I...
# 16                                                    NaN
# 17                                                    NaN
# 18                                                    NaN
# 19                                                    NaN
# 20                                                    NaN
# 21                                                    NaN
# 22                                                    NaN
# 23                                                    NaN
# 24                                                    NaN
# 25                                                    NaN
# 26      I am very interested in knowing what my reader...
# 27                                                    NaN
# 28                                                    NaN
# 29      Notas después del capítulo:\n1.   Les agradezc...
# ...                                                   ...
# 179377                                                NaN
# 179378                                                NaN
# 179379                                                NaN
# 179380                                                NaN
# 179381                                                NaN
# 179382                                                NaN
# 179383                                                NaN
# 179384                                                NaN
# 179385                                                NaN
# 179386                                                NaN
# 179387  I sorta let myself run away with this one so I...
# 179388                                                NaN
# 179389                                                NaN
# 179390                                                NaN
# 179391                                                NaN
# 179392                                                NaN
# 179393                                                NaN
# 179394                                                NaN
# 179395                                                NaN
# 179396                            thank you for reading!!
# 179397  This is all that I have to write for this stor...
# 179398  Reference/s:\nAunt Durilda – is a tribute to t...
# 179399                                                NaN
# 179400                                                NaN
# 179401                                                NaN
# 179402                                                NaN
# 179403                                                NaN
# 179404                                                NaN
# 179405                                                NaN
# 179406                                                NaN
#
# [179407 rows x 26 columns]

# %%
# Check fic overlap
print(len(set(char_fic_feats['fic_id']).intersection(set(metadata['fic_id']))))
print(len(char_fic_feats['fic_id'].unique()))
# Out:
# 66061
# 66061

# %%
# Merge
merged = pd.merge(char_fic_feats, metadata, on=['fic_id'])
print(len(char_fic_feats))
print(len(merged))
# Out:
# 279166
# 279166

# %%
import re

re.split(r'[\/ ]', 'Remus Lupin/Sirius Black')
# Out:
# ['Remus', 'Lupin', 'Sirius', 'Black']

# %%
# Load canonical list of characters
char_list_fpath = '/projects/fanfiction_gender_roles/scripts/harrypotter_characters.txt'

with open(char_list_fpath) as f:
    canonical_characters = f.read().splitlines()

extra = ['Dobby']
remove = ['Hogwarts', 'Slytherin', 'Gryffindor', 'Order', 'The',
         'The Slytherin',
          'The Headmaster',
         ]
canonical_characters += extra
canonical_characters = [c for c in canonical_characters if not c in remove]

canonical_character_name_parts = set([part for name in canonical_characters for part in name.split()])
exclude = set(['The'])
canonical_character_name_parts -= exclude
# print(len(canonical_character_name_parts))
# list(canonical_character_name_parts)[:10]

remove = ['Hogwarts', 'Slytherin', 'Gryffindor', 'Order', 'The',
         'The Slytherin',
          'The Headmaster',
          'Weasley', # ambiguous
          'Weasleys',
          'Hufflepuff',
         ]

name_transform = { # Might then miss when stories use these terms, though (same with canonicalize): might want to spread gender info afterward
    'Potter': 'Harry Potter',
    'Mr. Potter': 'Harry Potter',
    'Mr Potter': 'Harry Potter',
    'The Harry': 'Harry Potter',
    'Mr Weasley': 'Ron Weasley',
    'Tom': 'Tom Riddle',
    'Black': 'Sirius Black',
    'The Draco': 'Draco Malfoy',
    'The Dark Lord': 'Voldemort',
    'The Dark Lord Voldemort': 'Voldemort',
    'Dark Lord': 'Voldemort',
    'Lord': 'Voldemort',
    'Malfoy': 'Draco Malfoy',
    'James': 'James Potter I',
    'James Potter': 'James Potter I',
    'Lily': 'Lily J. Potter',
    'Albus': 'Albus Dumbledore',
    'Teddy': 'Teddy Lupin',
    'Newt': 'Newton Scamander',
    'Rose': 'Rose Granger-Weasley',
    'Lily Potter': 'Lily J. Potter',
    'Regulus': 'Regulus Black I',
    'Mrs Weasley': 'Molly Weasley',
}
    

def canonicalize(name):
    
    name_parts = name.split()
    new_name_parts = []
    
    for name_part in name_parts:
        if name_part in canonical_character_name_parts:
            new_name_parts.append(name_part)
            
    new_name = ' '.join(new_name_parts)
    
    if new_name in remove:
        new_name = ''
        
    if new_name in name_transform:
        new_name = name_transform[new_name]
            
    return new_name

# %%
# Load character gender dictionary

import json

with open('/data/fanfiction_gender_roles/harrypotter_ao3/hp_character_genders.json', 'r') as f:
    character_gender = json.load(f)

# %%
from IPython.core.debugger import set_trace
import re

# TODO: consider relationships with more than 2 characters differently
def char_in_relationship(char, rel):
    
    match = False
    rel_type = 'character_not_in_relationship'
    
    char_parts = set([c.lower() for c in char.split()])
    
    # Is the character in a relationship?
    for relationship in eval(rel):
        if not '/' in relationship: continue # isn't romantic
        rel_parts = set([c.lower() for c in re.split(r'[\/ ]', relationship)])
#         set_trace()
        if len(char_parts.intersection(rel_parts)) > 0:
            match = True
            
            # Determine other character in relationship and their gender
            rel_chars = relationship.split('/')
            other_char = ''
            for rel_char in rel_chars:
                if not any([char_part in rel_char.lower() for char_part in char_parts]):
                    other_char = canonicalize(rel_char)
                    
            # Determine gender of char, other char in relationship
            char_gender = character_gender[canonicalize(char)]
            if not other_char in character_gender: # other char gender unknown
                rel_type = 'unknown'
            else:
                other_char_gender = character_gender[other_char]
            
                if char_gender != other_char_gender:
                    rel_type = 'straight'

                else:
                    rel_type = 'queer'
    
            break
    
    return (match, rel_type)

# %%
print(char_in_relationship('Sirius', '["Remus Lupin/Sirius Black"]'))
print(char_in_relationship('Hermione', '["Hermione Granger/Draco Malfoy", "Fleur Delacour/Bill Weasley", "Arthur Weasley/Molly Weasley", "Lucius Malfoy/Narcissa Black Malfoy", "Katie Bell/Marcus Flint"]'))
print(char_in_relationship('Snape', '["Severus Snape/Original Female Character"]'))
# Out:
# (True, 'queer')
# (True, 'straight')
# (True, 'unknown')

# %%
merged['character_in_relationship'], merged['character_in_relationship_type'] = list(zip(*[char_in_relationship(tup[0], tup[1]) for tup in zip(merged['character_original'], merged['relationship'])]))
print(merged['character_in_relationship'].sum())
merged['character_in_relationship_type'].value_counts()
# Out:
# 93077
# character_not_in_relationship    186089
# queer                            56580
# straight                         32448
# unknown                          4049
# Name: character_in_relationship_type, dtype: int64

# %%
merged.drop(columns=['char_in_relationship'], inplace=True)
merged.columns
# Out:
# Index(['fic_id', 'character_original', 'character_canonical',
#        'character_gender', 'character_features', 'title', 'author',
#        'author_key', 'rating', 'category', 'fandom', 'relationship',
#        'character', 'additional tags', 'language', 'published', 'status',
#        'status date', 'words', 'comments', 'kudos', 'bookmarks', 'hits',
#        'chapter_count', 'series', 'seriespart', 'seriesid', 'summary',
#        'preface_notes', 'afterword_notes', 'character_in_relationship',
#        'character_in_relationship_type'],
#       dtype='object')

# %%
# Check char in relationship labeling
pd.set_option('display.max_colwidth', -1)
merged[merged['character_in_relationship']==False].sample(10).loc[:, ['fic_id', 'character_original', 'relationship']]
# Out:
#           fic_id character_original  \
# 171347  8209547   Harry
# 218808  12084768  Harry
# 60664   712827    Hermione
# 41445   12962706  Harry
# 99129   635844    Neville
# 36039   3374774   Hermione
# 113080  3330665   Albus
# 52758   5295572   Minerva
# 102685  233961    Alicia
# 83053   1525373   Diggory
#
#                                                               relationship
# 171347  ["Teddy Lupin/Victoire Weasley", "Teddy Lupin & Victoire Weasley"]
# 218808  []
# 60664   []
# 41445   ["Hermione Granger/Ginny Weasley"]
# 99129   ["Harry Potter/Severus Snape"]
# 36039   ["Draco Malfoy/Harry Potter"]
# 113080  []
# 52758   ["Sirius Black/Remus Lupin", "Draco Malfoy/Harry Potter"]
# 102685  ["Katie Bell/Marcus Flint"]
# 83053   ["Roger Davies/Fleur Delacour"]

# %%
# Check char in relationship labeling
pd.set_option('display.max_colwidth', -1)
merged[merged['character_in_relationship']==True].sample(10).loc[:, ['fic_id', 'character_original', 'relationship']]
# Out:
#           fic_id character_original  \
# 149409  1651082   Harry
# 169998  14869499  Tonks
# 200983  6267799   Ron
# 58186   2595152   Malfoy
# 105711  248997    Sybill
# 139083  14923379  Bill
# 209325  3325496   Harry
# 79070   573057    Hermione
# 116194  891078    Remus
# 239538  374732    Severus
#
#                                                                                                                                                                                                                                                                                                                       relationship
# 149409  ["Harry Potter/Severus Snape"]
# 169998  ["Remus Lupin/Nymphadora Tonks"]
# 200983  ["Harry Potter/Ron Weasley"]
# 58186   ["Draco Malfoy/Harry Potter"]
# 105711  ["Severus Snape/Sybill Trelawney"]
# 139083  ["Draco Malfoy/Harry Potter", "Luna Lovegood/Ginny Weasley", "Hermione Granger/Ron Weasley", "Angelina Johnson/George Weasley", "Fleur Delacour/Bill Weasley", "Arthur Weasley/Molly Weasley"]
# 209325  ["Hermione Granger & Harry Potter & Ron Weasley", "Hermione Granger & Harry Potter", "Hermione Granger & Ron Weasley", "Harry Potter & Ron Weasley", "Fred Weasley & George Weasley & Lee Jordan", "lightly implied Harry Potter/Draco Malfoy flirtatious rivalry", "weasley family - Relationship", "General Friendship"]
# 79070   ["Hermione Granger/Draco Malfoy"]
# 116194  ["Remus Lupin/Severus Snape"]
# 239538  ["Remus Lupin/Severus Snape"]

# %%
# Check relationship type labeling
from IPython.display import display

for rel_type in ['unknown', 'queer', 'straight']:
    display(merged[merged['character_in_relationship_type'] == rel_type].sample(10).loc[:, ['character_in_relationship_type', 'fic_id', 'character_original', 'relationship', 'category']])
# Out:
#        character_in_relationship_type    fic_id character_original  \
# 217559  unknown                        4001998   Draco
# 142184  unknown                        16201475  Potter
# 160804  unknown                        875827    Harry
# 168816  unknown                        14263503  Druella
# 139436  unknown                        7866745   Draco
# 45865   unknown                        14615643  Charlie
# 196113  unknown                        422526    Harry
# 14214   unknown                        653867    Bill
# 197042  unknown                        2590781   Harry
# 230475  unknown                        4351493   Severus
#
#                                                                                                                                                                          relationship  \
# 217559  ["Draco Malfoy/Alex Russo"]
# 142184  ["James Potter/Lily Evans Potter"]
# 160804  ["Harry Potter/Half-Blood Prince"]
# 168816  ["Druella Rosier Black & Narcissa Black Malfoy", "Cygnus Black/Druella Rosier Black", "Lucius Malfoy/Narcissa Black Malfoy", "Narcissa Black Malfoy & Andromeda Black Tonks"]
# 139436  ["Draco Malfoy/Other(s)", "Voldemort/Other(s)"]
# 45865   ["Charlie Weasley/Original Female Character(s)"]
# 196113  ["Harry/Teddy - Relationship"]
# 14214   ["Nymphadora Tonks/Charlie Weasley", "Bill Weasley/Original Female Character"]
# 197042  ["Spock/Harry Potter", "James T. Kirk/Leonard McCoy"]
# 230475  ["Severus Snape/OFC"]
#
#        category
# 217559  ["F/M"]
# 142184  ["F/M"]
# 160804  ["M/M"]
# 168816  ["Gen"]
# 139436  []
# 45865   ["F/M"]
# 196113  ["M/M"]
# 14214   ["F/M"]
# 197042  ["M/M"]
# 230475  ["F/M"]
#        character_in_relationship_type    fic_id character_original  \
# 80194   queer                          580094    Sirius
# 40388   queer                          622356    Draco
# 181895  queer                          10052486  Severus
# 40676   queer                          55315     Draco
# 94827   queer                          10060838  Tom
# 95008   queer                          10190321  Harry
# 95305   queer                          81277     Draco
# 277426  queer                          14342685  Harry
# 3671    queer                          292770    Hagrid
# 218241  queer                          14221179  Bill
#
#                                                                                                        relationship  \
# 80194   ["Sirius Black/Remus Lupin"]
# 40388   ["Draco Malfoy/Harry Potter"]
# 181895  ["Harry Potter/Severus Snape"]
# 40676   ["Harry Potter/Draco Malfoy"]
# 94827   ["Fred Weasley/George Weasley/Other(s)", "Harry Potter/Tom Riddle", "Hermione Granger/Ron Weasley"]
# 95008   ["Draco Malfoy/Harry Potter", "Lucius Malfoy/Harry Potter"]
# 95305   ["Harry/Draco"]
# 277426  ["Draco Malfoy/Harry Potter"]
# 3671    ["Rubeus Hagrid/Severus Snape"]
# 218241  ["Original Percival Graves/Newt Scamander", "Rolf Scamander/Bill Weasley", "Tina Goldstein/Newt Scamander"]
#
#                        category
# 80194   ["M/M"]
# 40388   ["M/M"]
# 181895  ["M/M", "Gen"]
# 40676   ["M/M"]
# 94827   ["M/M", "Multi", "F/M"]
# 95008   ["M/M"]
# 95305   ["M/M"]
# 277426  ["M/M"]
# 3671    ["M/M"]
# 218241  ["Gen", "M/M", "F/M"]
#        character_in_relationship_type    fic_id character_original  \
# 197683  straight                       10764942  Harry
# 24843   straight                       8725459   James
# 206290  straight                       6333055   Harry
# 68748   straight                       6059362   Fleur
# 114085  straight                       9780308   Hermione
# 169491  straight                       8387506   Hermione
# 171642  straight                       15831033  Draco
# 30434   straight                       15759117  Ginny
# 56260   straight                       703770    Harry
# 58718   straight                       1748846   Astoria
#
#                                                                                            relationship  \
# 197683  ["Harry Potter/Nymphadora Tonks"]
# 24843   ["James Potter/Lily Evans", "James Potter/Lily Evans Potter"]
# 206290  ["Hermione Granger/Harry Potter"]
# 68748   ["Fleur Delacour/Bill Weasley", "Hermione Granger/Ron Weasley"]
# 114085  ["Hermione Granger/Ron Weasley", "Ron Weasley & Hugo Weasley"]
# 169491  ["Draco Malfoy/Harry Potter", "Hermione Granger/Ron Weasley", "Pansy Parkinson/Blaise Zabini"]
# 171642  ["Hermione Granger/Draco Malfoy"]
# 30434   ["Harry Potter/Ginny Weasley"]
# 56260   ["Harry Potter/Ginny Weasley", "Harry Potter/Charlie Weasley", "Hermione Granger/Harry Potter"]
# 58718   ["Harry/Draco", "Astoria Greengrass/Draco Malfoy"]
#
#               category
# 197683  ["F/M"]
# 24843   ["F/M"]
# 206290  ["F/M"]
# 68748   ["F/M", "Gen"]
# 114085  ["Gen"]
# 169491  ["F/M", "M/M"]
# 171642  ["F/M"]
# 30434   ["F/M"]
# 56260   ["F/M", "M/M"]
# 58718   ["M/M"]

# %%
# Save out annotated data
outpath = f'/data/fanfiction_gender_roles/harrypotter_ao3/{dataset_name}/output/character_relationship_features.csv'
merged.to_csv(outpath, index=False)

# %% [markdown]
# ## Annotate character gender

# %%
# Annotate characters for gender (quickly, just with lexicon)
# Load all character names

import json
import os
from collections import Counter
from tqdm import tqdm_notebook as tqdm
from IPython.core.debugger import set_trace

dataset_name = 'complete_en_1k-50k'
pipeline_output_path = f'/data/fanfiction_gender_roles/harrypotter_ao3/{dataset_name}/output/'
output_dirpath = os.path.join(pipeline_output_path, 'char_features')

character_names = []

for fname in tqdm(sorted(os.listdir(output_dirpath))):
    with open(os.path.join(output_dirpath, fname)) as f:
        char_features = json.load(f)
              
    character_names.extend(list(char_features.keys()))
              
len(character_names)
# Out:
# HBox(children=(IntProgress(value=0, max=71943), HTML(value='')))
# 944371

# %%
with open('/data/fanfiction_gender_roles/tmp/hp_character_names.json', 'w') as f:
    json.dump(character_names, f)

# %%
character_names_ctr = Counter(character_names)
print(len(character_names_ctr))

# Refine characters
# characters_ctr_filtered = [el for el in character_names_ctr.most_common() if el[0] != '' and el[1] > 1]
characters_ctr_filtered = Counter({name: count for name,count in character_names_ctr.items() if name != '' and count > 1})
len(characters_ctr_filtered)

# Load canonical list of characters
char_list_fpath = '/projects/fanfiction_gender_roles/scripts/harrypotter_characters.txt'
with open(char_list_fpath) as f:
    canonical_characters = f.read().splitlines()
    
extra = ['Dobby']
remove = ['Hogwarts', 'Slytherin', 'Gryffindor', 'Order', 'The',
         'The Slytherin',
          'The Headmaster',
         ]
canonical_characters += extra
canonical_characters = [c for c in canonical_characters if not c in remove]

len(canonical_characters)
# Out:
# 116251
# 245

# %%
canonical_character_name_parts = set([part for name in canonical_characters for part in name.split()])
exclude = set(['The'])
canonical_character_name_parts -= exclude
# print(len(canonical_character_name_parts))
# list(canonical_character_name_parts)[:10]

remove = ['Hogwarts', 'Slytherin', 'Gryffindor', 'Order', 'The',
         'The Slytherin',
          'The Headmaster',
          'Weasley', # ambiguous
          'Weasleys',
          'Hufflepuff',
         ]

name_transform = { # Might then miss when stories use these terms, though (same with canonicalize): might want to spread gender info afterward
    'Potter': 'Harry Potter',
    'Mr. Potter': 'Harry Potter',
    'Mr Potter': 'Harry Potter',
    'The Harry': 'Harry Potter',
    'Mr Weasley': 'Ron Weasley',
    'Tom': 'Tom Riddle',
    'Black': 'Sirius Black',
    'The Draco': 'Draco Malfoy',
    'The Dark Lord': 'Voldemort',
    'The Dark Lord Voldemort': 'Voldemort',
    'Dark Lord': 'Voldemort',
    'Lord': 'Voldemort',
    'Malfoy': 'Draco Malfoy',
    'James': 'James Potter I',
    'James Potter': 'James Potter I',
    'Lily': 'Lily J. Potter',
    'Albus': 'Albus Dumbledore',
    'Teddy': 'Teddy Lupin',
    'Newt': 'Newton Scamander',
    'Rose': 'Rose Granger-Weasley',
    'Lily Potter': 'Lily J. Potter',
    'Regulus': 'Regulus Black I',
    'Mrs Weasley': 'Molly Weasley',
}
    

def canonicalize(name):
    
    name_parts = name.split()
    new_name_parts = []
    
    for name_part in name_parts:
        if name_part in canonical_character_name_parts:
            new_name_parts.append(name_part)
            
    new_name = ' '.join(new_name_parts)
    
    if new_name in remove:
        new_name = ''
        
    if new_name in name_transform:
        new_name = name_transform[new_name]
            
    return new_name

# %%
characters_ctr_filtered.most_common(200)
# Out:
# [('Harry', 24784),
#  ('Hermione', 17673),
#  ('Ron', 15328),
#  ('Draco', 13679),
#  ('Harry Potter', 13553),
#  ('Hogwarts', 13501),
#  ('Sirius', 12153),
#  ('Remus', 10555),
#  ('Ginny', 10156),
#  ('James', 9511),
#  ('Draco Malfoy', 8696),
#  ('Voldemort', 8579),
#  ('Severus', 7984),
#  ('Potter', 7404),
#  ('Dumbledore', 7304),
#  ('Lily', 7167),
#  ('Merlin', 6246),
#  ('Malfoy', 5929),
#  ('Snape', 5706),
#  ('Severus Snape', 5541),
#  ('Hermione Granger', 4785),
#  ('Ministry', 4512),
#  ('Neville', 4395),
#  ('Albus', 4149),
#  ('Peter', 4137),
#  ('George', 4134),
#  ('Slytherin', 4054),
#  ('Lucius', 3868),
#  ('Pansy', 3849),
#  ('Luna', 3845),
#  ('James Potter', 3567),
#  ('Gryffindor', 3499),
#  ('Fred', 3382),
#  ('Great Hall', 3287),
#  ('Lucius Malfoy', 3258),
#  ('Dark Lord', 3242),
#  ('Narcissa', 3238),
#  ('Weasley', 3214),
#  ('Christmas', 2945),
#  ('Molly', 2919),
#  ('Albus Dumbledore', 2902),
#  ('Moony', 2894),
#  ('Sirius Black', 2836),
#  ('Professor Snape', 2787),
#  ('Remus Lupin', 2781),
#  ('Mum', 2735),
#  ('Granger', 2691),
#  ('Scorpius', 2568),
#  ('God', 2532),
#  ('Blaise', 2475),
#  ('McGonagall', 2448),
#  ('Muggles', 2437),
#  ('Teddy', 2374),
#  ('Percy', 2370),
#  ('Dad', 2359),
#  ('Hagrid', 2352),
#  ('Lily Evans', 2346),
#  ('Mr. Potter', 2342),
#  ('Ron Weasley', 2294),
#  ('Bill', 2266),
#  ('Professor McGonagall', 2241),
#  ('Charlie', 2193),
#  ('Death Eaters', 2181),
#  ('Bellatrix', 2131),
#  ('Headmaster', 2122),
#  ('Ginny Weasley', 2097),
#  ('Minerva', 2032),
#  ('Seamus', 1963),
#  ('Aurors', 1922),
#  ('Fuck', 1893),
#  ('Father', 1875),
#  ('Quidditch', 1861),
#  ('Lord Voldemort', 1843),
#  ('Hufflepuff', 1836),
#  ('Grimmauld Place', 1832),
#  ('Dean', 1803),
#  ('Azkaban', 1773),
#  ('London', 1770),
#  ('Tonks', 1708),
#  ('Molly Weasley', 1702),
#  ('I', 1678),
#  ('Madam Pomfrey', 1673),
#  ('Arthur', 1671),
#  ('Tom', 1641),
#  ('Professor Dumbledore', 1635),
#  ('Tom Riddle', 1618),
#  ('Weasleys', 1575),
#  ('Malfoys', 1540),
#  ('Padfoot', 1511),
#  ('Death Eater', 1505),
#  ('Kingsley', 1496),
#  ('Fleur', 1495),
#  ('Mother', 1489),
#  ('Slytherins', 1430),
#  ('Regulus', 1417),
#  ('Lupin', 1408),
#  ('Mr. Malfoy', 1402),
#  ('Rose', 1386),
#  ('Miss Granger', 1386),
#  ('Newt', 1385),
#  ('Neville Longbottom', 1343),
#  ('Dudley', 1321),
#  ('Mrs. Weasley', 1320),
#  ('Diagon Alley', 1301),
#  ('Professor', 1296),
#  ('Astoria', 1261),
#  ('Andromeda', 1260),
#  ('Gryffindors', 1259),
#  ('The Dark Lord', 1252),
#  ('Ravenclaw', 1251),
#  ('Daddy', 1231),
#  ('Blaise Zabini', 1201),
#  ('Kreacher', 1189),
#  ('Manor', 1156),
#  ('Sorry', 1151),
#  ('Hogsmeade', 1140),
#  ('Tina', 1099),
#  ('Credence', 1061),
#  ('Peter Pettigrew', 1060),
#  ('Auror', 1038),
#  ('Minister', 1036),
#  ('Ronald', 1011),
#  ('Minerva McGonagall', 994),
#  ('Petunia', 981),
#  ('Fine', 977),
#  ('House', 971),
#  ('Order', 970),
#  ('Alright', 959),
#  ('Floo', 954),
#  ('Mr Potter', 951),
#  ('Narcissa Malfoy', 943),
#  ('Mione', 935),
#  ('Mr. Weasley', 931),
#  ('Goyle', 931),
#  ('Ronald Weasley', 927),
#  ('Dursleys', 907),
#  ('Black', 905),
#  ('Dobby', 896),
#  ('Lily Potter', 896),
#  ('Marauders', 884),
#  ('Pansy Parkinson', 882),
#  ('Prongs', 867),
#  ('Arthur Weasley', 843),
#  ('The Ministry', 839),
#  ('The', 825),
#  ('Magic', 824),
#  ('George Weasley', 812),
#  ('War', 811),
#  ('England', 800),
#  ('Luna Lovegood', 797),
#  ('Slughorn', 794),
#  ('Theo', 790),
#  ('Percival', 789),
#  ('Burrow', 788),
#  ('Wizengamot', 778),
#  ('Queenie', 777),
#  ('The Harry', 776),
#  ('Saturday', 774),
#  ('Longbottom', 770),
#  ('Malfoy Manor', 761),
#  ('Poppy', 761),
#  ('Angelina', 757),
#  ('Muggle', 757),
#  ('Friday', 752),
#  ('Grindelwald', 748),
#  ('Hugo', 747),
#  ('Rita Skeeter', 742),
#  ('Evans', 740),
#  ('Sir', 737),
#  ('Lavender', 736),
#  ('Ministry Magic', 736),
#  ('Daphne', 735),
#  ('Parvati', 713),
#  ('You-Know-Who', 710),
#  ('Cho', 709),
#  ('Wormtail', 708),
#  ('St. Mungo', 703),
#  ('Cedric', 685),
#  ('Moody', 677),
#  ('The Slytherin', 674),
#  ('Kingsley Shacklebolt', 662),
#  ('Oliver', 661),
#  ('Alice', 654),
#  ('Forbidden Forest', 653),
#  ('Harry James Potter', 652),
#  ('Madame Pomfrey', 650),
#  ('Mr Malfoy', 648),
#  ('Charlie Weasley', 641),
#  ('Marlene', 640),
#  ('Professor Slughorn', 635),
#  ('Percival Graves', 628),
#  ('Jamie', 620),
#  ('Wizarding World', 617),
#  ('Oliver Wood', 616),
#  ('Hedwig', 613),
#  ('The Headmaster', 612),
#  ('Nagini', 610),
#  ('Aunt Petunia', 601),
#  ('Time', 600),
#  ('Crabbe', 587)]

# %%
# Remove characters who don't have matches with canonical characters

# Filter, canonicalize names
characters_ctr_matches = Counter()
for name, count in characters_ctr_filtered.items():
    
    new_name = canonicalize(name)
    
    # Remove names
    if len(new_name) <= 1 or new_name in remove:
        continue
        
    # Transform names
    if new_name in name_transform:
        new_name = name_transform[new_name]
        
    if new_name in characters_ctr_matches:
        characters_ctr_matches[new_name] += count
        
    else:
        characters_ctr_matches[new_name] = count
    
print(len(characters_ctr_matches))
characters_ctr_matches.most_common()
# Out:
# 1971
# [('Harry', 31115),
#  ('Harry Potter', 28133),
#  ('Hermione', 20159),
#  ('Draco Malfoy', 19813),
#  ('Draco', 16983),
#  ('Ron', 16967),
#  ('Voldemort', 14113),
#  ('James Potter I', 14046),
#  ('Sirius', 13106),
#  ('Remus', 11668),
#  ('Ginny', 10927),
#  ('Snape', 9919),
#  ('Dumbledore', 9835),
#  ('Severus', 9109),
#  ('Lily J. Potter', 8743),
#  ('Albus Dumbledore', 7499),
#  ('Severus Snape', 5776),
#  ('McGonagall', 5314),
#  ('Sirius Black', 5183),
#  ('Granger', 5145),
#  ('Hermione Granger', 5039),
#  ('Neville', 4791),
#  ('George', 4509),
#  ('Peter', 4389),
#  ('Lucius', 4171),
#  ('Luna', 4149),
#  ('Pansy', 4109),
#  ('Tom Riddle', 3723),
#  ('Fred', 3583),
#  ('Narcissa', 3463),
#  ('Lucius Malfoy', 3304),
#  ('Molly', 3170),
#  ('Remus Lupin', 2886),
#  ('Teddy Lupin', 2868),
#  ('Scorpius', 2739),
#  ('Blaise', 2665),
#  ('Percy', 2646),
#  ('Lupin', 2580),
#  ('Hagrid', 2500),
#  ('Charlie', 2468),
#  ('Bill', 2444),
#  ('Lily Evans', 2411),
#  ('Bellatrix', 2344),
#  ('Molly Weasley', 2325),
#  ('Ron Weasley', 2320),
#  ('Minerva', 2149),
#  ('Seamus', 2149),
#  ('Ginny Weasley', 2121),
#  ('Lord Voldemort', 2042),
#  ('Dean', 2035),
#  ('Tonks', 1925),
#  ('Arthur', 1819),
#  ('Madam Pomfrey', 1681),
#  ('Newton Scamander', 1659),
#  ('Petunia', 1642),
#  ('Padfoot', 1608),
#  ('Fleur', 1597),
#  ('Kingsley', 1588),
#  ('Mother', 1569),
#  ('Rose Granger-Weasley', 1553),
#  ('Ravenclaw', 1537),
#  ('Regulus Black I', 1536),
#  ('Slughorn', 1463),
#  ('Graves', 1410),
#  ('Dudley', 1398),
#  ('Andromeda', 1385),
#  ('Neville Longbottom', 1373),
#  ('Longbottom', 1339),
#  ('Astoria', 1275),
#  ('Kreacher', 1243),
#  ('Tina', 1227),
#  ('Evans', 1212),
#  ('Blaise Zabini', 1207),
#  ('Marauders', 1200),
#  ('Dursleys', 1152),
#  ('Flitwick', 1103),
#  ('Peter Pettigrew', 1064),
#  ('Minerva McGonagall', 1064),
#  ('Vernon', 1056),
#  ('Goyle', 1054),
#  ('Ronald', 1034),
#  ('Ronald Weasley', 1021),
#  ('Moody', 985),
#  ('Godric', 952),
#  ('Narcissa Malfoy', 945),
#  ('Dobby', 943),
#  ('Percival', 910),
#  ('Pansy Parkinson', 890),
#  ('Pomfrey', 862),
#  ('Arthur Weasley', 850),
#  ('Queenie', 849),
#  ('George Weasley', 816),
#  ('Grindelwald', 811),
#  ('Luna Lovegood', 802),
#  ('Zabini', 792),
#  ('Angelina', 789),
#  ('Poppy', 779),
#  ('Hugo', 776),
#  ('Daphne', 768),
#  ('Nott', 764),
#  ('Lavender', 744),
#  ('Rita Skeeter', 744),
#  ('Oliver', 735),
#  ('Parvati', 730),
#  ('Parkinson', 730),
#  ('John', 730),
#  ('Cho', 720),
#  ('Umbridge', 718),
#  ('Alice', 716),
#  ('Cedric', 713),
#  ('Hannah', 701),
#  ('Kingsley Shacklebolt', 699),
#  ('Marlene', 668),
#  ('Harry James Potter', 664),
#  ('Scamander', 654),
#  ('Percival Graves', 654),
#  ('Filch', 650),
#  ('Mary', 646),
#  ('Charlie Weasley', 643),
#  ('Crabbe', 633),
#  ('Oliver Wood', 618),
#  ('Nagini', 616),
#  ('Victoire', 571),
#  ('Lovegood', 562),
#  ('Percy Weasley', 557),
#  ('Shacklebolt', 555),
#  ('Pettigrew', 553),
#  ('Riddle', 548),
#  ('Dean Thomas', 541),
#  ('Scorpius Malfoy', 537),
#  ('Salazar', 529),
#  ('Padma', 519),
#  ('Madam', 515),
#  ('Frank', 512),
#  ('Theodore Nott', 509),
#  ('Ollivander', 502),
#  ('Newt Scamander', 494),
#  ('Bill Weasley', 469),
#  ('Viktor Krum', 465),
#  ('Fred Weasley', 454),
#  ('Bellatrix Lestrange', 451),
#  ('Cedric Diggory', 449),
#  ('Susan', 447),
#  ('Trelawney', 447),
#  ('Greyback', 447),
#  ('Rodolphus', 436),
#  ('Marcus', 431),
#  ('Prince', 430),
#  ('Millicent', 426),
#  ('Sprout', 422),
#  ('Fudge', 420),
#  ('Salazar Slytherin', 420),
#  ('Daphne Greengrass', 398),
#  ('Goldstein', 396),
#  ('Albus Potter', 395),
#  ('Phoenix', 391),
#  ('Dursley', 379),
#  ('Binns', 376),
#  ('Viktor', 365),
#  ('Lestrange', 361),
#  ('Nymphadora Tonks', 359),
#  ('Colin', 358),
#  ('Aberforth', 352),
#  ('Fenrir Greyback', 350),
#  ('Madam Pince', 348),
#  ('Katie', 346),
#  ('Krum', 346),
#  ('Lee', 339),
#  ('Louis', 334),
#  ('Walburga', 320),
#  ('Lucy', 319),
#  ('Greengrass', 318),
#  ('Crouch', 316),
#  ('Ernie', 311),
#  ('Lee Jordan', 308),
#  ('Hannah Abbott', 308),
#  ('Marcus Flint', 307),
#  ('Harry Draco', 306),
#  ('Nymphadora', 302),
#  ('Filius', 296),
#  ('Rose Weasley', 296),
#  ('Smith', 287),
#  ('Michael', 286),
#  ('Lockhart', 286),
#  ('Seamus Finnigan', 285),
#  ('Justin', 284),
#  ('Gellert Grindelwald', 282),
#  ('Gellert', 280),
#  ('Dorcas', 277),
#  ('Robards', 277),
#  ('Pomona', 272),
#  ('Thomas', 271),
#  ('Regulus Black', 271),
#  ('Susan Bones', 270),
#  ('Katie Bell', 267),
#  ('Dolores Umbridge', 267),
#  ('Dolohov', 267),
#  ('Cho Chang', 266),
#  ('Myrtle', 261),
#  ('Draco Harry', 261),
#  ('Harry Ron', 256),
#  ('Quirrell', 256),
#  ('Wood', 253),
#  ('Ted', 247),
#  ('Jones', 241),
#  ('Ginny Potter', 240),
#  ('Colin Creevey', 239),
#  ('Rabastan', 239),
#  ('Millicent Bulstrode', 238),
#  ('Vernon Dursley', 238),
#  ('Theodore', 237),
#  ('Zacharias Smith', 235),
#  ('Gilderoy Lockhart', 235),
#  ('Fleur Delacour', 232),
#  ('Abraxas', 231),
#  ('Terry Boot', 225),
#  ('Orion', 222),
#  ('Poppy Pomfrey', 220),
#  ('Dominique', 219),
#  ('Frank Longbottom', 218),
#  ('Alicia', 216),
#  ('Harry Harry', 215),
#  ('Gregory Goyle', 214),
#  ('Padma Patil', 214),
#  ('Marlene McKinnon', 214),
#  ('Magical', 213),
#  ('Flint', 213),
#  ('Audrey', 209),
#  ('Ron Hermione', 209),
#  ('Hope', 206),
#  ('Rosmerta', 204),
#  ('Andromeda Tonks', 203),
#  ('Tina Goldstein', 201),
#  ('Alastor Moody', 201),
#  ('Amelia', 201),
#  ('Nick', 199),
#  ('Gideon', 198),
#  ('Finnigan', 197),
#  ('Pince', 195),
#  ('Dennis', 194),
#  ('Skeeter', 193),
#  ('Parvati Patil', 191),
#  ('Peeves', 188),
#  ('Harry Hermione', 188),
#  ('Rowena', 188),
#  ('Horace Slughorn', 186),
#  ('Fenrir', 184),
#  ('Diggory', 183),
#  ('Rodolphus Lestrange', 182),
#  ('Godric Gryffindor', 182),
#  ('Barebone', 182),
#  ('Lavender Brown', 181),
#  ('Mrs', 181),
#  ('Mrs Malfoy', 181),
#  ('Madam Hooch', 180),
#  ('Eileen', 178),
#  ('Albus Severus Potter', 177),
#  ('Hermione Weasley', 175),
#  ('Fabian', 175),
#  ('Helga', 172),
#  ('Terry', 171),
#  ('Hooch', 171),
#  ('Roxanne', 170),
#  ('Rowena Ravenclaw', 168),
#  ('Albus Severus', 168),
#  ('Alice Longbottom', 164),
#  ('Anthony', 163),
#  ('Penelope', 163),
#  ('Dudley Dursley', 162),
#  ('Cornelius Fudge', 161),
#  ('Horace', 161),
#  ('Patil', 160),
#  ('Rolf', 160),
#  ('Helga Hufflepuff', 160),
#  ('Madam Rosmerta', 159),
#  ('Mrs Potter', 159),
#  ('Scrimgeour', 156),
#  ('Gabrielle', 156),
#  ('Alastor', 153),
#  ('Ron Harry', 152),
#  ('Lysander', 148),
#  ('Amelia Bones', 148),
#  ('Dawlish', 148),
#  ('Penny', 147),
#  ('Vincent', 143),
#  ('Cormac McLaggen', 143),
#  ('Lorcan', 142),
#  ('Cormac', 142),
#  ('Justin Finch-Fletchley', 141),
#  ('Michael Corner', 140),
#  ('Ted Tonks', 140),
#  ('Hermione Ron', 140),
#  ('Ernie Macmillan', 139),
#  ('Alphard', 139),
#  ('Walburga Black', 139),
#  ('Dennis Creevey', 137),
#  ('Evan', 137),
#  ('Brown', 136),
#  ('Ariana', 135),
#  ('Mary Lou', 135),
#  ('Petunia Dursley', 134),
#  ('Tobias', 134),
#  ('Alecto', 132),
#  ('Rubeus Hagrid', 132),
#  ('Lily Luna', 131),
#  ('Gregory', 130),
#  ('Malfoy Harry', 129),
#  ('Astoria Greengrass', 126),
#  ('Queenie Goldstein', 126),
#  ('Sirius Remus', 123),
#  ('Draco Lucius Malfoy', 122),
#  ('Potter Draco', 121),
#  ('Narcissa Black', 121),
#  ('Lord Malfoy', 120),
#  ('Cygnus', 119),
#  ('Karkaroff', 119),
#  ('Vincent Crabbe', 118),
#  ('James Sirius', 118),
#  ('Sinistra', 118),
#  ('Creevey', 118),
#  ('Lisa', 117),
#  ('Marge', 117),
#  ('Adrian', 116),
#  ('Antonin Dolohov', 116),
#  ('McLaggen', 115),
#  ('Druella', 114),
#  ('Anthony Goldstein', 114),
#  ('Macnair', 113),
#  ('Emmeline', 113),
#  ('Dippet', 112),
#  ('Figg', 111),
#  ('Vector', 110),
#  ('Abraxas Malfoy', 110),
#  ('Aberforth Dumbledore', 107),
#  ('James Lily', 106),
#  ('Angelina Johnson', 105),
#  ('Baron', 105),
#  ('Tracey', 105),
#  ('Bulstrode', 105),
#  ('Amycus', 103),
#  ('Bones', 102),
#  ('Adrian Pucey', 101),
#  ('Harry Severus', 99),
#  ('Harry Malfoy', 99),
#  ('Rabastan Lestrange', 97),
#  ('Fred George', 97),
#  ('Filius Flitwick', 96),
#  ('Prewett', 95),
#  ('Hestia', 94),
#  ('Hermione Harry', 94),
#  ('Augusta', 94),
#  ('Bloody Baron', 93),
#  ('Mundungus Fletcher', 93),
#  ('Euphemia', 93),
#  ('Lord Potter', 93),
#  ('Tracey Davis', 90),
#  ('Helena', 90),
#  ('Bellatrix Black', 89),
#  ('Harry Snape', 89),
#  ('Alicia Spinnet', 89),
#  ('Johnson', 88),
#  ('Rita', 88),
#  ('Penelope Clearwater', 87),
#  ('Remus John Lupin', 85),
#  ('Tobias Snape', 84),
#  ('Rufus Scrimgeour', 84),
#  ('Argus', 84),
#  ('Dorcas Meadowes', 84),
#  ('Phineas', 83),
#  ('Sorting Hat', 83),
#  ('Severus Harry', 82),
#  ('Romilda Vane', 82),
#  ('Carrow', 82),
#  ('Aurora', 81),
#  ('Amos Diggory', 80),
#  ('Moaning Myrtle', 80),
#  ('Arabella Figg', 80),
#  ('Rosier', 80),
#  ('Roger Davies', 80),
#  ('Zacharias', 80),
#  ('Evan Rosier', 79),
#  ('McKinnon', 79),
#  ('Xenophilius', 76),
#  ('Roger', 75),
#  ('Kettleburn', 75),
#  ('Argus Filch', 75),
#  ('Mundungus', 75),
#  ('Augusta Longbottom', 75),
#  ('Benjy', 75),
#  ('Harry James', 74),
#  ('Marietta', 74),
#  ('Lyall', 74),
#  ('Amycus Carrow', 74),
#  ('Rolanda', 73),
#  ('Chang', 73),
#  ('Crouch Jr.', 73),
#  ('Potter Harry', 71),
#  ('Romilda', 71),
#  ('Irma', 71),
#  ('Pandora', 71),
#  ('Benjy Fenwick', 71),
#  ('Fleamont', 70),
#  ('Cornelius', 69),
#  ('Lily James', 69),
#  ('Remus Sirius', 68),
#  ('Delacour', 68),
#  ('Orion Black', 68),
#  ('Mandy', 67),
#  ('Sybill Trelawney', 67),
#  ('Bell', 67),
#  ('Xenophilius Lovegood', 66),
#  ('Molly Prewett', 65),
#  ('Piers', 65),
#  ('Madam Bones', 65),
#  ('Victoire Weasley', 65),
#  ('Rowan', 65),
#  ('Rolf Scamander', 64),
#  ('Hugo Weasley', 64),
#  ('Mrs Black', 64),
#  ('Gilderoy', 63),
#  ('Alecto Carrow', 63),
#  ('Antonin', 63),
#  ('Stan', 62),
#  ('James Sirius Potter', 61),
#  ('Arabella', 61),
#  ('Finch-Fletchley', 61),
#  ('Lord Black', 61),
#  ('Gawain Robards', 61),
#  ('Gideon Prewett', 61),
#  ('Davies', 60),
#  ('Rookwood', 60),
#  ('Eileen Prince', 59),
#  ('Harry Ginny', 59),
#  ('Phineas Nigellus', 59),
#  ('Montague', 59),
#  ('Maxime', 59),
#  ('Pucey', 58),
#  ('Draco Draco', 58),
#  ('Dolores', 58),
#  ('Rolanda Hooch', 58),
#  ('Snape Harry', 57),
#  ('Merope', 57),
#  ('Fleur Weasley', 57),
#  ('Ludo Bagman', 57),
#  ('Dorea', 56),
#  ('Abbott', 56),
#  ('Igor Karkaroff', 56),
#  ('Fabian Prewett', 56),
#  ('Macmillan', 56),
#  ('Sybill', 55),
#  ('Lisa Turpin', 55),
#  ('Davis', 55),
#  ('Ginny Harry', 54),
#  ('Rowle', 54),
#  ('Augustus', 53),
#  ('Petunia Evans', 53),
#  ('Emmeline Vance', 51),
#  ('Severus Tobias Snape', 51),
#  ('James Remus', 51),
#  ('Draco Potter', 51),
#  ('Mary Macdonald', 51),
#  ('Lily Luna Potter', 50),
#  ('Amos', 49),
#  ('Hermione Draco', 48),
#  ('Mrs Granger', 48),
#  ('Rufus', 48),
#  ('Bathilda', 48),
#  ('Stan Shunpike', 47),
#  ('Mrs Figg', 47),
#  ('Harry Remus', 47),
#  ('Bathilda Bagshot', 47),
#  ('Sirius Orion Black', 46),
#  ('Hermione Malfoy', 46),
#  ('Irma Pince', 46),
#  ('Fleamont Potter', 46),
#  ('Hat', 45),
#  ('Charlus', 45),
#  ('Rubeus', 45),
#  ('Euphemia Potter', 45),
#  ('Mandy Brocklehurst', 45),
#  ('Ginny Hermione', 43),
#  ('Gabrielle Delacour', 43),
#  ('Hogwarts Harry', 42),
#  ('Caradoc', 42),
#  ('Bagman', 42),
#  ('James James', 41),
#  ('Vance', 41),
#  ('Draco Hermione', 41),
#  ('Eileen Snape', 41),
#  ('Lily Lily', 41),
#  ('Higgs', 41),
#  ('Lucy Weasley', 40),
#  ('Jordan', 40),
#  ('Arcturus', 40),
#  ('Graham', 40),
#  ('Cassiopeia', 40),
#  ('Ron Ron', 39),
#  ('Sirius James', 38),
#  ('Morag', 38),
#  ('Malfoy Draco', 38),
#  ('Thorfinn Rowle', 38),
#  ('Igor', 38),
#  ('Bartemius Crouch', 38),
#  ('Boot', 37),
#  ('Charlus Potter', 37),
#  ('Harry Sirius', 36),
#  ('Louis Weasley', 36),
#  ('Ron Ginny', 36),
#  ('Headless Nick', 36),
#  ('Lyall Lupin', 36),
#  ('Gaunt', 35),
#  ('Harry Dumbledore', 35),
#  ('Harry Voldemort', 35),
#  ('Andromeda Black', 35),
#  ('Terence Higgs', 35),
#  ('Fenwick', 35),
#  ('Cygnus Black', 35),
#  ('Lou', 34),
#  ('Walden Macnair', 34),
#  ('Fletcher', 34),
#  ('Remus Remus', 34),
#  ('Terence', 34),
#  ('Elphias', 33),
#  ('Garrick Ollivander', 32),
#  ('Potter Malfoy', 32),
#  ('Slytherin Prince', 32),
#  ('Gawain', 32),
#  ('Hermione Hermione', 32),
#  ('Armando Dippet', 32),
#  ('Walden', 31),
#  ('Thomas Riddle', 31),
#  ('Sirius Harry', 31),
#  ('Burbage', 31),
#  ('Mrs Dursley', 31),
#  ('Seamus Dean', 31),
#  ('Harry Neville', 30),
#  ('James Peter', 30),
#  ('Tom Harry', 29),
#  ('Ron Draco', 29),
#  ('Elphias Doge', 29),
#  ('Phineas Nigellus Black', 29),
#  ('Dumbledore Harry', 28),
#  ('Hermione Ginny', 28),
#  ('Mary Lou Barebone', 28),
#  ('Hestia Jones', 28),
#  ('Druella Black', 28),
#  ('Remus Harry', 27),
#  ('Voldemort Harry', 27),
#  ('Draco Lucius', 27),
#  ('Potter Snape', 27),
#  ('Septima', 27),
#  ('Lorcan Scamander', 27),
#  ('Harry Luna', 26),
#  ('Harry Dean', 26),
#  ('Malfoy Hermione', 26),
#  ('Mrs Evans', 26),
#  ('Dearborn', 26),
#  ('Madam Umbridge', 26),
#  ('Lord Slytherin', 26),
#  ('George Fred', 25),
#  ('Marietta Edgecombe', 25),
#  ('Augustus Rookwood', 25),
#  ('Malfoy Potter', 25),
#  ('Hermione Snape', 25),
#  ('Potter Severus', 24),
#  ('Harry Tom', 24),
#  ('Alice Prewett', 24),
#  ('Pomona Sprout', 24),
#  ('Draco Pansy', 24),
#  ('Potter Potter', 24),
#  ('Charity Burbage', 24),
#  ('Mrs Longbottom', 24),
#  ('Hannah Longbottom', 24),
#  ('Prince Harry', 23),
#  ('Hermione Potter', 23),
#  ('Barnaby', 23),
#  ('John Dawlish', 23),
#  ('Staff', 22),
#  ('Severus Draco', 22),
#  ('Pansy Draco', 22),
#  ('Helena Ravenclaw', 22),
#  ('Harry Dudley', 22),
#  ('James Fleamont Potter', 22),
#  ('Lysander Scamander', 22),
#  ('Clearwater', 22),
#  ('Dominique Weasley', 22),
#  ('James Harry', 21),
#  ('Severus Hermione', 21),
#  ('Quirinus Quirrell', 21),
#  ('Draco Blaise', 21),
#  ('Mrs Lupin', 21),
#  ('John Lupin', 21),
#  ('Astoria Malfoy', 21),
#  ('Bagshot', 21),
#  ('Blaise Draco', 21),
#  ('Severus Remus', 20),
#  ('Aurora Sinistra', 20),
#  ('Ariana Dumbledore', 20),
#  ('Sirius Sirius', 20),
#  ('Charity', 20),
#  ('Doge', 20),
#  ('Roxanne Weasley', 20),
#  ('Remus James', 20),
#  ('Harry Evans', 20),
#  ('Pandora Lovegood', 19),
#  ('Severus Potter', 19),
#  ('Diary', 19),
#  ('Lily Harry', 19),
#  ('Harry Bloody Potter', 19),
#  ('Narcissa Draco', 19),
#  ('Phineas Black', 19),
#  ('Teddy Harry', 19),
#  ('Bloody Potter', 19),
#  ('Remus Lily', 19),
#  ('Sirius Lily', 19),
#  ('Merula', 19),
#  ('Luna Harry', 18),
#  ('Snape Snape', 18),
#  ('Harry Bill', 18),
#  ('Luna Neville', 18),
#  ('Alphard Black', 18),
#  ('Tina Scamander', 18),
#  ('Tom Riddle Sr.', 18),
#  ('Scorpius Albus', 18),
#  ('Harry Lily', 18),
#  ('Draco Ron', 18),
#  ('Caradoc Dearborn', 18),
#  ('Dorea Potter', 18),
#  ('Mrs Snape', 18),
#  ('Severus Albus', 17),
#  ('Jr.', 17),
#  ('Granger Weasley', 17),
#  ('Harry Potter Draco', 17),
#  ('Hogwarts Draco', 17),
#  ('Mrs Scamander', 17),
#  ('Meadowes', 17),
#  ('Ron Neville', 17),
#  ('Remus Peter', 17),
#  ('Hogwarts Hermione', 16),
#  ('Merope Gaunt', 16),
#  ('Gryffindor Potter', 16),
#  ('Malfoy Ron', 16),
#  ('Weasley Draco', 16),
#  ('Beasts', 16),
#  ('Mrs Zabini', 16),
#  ('Quirinus', 16),
#  ('Sirius Peter', 16),
#  ('Mrs Tonks', 15),
#  ('Lord Lucius Malfoy', 15),
#  ('Hermione Severus', 15),
#  ('Severus Lucius', 15),
#  ('Hermione Neville', 15),
#  ('Lily Remus', 15),
#  ('Bloody', 15),
#  ('Lily Evan', 15),
#  ('Harry Teddy', 15),
#  ('Lucius Narcissa', 15),
#  ('Ginny Luna', 15),
#  ('Edgecombe', 15),
#  ('Audrey Weasley', 15),
#  ('Ted Lupin', 15),
#  ('Garrick', 15),
#  ('Bill Charlie', 15),
#  ('Fred II', 15),
#  ('Bartemius', 15),
#  ('Potter Weasley', 15),
#  ('Morag MacDougal', 14),
#  ('Severus Severus', 14),
#  ('Newt Percival', 14),
#  ('Lucius Harry', 14),
#  ('Crabbe Goyle', 14),
#  ('Remus Severus', 14),
#  ('Lily Severus', 14),
#  ('Lily Evans Potter', 14),
#  ('Hagrid Harry', 14),
#  ('Remus Tonks', 14),
#  ('Malfoy Malfoy', 14),
#  ('Neville Harry', 14),
#  ('Harry Pansy', 14),
#  ('Draco Severus', 14),
#  ('Draco Snape', 14),
#  ('Ginny Ginny', 14),
#  ('Lord Riddle', 14),
#  ('Scorpius Draco', 14),
#  ('Vane', 14),
#  ('Harry Granger', 14),
#  ('Corner', 14),
#  ('Granger Draco', 14),
#  ('Newt Tina', 14),
#  ('Teddy Remus Lupin', 14),
#  ('Hope Lupin', 14),
#  ('Harry Black', 14),
#  ('Lord Harry Potter', 13),
#  ('Harry Albus', 13),
#  ('Draco Malfoy Harry', 13),
#  ('Snape Severus', 13),
#  ('Harry Lucius', 13),
#  ('Pansy Blaise', 13),
#  ('Spinnet', 13),
#  ('Ginny Draco', 13),
#  ('III', 13),
#  ('Severus Lily', 13),
#  ('Rose Potter', 13),
#  ('Percival Weasley', 13),
#  ('Luna Luna', 13),
#  ('II', 13),
#  ('Thorfinn', 13),
#  ('James Evans', 13),
#  ('Molly Arthur', 13),
#  ('Madam Lestrange', 13),
#  ('Tom Tom', 13),
#  ('Lily Sirius', 12),
#  ('Ron Malfoy', 12),
#  ('Severus Minerva', 12),
#  ('Silvanus', 12),
#  ('Dumbledore Voldemort', 12),
#  ('George Harry', 12),
#  ('Regulus Arcturus Black', 12),
#  ('Evans James', 12),
#  ('Harry George', 12),
#  ('Piers Polkiss', 12),
#  ('Sirius Regulus', 12),
#  ('James Albus', 12),
#  ('Graham Montague', 12),
#  ('Severus Dumbledore', 12),
#  ('Dean Seamus', 12),
#  ('Albus Scorpius', 12),
#  ('Olympe', 12),
#  ('Lily Riddle', 12),
#  ('Remus Snape', 11),
#  ('Hogwarts Severus Snape', 11),
#  ('Harry Hogwarts', 11),
#  ('Charlie Bill', 11),
#  ('Lord Draco Malfoy', 11),
#  ('Percival Dumbledore', 11),
#  ('Hogwarts Albus Dumbledore', 11),
#  ('Lucius Severus', 11),
#  ('John Smith', 11),
#  ('Ron George', 11),
#  ('Ginny Ron', 11),
#  ('Newt Newt', 11),
#  ('Shunpike', 11),
#  ('Arcturus Black', 11),
#  ('Tina Newt', 11),
#  ('Draco Abraxas Malfoy', 11),
#  ('Arthur Molly', 11),
#  ('Peter Remus', 11),
#  ('Harry Harry Potter', 11),
#  ('Malfoy Draco Malfoy', 10),
#  ('Lord Snape', 10),
#  ('Peter Peter', 10),
#  ('Luna Draco', 10),
#  ('Prince Slytherin', 10),
#  ('Potter James', 10),
#  ('Harry Fred', 10),
#  ('Ludo', 10),
#  ('Potter Granger', 10),
#  ('Prince James', 10),
#  ('Hermione Blaise', 10),
#  ('Angelina Weasley', 10),
#  ('James Severus', 10),
#  ('James Charlus Potter', 10),
#  ('Cuthbert Binns', 10),
#  ('Bloody Malfoy', 10),
#  ('Neville Hermione', 10),
#  ('Pansy Harry', 10),
#  ('Peter Sirius', 10),
#  ('Theodore Remus Lupin', 10),
#  ('Remus Dumbledore', 10),
#  ('Lord Harry', 10),
#  ('Neville Luna', 10),
#  ('Hogwarts Potter', 10),
#  ('Peter James', 10),
#  ('Draco Narcissa', 10),
#  ('Harry Cedric', 10),
#  ('Armando', 10),
#  ('MacDougal', 10),
#  ('Bill Fleur', 10),
#  ('Salazar Draco', 10),
#  ('Pansy Potter', 10),
#  ('Lucius Abraxas Malfoy', 10),
#  ('Penny Haywood', 10),
#  ('Granger Hermione', 10),
#  ('Dudley Harry', 10),
#  ('Madam Malfoy', 9),
#  ('Slytherin Harry', 9),
#  ('Voldemort Ron', 9),
#  ('Harry Hagrid', 9),
#  ('Voldemort Dumbledore', 9),
#  ('Hermione Luna', 9),
#  ('Hermione Black', 9),
#  ('Silvanus Kettleburn', 9),
#  ('Lucius Draco', 9),
#  ('Molly Harry', 9),
#  ('Mrs Smith', 9),
#  ('Gryffindor Slytherin', 9),
#  ('Druella Rosier', 9),
#  ('Draco Ginny', 9),
#  ('Albus Harry', 9),
#  ('Lily Petunia', 9),
#  ('Mrs Harry Potter', 9),
#  ('Hogwarts Remus', 9),
#  ('Neville Ron', 9),
#  ('Prince Potter', 9),
#  ('Lord Prince', 9),
#  ('Tom Riddle Jr.', 9),
#  ('Harry Charlie', 9),
#  ('Severus Prince', 9),
#  ('Marge Dursley', 9),
#  ('Euphemia Rowle', 9),
#  ('Madam Longbottom', 9),
#  ('Septima Vector', 9),
#  ('Luna Hermione', 9),
#  ('Weasley Ron', 9),
#  ('Ginny Malfoy', 9),
#  ('Neville Draco', 9),
#  ('Minerva Severus', 9),
#  ('Harry Cho', 9),
#  ('Harry Seamus', 8),
#  ('Weasley Harry', 8),
#  ('Snape Ron', 8),
#  ('Pansy Pansy', 8),
#  ('Dumbledore Severus', 8),
#  ('Harry Vernon', 8),
#  ('Malfoy Sr.', 8),
#  ('Harry Molly', 8),
#  ('Draco Granger', 8),
#  ('Madam Maxime', 8),
#  ('Snape Potter', 8),
#  ('Lily Potter Evans', 8),
#  ('Hogwarts Ron', 8),
#  ('Luna Ginny', 8),
#  ('Harry Gryffindor', 8),
#  ('Tina Tina', 8),
#  ('Dorea Black', 8),
#  ('Turpin', 8),
#  ('Queenie Tina', 8),
#  ('Salazar Harry', 8),
#  ('Brocklehurst', 8),
#  ('Harry Kreacher', 8),
#  ('Percy Graves', 8),
#  ('Blaise Harry', 8),
#  ('Hogwarts Dumbledore', 8),
#  ('Dumbledore Sirius', 8),
#  ('Macdonald', 8),
#  ('Snape Sirius', 8),
#  ('Lily Narcissa', 8),
#  ('Snape Draco', 8),
#  ('Headless', 8),
#  ('Harry Weasley', 8),
#  ('Lucius Lucius', 8),
#  ('Percival Newt', 7),
#  ('Potter Hogwarts', 7),
#  ('Tonks Harry', 7),
#  ('Draco Voldemort', 7),
#  ('Voldemort Tom', 7),
#  ('Hermione Pansy', 7),
#  ('Snape Hermione', 7),
#  ('Lord Sirius', 7),
#  ('Dobby Harry', 7),
#  ('Voldemort Severus', 7),
#  ('Narcissa Lucius', 7),
#  ('Lily Hermione', 7),
#  ('Prince Draco', 7),
#  ('Cuthbert', 7),
#  ('Malfoy Ginny', 7),
#  ('Ginny Longbottom', 7),
#  ('Lord Parkinson', 7),
#  ('Mrs Draco Malfoy', 7),
#  ('Slytherin Gryffindor', 7),
#  ('Gryffindor Harry', 7),
#  ('Potter Pansy', 7),
#  ('Dumbledore Snape', 7),
#  ('Mrs Brown', 7),
#  ('Draco Draco Malfoy', 7),
#  ('Percy Percy', 7),
#  ('Dean Dean', 7),
#  ('Bloody Hermione', 7),
#  ('Rose Evans', 7),
#  ('George George', 7),
#  ('Charlie Charlie', 7),
#  ('Mrs Jones', 7),
#  ('Tina Queenie', 7),
#  ('Neville Ginny', 7),
#  ('Godric Harry', 7),
#  ('Ginny Thomas', 7),
#  ('Ginny Neville', 7),
#  ('Madam Sprout', 7),
#  ('Narcissa Black Malfoy', 7),
#  ('Lily Rose', 7),
#  ('Lord Nott', 7),
#  ('Neville Neville', 7),
#  ('Albus James', 7),
#  ('Teddy Draco', 7),
#  ('Hermione Rose', 7),
#  ('James Dean', 7),
#  ('Lily Snape', 7),
#  ('Potter Lily', 7),
#  ('George Fabian Weasley', 7),
#  ('Salazar Potter', 7),
#  ('Nigellus', 7),
#  ('Rose Granger', 7),
#  ('Evans Lily', 7),
#  ('Lupin Remus', 7),
#  ('Irma Crabbe', 7),
#  ('Mrs Thomas', 7),
#  ('Draco Black', 7),
#  ('Lord Longbottom', 7),
#  ('Pansy Hermione', 7),
#  ('Barnaby Lee', 7),
#  ('Narcissa Malfoy Black', 7),
#  ('Harry Percy', 7),
#  ('Snape Dumbledore', 7),
#  ('Snape Remus', 6),
#  ('Charlie Potter', 6),
#  ('Lord Gryffindor', 6),
#  ('Prince Sirius', 6),
#  ('Ronald Hermione', 6),
#  ('Harry Dobby', 6),
#  ('Narcissa Severus', 6),
#  ('Charlie Ron', 6),
#  ('Charlie Harry', 6),
#  ('Harry Potter Malfoy', 6),
#  ('Weasley Granger', 6),
#  ('Severus Snape Harry', 6),
#  ('Lord Zabini', 6),
#  ('Hermione Lucius', 6),
#  ('Percy Ron', 6),
#  ('Blaise Pansy', 6),
#  ('Crouch Sr.', 6),
#  ('Irma Black', 6),
#  ('Pansy Ron', 6),
#  ('Lord Lucius', 6),
#  ('Malfoy Lord', 6),
#  ('Lord Grindelwald', 6),
#  ('Molly Ginny', 6),
#  ('Hogwarts Albus', 6),
#  ('Bill Bill', 6),
#  ('Tom Voldemort', 6),
#  ('Mrs Lestrange', 6),
#  ('Lord James', 6),
#  ('Cassiopeia Black', 6),
#  ('Fred Hermione', 6),
#  ('Alice Frank', 6),
#  ('Severus Sirius', 6),
#  ('Theodore Lupin', 6),
#  ('James Teddy', 6),
#  ('Albus Rose', 6),
#  ('Bellatrix Black Lestrange', 6),
#  ('Harry Blaise', 6),
#  ('Hestia Carrow', 6),
#  ('Portrait Snape', 6),
#  ('Harry McGonagall', 6),
#  ('Potter Albus', 6),
#  ('Albus Snape', 6),
#  ('Mrs Nott', 6),
#  ('Hogwarts Malfoy', 6),
#  ('Draco Teddy', 6),
#  ('Draco Dobby', 6),
#  ('Theodore Tonks', 6),
#  ('Fleur Hermione', 6),
#  ('Mrs Parkinson', 6),
#  ('Ginny Potter Weasley', 6),
#  ('George Lee', 6),
#  ('Gryffindor Harry Potter', 6),
#  ('Luna Scamander', 6),
#  ('Pansy Malfoy', 6),
#  ('Pansy Nott', 6),
#  ('Voldemort Hermione', 6),
#  ('Lord Greengrass', 6),
#  ('Weasley Potter', 6),
#  ('Sirius Orion', 6),
#  ('Hogwarts Staff', 6),
#  ('Merula Snyde', 6),
#  ('Teddy James', 6),
#  ('Lord Harry James Potter', 6),
#  ('Bloody Snape', 6),
#  ('Harry Harry Harry', 6),
#  ('Voldemort Draco', 6),
#  ('Harry Hannah', 5),
#  ('George Hermione', 5),
#  ('Petunia Dudley', 5),
#  ('Teddy Teddy', 5),
#  ('Ron Seamus', 5),
#  ('Potter Black', 5),
#  ('Severus Narcissa', 5),
#  ('Nearly Headless Nick', 5),
#  ('Madam Snape', 5),
#  ('Moody Harry', 5),
#  ('James Snape', 5),
#  ('Andromeda Black Tonks', 5),
#  ('Bill Harry', 5),
#  ('Lord Sirius Black', 5),
#  ('Molly Ron', 5),
#  ('Harry Slytherin', 5),
#  ('Ted Remus Lupin', 5),
#  ('Hermione Minerva', 5),
#  ('Bartemius Crouch Jr.', 5),
#  ('Harry Severus Snape', 5),
#  ('Harry Potter Dobby', 5),
#  ...]

# %%
character_gender = {} # Keys are character names from character features
characters_no_genderbox = []
characters_http_error = []

# %%
character_gender
# Out:
# {'Harry': 'male',
#  'Hermione': 'female',
#  'Draco': 'male',
#  'Ron': 'male',
#  'Harry Potter': 'male',
#  'Voldemort': 'male',
#  'Sirius': 'male',
#  'Remus': 'male'}

# %%
# Get gender from wikia page
import urllib.request
from bs4 import BeautifulSoup
from tqdm import tqdm_notebook as tqdm
from IPython.core.debugger import set_trace
import time
import urllib.error

for character in tqdm([name for name, count in characters_ctr_matches.most_common()]):
    
    if character in character_gender: continue
    if character in characters_no_genderbox: continue
    if character in characters_http_error: continue
    
    url_base = 'https://harrypotter.fandom.com/wiki/{}'
    try:
        html_str = urllib.request.urlopen(url_base.format(character.replace(' ', '_'))).read()
    except urllib.error.HTTPError as e:
        characters_http_error.append(character)
        print(f'Character {character} HTTP error')
        
    soup = BeautifulSoup(html_str, 'html.parser')
    
    if soup is None:
        print(html_str)
        break

    # div = list(soup.find('div', {'data-source':"gender"}).children)
    # soup.find('div', {'data-source':"gender"}).text
    genderbox = soup.find('div', {'data-source':"gender"})
    if genderbox is None:
        print(f'Character {character} has no gender box')
        characters_no_genderbox.append(character)
        continue
        
    gender = genderbox.find('div').text.lower()
    time.sleep(.5)
    
    character_gender[character] = gender
    
character_gender
# Out:
# HBox(children=(IntProgress(value=0, max=1971), HTML(value='')))
# {'Harry': 'male',
#  'Hermione': 'female',
#  'Draco': 'male',
#  'Ron': 'male',
#  'Harry Potter': 'male',
#  'Voldemort': 'male',
#  'Sirius': 'male',
#  'Remus': 'male',
#  'Draco Malfoy': 'male',
#  'Ginny': 'female',
#  'James Potter I': 'male',
#  'Snape': 'male',
#  'Dumbledore': 'male',
#  'Severus': 'male',
#  'Lily J. Potter': 'female',
#  'Severus Snape': 'male',
#  'McGonagall': 'female',
#  'Sirius Black': 'male',
#  'Granger': 'male',
#  'Hermione Granger': 'female',
#  'Neville': 'male',
#  'George': 'male',
#  'Albus Dumbledore': 'male',
#  'Peter': 'male',
#  'Lucius': 'male',
#  'Luna': 'female',
#  'Pansy': 'female',
#  'Tom Riddle': 'male',
#  'Fred': 'male',
#  'Narcissa': 'female',
#  'Lucius Malfoy': 'male',
#  'Molly': 'female',
#  'Remus Lupin': 'male',
#  'Scorpius': 'male',
#  'Blaise': 'male',
#  'Percy': 'male',
#  'Lupin': 'male',
#  'Teddy Lupin': 'male',
#  'Hagrid': 'male',
#  'Charlie': 'male',
#  'Bill': 'male',
#  'Lily Evans': 'female',
#  'Bellatrix': 'female',
#  'Ron Weasley': 'male',
#  'Minerva': 'female',
#  'Seamus': 'male',
#  'Ginny Weasley': 'female',
#  'Lord Voldemort': 'male',
#  'Dean': 'male',
#  'Tonks': 'female',
#  'Arthur': 'male',
#  'Molly Weasley': 'female',
#  'Madam Pomfrey': 'female[5]',
#  'Petunia': 'female',
#  'Padfoot': 'male',
#  'Fleur': 'female',
#  'Kingsley': 'male[5]',
#  'Slughorn': 'male',
#  'Graves': 'male',
#  'Dudley': 'male',
#  'Andromeda': 'male',
#  'Neville Longbottom': 'male',
#  'Astoria': 'female',
#  'Kreacher': 'male',
#  'Tina': 'female',
#  'Blaise Zabini': 'male',
#  'Flitwick': 'male',
#  'Peter Pettigrew': 'male',
#  'Minerva McGonagall': 'female',
#  'Vernon': 'male',
#  'Goyle': 'male',
#  'Ronald': 'male',
#  'Ronald Weasley': 'male',
#  'Moody': 'male[4]',
#  'Godric': 'male[3]',
#  'Narcissa Malfoy': 'female',
#  'Dobby': 'male',
#  'Pansy Parkinson': 'female',
#  'Pomfrey': 'female[5]',
#  'Arthur Weasley': 'male',
#  'Queenie': 'female',
#  'George Weasley': 'male',
#  'Grindelwald': 'male',
#  'Luna Lovegood': 'female',
#  'Zabini': 'female',
#  'Angelina': 'female',
#  'Hugo': 'male',
#  'Nott': 'male',
#  'Rita Skeeter': 'female',
#  'Oliver': 'female',
#  'Parvati': 'female',
#  'Parkinson': 'female',
#  'John': 'male',
#  'Cho': 'female',
#  'Alice': 'female',
#  'Cedric': 'male',
#  'Kingsley Shacklebolt': 'male[5]',
#  'Marlene': 'male[5]',
#  'Harry James Potter': 'male',
#  'Scamander': 'male',
#  'Percival Graves': 'male',
#  'Filch': 'male',
#  'Mary': 'female',
#  'Charlie Weasley': 'male',
#  'Crabbe': 'male',
#  'Oliver Wood': 'male',
#  'Nagini': 'female',
#  'Victoire': 'female',
#  'Percy Weasley': 'male',
#  'Shacklebolt': 'male[5]',
#  'Dean Thomas': 'male',
#  'Scorpius Malfoy': 'male',
#  'Salazar': 'male[5]',
#  'Padma': 'female',
#  'Frank': 'male',
#  'Theodore Nott': 'male',
#  'Ollivander': 'male',
#  'Newt Scamander': 'male[2]',
#  'Bill Weasley': 'male',
#  'Viktor Krum': 'male',
#  'Fred Weasley': 'male',
#  'Bellatrix Lestrange': 'female',
#  'Cedric Diggory': 'male[5]',
#  'Susan': 'male[5]',
#  'Greyback': 'male[1]',
#  'Rodolphus': 'male[1]',
#  'Fudge': 'male',
#  'Salazar Slytherin': 'male[5]',
#  'Daphne Greengrass': 'female',
#  'Goldstein': 'female',
#  'Albus Potter': 'male',
#  'Binns': 'male',
#  'Viktor': 'male',
#  'Lestrange': 'male',
#  'Nymphadora Tonks': 'female',
#  'Colin': 'male',
#  'Aberforth': 'male[5]',
#  'Fenrir Greyback': 'male[1]',
#  'Madam Pince': 'female[3]',
#  'Katie': 'female[3]',
#  'Krum': 'male',
#  'Lee': 'male',
#  'Louis': 'male',
#  'Walburga': 'male',
#  'Lucy': 'female',
#  'Greengrass': 'female',
#  'Lee Jordan': 'male',
#  'Hannah Abbott': 'female',
#  'Marcus Flint': 'male',
#  'Harry Draco': 'male',
#  'Nymphadora': 'female',
#  'Filius': 'female',
#  'Rose Weasley': 'female',
#  'Michael': 'male',
#  'Lockhart': 'male',
#  'Seamus Finnigan': 'male',
#  'Justin': 'male',
#  'Gellert Grindelwald': 'male',
#  'Gellert': 'male',
#  'Dorcas': 'male',
#  'Robards': 'male',
#  'Pomona': 'male',
#  'Thomas': 'male',
#  'Regulus Black': 'male',
#  'Susan Bones': 'female',
#  'Katie Bell': 'female',
#  'Dolores Umbridge': 'female',
#  'Dolohov': 'male',
#  'Cho Chang': 'female',
#  'Myrtle': 'female',
#  'Draco Harry': 'female',
#  'Harry Ron': 'female',
#  'Quirrell': 'male[6]',
#  'Wood': 'male',
#  'Ted': 'male',
#  'Ginny Potter': 'female',
#  'Colin Creevey': 'male',
#  'Rabastan': 'male',
#  'Millicent Bulstrode': 'female',
#  'Vernon Dursley': 'male',
#  'Theodore': 'male',
#  'Zacharias Smith': 'male',
#  'Gilderoy Lockhart': 'male',
#  'Fleur Delacour': 'female',
#  'Abraxas': 'female',
#  'Terry Boot': 'male',
#  'Poppy Pomfrey': 'female[5]',
#  'Dominique': 'female',
#  'Frank Longbottom': 'male',
#  'Alicia': 'male',
#  'Harry Harry': 'male',
#  'Gregory Goyle': 'male',
#  'Padma Patil': 'female',
#  'Marlene McKinnon': 'female',
#  'Audrey': 'female',
#  'Ron Hermione': 'female',
#  'Hope': 'female',
#  'Rosmerta': 'female',
#  'Andromeda Tonks': 'female',
#  'Tina Goldstein': 'female',
#  'Alastor Moody': 'male[4]',
#  'Amelia': 'male[4]',
#  'Nick': 'male[4]',
#  'Gideon': 'male[4]',
#  'Finnigan': 'male[4]',
#  'Pince': 'male[4]',
#  'Dennis': 'male',
#  'Skeeter': 'female',
#  'Parvati Patil': 'female',
#  'Peeves': 'male',
#  'Harry Hermione': 'male',
#  'Rowena': 'female[5]',
#  'Horace Slughorn': 'male',
#  'Fenrir': 'male[1]',
#  'Diggory': 'male[1]',
#  'Rodolphus Lestrange': 'male',
#  'Godric Gryffindor': 'male[3]',
#  'Barebone': 'male[3]',
#  'Lavender Brown': 'female',
#  'Mrs': 'female',
#  'Mrs Malfoy': 'female',
#  'Madam Hooch': 'female[2]',
#  'Eileen': 'female[2]',
#  'Albus Severus Potter': 'male',
#  'Hermione Weasley': 'female',
#  'Fabian': 'female',
#  'Helga': 'female',
#  'Terry': 'female',
#  'Hooch': 'female[2]',
#  'Roxanne': 'female',
#  'Rowena Ravenclaw': 'female[5]',
#  'Albus Severus': 'male',
#  'Alice Longbottom': 'female',
#  'Anthony': 'female',
#  'Dudley Dursley': 'male',
#  'Cornelius Fudge': 'male',
#  'Horace': 'male',
#  'Patil': 'male',
#  'Rolf': 'male',
#  'Helga Hufflepuff': 'female',
#  'Madam Rosmerta': 'female',
#  'Mrs Potter': 'female',
#  'Lysander': 'male',
#  'Amelia Bones': 'female',
#  'Dawlish': 'male',
#  'Penny': 'male',
#  'Vincent': 'male',
#  'Cormac McLaggen': 'male',
#  'Lorcan': 'male',
#  'Cormac': 'male',
#  'Justin Finch-Fletchley': 'male',
#  'Michael Corner': 'male',
#  'Ted Tonks': 'male',
#  'Hermione Ron': 'male',
#  'Ernie Macmillan': 'male',
#  'Alphard': 'male',
#  'Walburga Black': 'female[1]',
#  'Dennis Creevey': 'male',
#  'Evan': 'male',
#  'Ariana': 'female',
#  'Mary Lou': 'female',
#  'Petunia Dursley': 'female',
#  'Tobias': 'female',
#  'Alecto': 'female[4]',
#  'Rubeus Hagrid': 'male',
#  'Lily Luna': 'female',
#  'Gregory': 'female',
#  'Malfoy Harry': 'female',
#  'Astoria Greengrass': 'female',
#  'Queenie Goldstein': 'female',
#  'Sirius Remus': 'female',
#  'Draco Lucius Malfoy': 'male',
#  'Potter Draco': 'male',
#  'Narcissa Black': 'female',
#  'Lord Malfoy': 'female',
#  'Cygnus': 'female',
#  'Karkaroff': 'male',
#  'Vincent Crabbe': 'male',
#  'James Sirius': 'male',
#  'Marge': 'female',
#  'Adrian': 'male',
#  'Antonin Dolohov': 'male',
#  'McLaggen': 'male',
#  'Druella': 'male',
#  'Anthony Goldstein': 'male',
#  'Macnair': 'male',
#  'Emmeline': 'male',
#  'Dippet': 'male[4]',
#  'Figg': 'male[4]',
#  'Vector': 'male[4]',
#  'Abraxas Malfoy': 'male',
#  'Aberforth Dumbledore': 'male[5]',
#  'James Lily': 'male[5]',
#  'Angelina Johnson': 'female',
#  'Amycus': 'male[4]',
#  'Adrian Pucey': 'male',
#  'Harry Severus': 'male',
#  'Harry Malfoy': 'male',
#  'Rabastan Lestrange': 'male',
#  'Fred George': 'male',
#  'Filius Flitwick': 'male',
#  'Bloody Baron': 'male[3]',
#  'Mundungus Fletcher': 'male[3]',
#  'Euphemia': 'male[3]',
#  'Lord Potter': 'male[3]',
#  'Tracey Davis': 'female',
#  'Helena': 'female',
#  'Bellatrix Black': 'female',
#  'Harry Snape': 'female',
#  'Alicia Spinnet': 'female',
#  'Johnson': 'female',
#  'Rita': 'female',
#  'Penelope Clearwater': 'female',
#  'Remus John Lupin': 'male',
#  'Tobias Snape': 'male[3]',
#  'Rufus Scrimgeour': 'male',
#  'Argus': 'male',
#  'Dorcas Meadowes': 'female',
#  'Phineas': 'female',
#  'Romilda Vane': 'female',
#  'Amos Diggory': 'male[3]',
#  'Moaning Myrtle': 'female',
#  'Arabella Figg': 'female',
#  'Roger Davies': 'male',
#  'Zacharias': 'male',
#  'Evan Rosier': 'male',
#  'McKinnon': 'male',
#  'Xenophilius': 'male',
#  'Kettleburn': 'male',
#  'Argus Filch': 'male',
#  'Mundungus': 'male[3]',
#  'Augusta Longbottom': 'female',
#  'Benjy': 'female',
#  'Harry James': 'female',
#  'Marietta': 'female',
#  'Lyall': 'female',
#  'Amycus Carrow': 'male[4]',
#  'Rolanda': 'male[4]',
#  'Chang': 'male[4]',
#  'Crouch Jr.': 'male[4]',
#  'Potter Harry': 'male[4]',
#  'Romilda': 'male[4]',
#  'Irma': 'male[4]',
#  'Pandora': 'male[4]',
#  'Benjy Fenwick': 'male',
#  'Fleamont': 'male',
#  'Orion Black': 'male',
#  'Mandy': 'male',
#  'Sybill Trelawney': 'female',
#  'Xenophilius Lovegood': 'male',
#  'Molly Prewett': 'female',
#  'Piers': 'female',
#  'Madam Bones': 'female',
#  'Victoire Weasley': 'female',
#  'Rolf Scamander': 'male',
#  'Hugo Weasley': 'male',
#  'Mrs Black': 'female[1]',
#  'Gilderoy': 'male',
#  'Alecto Carrow': 'female[4]',
#  'Antonin': 'female[4]',
#  'Stan': 'female[4]',
#  'James Sirius Potter': 'male',
#  'Arabella': 'male',
#  'Finch-Fletchley': 'male',
#  'Lord Black': 'male',
#  'Gawain Robards': 'male',
#  'Gideon Prewett': 'male',
#  'Davies': 'male',
#  'Rookwood': 'male',
#  'Eileen Prince': 'female[5]',
#  'Harry Ginny': 'female[5]',
#  'Phineas Nigellus': 'male',
#  'Montague': 'male',
#  'Maxime': 'male',
#  'Pucey': 'male',
#  'Draco Draco': 'male',
#  'Dolores': 'female',
#  'Rolanda Hooch': 'female[2]',
#  'Snape Harry': 'female[2]',
#  'Merope': 'female',
#  'Fleur Weasley': 'female',
#  'Ludo Bagman': 'male',
#  'Dorea': 'female',
#  'Igor Karkaroff': 'male',
#  'Fabian Prewett': 'male',
#  'Macmillan': 'male',
#  'Sybill': 'female',
#  'Lisa Turpin': 'female',
#  'Davis': 'male',
#  'Ginny Harry': 'male',
#  'Rowle': 'male',
#  'Augustus': 'male',
#  'Petunia Evans': 'female',
#  'Emmeline Vance': 'female',
#  'Severus Tobias Snape': 'female',
#  'James Remus': 'female',
#  'Draco Potter': 'female',
#  'Mary Macdonald': 'female[5]',
#  'Lily Luna Potter': 'female',
#  'Amos': 'male[3]',
#  'Hermione Draco': 'male[3]',
#  'Mrs Granger': 'male[3]',
#  'Stan Shunpike': 'male',
#  'Mrs Figg': 'female',
#  'Harry Remus': 'female',
#  'Bathilda Bagshot': 'female[5]',
#  'Sirius Orion Black': 'female[5]',
#  'Hermione Malfoy': 'female[5]',
#  'Irma Pince': 'female[3]',
#  'Fleamont Potter': 'male',
#  'Hat': 'male',
#  'Charlus': 'male',
#  'Rubeus': 'male',
#  'Euphemia Potter': 'female',
#  'Mandy Brocklehurst': 'female[3]',
#  'Ginny Hermione': 'female[3]',
#  'Gabrielle Delacour': 'female',
#  'Hogwarts Harry': 'female',
#  'Caradoc': 'female',
#  'Bagman': 'male',
#  'James James': 'male',
#  'Vance': 'male',
#  'Draco Hermione': 'male',
#  'Eileen Snape': 'female[5]',
#  'Lily Lily': 'female[5]',
#  'Higgs': 'female[5]',
#  'Lucy Weasley': 'female',
#  'Jordan': 'female',
#  'Arcturus': 'female',
#  'Morag': 'female',
#  'Malfoy Draco': 'female',
#  'Thorfinn Rowle': 'male',
#  'Igor': 'male',
#  'Charlus Potter': 'male',
#  'Harry Sirius': 'male',
#  'Louis Weasley': 'male',
#  'Ron Ginny': 'male',
#  'Headless Nick': 'male',
#  'Lyall Lupin': 'male',
#  'Andromeda Black': 'female',
#  'Terence Higgs': 'male',
#  'Fenwick': 'male',
#  'Walden Macnair': 'male',
#  'Fletcher': 'male',
#  'Remus Remus': 'male',
#  'Terence': 'male',
#  'Elphias': 'male',
#  'Garrick Ollivander': 'male',
#  'Potter Malfoy': 'male',
#  'Slytherin Prince': 'male',
#  'Gawain': 'male',
#  'Hermione Hermione': 'male',
#  'Armando Dippet': 'male[4]',
#  'Walden': 'male[4]',
#  'Thomas Riddle': 'male',
#  'Sirius Harry': 'male',
#  'Burbage': 'male',
#  'Mrs Dursley': 'male',
#  'Seamus Dean': 'male',
#  'Harry Neville': 'male',
#  'James Peter': 'male',
#  'Tom Harry': 'male',
#  'Ron Draco': 'male',
#  'Elphias Doge': 'male[6]',
#  'Phineas Nigellus Black': 'male',
#  'Dumbledore Harry': 'male',
#  'Hermione Ginny': 'male',
#  'Mary Lou Barebone': 'female',
#  'Hestia Jones': 'female',
#  'Druella Black': 'female[2]',
#  'Remus Harry': 'female[2]',
#  'Voldemort Harry': 'female[2]',
#  'Draco Lucius': 'female[2]',
#  'Potter Snape': 'female[2]',
#  'Septima': 'female[2]',
#  'Lorcan Scamander': 'male',
#  'Harry Luna': 'male',
#  'Harry Dean': 'male',
#  'Malfoy Hermione': 'male',
#  'Mrs Evans': 'male',
#  'Dearborn': 'male',
#  'Madam Umbridge': 'male',
#  'Lord Slytherin': 'male',
#  'George Fred': 'male',
#  'Marietta Edgecombe': 'female',
#  'Augustus Rookwood': 'male',
#  'Malfoy Potter': 'male',
#  'Hermione Snape': 'male',
#  'Potter Severus': 'male',
#  'Harry Tom': 'male',
#  'Alice Prewett': 'female',
#  'Pomona Sprout': 'female',
#  'Draco Pansy': 'female',
#  'Potter Potter': 'female',
#  'Charity Burbage': 'female',
#  'Mrs Longbottom': 'female',
#  'Hannah Longbottom': 'female',
#  'Prince Harry': 'female',
#  'Hermione Potter': 'female',
#  'Barnaby': 'female',
#  'John Dawlish': 'male',
#  'Helena Ravenclaw': 'female[5]',
#  'Harry Dudley': 'female[5]',
#  'James Fleamont Potter': 'female[5]',
#  'Lysander Scamander': 'male',
#  'Clearwater': 'female',
#  'Dominique Weasley': 'female',
#  'James Harry': 'female',
#  'Severus Hermione': 'female',
#  'Quirinus Quirrell': 'male[6]',
#  'Draco Blaise': 'male[6]',
#  'Mrs Lupin': 'male[6]',
#  'John Lupin': 'male[6]',
#  'Astoria Malfoy': 'female',
#  'Aurora Sinistra': 'female[3]',
#  'Ariana Dumbledore': 'female',
#  'Sirius Sirius': 'female',
#  'Charity': 'female',
#  'Doge': 'female',
#  'Roxanne Weasley': 'female',
#  'Remus James': 'female',
#  'Harry Evans': 'female',
#  'Pandora Lovegood': 'female',
#  'Severus Potter': 'female',
#  'Diary': 'female',
#  'Lily Harry': 'female',
#  'Harry Bloody Potter': 'female',
#  'Narcissa Draco': 'female',
#  'Phineas Black': 'male[1]',
#  'Teddy Harry': 'male[1]',
#  'Bloody Potter': 'male[1]',
#  'Remus Lily': 'male[1]',
#  'Sirius Lily': 'male[1]',
#  'Merula': 'male[1]',
#  'Luna Harry': 'male[1]',
#  'Snape Snape': 'male[1]',
#  'Harry Bill': 'male[1]',
#  'Luna Neville': 'male[1]',
#  'Alphard Black': 'male[3]',
#  'Tina Scamander': 'female',
#  'Tom Riddle Sr.': 'male',
#  'Scorpius Albus': 'male',
#  'Harry Lily': 'male',
#  'Draco Ron': 'male',
#  'Caradoc Dearborn': 'male',
#  'Dorea Potter': 'female',
#  'Mrs Snape': 'female',
#  'Severus Albus': 'female',
#  'Jr.': 'female',
#  'Granger Weasley': 'female',
#  'Harry Potter Draco': 'female',
#  'Hogwarts Draco': 'female',
#  'Mrs Scamander': 'female',
#  'Meadowes': 'female',
#  'Ron Neville': 'female',
#  'Remus Peter': 'female',
#  'Hogwarts Hermione': 'female',
#  'Merope Gaunt': 'female',
#  'Gryffindor Potter': 'female',
#  'Malfoy Ron': 'female',
#  'Weasley Draco': 'female',
#  'Edgecombe': 'female',
#  'Audrey Weasley': 'female',
#  'Ted Lupin': 'male',
#  'Garrick': 'male',
#  'Bill Charlie': 'male',
#  'Fred II': 'male',
#  'Morag MacDougal': 'female',
#  'Severus Severus': 'female',
#  'Newt Percival': 'female',
#  'Lucius Harry': 'female',
#  'Crabbe Goyle': 'female',
#  'Remus Severus': 'female',
#  'Lily Severus': 'female',
#  'Lily Evans Potter': 'female',
#  'Hagrid Harry': 'female',
#  'Remus Tonks': 'female',
#  'Malfoy Malfoy': 'female',
#  'Neville Harry': 'female',
#  'Harry Pansy': 'female',
#  'Draco Severus': 'female',
#  'Draco Snape': 'female',
#  'Ginny Ginny': 'female',
#  'Lord Riddle': 'female',
#  'Scorpius Draco': 'female',
#  'Vane': 'female',
#  'Harry Granger': 'female',
#  'Corner': 'female',
#  'Granger Draco': 'female',
#  'Newt Tina': 'female',
#  'Teddy Remus Lupin': 'male',
#  'Hope Lupin': 'female[2]',
#  'Harry Black': 'female[2]',
#  'Lord Harry Potter': 'female[2]',
#  'Harry Albus': 'female[2]',
#  'Draco Malfoy Harry': 'female[2]',
#  'Snape Severus': 'female[2]',
#  'Harry Lucius': 'female[2]',
#  'Pansy Blaise': 'female[2]',
#  'Spinnet': 'female[2]',
#  'Ginny Draco': 'female[2]',
#  'III': 'female[2]',
#  'Severus Lily': 'female[2]',
#  'Rose Potter': 'female[2]',
#  'Percival Weasley': 'male',
#  'Luna Luna': 'male',
#  'II': 'male',
#  'Thorfinn': 'male',
#  'James Evans': 'male',
#  'Molly Arthur': 'male',
#  'Madam Lestrange': 'male',
#  'Tom Tom': 'male',
#  'Lily Sirius': 'male',
#  'Ron Malfoy': 'male',
#  'Severus Minerva': 'male',
#  'Silvanus': 'male',
#  'Dumbledore Voldemort': 'male',
#  'George Harry': 'male',
#  'Regulus Arcturus Black': 'male',
#  'Evans James': 'male',
#  'Harry George': 'male',
#  'Piers Polkiss': 'male',
#  'Sirius Regulus': 'male',
#  'James Albus': 'male',
#  'Graham Montague': 'male',
#  'Severus Dumbledore': 'male',
#  'Dean Seamus': 'male',
#  'Albus Scorpius': 'male',
#  'Olympe': 'male',
#  'Lily Riddle': 'male',
#  'Remus Snape': 'male',
#  'Hogwarts Severus Snape': 'male',
#  'Harry Hogwarts': 'male',
#  'Charlie Bill': 'male',
#  'Lord Draco Malfoy': 'male',
#  'Percival Dumbledore': 'male',
#  'Hogwarts Albus Dumbledore': 'male',
#  'Lucius Severus': 'male',
#  'John Smith': 'male',
#  'Ron George': 'male',
#  'Ginny Ron': 'male',
#  'Newt Newt': 'male',
#  'Shunpike': 'male',
#  'Angelina Weasley': 'female',
#  'James Severus': 'female',
#  'James Charlus Potter': 'female',
#  'Cuthbert Binns': 'male',
#  'Bloody Malfoy': 'male',
#  'Neville Hermione': 'male',
#  'Pansy Harry': 'male',
#  'Peter Sirius': 'male',
#  'Theodore Remus Lupin': 'male',
#  'Remus Dumbledore': 'male',
#  'Lord Harry': 'male',
#  'Neville Luna': 'male',
#  'Hogwarts Potter': 'male',
#  'Peter James': 'male',
#  'Draco Narcissa': 'male',
#  'Harry Cedric': 'male',
#  'Armando': 'male',
#  'MacDougal': 'male',
#  'Bill Fleur': 'male',
#  'Salazar Draco': 'male',
#  'Pansy Potter': 'male',
#  'Lucius Abraxas Malfoy': 'male',
#  'Penny Haywood': 'female',
#  'Granger Hermione': 'female',
#  'Dudley Harry': 'female',
#  'Madam Malfoy': 'female',
#  'Slytherin Harry': 'female',
#  'Voldemort Ron': 'female',
#  'Harry Hagrid': 'female',
#  'Voldemort Dumbledore': 'female',
#  'Hermione Luna': 'female',
#  'Hermione Black': 'female',
#  'Silvanus Kettleburn': 'male',
#  'Lucius Draco': 'male',
#  'Molly Harry': 'male',
#  'Mrs Smith': 'male',
#  'Gryffindor Slytherin': 'male',
#  'Druella Rosier': 'female[2]',
#  'Draco Ginny': 'female[2]',
#  'Albus Harry': 'female[2]',
#  'Lily Petunia': 'female[2]',
#  'Mrs Harry Potter': 'female[2]',
#  'Hogwarts Remus': 'female[2]',
#  'Neville Ron': 'female[2]',
#  'Prince Potter': 'female[2]',
#  'Lord Prince': 'female[2]',
#  'Tom Riddle Jr.': 'female[2]',
#  'Harry Charlie': 'female[2]',
#  'Severus Prince': 'female[2]',
#  'Marge Dursley': 'female',
#  'Euphemia Rowle': 'female',
#  'Madam Longbottom': 'female',
#  'Septima Vector': 'female',
#  'Luna Hermione': 'female',
#  'Weasley Ron': 'female',
#  'Ginny Malfoy': 'female',
#  'Neville Draco': 'female',
#  'Minerva Severus': 'female',
#  'Harry Cho': 'female',
#  'Harry Seamus': 'female',
#  'Weasley Harry': 'female',
#  'Snape Ron': 'female',
#  'Pansy Pansy': 'female',
#  'Dumbledore Severus': 'female',
#  'Harry Vernon': 'female',
#  'Malfoy Sr.': 'female',
#  'Harry Molly': 'female',
#  'Draco Granger': 'female',
#  'Madam Maxime': 'female',
#  'Snape Potter': 'female',
#  'Lily Potter Evans': 'female',
#  'Hogwarts Ron': 'female',
#  'Luna Ginny': 'female',
#  'Harry Gryffindor': 'female',
#  'Tina Tina': 'female',
#  'Dorea Black': 'female',
#  'Turpin': 'female',
#  'Queenie Tina': 'female',
#  'Salazar Harry': 'female',
#  'Brocklehurst': 'female',
#  'Harry Kreacher': 'female',
#  'Percy Graves': 'female',
#  'Blaise Harry': 'female',
#  'Hogwarts Dumbledore': 'female',
#  'Dumbledore Sirius': 'female',
#  'Macdonald': 'female',
#  'Snape Sirius': 'female',
#  'Lily Narcissa': 'female',
#  'Snape Draco': 'female',
#  'Headless': 'female',
#  'Harry Weasley': 'female',
#  'Lucius Lucius': 'female',
#  'Percival Newt': 'female',
#  'Potter Hogwarts': 'female',
#  'Tonks Harry': 'female',
#  'Draco Voldemort': 'female',
#  'Voldemort Tom': 'female',
#  'Hermione Pansy': 'female',
#  'Snape Hermione': 'female',
#  'Lord Sirius': 'female',
#  'Dobby Harry': 'female',
#  'Voldemort Severus': 'female',
#  'Narcissa Lucius': 'female',
#  'Lily Hermione': 'female',
#  'Prince Draco': 'female',
#  'Cuthbert': 'female',
#  'Malfoy Ginny': 'female',
#  'Ginny Longbottom': 'female',
#  'Lord Parkinson': 'female',
#  'Mrs Draco Malfoy': 'female',
#  'Slytherin Gryffindor': 'female',
#  'Gryffindor Harry': 'female',
#  'Potter Pansy': 'female',
#  'Dumbledore Snape': 'female',
#  'Mrs Brown': 'female',
#  'Draco Draco Malfoy': 'female',
#  'Percy Percy': 'female',
#  'Dean Dean': 'female',
#  'Bloody Hermione': 'female',
#  'Rose Evans': 'female',
#  'George George': 'female',
#  'Charlie Charlie': 'female',
#  'Mrs Jones': 'female',
#  'Tina Queenie': 'female',
#  'Neville Ginny': 'female',
#  'Godric Harry': 'female',
#  'Ginny Thomas': 'female',
#  'Ginny Neville': 'female',
#  'Madam Sprout': 'female',
#  'Narcissa Black Malfoy': 'female',
#  'Lily Rose': 'female',
#  'Lord Nott': 'female',
#  'Neville Neville': 'female',
#  'Albus James': 'female',
#  'Teddy Draco': 'female',
#  'Hermione Rose': 'female',
#  'James Dean': 'female',
#  'Lily Snape': 'female',
#  'Potter Lily': 'female',
#  'George Fabian Weasley': 'female',
#  'Salazar Potter': 'female',
#  'Nigellus': 'female',
#  'Rose Granger': 'female',
#  'Evans Lily': 'female',
#  'Lupin Remus': 'female',
#  'Irma Crabbe': 'female',
#  'Mrs Thomas': 'female',
#  'Draco Black': 'female',
#  'Lord Longbottom': 'female',
#  'Pansy Hermione': 'female',
#  'Barnaby Lee': 'male',
#  'Narcissa Malfoy Black': 'male',
#  'Harry Percy': 'male',
#  'Snape Dumbledore': 'male',
#  'Snape Remus': 'male',
#  'Charlie Potter': 'male',
#  'Lord Gryffindor': 'male',
#  'Prince Sirius': 'male',
#  'Ronald Hermione': 'male',
#  'Harry Dobby': 'male',
#  'Narcissa Severus': 'male',
#  'Charlie Ron': 'male',
#  'Charlie Harry': 'male',
#  'Harry Potter Malfoy': 'male',
#  'Weasley Granger': 'male',
#  'Severus Snape Harry': 'male',
#  'Lord Zabini': 'male',
#  'Hermione Lucius': 'male',
#  'Percy Ron': 'male',
#  'Blaise Pansy': 'male',
#  'Crouch Sr.': 'male',
#  'Irma Black': 'female',
#  'Pansy Ron': 'female',
#  'Lord Lucius': 'female',
#  'Malfoy Lord': 'female',
#  'Lord Grindelwald': 'female',
#  'Molly Ginny': 'female',
#  'Hogwarts Albus': 'female',
#  'Bill Bill': 'female',
#  'Tom Voldemort': 'female',
#  'Mrs Lestrange': 'female',
#  'Lord James': 'female',
#  'Cassiopeia Black': 'female[1]',
#  'Fred Hermione': 'female[1]',
#  'Alice Frank': 'female[1]',
#  'Severus Sirius': 'female[1]',
#  'Theodore Lupin': 'female[1]',
#  'James Teddy': 'female[1]',
#  'Albus Rose': 'female[1]',
#  'Bellatrix Black Lestrange': 'female[1]',
#  'Harry Blaise': 'female[1]',
#  'Hestia Carrow': 'female',
#  'Portrait Snape': 'female',
#  'Harry McGonagall': 'female',
#  'Potter Albus': 'female',
#  'Albus Snape': 'female',
#  'Mrs Nott': 'female',
#  'Hogwarts Malfoy': 'female',
#  'Draco Teddy': 'female',
#  'Draco Dobby': 'female',
#  'Theodore Tonks': 'female',
#  'Fleur Hermione': 'female',
#  'Mrs Parkinson': 'female',
#  'Ginny Potter Weasley': 'female',
#  'George Lee': 'female',
#  'Gryffindor Harry Potter': 'female',
#  'Luna Scamander': 'female',
#  'Pansy Malfoy': 'female',
#  'Pansy Nott': 'female',
#  'Voldemort Hermione': 'female',
#  'Lord Greengrass': 'female',
#  'Weasley Potter': 'female',
#  'Sirius Orion': 'female',
#  'Merula Snyde': 'female',
#  'Teddy James': 'female',
#  'Lord Harry James Potter': 'female',
#  'Bloody Snape': 'female',
#  'Harry Harry Harry': 'female',
#  'Voldemort Draco': 'female',
#  'Harry Hannah': 'female',
#  'George Hermione': 'female',
#  'Petunia Dudley': 'female',
#  'Teddy Teddy': 'female',
#  'Ron Seamus': 'female',
#  'Potter Black': 'female',
#  'Severus Narcissa': 'female',
#  'Nearly Headless Nick': 'male[4]',
#  'Madam Snape': 'male[4]',
#  'Moody Harry': 'male[4]',
#  'James Snape': 'male[4]',
#  'Andromeda Black Tonks': 'male[4]',
#  'Bill Harry': 'male[4]',
#  'Lord Sirius Black': 'male[4]',
#  'Molly Ron': 'male[4]',
#  'Harry Slytherin': 'male[4]',
#  'Ted Remus Lupin': 'male',
#  'Hermione Minerva': 'male',
#  'Bartemius Crouch Jr.': 'male',
#  'Harry Severus Snape': 'male',
#  'Harry Potter Dobby': 'male',
#  'Fred Harry': 'male',
#  'Harry Petunia': 'male',
#  'Scorpius Rose': 'male',
#  'Weasleys Harry': 'male',
#  'Lupin Harry': 'male',
#  'Vernon Dudley': 'male',
#  'Lord Lestrange': 'male',
#  'John Thomas': 'male',
#  'Madam Potter': 'male',
#  'Hogwarts Snape': 'male',
#  'Ginny Zabini': 'male',
#  'Harry Viktor': 'male',
#  'Luna Potter': 'male',
#  'Charlie Fred': 'male',
#  'Ron Fred': 'male',
#  'Luna Ron': 'male',
#  'Penny Clearwater': 'male',
#  'Nott Sr.': 'male',
#  'Arthur Ron': 'male',
#  'Crabbe Sr.': 'male',
#  'Tom Gaunt': 'male',
#  'Hufflepuff Slytherin': 'male',
#  'Evans Sirius': 'male',
#  'Ron Snape': 'male',
#  'Lily Black': 'male',
#  'Ginny Dean': 'male',
#  'Fleur Bill': 'male',
#  'Nymphadora Lupin': 'female',
#  'Sirius Lupin': 'female',
#  'Lily Ginny': 'female',
#  'Hogwarts Sirius': 'female',
#  'Lupin Severus': 'female',
#  'Scorpius Potter': 'female',
#  'Mrs Creevey': 'female',
#  'Madam Granger': 'female',
#  'James Black': 'female',
#  'Minerva Albus': 'female',
#  'Lily Lupin': 'female',
#  'Harry Arthur': 'female',
#  'Portrait Albus': 'female',
#  'Scorpius Draco Malfoy': 'female',
#  'Sirius Potter': 'female',
#  'Potter Mother': 'female',
#  'Tom Sr.': 'female',
#  'Blaise Blaise': 'female',
#  'Dean Harry': 'female',
#  'Weasley Weasley': 'female',
#  'Mrs Finnigan': 'female',
#  'George Ron': 'female',
#  'Harry Kingsley': 'female',
#  'Bill Ginny': 'female',
#  'Mrs Pettigrew': 'female',
#  'Harry Riddle': 'female',
#  'Cassiopeia Malfoy': 'female',
#  'Slytherin Malfoy': 'female',
#  'George Angelina': 'female',
#  'Ron Luna': 'female',
#  'Hermione Granger Weasley': 'female',
#  'Rolf Luna': 'female',
#  'Granger Pansy': 'female',
#  'Madam Prince': 'female',
#  'Hufflepuff Cedric Diggory': 'female',
#  'Remus Nymphadora': 'female',
#  'Lucius Snape': 'female',
#  'Lord Peter': 'female',
#  'McGonagall Hermione': 'female',
#  'Malfoy Granger': 'female',
#  'Minerva Harry': 'female',
#  'Ron Percy': 'female',
#  'Madam Trelawney': 'female',
#  'James Arthur': 'female',
#  'Dumbledore Lucius': 'female',
#  'Charlie George': 'female',
#  'Percy Charlie': 'female',
#  'Hogwarts Harry Potter': 'female',
#  'Sirius Dumbledore': 'female',
#  'Hope Harry': 'female',
#  'Remus Hermione': 'female',
#  'Mrs Prewett': 'female',
#  'Evan Potter': 'female',
#  'Neville Blaise': 'female',
#  'Black Potter': 'female',
#  'Harry Longbottom': 'female',
#  'Godric Salazar': 'female',
#  'Padfoot James': 'female',
#  'Slytherin Draco Malfoy': 'female',
#  'Peter Harry': 'female',
#  'Remus Bill': 'female',
#  'Granger Malfoy': 'female',
#  'Harry Andromeda': 'female',
#  'Longbottom Draco': 'female',
#  'Lord Hermione': 'female',
#  'Draco Charlie': 'female',
#  'Percy Newt': 'female',
#  'Lord Severus': 'female',
#  'Mother Weasley': 'female',
#  'Slytherin Hermione': 'female',
#  'Mrs Draco': 'female',
#  'Dumbledore Hogwarts': 'female',
#  'Dumbledore McGonagall': 'female',
#  'Bloody Harry': 'female',
#  'Hermione Weasley Granger': 'female',
#  'Dumbledore Potter': 'female',
#  'Mrs Bulstrode': 'female',
#  'Mother Potter': 'female',
#  'Hogwarts Hogwarts': 'female',
#  'Percy George': 'female',
#  'Hermione Fred': 'female',
#  'Bill Remus': 'female',
#  'Mrs Delacour': 'female',
#  'George Percy': 'male',
#  'Scorpius Harry': 'male',
#  'McGonagall Flitwick': 'male',
#  'Padfoot Remus': 'male',
#  'Regulus Regulus': 'male',
#  'Molly Molly': 'male',
#  'Lord James Potter': 'male',
#  ...}

# %%
# See how many characters, uses have annotated gender

print(len(character_gender))
# print(len(characters_ctr_matches))
print(len(character_gender)/len(characters_ctr_matches))
# Out:
# 1681
# 0.8528665651953323

# %%
labeled_uses = sum([characters_ctr_matches[name] for name in character_gender])
print(labeled_uses)

# unlabeled_uses = sum([characters_ctr_matches[name] for name in characters_no_genderbox + characters_http_error])
# print(unlabeled_uses)
total_uses = sum(characters_ctr_matches.values())

print(labeled_uses/total_uses)
# Out:
# 480383
# 0.955316872558924

# %%
# Save character gender json
with open('/data/fanfiction_gender_roles/harrypotter_ao3/hp_character_genders.json', 'w') as f:
    json.dump(character_gender, f)

# %% [markdown]
# ## Create spreadsheet with character features, gender, etc

# %%
# Load character gender dictionary
import json

with open('/data/fanfiction_gender_roles/harrypotter_ao3/hp_character_genders.json', 'r') as f:
    character_gender = json.load(f)

# Load canonical character names to remove from character features
char_list_fpath = '/projects/fanfiction_gender_roles/scripts/harrypotter_characters.txt'
with open(char_list_fpath) as f:
    canonical_characters = f.read().splitlines()
    
extra = ['Dobby']
remove = ['Hogwarts', 'Slytherin', 'Gryffindor', 'Order', 'The',
         'The Slytherin',
          'The Headmaster',
         ]
canonical_characters += extra
canonical_characters = [c for c in canonical_characters if not c in remove]

print(len(canonical_characters))

canonical_character_name_parts = set([part for name in canonical_characters for part in name.split()])
exclude = set(['the'])
canonical_character_name_parts -= exclude
list(canonical_character_name_parts)[:10]

remove = ['Hogwarts', 'Slytherin', 'Gryffindor', 'Order', 'The',
         'The Slytherin',
          'The Headmaster',
          'Weasley', # ambiguous
          'Weasleys',
          'Hufflepuff',
         ]

name_transform = { # Might then miss when stories use these terms, though (same with canonicalize): might want to spread gender info afterward
    'Potter': 'Harry Potter',
    'Mr. Potter': 'Harry Potter',
    'Mr Potter': 'Harry Potter',
    'The Harry': 'Harry Potter',
    'Mr Weasley': 'Ron Weasley',
    'Tom': 'Tom Riddle',
    'Black': 'Sirius Black',
    'The Draco': 'Draco Malfoy',
    'The Dark Lord': 'Voldemort',
    'The Dark Lord Voldemort': 'Voldemort',
    'Dark Lord': 'Voldemort',
    'Lord': 'Voldemort',
    'Malfoy': 'Draco Malfoy',
    'James': 'James Potter I',
    'James Potter': 'James Potter I',
    'Lily': 'Lily J. Potter',
    'Albus': 'Albus Dumbledore',
    'Teddy': 'Teddy Lupin',
    'Newt': 'Newton Scamander',
    'Rose': 'Rose Granger-Weasley',
    'Lily Potter': 'Lily J. Potter',
    'Regulus': 'Regulus Black I',
    'Mrs Weasley': 'Molly Weasley',
}
    

def canonicalize(name):
    
    name_parts = name.split()
    new_name_parts = []
    
    for name_part in name_parts:
        if name_part in canonical_character_name_parts:
            new_name_parts.append(name_part)
            
    new_name = ' '.join(new_name_parts)
    
    if new_name in remove:
        new_name = ''
        
    if new_name in name_transform:
        new_name = name_transform[new_name]
            
    return new_name
# Out:
# 245

# %%
# Load character features, merge with gender, etc
import os
import json
import pandas as pd
from tqdm import tqdm_notebook as tqdm
from IPython.core.debugger import set_trace

dataset_name = 'complete_en_1k-50k'
output_path = f'/data/fanfiction_gender_roles/harrypotter_ao3/{dataset_name}/output/char_features'

header = ['fic_id', 'character_original', 'character_canonical', 'character_gender', 'character_features']
# outlines = [header]
outlines = []

name_parts_lower = [c.lower() for c in canonical_character_name_parts]

for fname in tqdm(os.listdir(output_path)):
    fic_id = fname.split('.')[0]
    
    with open(os.path.join(output_path, fname)) as f:
        char_features = json.load(f)
              
    for char in char_features:
        canonical_char = canonicalize(char)
        if not canonical_char in character_gender: continue
        gender = character_gender[canonical_char]
        
        feats = ' '.join([feat for feat in char_features[char] if not feat in name_parts_lower])
        if len(feats) < 1: continue
        outlines.append([fic_id, char, canonical_char, gender, feats])
            
out_df = pd.DataFrame(outlines[1:], columns=header)
out_df
# Out:
# HBox(children=(IntProgress(value=0, max=71943), HTML(value='')))
#           fic_id character_original character_canonical character_gender  \
# 0        5888698              Remus               Remus             male
# 1        5888698            Padfoot             Padfoot             male
# 2          10199              Draco               Draco             male
# 3        5355224           Hermione            Hermione           female
# 4        5355224              Draco               Draco             male
# 5        5355224              Ginny               Ginny           female
# 6        5355224               Luna                Luna           female
# 7        5355224            Salazar             Salazar          male[5]
# 8       10838292              Remus               Remus             male
# 9       10838292            Marlene             Marlene          male[5]
# 10      10838292             Sirius              Sirius             male
# 11      10838292              James      James Potter I             male
# 12      15522078          Voldemort           Voldemort             male
# 13      15522078              Patil               Patil             male
# 14      15522078           Hermione            Hermione           female
# 15      15522078              Harry               Harry             male
# 16      15522078              Draco               Draco             male
# 17      15522078             Blaise              Blaise             male
# 18      15522078             Zabini              Zabini           female
# 19      15522078               Dean                Dean             male
# 20      15522078         Dumbledore          Dumbledore             male
# 21      15522078              Snape               Snape             male
# 22      15522078            Severus             Severus             male
# 23      15522078               Lord           Voldemort             male
# 24      15522078              Dobby               Dobby             male
# 25      15522078               Lily      Lily J. Potter           female
# 26       9525716            Michael             Michael             male
# 27       9525716              Terry               Terry           female
# 28       9525716            Anthony             Anthony           female
# 29       9525716             Ariana              Ariana           female
# ...          ...                ...                 ...              ...
# 279136  10786131            Severus             Severus             male
# 279137  10786131         Dumbledore          Dumbledore             male
# 279138  10786131          Voldemort           Voldemort             male
# 279139  10786131               Lily      Lily J. Potter           female
# 279140  14829977            Severus             Severus             male
# 279141  14829977            Minerva             Minerva           female
# 279142  14829977            Granger             Granger             male
# 279143  14829977            Regulus     Regulus Black I          male[1]
# 279144  14829977          Voldemort           Voldemort             male
# 279145  14829977             Hagrid              Hagrid             male
# 279146  14829977           Kingsley            Kingsley          male[5]
# 279147  14829977            Padfoot             Padfoot             male
# 279148  14829977              James      James Potter I             male
# 279149   7881532              Lupin               Lupin             male
# 279150   7881532              Remus               Remus             male
# 279151  10076291              Harry               Harry             male
# 279152  10076291             Potter        Harry Potter             male
# 279153  10076291                Ron                 Ron             male
# 279154  10076291              Goyle               Goyle             male
# 279155  10076291             Crabbe              Crabbe             male
# 279156   9182275             Graves              Graves             male
# 279157   8703775               Newt    Newton Scamander          male[2]
# 279158   8703775              Percy               Percy             male
# 279159   8703775            Queenie             Queenie           female
# 279160   8703775               Tina                Tina           female
# 279161   8485216          Voldemort           Voldemort             male
# 279162   8485216              Harry               Harry             male
# 279163   8485216             Sirius              Sirius             male
# 279164   8485216              Snape               Snape             male
# 279165   2789771            Granger             Granger             male
#
#                                        character_features
# 0       carries cherished carried carried was been wan...
# 1                                                      by
# 2       responded hinted is walked knew question sat c...
# 3       was felt growled let doing read gotten going r...
# 4       find like pouted gripped smirked joked drawled...
# 5       said snapped said said snickered getting think...
# 6       's said seemed imagine said said smiled asked ...
# 7                                                  damned
# 8       considered thought asked doing pulled going op...
# 9       liked tell trying mean mind mind touch said kn...
# 10      said get try sleep go have had staring tasted ...
# 11      said sound dropped said said was said get said...
# 12      know coming used met am had talking thought am...
# 13      was was had blamed friends took smiled could s...
# 14      thinking interject rolled answered smiled said...
# 15      at for at hiding tell fucking scowled be turni...
# 16      seemed threw have chocked scrubbed breaking go...
# 17      spoke spoke did lost sat realised murmured gon...
# 18                                     was gone patronize
# 19                                               answered
# 20                                         was as flicked
# 21      wearing shaking through as lifting into decidi...
# 22      swore was be looked read was whimpered spread ...
# 23                                 following with sneered
# 24                                            found as as
# 25                                             had folded
# 26      sitting hates dropping glances mean crying lau...
# 27      put goes trails turns says says wants says mea...
# 28      says says thinks standing gives closes mean sa...
# 29                                               comes be
# ...                                                   ...
# 279136  looked stumbled getting fell tried moaned bega...
# 279137                                 achieve son person
# 279138                                             is one
# 279139                                        haunt about
# 279140  knew imagine realised do grabbed got had knew ...
# 279141                                did attract was did
# 279142  hated knelt submitted given been took bend sla...
# 279143                                was like marked man
# 279144                                               with
# 279145                                               walk
# 279146                            requested spoke droning
# 279147                                       trotted into
# 279148  was raged threw picked created knew took tore ...
# 279149                  kept was was be have relationship
# 279150                                            replied
# 279151  sighed pointed jerked lunged cast pointed aske...
# 279152                                          detention
# 279153  grumbled walked snarled 're humiliated be chuc...
# 279154                                                 on
# 279155  come do was do was licked said kiss wish thoug...
# 279156  smell missed said reached continued pulled rei...
# 279157  suffer asked asked locked looked think stood l...
# 279158     went took have said said to pushed followed at
# 279159  knew looked has loved met gave started correct...
# 279160  grumbled followed looked change got sunken hea...
# 279161  blames dealing 's make 's going going making b...
# 279162  is starts doing stuffs pets pick turns want sn...
# 279163                   make than good beautiful good us
# 279164  tipped fall open slipped reach hang manages gl...
# 279165                                             showed
#
# [279166 rows x 5 columns]

# %%
outpath = f'/data/fanfiction_gender_roles/harrypotter_ao3/{dataset_name}/output/character_gender_features.csv'
out_df.to_csv(outpath, index=False)

# %%
# Print #stories

len(out_df['fic_id'].unique())
# Out:
# 66061

# %% [markdown]
# # Postag, parse character assertions

# %%
# Load assertions for characters
import json
from tqdm import tqdm_notebook as tqdm
import os

dataset_name = 'complete_en_1k-50k'
pipeline_output_path = f'/data/fanfiction_gender_roles/harrypotter_ao3/{dataset_name}/output/'

char_assertions = {}
assertions_dirpath = os.path.join(pipeline_output_path, 'assertion_extraction')

# for fic, chars in tqdm(fic_chars.items()):
for fname in tqdm(os.listdir(assertions_dirpath)):
    fic_assertions_path = os.path.join(assertions_dirpath, fname)
#     if not os.path.exists(fic_assertions_path):
#         continue
        
    with open(fic_assertions_path) as f:
        char_assertions[fname[:-5]] = json.load(f)
        
len(char_assertions)
# Out:
# HBox(children=(IntProgress(value=0, max=14989), HTML(value='')))
# 14989

# %%
char_assertions.keys()
# Out:
# dict_keys(['4012087', '5480774', '183523', '4465862', '7514581', '918622', '4459220', '54247', '726061', '309535', '11032020', '16391837', '8531686', '248467', '3934807', '3976168', '8204464', '8221997', '789612', '8206435', '235541', '7885909', '3791320', '306401', '16111841', '84543', '11969865', '6664459', '115796', '11577444', '5924032', '391709', '1817845', '9663557', '239881', '8252444', '810012', '3773293', '755306', '234598', '9243137', '1111335', '16453394', '6605119', '4020754', '8811436', '3917428', '7277893', '300671', '544208', '929056', '2495252', '292770', '11063691', '12806625', '169335', '8204017', '5756434', '3789070', '8833084', '1110433', '9391574', '3728875', '6177028', '1114491', '16004126', '306116', '11291925', '61305', '9133588', '75719', '8209016', '853363', '29676', '982077', '2315891', '856353', '532950', '12420267', '6675562', '299936', '2943011', '308278', '53731', '3789397', '1827937', '2304326', '8198329', '661730', '168040', '11662965', '16040645', '1899714', '4791557', '753932', '6117986', '11246277', '921570', '1121247', '7870972', '11944233', '7227160', '201776', '4011964', '72733', '3965281', '612860', '7855999', '392015', '8169500', '403512', '7628893', '981353', '246331', '400719', '241198', '7597852', '9190247', '3964213', '182004', '1691528', '4075366', '964223', '391393', '167355', '9822929', '332573', '400944', '16245176', '8210705', '299720', '549693', '6154092', '9849392', '5338412', '5933077', '9258329', '8205143', '300147', '540884', '4709465', '8871535', '916231', '449375', '3386795', '9890435', '667486', '8854672', '2382668', '208988', '474711', '7867294', '11956635', '9848264', '8172242', '163174', '5332439', '7669231', '201960', '960002', '440155', '7868047', '9112684', '11259597', '6625513', '5496917', '9893675', '4714091', '16197818', '295454', '5797459', '4771694', '2345984', '9850970', '1114478', '9278171', '542586', '4733387', '546524', '5934295', '11294748', '9649505', '544029', '5456021', '8831878', '9239099', '16492055', '4040224', '8533711', '290294', '7506304', '910961', '677837', '2371463', '2350856', '7650007', '592472', '10814040', '11692494', '11746860', '4595955', '4054594', '6118054', '5924377', '11853558', '767513', '201124', '473180', '295143', '826542', '297112', '1805074', '306620', '2306912', '16301780', '8202802', '169567', '544062', '3789622', '751306', '3969877', '618301', '572758', '783453', '16530026', '6181156', '238605', '331224', '394553', '7868434', '16534328', '7635481', '16204256', '8214157', '371240', '2401532', '4012780', '206930', '8839390', '7890550', '16037840', '2404502', '8233603', '7677718', '298818', '16055258', '5930362', '40394', '9118861', '3968377', '11063481', '8836108', '8201237', '9829715', '9893720', '16367504', '4453547', '5953594', '4431323', '3061787', '306306', '1650755', '5925877', '960078', '16161332', '4056187', '394392', '309279', '760054', '54813', '242183', '5923630', '16063685', '5303318', '3775567', '16473680', '3382706', '5930329', '6601510', '9199190', '664808', '290862', '1800529', '168334', '7685749', '4429073', '11295150', '5428376', '11714703', '1664', '9894332', '3325418', '4041004', '11022522', '2312027', '8841559', '987890', '16226141', '7282393', '333244', '11945991', '8844871', '205098', '5700358', '7888600', '595815', '374603', '9849800', '540272', '912901', '16436549', '8513533', '4755380', '3345266', '188426', '11431767', '2318168', '9202793', '5933551', '115661', '47505', '9106459', '236475', '4793201', '234540', '8218376', '631303', '854956', '9132256', '7871053', '2392538', '16298231', '4069309', '5722399', '1615730', '576548', '4744400', '3335189', '4015075', '574801', '2400350', '8208500', '810023', '57036', '11308737', '5941762', '445585', '852454', '11556924', '8208995', '7888972', '8806210', '2076906', '376844', '335371', '8862487', '3368255', '243627', '2316143', '3371480', '11072964', '8213209', '8205644', '4001998', '3789805', '301866', '16307528', '1117293', '5448485', '11661198', '2415737', ...

# %%
char_assertions['4012087'].keys()
# Out:
# dict_keys(["($_Sirius_')", '($_Snivellus)', '($_the_entire_time_Severus)', '($_Black)', '($_Harry)', '($_Lily)', "($_Severus_')", '($_James)', '($_Dumbledore)', '($_Merlin)', '($_Mordred)', '($_Lupin)'])

# %%
char_assertions['4012087']["($_Sirius_')"]
# Out:
# ["Sirius ($_Sirius_') took the glass . `` Not trying to poison me , are you , Snivellus ($_Snivellus) ? '' His ($_the_entire_time_Severus) concern was feigned ; he ($_the_entire_time_Severus) drank immediately . \n",
#  " Sirius ($_Sirius_') stared into his ($_the_entire_time_Severus) goblet , one corner of his ($_the_entire_time_Severus) mouth twitching . `` Oh , I see . '' He ($_the_entire_time_Severus) paused , seeming to consider . `` I ($_the_entire_time_Severus) 'm an enemy of Voldemort .",
#  "`` No . '' The word was barked out between gritted teeth , resentful , and Sirius ($_Sirius_') put one hand over his ($_the_entire_time_Severus) mouth , turned his ($_the_entire_time_Severus) head away for a moment , clearly wanting to leave it at that . But then he ($_the_entire_time_Severus) grated out , `` As soon as I ($_the_entire_time_Severus) knew he ($_the_entire_time_Severus) was my ($_the_entire_time_Severus) responsibility , I ($_the_entire_time_Severus) gave him ($_the_entire_time_Severus) up to Dumbledore even though we did n't completely trust him ($_the_entire_time_Severus) , just so I ($_the_entire_time_Severus) could chase down revenge . '' \n",
#  "`` Do n't you ($_the_entire_time_Severus) say a word against Lily ($_Lily) , '' Sirius ($_Sirius_') grumbled . \n",
#  " Proving his madness , Sirius ($_Sirius_') laughed aloud then . `` No , I ($_Sirius_') 'm -- ! No ! What? Is Lily ($_Lily) what 's had your ($_Severus_') knicks in a twist all these years ? ''",
#  "`` Yes , '' Severus ($_the_entire_time_Severus) replied immediately , though his ($_the_entire_time_Severus) teeth . He ($_the_entire_time_Severus) looked away quickly , but Sirius ($_Sirius_') had got it ($_Sirius_') . \n",
#  "`` Because people are awful to me ($_the_entire_time_Severus) , '' he ($_the_entire_time_Severus) ground out , jerking a hand at Sirius ($_Sirius_') as an example . `` I ($_the_entire_time_Severus) become defensive and I ($_the_entire_time_Severus) hurt them before they can hurt me ($_the_entire_time_Severus) . '' Severus ($_the_entire_time_Severus) refused to allow himself ($_the_entire_time_Severus) to colour with embarrassment . `` Why have you ($_the_entire_time_Severus) always hated me ($_the_entire_time_Severus) so ? '' \n",
#  "`` Because you ($_the_entire_time_Severus) remind me ($_the_entire_time_Severus) of myself ($_the_entire_time_Severus) , '' Sirius ($_Sirius_') snapped . '' ... of the Blacks . '' \n",
#  "`` It 's for Lily ($_Lily) that you ($_Lily) 're helping Harry ($_Harry) now , is n't it ? '' Sirius ($_Sirius_') asked . \n",
#  "`` And yet you ($_Lily) treat him appallingly yourself ($_Lily) , '' Sirius ($_Sirius_') pointed out . \n",
#  "Sirius ($_Sirius_') frowned , shook his head . `` That absolutely is n't the truth , '' he said carefully . `` Nothing about that is true . '' \n",
#  "`` Are you ($_the_entire_time_Severus) loyal to Dumbledore ? '' Sirius ($_Sirius_') eventually asked . \n",
#  "`` No , I 'm only loyal to my family . '' He ($_James) clearly did n't refer to the ancient and most noble house of Black ($_Black) . There was another long silence . Each man watched the other carefully , unsure what to make of this development . Sirius ($_Sirius_') drank more of the dosed wine . \n",
#  " `` Of course not , '' Sirius ($_Sirius_') said with a shrug . `` We ($_Sirius_') were at war -- and not regular war , mind you , special evil racist wizard war , '' he ($_James) elaborated unnecessarily , grimly amused by his ($_James) own summation . `` She fell pregnant , James ($_James) was -- I ($_James) loved him ($_James) dearly , you understand , but he ($_James) was an absolute tit , he ($_James) really was . The -- our ($_Sirius_') whole lives were a trainwreck and we ($_Sirius_') all knew it . None of us ($_Sirius_') were happy , but we ($_Sirius_') were young , and that 's enough sometimes ... I ($_James) want to talk about something else . ''",
#  "Severus ($_the_entire_time_Severus) began to wonder if he ($_the_entire_time_Severus) had perhaps tipped a bit more into Sirius_' ($_Sirius_') goblet than was required -- the man was beginning to sound quite alarmingly drugged , not a typical reaction at all . Well , that or he ($_the_entire_time_Severus) was just already sauced . Considering his ($_the_entire_time_Severus) bony frame , either was equally likely . \n",
#  "`` No , '' Sirius ($_Sirius_') said . `` Afraid I have n't had the pleasure of shagging Merlin ($_Merlin) , I could n't tell you ($_the_entire_time_Severus) anything about that . '' \n",
#  '`` Because he lived so long ago , \'\' he blurted . Sirius ($_Sirius_\') paused , confused . He seemed to consult a patch of space immediately in front of his face . His focus slowly lengthened until he was looking at Severus ($_the_entire_time_Severus) again . `` I do n\'t understand . Why what?" \n',
#  " `` To you ($_the_entire_time_Severus) , perhaps . Which means , incidentally , that James ($_James) owes me five squids , wherever he ($_James) is . '' He ($_James) ignored the werewolf issue altogether ; Remus was as human as he ($_James) . Sirius ($_Sirius_') briefly consulted the space in front of his ($_James) eyes again . `` We ... fit . We were attracted to each other . He ($_James) understood me , I understood him ($_James) . ''",
#  ' `` We know you ($_James) turned coat for us , \'\' he ($_James) said then . `` Which means your ($_James) first loyalty was to them . \'\' Eyes narrowed , he ($_James) drew out a cigarette . `` You ($_James) , \'\' he ($_James) said , pausing to spark it on his ($_James) knuckle , \'\' participated . Willingly." It was clear Sirius ($_Sirius_\') would never forgive him ($_James) for it , whatever truths they ($_Sirius_\') were sharing tonight notwithstanding .',
#  "Sirius ($_Sirius_') seemed to regard him ($_the_entire_time_Severus) with something like sympathy or even understanding for a bare second , but then he ($_the_entire_time_Severus) smirked , cruelly . `` James ($_James) was a pureblood , just like me . You 've been envious all along . '' \n",
#  "`` I did the same , '' Sirius ($_Sirius_') blurted around the filter of his ($_the_entire_time_Severus) cigarette . `` That night , at the willow . I tried to frighten you because I thought it would make me feel better about being so much like you , so much like the whole pureblooded serpent 's nest I 'd come from . I never thought you 'd go . I thought it would prove that you were a coward , that I was better than you because I was brave enough to face him -- '' \n",
#  "`` It 's no wonder they made you ` ead-of - ` ouse , '' Sirius ($_Sirius_') drawled , dropping his haiches in a momentary and deliberate eschewing of his class -- like using ` squids ' for a bet . He took a long drag . \n",
#  "`` Yes ... '' Sirius ($_Sirius_') said slowly , and he sounded sad . He might not have been sorry for the effect his prank had had on Severus ($_the_entire_time_Severus) , particularly . `` Do you feel remorse ? For the people you killed ? Because of their blood-status ? '' \n",
#  "`` Mordred ($_Mordred) 's cock , you really are into it ($_Mordred) , '' Sirius ($_Sirius_') observed . `` I 'm proud of it ($_Mordred) , sir . It ($_Mordred) may be my greatest accomplishment in life . '' He shrugged . `` It 's not as though I had a choice in the matter . '' \n",
#  "Sirius ($_Sirius_') shrugged again as if that settled the matter , grinning mildly . \n",
#  "Sirius ($_Sirius_') nodded . `` Because I was born a blood-traitor , and I knew it early . I never had a choice in which side to take . '' \n",
#  "Sirius ($_Sirius_') grinned wickedly .  he prodded , still slurring charmingly , for he was n't bound to answer a question half-asked . `` Motorbike enthusiasts ? Avid readers ? Drinkers of black coffee ? '' \n",
#  "Sirius ($_Sirius_') pursed his lips in a considering sort of way ; at length he shrugged . `` I do n't think so , '' he finally said , grinding his cigarette out on the table . \n",
#  '`` Of course I do . Now." Sirius ($_Sirius_\') was silent for a moment , again consulting the middle distance . `` I should have trusted him_all ($_Lupin) along . \'\' \n',
#  "Sirius ($_Sirius_') quite overarched a single brow , in a magnificent display of aristocratic disdain . `` Other way ` round , darling , '' he said , his now dramatically slow and precise diction seething-facetious . `` Oh , or did you mean his furry little problem ? '' \n",
#  "Sirius ($_Sirius_') looked haughty , but he ($_the_entire_time_Severus) admitted , `` I ($_the_entire_time_Severus) 'm sure Remus would thank you to bring some wolfsbane potion next week . '' \n",
#  "`` It makes him ($_the_entire_time_Severus) much more comfortable , '' Sirius ($_Sirius_') clarified , still a touch overproud . There was a long silence . Then , a not-so-subtle highborn dismissal , `` Was there anything else ? '' \n",
#  "Sirius ($_Sirius_') nodded , seemed to consider for a moment , then he ($_the_entire_time_Severus) met the other man 's eyes again . `` Did you really love her ? '' he ($_the_entire_time_Severus) asked then . `` Lily ($_Lily) , I ($_the_entire_time_Severus) mean . '' \n",
#  "`` Sometimes I think I know that feeling , '' Sirius ($_Sirius_') admitted with a wry quirk of the lip . `` You and I , we were always far too similar . '' And then , turning it into a sly grin , he ($_the_entire_time_Severus) stood and drew something small out of his ($_the_entire_time_Severus) waistcoat pocket . Leaning forward over the table , he ($_the_entire_time_Severus) set it down before the other man 's glass . `` Goodnight , Severus , it 's been a pleasure , '' he ($_the_entire_time_Severus) said sweetly , and then he ($_the_entire_time_Severus) turned to go , waving over his ($_the_entire_time_Severus) shoulder as he ($_the_entire_time_Severus) left the room . \n",
#  "It was a tiny , ornate phial , empty now . The little parchment tag , labelled in Sirius ($_Sirius_') ' own hand , read Draught of Silver-Tongue . \n"]

# %%
from IPython.core.debugger import set_trace

# Replace pronouns with coref result
# replacements = [] # indices of replacements to do

test_split = test.split()
for i, word in enumerate(test_split):
    if word.startswith('($_'):
        name = ' '.join([part for part in word.split('_') if part[0].isupper()])
        if name.endswith(')'):
            name = name[:-1]
        test_split[i-1] = name
        test_split[i] = ''
        
test_replaced = ' '.join(test_split)
test_replaced
# Out:
# 'Sirius  took the glass . `` Not trying to poison me , are you , Snivellus  ? \'\' Severus  concern was feigned ; Severus  drank immediately . Sirius  stared into Severus  goblet , one corner of Severus  mouth twitching . `` Oh , I see . \'\' Severus  paused , seeming to consider . `` Severus  \'m an enemy of Voldemort . `` No . \'\' The word was barked out between gritted teeth , resentful , and Sirius  put one hand over Severus  mouth , turned Severus  head away for a moment , clearly wanting to leave it at that . But then Severus  grated out , `` As soon as Severus  knew Severus  was Severus  responsibility , Severus  gave Severus  up to Dumbledore even though we did n\'t completely trust Severus  , just so Severus  could chase down revenge . \'\' `` Do n\'t Severus  say a word against Lily  , \'\' Sirius  grumbled . Proving his madness , Sirius  laughed aloud then . `` No , Sirius  \'m -- ! No ! What? Is Lily  what \'s had Severus  knicks in a twist all these years ? \'\' `` Yes , \'\' Severus  replied immediately , though Severus  teeth . Severus  looked away quickly , but Sirius  had got Sirius  . `` Because people are awful to Severus  , \'\' Severus  ground out , jerking a hand at Sirius  as an example . `` Severus  become defensive and Severus  hurt them before they can hurt Severus  . \'\' Severus  refused to allow Severus  to colour with embarrassment . `` Why have Severus  always hated Severus  so ? \'\' `` Because Severus  remind Severus  of Severus  , \'\' Sirius  snapped . \'\' ... of the Blacks . \'\' `` It \'s for Lily  that Lily  \'re helping Harry  now , is n\'t it ? \'\' Sirius  asked . `` And yet Lily  treat him appallingly Lily  , \'\' Sirius  pointed out . Sirius  frowned , shook his head . `` That absolutely is n\'t the truth , \'\' he said carefully . `` Nothing about that is true . \'\' `` Are Severus  loyal to Dumbledore ? \'\' Sirius  eventually asked . `` No , I \'m only loyal to my family . \'\' James  clearly did n\'t refer to the ancient and most noble house of Black  . There was another long silence . Each man watched the other carefully , unsure what to make of this development . Sirius  drank more of the dosed wine . `` Of course not , \'\' Sirius  said with a shrug . `` Sirius  were at war -- and not regular war , mind you , special evil racist wizard war , \'\' James  elaborated unnecessarily , grimly amused by James  own summation . `` She fell pregnant , James  was -- James  loved James  dearly , you understand , but James  was an absolute tit , James  really was . The -- Sirius  whole lives were a trainwreck and Sirius  all knew it . None of Sirius  were happy , but Sirius  were young , and that \'s enough sometimes ... James  want to talk about something else . \'\' Severus  began to wonder if Severus  had perhaps tipped a bit more into Sirius  goblet than was required -- the man was beginning to sound quite alarmingly drugged , not a typical reaction at all . Well , that or Severus  was just already sauced . Considering Severus  bony frame , either was equally likely . `` No , \'\' Sirius  said . `` Afraid I have n\'t had the pleasure of shagging Merlin  , I could n\'t tell Severus  anything about that . \'\' `` Because he lived so long ago , \'\' he blurted . Sirius  paused , confused . He seemed to consult a patch of space immediately in front of his face . His focus slowly lengthened until he was looking at Severus  again . `` I do n\'t understand . Why what?" `` To Severus  , perhaps . Which means , incidentally , that James  owes me five squids , wherever James  is . \'\' James  ignored the werewolf issue altogether ; Remus was as human as James  . Sirius  briefly consulted the space in front of James  eyes again . `` We ... fit . We were attracted to each other . James  understood me , I understood James  . \'\' `` We know James  turned coat for us , \'\' James  said then . `` Which means James  first loyalty was to them . \'\' Eyes narrowed , James  drew out a cigarette . `` Jam ...

# %%
# Postag assertions
import spacy
# nlp = spacy.load('en', disable=['parser', 'ner'])
nlp = spacy.load('en', disable=['ner'])

# %%
test = ' '.join(char_assertions['4012087']["($_Sirius_')"])
annotated = nlp(test)

# %%
annotated = nlp(test_replaced)

# %%
feats = [(tok, tok.tag_, tok.dep_, tok.head, [c for c in tok.children]) for tok in annotated]
feats
# Out:
# [(Sirius, 'NNP', 'nsubj', took, [ ]),
#  ( , '', '', Sirius, []),
#  (took, 'VBD', 'ROOT', took, [Sirius, glass, .]),
#  (the, 'DT', 'det', glass, []),
#  (glass, 'NN', 'dobj', took, [the]),
#  (., '.', 'punct', took, []),
#  (``, '``', 'punct', are, []),
#  (Not, 'RB', 'neg', trying, []),
#  (trying, 'VBG', 'csubj', are, [Not, poison]),
#  (to, 'TO', 'aux', poison, []),
#  (poison, 'VB', 'xcomp', trying, [to, me]),
#  (me, 'PRP', 'dobj', poison, []),
#  (,, ',', 'punct', are, []),
#  (are, 'VBP', 'ROOT', are, [``, trying, ,, you, ,, Snivellus, ?, '']),
#  (you, 'PRP', 'nsubj', are, []),
#  (,, ',', 'punct', are, []),
#  (Snivellus, 'NNP', 'npadvmod', are, [ ]),
#  ( , '', '', Snivellus, []),
#  (?, '.', 'punct', are, []),
#  ('', "''", 'punct', are, []),
#  (Severus, 'NNP', 'nmod', concern, [ ]),
#  ( , '', '', Severus, []),
#  (concern, 'NN', 'nsubjpass', feigned, [Severus]),
#  (was, 'VBD', 'auxpass', feigned, []),
#  (feigned, 'VBN', 'ccomp', drank, [concern, was]),
#  (;, ':', 'punct', drank, []),
#  (Severus, 'NNP', 'nsubj', drank, [ ]),
#  ( , '', '', Severus, []),
#  (drank, 'VBD', 'ROOT', drank, [feigned, ;, Severus, immediately, .]),
#  (immediately, 'RB', 'advmod', drank, []),
#  (., '.', 'punct', drank, []),
#  (Sirius, 'NNP', 'nsubj', stared, [ ]),
#  ( , '', '', Sirius, []),
#  (stared, 'VBD', 'ROOT', stared, [Sirius, into, .]),
#  (into, 'IN', 'prep', stared, [goblet]),
#  (Severus, 'NNP', 'compound', goblet, [ ]),
#  ( , '', '', Severus, []),
#  (goblet, 'NN', 'pobj', into, [Severus, ,, corner]),
#  (,, ',', 'punct', goblet, []),
#  (one, 'CD', 'nummod', corner, []),
#  (corner, 'NN', 'appos', goblet, [one, of, twitching]),
#  (of, 'IN', 'prep', corner, [mouth]),
#  (Severus, 'NNP', 'compound', mouth, [ ]),
#  ( , '', '', Severus, []),
#  (mouth, 'NN', 'pobj', of, [Severus]),
#  (twitching, 'NN', 'acl', corner, []),
#  (., '.', 'punct', stared, []),
#  (``, '``', 'punct', see, []),
#  (Oh, 'UH', 'intj', see, []),
#  (,, ',', 'punct', see, []),
#  (I, 'PRP', 'nsubj', see, []),
#  (see, 'VBP', 'ROOT', see, [``, Oh, ,, I, ., '']),
#  (., '.', 'punct', see, []),
#  ('', "''", 'punct', see, []),
#  (Severus, 'NNP', 'nsubj', paused, [ ]),
#  ( , '', '', Severus, []),
#  (paused, 'VBD', 'ROOT', paused, [Severus, ,, seeming, .]),
#  (,, ',', 'punct', paused, []),
#  (seeming, 'VBG', 'advcl', paused, [consider]),
#  (to, 'TO', 'aux', consider, []),
#  (consider, 'VB', 'advcl', seeming, [to]),
#  (., '.', 'punct', paused, []),
#  (``, '``', 'punct', enemy, []),
#  (Severus, 'NNP', 'poss', enemy, [ , ']),
#  ( , '', '', Severus, []),
#  (', '``', 'case', Severus, []),
#  (m, 'NN', 'nmod', enemy, []),
#  (an, 'DT', 'det', enemy, []),
#  (enemy, 'NN', 'ROOT', enemy, [``, Severus, m, an, of, .]),
#  (of, 'IN', 'prep', enemy, [Voldemort]),
#  (Voldemort, 'NNP', 'pobj', of, []),
#  (., '.', 'punct', enemy, []),
#  (``, '``', 'punct', No, []),
#  (No, 'UH', 'ROOT', No, [``, ., '']),
#  (., '.', 'punct', No, []),
#  ('', "''", 'punct', No, []),
#  (The, 'DT', 'det', word, []),
#  (word, 'NN', 'nsubjpass', barked, [The]),
#  (was, 'VBD', 'auxpass', barked, []),
#  (barked, 'VBN', 'ROOT', barked, [word, was, out, between, put, ,, turned, .]),
#  (out, 'RP', 'prt', barked, []),
#  (between, 'IN', 'prep', barked, [teeth]),
#  (gritted, 'VBN', 'amod', teeth, []),
#  (teeth, 'NNS', 'pobj', between, [gritted, ,, resentful]),
#  (,, ',', 'punct', teeth, []),
#  (resentful, 'JJ', 'conj', teeth, [,, and, Sirius]),
#  (,, ',', 'punct', resentful, []),
#  (and, 'CC', 'cc', resentful, []),
#  (Sirius, 'NNP', 'conj', resentful, [ ]),
#  ( , '', '', Sirius, []),
#  (put, 'VBD', 'conj', barked, [hand, over]),
#  (one, 'CD', 'nummod', hand, []),
#  (hand, 'NN', 'dobj', put, [one]),
#  (over, 'IN', 'prep', put, [mouth]),
#  (Severus, 'NNP', 'compound', mouth, [ ]),
#  ( , '', '', Severus, []),
#  (mouth, 'NN', 'pobj', over, [Severus]),
#  (,, ',', 'punct', barked, []),
#  (turned, 'VBD', 'conj', barked, [head, away, for, ,, wanting]),
#  (Severus, 'NNP', 'compound', head, [ ]),
#  ( , '', '', Severus, []),
#  (head, 'VBP', 'dobj', turned, [Severus]),
#  (away, 'RB', 'advmod', turned, []),
#  (for, 'IN', 'prep', turned, [moment]),
#  (a, 'DT', 'det', moment, []),
#  (moment, 'NN', 'pobj', for, [a]),
#  (,, ',', 'punct', turned, []),
#  (clearly, 'RB', 'advmod', wanting, []),
#  (wanting, 'VBG', 'advcl', turned, [clearly, leave]),
#  (to, 'TO', 'aux', leave, []),
#  (leave, 'VB', 'xcomp', wanting, [to, it, at]),
#  (it, 'PRP', 'dobj', leave, []),
#  (at, 'IN', 'prep', leave, [that]),
#  (that, 'DT', 'pobj', at, []),
#  (., '.', 'punct', barked, []),
#  (But, 'CC', 'cc', grated, []),
#  (then, 'RB', 'advmod', grated, []),
#  (Severus, 'NNP', 'nsubj', grated, [ ]),
#  ( , '', '', Severus, []),
#  (grated, 'VBD', 'ccomp', gave, [But, then, Severus, out, ,, ``, was]),
#  (out, 'RP', 'prt', grated, []),
#  (,, ',', 'punct', grated, []),
#  (``, '``', 'punct', grated, []),
#  (As, 'RB', 'advmod', soon, []),
#  (soon, 'RB', 'advmod', was, [As, knew]),
#  (as, 'IN', 'mark', knew, []),
#  (Severus, 'NNP', 'nsubj', knew, [ ]),
#  ( , '', '', Severus, []),
#  (knew, 'VBD', 'advcl', soon, [as, Severus, Severus]),
#  (Severus, 'NNP', 'dobj', knew, [ ]),
#  ( , '', '', Severus, []),
#  (was, 'VBD', 'ccomp', grated, [soon, responsibility]),
#  (Severus, 'NNP', 'nmod', responsibility, [ ]),
#  ( , '', '', Severus, []),
#  (responsibility, 'NN', 'attr', was, [Severus]),
#  (,, ',', 'punct', gave, []),
#  (Severus, 'NNP', 'nsubj', gave, [ ]),
#  ( , '', '', Severus, []),
#  (gave, 'VBD', 'ROOT', gave, [grated, ,, Severus, Severus, up, trust, ., '']),
#  (Severus, 'NNP', 'dative', gave, [ ]),
#  ( , '', '', Severus, []),
#  (up, 'RP', 'prt', gave, [to]),
#  (to, 'IN', 'prep', up, [Dumbledore]),
#  (Dumbledore, 'NNP', 'pobj', to, []),
#  (even, 'RB', 'advmod', trust, []),
#  (though, 'IN', 'mark', trust, []),
#  (we, 'PRP', 'nsubj', trust, []),
#  (did, 'VBD', 'aux', trust, []),
#  (n't, 'RB', 'neg', trust, []),
#  (completely, 'RB', 'advmod', trust, []),
#  (trust,
#   'VB',
#   'advcl',
#   gave,
#   [even, though, we, did, n't, completely, Severus, ,, chase]),
#  (Severus, 'NNP', 'dobj', trust, [ ]),
#  ( , '', '', Severus, []),
#  (,, ',', 'punct', trust, []),
#  (just, 'RB', 'advmod', chase, []),
#  (so, 'RB', 'advmod', chase, []),
#  (Severus, 'NNP', 'nsubj', chase, [ ]),
#  ( , '', '', Severus, []),
#  (could, 'MD', 'aux', chase, []),
#  (chase, 'VB', 'advcl', trust, [just, so, Severus, could, down, revenge]),
#  (down, 'RP', 'prt', chase, []),
#  (revenge, 'NN', 'dobj', chase, []),
#  (., '.', 'punct', gave, []),
#  ('', "''", 'punct', gave, []),
#  (``, '``', 'punct', say, []),
#  (Do, 'VB', 'aux', say, []),
#  (n't, 'RB', 'neg', say, []),
#  (Severus, 'NNP', 'nsubj', say, [ ]),
#  ( , '', '', Severus, []),
#  (say, 'VB', 'ROOT', say, [``, Do, n't, Severus, word, ,, '', grumbled, .]),
#  (a, 'DT', 'det', word, []),
#  (word, 'NN', 'dobj', say, [a, against]),
#  (against, 'IN', 'prep', word, [Lily]),
#  (Lily, 'NNP', 'pobj', against, [ ]),
#  ( , '', '', Lily, []),
#  (,, ',', 'punct', say, []),
#  ('', "''", 'punct', say, []),
#  (Sirius, 'NNP', 'nsubj', grumbled, [ ]),
#  ( , '', '', Sirius, []),
#  (grumbled, 'VBD', 'ccomp', say, [Sirius]),
#  (., '.', 'punct', say, []),
#  (Proving, 'VBG', 'advcl', laughed, [madness]),
#  (his, 'PRP$', 'poss', madness, []),
#  (madness, 'NN', 'dobj', Proving, [his]),
#  (,, ',', 'punct', laughed, []),
#  (Sirius, 'NNP', 'nsubj', laughed, [ ]),
#  ( , '', '', Sirius, []),
#  (laughed, 'VBD', 'ROOT', laughed, [Proving, ,, Sirius, aloud, then, .]),
#  (aloud, 'RB', 'advmod', laughed, []),
#  (then, 'RB', 'advmod', laughed, []),
#  (., '.', 'punct', laughed, []),
#  (``, '``', 'punct', m, []),
#  (No, 'UH', 'intj', m, []),
#  (,, ',', 'punct', m, []),
#  (Sirius, 'NNP', 'poss', m, [ ]),
#  ( , '', '', Sirius, []),
#  (', 'POS', 'punct', m, []),
#  (m, 'NN', 'ROOT', m, [``, No, ,, Sirius, ', --, !]),
#  (--, ':', 'punct', m, []),
#  (!, '.', 'punct', m, []),
#  (No, 'UH', 'ROOT', No, [!]),
#  (!, '.', 'punct', No, []),
#  (What, 'WP', 'ROOT', What, [?]),
#  (?, '.', 'punct', What, []),
#  (Is, 'VBZ', 'ROOT', Is, [Lily, had, years, ?, '']),
#  (Lily, 'NNP', 'nsubj', Is, [ ]),
#  ( , '', '', Lily, []),
#  (what, 'WP', 'nsubjpass', had, []),
#  ('s, 'VBZ', 'auxpass', had, []),
#  (had, 'VBD', 'ccomp', Is, [what, 's, knicks]),
#  (Severus, 'NNP', 'compound', knicks, [ ]),
#  ( , '', '', Severus, []),
#  (knicks, 'NNS', 'ccomp', had, [Severus, in]),
#  (in, 'IN', 'prep', knicks, [twist]),
#  (a, 'DT', 'det', twist, []),
#  (twist, 'NN', 'pobj', in, [a]),
#  (all, 'PDT', 'predet', years, []),
#  (these, 'DT', 'det', years, []),
#  (years, 'NNS', 'npadvmod', Is, [all, these]),
#  (?, '.', 'punct', Is, []),
#  ('', "''", 'punct', Is, []),
#  (``, '``', 'punct', replied, []),
#  (Yes, 'UH', 'intj', replied, []),
#  (,, ',', 'punct', replied, []),
#  ('', "''", 'punct', replied, []),
#  (Severus, 'NNP', 'nsubj', replied, [ ]),
#  ( , '', '', Severus, []),
#  (replied,
#   'VBD',
#   'ROOT',
#   replied,
#   [``, Yes, ,, '', Severus, immediately, ,, teeth, .]),
#  (immediately, 'RB', 'advmod', replied, []),
#  (,, ',', 'punct', replied, []),
#  (though, 'IN', 'mark', teeth, []),
#  (Severus, 'NNP', 'nsubj', teeth, [ ]),
#  ( , '', '', Severus, []),
#  (teeth, 'NNS', 'advcl', replied, [though, Severus]),
#  (., '.', 'punct', replied, []),
#  (Severus, 'NNP', 'nsubj', looked, [ ]),
#  ( , '', '', Severus, []),
#  (looked, 'VBD', 'ROOT', looked, [Severus, away, quickly, ,, but, got]),
#  (away, 'RB', 'advmod', looked, []),
#  (quickly, 'RB', 'advmod', looked, []),
#  (,, ',', 'punct', looked, []),
#  (but, 'CC', 'cc', looked, []),
#  (Sirius, 'NNP', 'nsubj', got, [ ]),
#  ( , '', '', Sirius, []),
#  (had, 'VBD', 'aux', got, []),
#  (got, 'VBN', 'conj', looked, [Sirius, had, Sirius, .]),
#  (Sirius, 'NNP', 'dobj', got, [ ]),
#  ( , '', '', Sirius, []),
#  (., '.', 'punct', got, []),
#  (``, '``', 'punct', ground, []),
#  (Because, 'IN', 'mark', are, []),
#  (people, 'NNS', 'nsubj', are, []),
#  (are, 'VBP', 'advcl', ground, [Because, people, awful]),
#  (awful, 'JJ', 'acomp', are, [to]),
#  (to, 'IN', 'prep', awful, [Severus]),
#  (Severus, 'NNP', 'pobj', to, [ ]),
#  ( , '', '', Severus, []),
#  (,, ',', 'punct', ground, []),
#  ('', "''", 'punct', ground, []),
#  (Severus, 'NNP', 'nsubj', ground, [ ]),
#  ( , '', '', Severus, []),
#  (ground,
#   'VBD',
#   'ROOT',
#   ground,
#   [``, are, ,, '', Severus, out, ,, jerking, .]),
#  (out, 'RP', 'prt', ground, []),
#  (,, ',', 'punct', ground, []),
#  (jerking, 'VBG', 'advcl', ground, [hand, at, as]),
#  (a, 'DT', 'det', hand, []),
#  (hand, 'NN', 'dobj', jerking, [a]),
#  (at, 'IN', 'prep', jerking, [Sirius]),
#  (Sirius, 'NNP', 'pobj', at, [ ]),
#  ( , '', '', Sirius, []),
#  (as, 'IN', 'prep', jerking, [example]),
#  (an, 'DT', 'det', example, []),
#  (example, 'NN', 'pobj', as, [an]),
#  (., '.', 'punct', ground, []),
#  (``, '``', 'punct', become, []),
#  (Severus, 'NNP', 'csubj', become, [ ]),
#  ( , '', '', Severus, []),
#  (become, 'VBP', 'ROOT', become, [``, Severus, defensive, and, hurt]),
#  (defensive, 'JJ', 'acomp', become, []),
#  (and, 'CC', 'cc', become, []),
#  (Severus, 'NNP', 'nsubj', hurt, [ ]),
#  ( , '', '', Severus, []),
#  (hurt, 'VBD', 'conj', become, [Severus, them, hurt, ., '']),
#  (them, 'PRP', 'dobj', hurt, []),
#  (before, 'IN', 'mark', hurt, []),
#  (they, 'PRP', 'nsubj', hurt, []),
#  (can, 'MD', 'aux', hurt, []),
#  (hurt, 'VB', 'advcl', hurt, [before, they, can, Severus]),
#  (Severus, 'NNP', 'dobj', hurt, [ ]),
#  ( , '', '', Severus, []),
#  (., '.', 'punct', hurt, []),
#  ('', "''", 'punct', hurt, []),
#  (Severus, 'NNP', 'nsubj', refused, [ ]),
#  ( , '', '', Severus, []),
#  (refused, 'VBD', 'ROOT', refused, [Severus, allow, .]),
#  (to, 'TO', 'aux', allow, []),
#  (allow, 'VB', 'xcomp', refused, [to, Severus, to, with]),
#  (Severus, 'NNP', 'dobj', allow, [ ]),
#  ( , '', '', Severus, []),
#  (to, 'TO', 'prep', allow, [colour]),
#  (colour, 'VB', 'pobj', to, []),
#  (with, 'IN', 'prep', allow, [embarrassment]),
#  (embarrassment, 'NN', 'pobj', with, []),
#  (., '.', 'punct', refused, []),
#  (``, '``', 'punct', hated, []),
#  (Why, 'WRB', 'advmod', hated, []),
#  (have, 'VBP', 'aux', hated, []),
#  (Severus, 'NNP', 'nsubj', hated, [ ]),
#  ( , '', '', Severus, []),
#  (always, 'RB', 'advmod', hated, []),
#  (hated,
#   'VBD',
#   'ROOT',
#   hated,
#   [``, Why, have, Severus, always, Severus, so, ?, '']),
#  (Severus, 'NNP', 'dobj', hated, [ ]),
#  ( , '', '', Severus, []),
#  (so, 'RB', 'advmod', hated, []),
#  (?, '.', 'punct', hated, []),
#  ('', "''", 'punct', hated, []),
#  (``, '``', 'punct', snapped, []),
#  (Because, 'IN', 'mark', remind, []),
#  (Severus, 'NNP', 'nsubj', remind, [ ]),
#  ( , '', '', Severus, []),
#  (remind, 'VBP', 'advcl', snapped, [Because, Severus, Severus, of]),
#  (Severus, 'NNP', 'dobj', remind, [ ]),
#  ( , '', '', Severus, []),
#  (of, 'IN', 'prep', remind, [Severus]),
#  (Severus, 'NNP', 'pobj', of, [ ]),
#  ( , '', '', Severus, []),
#  (,, ',', 'punct', snapped, []),
#  ('', "''", 'punct', snapped, []),
#  (Sirius, 'NNP', 'nsubj', snapped, [ ]),
#  ( , '', '', Sirius, []),
#  (snapped,
#   'VBD',
#   'ROOT',
#   snapped,
#   [``, remind, ,, '', Sirius, ., '', ..., of, ., '']),
#  (., '.', 'punct', snapped, []),
#  ('', "''", 'punct', snapped, []),
#  (..., 'NFP', 'punct', snapped, []),
#  (of, 'IN', 'prep', snapped, [Blacks]),
#  (the, 'DT', 'det', Blacks, []),
#  (Blacks, 'NNPS', 'pobj', of, [the]),
#  (., '.', 'punct', snapped, []),
#  ('', "''", 'punct', snapped, []),
#  (``, '``', 'punct', 's, []),
#  (It, 'PRP', 'nsubj', 's, []),
#  ('s, 'VBZ', 'ccomp', is, [``, It, for, helping]),
#  (for, 'IN', 'prep', 's, [Lily]),
#  (Lily, 'NNP', 'pobj', for, [ ]),
#  ( , '', '', Lily, []),
#  (that, 'IN', 'mark', helping, []),
#  (Lily, 'NNP', 'nsubj', helping, [ ]),
#  ( , '', '', Lily, []),
#  ('re, 'VBP', 'aux', helping, []),
#  (helping, 'VBG', 'ccomp', 's, [that, Lily, 're, Harry, now]),
#  (Harry, 'NNP', 'dobj', helping, [ ]),
#  ( , '', '', Harry, []),
#  (now, 'RB', 'advmod', helping, []),
#  (,, ',', 'punct', is, []),
#  (is, 'VBZ', 'ROOT', is, ['s, ,, n't, it, ?, '']),
#  (n't, 'RB', 'neg', is, []),
#  (it, 'PRP', 'nsubj', is, []),
#  (?, '.', 'punct', is, []),
#  ('', "''", 'punct', is, []),
#  (Sirius, 'NNP', 'nsubj', asked, [ ]),
#  ( , '', '', Sirius, []),
#  (asked, 'VBD', 'ROOT', asked, [Sirius, .]),
#  (., '.', 'punct', asked, []),
#  (``, '``', 'punct', treat, []),
#  (And, 'CC', 'cc', treat, []),
#  (yet, 'RB', 'advmod', Lily, []),
#  (Lily, 'NNP', 'nsubj', treat, [yet,  ]),
#  ( , '', '', Lily, []),
#  (treat, 'VBP', 'ccomp', pointed, [``, And, Lily, him, Lily, ,, '']),
#  (him, 'PRP', 'dobj', treat, []),
#  (appallingly, 'RB', 'advmod', Lily, []),
#  (Lily, 'NNP', 'advmod', treat, [appallingly,  ]),
#  ( , '', '', Lily, []),
#  (,, ',', 'punct', treat, []),
#  ('', "''", 'punct', treat, []),
#  (Sirius, 'NNP', 'nsubj', pointed, [ ]),
#  ( , '', '', Sirius, []),
#  (pointed, 'VBD', 'ROOT', pointed, [treat, Sirius, out, .]),
#  (out, 'RP', 'prt', pointed, []),
#  (., '.', 'punct', pointed, []),
#  (Sirius, 'NNP', 'nsubj', frowned, [ ]),
#  ( , '', '', Sirius, []),
#  (frowned, 'VBD', 'ROOT', frowned, [Sirius, ,, shook, .]),
#  (,, ',', 'punct', frowned, []),
#  (shook, 'VBD', 'conj', frowned, [head]),
#  (his, 'PRP$', 'poss', head, []),
#  (head, 'NN', 'dobj', shook, [his]),
#  (., '.', 'punct', frowned, []),
#  (``, '``', 'punct', is, []),
#  (That, 'DT', 'nsubj', is, []),
#  (absolutely, 'RB', 'advmod', is, []),
#  (is, 'VBZ', 'ccomp', said, [``, That, absolutely, n't, truth]),
#  (n't, 'RB', 'neg', is, []),
#  (the, 'DT', 'det', truth, []),
#  (truth, 'NN', 'attr', is, [the]),
#  (,, ',', 'punct', said, []),
#  ('', "''", 'punct', said, []),
#  (he, 'PRP', 'nsubj', said, []),
#  (said, 'VBD', 'ROOT', said, [is, ,, '', he, carefully, .]),
#  (carefully, 'RB', 'advmod', said, []),
#  (., '.', 'punct', said, []),
#  (``, '``', 'punct', is, []),
#  (Nothing, 'NN', 'nsubj', is, [about]),
#  (about, 'IN', 'prep', Nothing, [that]),
#  (that, 'DT', 'pobj', about, []),
#  (is, 'VBZ', 'ROOT', is, [``, Nothing, true, ., '']),
#  (true, 'JJ', 'acomp', is, []),
#  (., '.', 'punct', is, []),
#  ('', "''", 'punct', is, []),
#  (``, '``', 'punct', Are, []),
#  (Are, 'VBP', 'ROOT', Are, [``, Severus, loyal, ?, '']),
#  (Severus, 'NNP', 'nsubj', Are, [ ]),
#  ( , '', '', Severus, []),
#  (loyal, 'JJ', 'acomp', Are, [to]),
#  (to, 'IN', 'prep', loyal, [Dumbledore]),
#  (Dumbledore, 'NNP', 'pobj', to, []),
#  (?, '.', 'punct', Are, []),
#  ('', "''", 'punct', Are, []),
#  (Sirius, 'NNP', 'nsubj', asked, [ ]),
#  ( , '', '', Sirius, []),
#  (eventually, 'RB', 'advmod', asked, []),
#  (asked, 'VBD', 'ROOT', asked, [Sirius, eventually, .]),
#  (., '.', 'punct', asked, []),
#  (``, '``', 'punct', No, []),
#  (No, 'UH', 'ROOT', No, [``, ,]),
#  (,, ',', 'punct', No, [m, ., '']),
#  (I, 'PRP', 'poss', m, [']),
#  (', "''", 'case', I, []),
#  (m, 'VBZ', 'intj', ,, [I, loyal]),
#  (only, 'RB', 'advmod', loyal, []),
#  (loyal, 'JJ', 'amod', m, [only, to]),
#  (to, 'IN', 'prep', loyal, [family]),
#  (my, 'PRP$', 'poss', family, []),
#  (family, 'NN', 'pobj', to, [my]),
#  (., '.', 'punct', ,, []),
#  ('', "''", 'punct', ,, []),
#  (James, 'NNP', 'nsubj', refer, [ ]),
#  ( , '', '', James, []),
#  (clearly, 'RB', 'advmod', refer, []),
#  (did, 'VBD', 'aux', refer, []),
#  (n't, 'RB', 'neg', refer, []),
#  (refer, 'VB', 'ROOT', refer, [James, clearly, did, n't, to, .]),
#  (to, 'IN', 'prep', refer, [house]),
#  (the, 'DT', 'det', house, []),
#  (ancient, 'JJ', 'amod', house, [and, noble]),
#  (and, 'CC', 'cc', ancient, []),
#  (most, 'RBS', 'advmod', noble, []),
#  (noble, 'JJ', 'conj', ancient, [most]),
#  (house, 'NN', 'pobj', to, [the, ancient, of]),
#  (of, 'IN', 'prep', house, [Black]),
#  (Black, 'NNP', 'pobj', of, [ ]),
#  ( , '', '', Black, []),
#  (., '.', 'punct', refer, []),
#  (There, 'EX', 'expl', was, []),
#  (was, 'VBD', 'ROOT', was, [There, silence, .]),
#  (another, 'DT', 'det', silence, []),
#  (long, 'JJ', 'amod', silence, []),
#  (silence, 'NN', 'attr', was, [another, long]),
#  (., '.', 'punct', was, []),
#  (Each, 'DT', 'det', man, []),
#  (man, 'NN', 'nsubj', watched, [Each]),
#  (watched, 'VBD', 'ROOT', watched, [man, other, carefully, ,, unsure, .]),
#  (the, 'DT', 'det', other, []),
#  (other, 'JJ', 'dobj', watched, [the]),
#  (carefully, 'RB', 'advmod', watched, []),
#  (,, ',', 'punct', watched, []),
#  (unsure, 'JJ', 'conj', watched, [make]),
#  (what, 'WP', 'dobj', make, []),
#  (to, 'TO', 'aux', make, []),
#  (make, 'VB', 'ccomp', unsure, [what, to, of]),
#  (of, 'IN', 'prep', make, [development]),
#  (this, 'DT', 'det', development, []),
#  (development, 'NN', 'pobj', of, [this]),
#  (., '.', 'punct', watched, []),
#  (Sirius, 'NNP', 'nsubj', drank, [ ]),
#  ( , '', '', Sirius, []),
#  (drank, 'VBD', 'ROOT', drank, [Sirius, more, .]),
#  (more, 'JJR', 'dobj', drank, [of]),
#  (of, 'IN', 'prep', more, [wine]),
#  (the, 'DT', 'det', wine, []),
#  (dosed, 'VBN', 'amod', wine, []),
#  (wine, 'NN', 'pobj', of, [the, dosed]),
#  (., '.', 'punct', drank, []),
#  (``, '``', 'punct', said, []),
#  (Of, 'RB', 'advmod', course, []),
#  (course, 'RB', 'advmod', not, [Of]),
#  (not, 'RB', 'ccomp', said, [course]),
#  (,, ',', 'punct', said, []),
#  ('', "''", 'punct', said, []),
#  (Sirius, 'NNP', 'nsubj', said, [ ]),
#  ( , '', '', Sirius, []),
#  (said, 'VBD', 'ROOT', said, [``, not, ,, '', Sirius, with, .]),
#  (with, 'IN', 'prep', said, [shrug]),
#  (a, 'DT', 'det', shrug, []),
#  (shrug, 'NN', 'pobj', with, [a]),
#  (., '.', 'punct', said, []),
#  (``, '``', 'punct', were, []),
#  (Sirius, 'NNP', 'nsubj', were, [ ]),
#  ( , '', '', Sirius, []),
#  (were, 'VBD', 'ROOT', were, [``, Sirius, at, --, and, war, elaborated, .]),
#  (at, 'IN', 'prep', were, [war]),
#  (war, 'NN', 'pobj', at, []),
#  (--, ':', 'punct', were, []),
#  (and, 'CC', 'cc', were, []),
#  (not, 'RB', 'neg', war, []),
#  (regular, 'JJ', 'amod', war, []),
#  (war, 'NN', 'conj', were, [not, regular, ,, mind, ,, war, ,, '']),
#  (,, ',', 'punct', war, []),
#  (mind, 'VB', 'conj', war, [you]),
#  (you, 'PRP', 'dobj', mind, []),
#  (,, ',', 'punct', war, []),
#  (special, 'JJ', 'amod', war, []),
#  (evil, 'JJ', 'amod', war, []),
#  (racist, 'JJ', 'amod', war, []),
#  (wizard, 'NN', 'amod', war, []),
#  (war, 'NN', 'conj', war, [special, evil, racist, wizard]),
#  (,, ',', 'punct', war, []),
#  ('', "''", 'punct', war, []),
#  (James, 'NNP', 'nsubj', elaborated, [ ]),
#  ( , '', '', James, []),
#  (elaborated, 'VBD', 'conj', were, [James, unnecessarily, ,, amused]),
#  (unnecessarily, 'RB', 'advmod', elaborated, []),
#  (,, ',', 'punct', elaborated, []),
#  (grimly, 'RB', 'advmod', amused, []),
#  (amused, 'VBN', 'advcl', elaborated, [grimly, by]),
#  (by, 'IN', 'agent', amused, [summation]),
#  (James, 'NNP', 'nmod', summation, [ ]),
#  ( , '', '', James, []),
#  (own, 'JJ', 'amod', summation, []),
#  (summation, 'NN', 'pobj', by, [James, own]),
#  (., '.', 'punct', were, []),
#  (``, '``', 'punct', fell, []),
#  (She, 'PRP', 'nsubj', fell, []),
#  (fell, 'VBD', 'ROOT', fell, [``, She, pregnant, ,, was, loved]),
#  (pregnant, 'JJ', 'acomp', fell, []),
#  (,, ',', 'punct', fell, []),
#  (James, 'NNP', 'nsubj', was, [ ]),
#  ( , '', '', James, []),
#  (was, 'VBD', 'conj', fell, [James, --]),
#  (--, ':', 'punct', was, []),
#  (James, 'NNP', 'nsubj', loved, [ ]),
#  ( , '', '', James, []),
#  (loved, 'VBD', 'conj', fell, [James, James, dearly, ,, understand, but, was]),
#  (James, 'NNP', 'dobj', loved, [ ]),
#  ( , '', '', James, []),
#  (dearly, 'RB', 'advmod', loved, []),
#  (,, ',', 'punct', loved, []),
#  (you, 'PRP', 'nsubj', understand, []),
#  (understand, 'VBP', 'parataxis', loved, [you, ,]),
#  (,, ',', 'punct', understand, []),
#  (but, 'CC', 'cc', loved, []),
#  (James, 'NNP', 'nsubj', was, [ ]),
#  ( , '', '', James, []),
#  (was, 'VBD', 'conj', loved, [James, tit, ,, was, .]),
#  (an, 'DT', 'det', tit, []),
#  (absolute, 'JJ', 'amod', tit, []),
#  (tit, 'NN', 'attr', was, [an, absolute]),
#  (,, ',', 'punct', was, []),
#  (James, 'NNP', 'nsubj', was, [ ]),
#  ( , '', '', James, []),
#  (really, 'RB', 'advmod', was, []),
#  (was, 'VBD', 'conj', was, [James, really]),
#  (., '.', 'punct', was, []),
#  (The, 'DT', 'intj', were, []),
#  (--, ':', 'punct', were, []),
#  (Sirius, 'NNP', 'nmod', lives, [ ]),
#  ( , '', '', Sirius, []),
#  (whole, 'JJ', 'amod', lives, []),
#  (lives, 'NNS', 'nsubj', were, [Sirius, whole]),
#  (were, 'VBD', 'ROOT', were, [The, --, lives, trainwreck, all, knew, .]),
#  (a, 'DT', 'det', trainwreck, []),
#  (trainwreck, 'NN', 'attr', were, [a, and, Sirius]),
#  (and, 'CC', 'cc', trainwreck, []),
#  (Sirius, 'NNP', 'conj', trainwreck, [ ]),
#  ( , '', '', Sirius, []),
#  (all, 'DT', 'dep', were, []),
#  (knew, 'VBD', 'conj', were, [it]),
#  (it, 'PRP', 'dobj', knew, []),
#  (., '.', 'punct', were, []),
#  (None, 'NN', 'nsubj', were, [of]),
#  (of, 'IN', 'prep', None, [Sirius]),
#  (Sirius, 'NNP', 'pobj', of, [ ]),
#  ( , '', '', Sirius, []),
#  (were, 'VBD', 'ROOT', were, [None, happy, ,, but, were]),
#  (happy, 'JJ', 'acomp', were, []),
#  (,, ',', 'punct', were, []),
#  (but, 'CC', 'cc', were, []),
#  (Sirius, 'NNP', 'nsubj', were, [ ]),
#  ( , '', '', Sirius, []),
#  (were, 'VBD', 'conj', were, [Sirius, young, ,, and, 's]),
#  (young, 'JJ', 'acomp', were, []),
#  (,, ',', 'punct', were, []),
#  (and, 'CC', 'cc', were, []),
#  (that, 'DT', 'nsubj', 's, []),
#  ('s, 'VBZ', 'conj', were, [that, enough, sometimes, ...]),
#  (enough, 'JJ', 'acomp', 's, []),
#  (sometimes, 'RB', 'advmod', 's, []),
#  (..., ':', 'punct', 's, []),
#  (James, 'NNP', 'nsubj', want, [ ]),
#  ( , '', '', James, []),
#  (want, 'VBP', 'ROOT', want, [James, talk, ., '']),
#  (to, 'TO', 'aux', talk, []),
#  (talk, 'VB', 'xcomp', want, [to, about]),
#  (about, 'IN', 'prep', talk, [something]),
#  (something, 'NN', 'pobj', about, [else]),
#  (else, 'RB', 'advmod', something, []),
#  (., '.', 'punct', want, []),
#  ('', "''", 'punct', want, []),
#  (Severus, 'NNP', 'nsubj', began, [ ]),
#  ( , '', '', Severus, []),
#  (began, 'VBD', 'ccomp', beginning, [Severus, wonder]),
#  (to, 'TO', 'aux', wonder, []),
#  (wonder, 'VB', 'xcomp', began, [to, tipped]),
#  (if, 'IN', 'mark', tipped, []),
#  (Severus, 'NNP', 'nsubj', tipped, [ ]),
#  ( , '', '', Severus, []),
#  (had, 'VBD', 'aux', tipped, []),
#  (perhaps, 'RB', 'advmod', tipped, []),
#  (tipped, 'VBN', 'ccomp', wonder, [if, Severus, had, perhaps, more, into]),
#  (a, 'DT', 'det', bit, []),
#  (bit, 'NN', 'npadvmod', more, [a]),
#  (more, 'JJR', 'advmod', tipped, [bit]),
#  (into, 'IN', 'prep', tipped, [Sirius, goblet]),
#  (Sirius, 'NNP', 'pobj', into, [ ]),
#  ( , '', '', Sirius, []),
#  (goblet, 'NN', 'pobj', into, [required]),
#  (than, 'IN', 'mark', required, []),
#  (was, 'VBD', 'auxpass', required, []),
#  (required, 'VBN', 'advcl', goblet, [than, was]),
#  (--, ':', 'punct', beginning, []),
#  (the, 'DT', 'det', man, []),
#  (man, 'NN', 'nsubj', beginning, [the]),
#  (was, 'VBD', 'aux', beginning, []),
#  (beginning, 'VBG', 'ROOT', beginning, [began, --, man, was, sound, .]),
#  (to, 'TO', 'aux', sound, []),
#  (sound, 'VB', 'xcomp', beginning, [to, reaction]),
#  (quite, 'RB', 'advmod', alarmingly, []),
#  (alarmingly, 'RB', 'advmod', drugged, [quite]),
#  (drugged, 'VBN', 'amod', reaction, [alarmingly]),
#  (,, ',', 'punct', reaction, []),
#  (not, 'RB', 'neg', reaction, []),
#  (a, 'DT', 'det', reaction, []),
#  (typical, 'JJ', 'amod', reaction, []),
#  (reaction, 'NN', 'dobj', sound, [drugged, ,, not, a, typical, all]),
#  (at, 'RB', 'advmod', all, []),
#  (all, 'RB', 'advmod', reaction, [at]),
#  (., '.', 'punct', beginning, []),
#  (Well, 'UH', 'intj', sauced, []),
#  (,, ',', 'punct', sauced, []),
#  (that, 'DT', 'nsubjpass', sauced, [or, Severus]),
#  (or, 'CC', 'cc', that, []),
#  (Severus, 'NNP', 'conj', that, [ ]),
#  ( , '', '', Severus, []),
#  (was, 'VBD', 'auxpass', sauced, []),
#  (just, 'RB', 'advmod', sauced, []),
#  (already, 'RB', 'advmod', sauced, []),
#  (sauced, 'VBN', 'ROOT', sauced, [Well, ,, that, was, just, already, .]),
#  (., '.', 'punct', sauced, []),
#  (Considering, 'VBG', 'prep', was, [frame]),
#  (Severus, 'NNP', 'nmod', frame, [ ]),
#  ( , '', '', Severus, []),
#  (bony, 'NN', 'compound', frame, []),
#  (frame, 'NN', 'pobj', Considering, [Severus, bony]),
#  (,, ',', 'punct', was, []),
#  (either, 'CC', 'preconj', was, []),
#  (was, 'VBD', 'ROOT', was, [Considering, ,, either, likely, .]),
#  (equally, 'RB', 'advmod', likely, []),
#  (likely, 'JJ', 'acomp', was, [equally]),
#  (., '.', 'punct', was, []),
#  (``, '``', 'punct', said, []),
#  (No, 'UH', 'intj', said, []),
#  (,, ',', 'punct', said, []),
#  ('', "''", 'punct', said, []),
#  (Sirius, 'NNP', 'nsubj', said, [ ]),
#  ( , '', '', Sirius, []),
#  (said, 'VBD', 'ROOT', said, [``, No, ,, '', Sirius, .]),
#  (., '.', 'punct', said, []),
#  (``, '``', 'punct', had, []),
#  (Afraid, 'NNP', 'advmod', had, []),
#  (I, 'PRP', 'nsubj', had, []),
#  (have, 'VBP', 'aux', had, []),
#  (n't, 'RB', 'neg', had, []),
#  (had, 'VBN', 'ccomp', tell, [``, Afraid, I, have, n't, pleasure]),
#  (the, 'DT', 'det', pleasure, []),
#  (pleasure, 'NN', 'dobj', had, [the, of]),
#  (of, 'IN', 'prep', pleasure, [shagging]),
#  (shagging, 'VBG', 'pcomp', of, [Merlin]),
#  (Merlin, 'NNP', 'dobj', shagging, [ ]),
#  ( , '', '', Merlin, []),
#  (,, ',', 'punct', tell, []),
#  (I, 'PRP', 'nsubj', tell, []),
#  (could, 'MD', 'aux', tell, []),
#  (n't, 'RB', 'neg', tell, []),
#  (tell, 'VB', 'ROOT', tell, [had, ,, I, could, n't, Severus, anything, ., '']),
#  (Severus, 'NNP', 'dobj', tell, [ ]),
#  ( , '', '', Severus, []),
#  (anything, 'NN', 'dobj', tell, [about]),
#  (about, 'IN', 'prep', anything, [that]),
#  (that, 'DT', 'pobj', about, []),
#  (., '.', 'punct', tell, []),
#  ('', "''", 'punct', tell, []),
#  (``, '``', 'punct', blurted, []),
#  (Because, 'IN', 'mark', lived, []),
#  (he, 'PRP', 'nsubj', lived, []),
#  (lived, 'VBD', 'advcl', blurted, [Because, he, ago]),
#  (so, 'RB', 'advmod', long, []),
#  (long, 'RB', 'advmod', ago, [so]),
#  (ago, 'RB', 'advmod', lived, [long]),
#  (,, ',', 'punct', blurted, []),
#  ('', "''", 'punct', blurted, []),
#  (he, 'PRP', 'nsubj', blurted, []),
#  (blurted, 'VBD', 'ROOT', blurted, [``, lived, ,, '', he, .]),
#  (., '.', 'punct', blurted, []),
#  (Sirius, 'NNP', 'nsubj', paused, [ ]),
#  ( , '', '', Sirius, []),
#  (paused, 'VBD', 'ROOT', paused, [Sirius, ,, confused, .]),
#  (,, ',', 'punct', paused, []),
#  (confused, 'JJ', 'advcl', paused, []),
#  (., '.', 'punct', paused, []),
#  (He, 'PRP', 'nsubj', seemed, []),
#  (seemed, 'VBD', 'ROOT', seemed, [He, consult, .]),
#  (to, 'TO', 'aux', consult, []),
#  (consult, 'VB', 'xcomp', seemed, [to, patch, in]),
#  (a, 'DT', 'det', patch, []),
#  (patch, 'NN', 'dobj', consult, [a, of]),
#  (of, 'IN', 'prep', patch, [space]),
#  (space, 'NN', 'pobj', of, []),
#  (immediately, 'RB', 'advmod', in, []),
#  (in, 'IN', 'prep', consult, [immediately, front]),
#  (front, 'NN', 'pobj', in, [of]),
#  (of, 'IN', 'prep', front, [face]),
#  (his, 'PRP$', 'poss', face, []),
#  (face, 'NN', 'pobj', of, [his]),
#  (., '.', 'punct', seemed, []),
#  (His, 'PRP$', 'poss', focus, []),
#  (focus, 'NN', 'nsubj', lengthened, [His]),
#  (slowly, 'RB', 'advmod', lengthened, []),
#  (lengthened, 'VBD', 'ROOT', lengthened, [focus, slowly, looking, .]),
#  (until, 'IN', 'mark', looking, []),
#  (he, 'PRP', 'nsubj', looking, []),
#  (was, 'VBD', 'aux', looking, []),
#  (looking, 'VBG', 'advcl', lengthened, [until, he, was, at, again]),
#  (at, 'IN', 'prep', looking, [Severus]),
#  (Severus, 'NNP', 'pobj', at, [ ]),
#  ( , '', '', Severus, []),
#  (again, 'RB', 'advmod', looking, []),
#  (., '.', 'punct', lengthened, []),
#  (``, '``', 'punct', understand, []),
#  (I, 'PRP', 'nsubj', understand, []),
#  (do, 'VBP', 'aux', understand, []),
#  (n't, 'RB', 'neg', understand, []),
#  (understand, 'VB', 'ROOT', understand, [``, I, do, n't, .]),
#  (., '.', 'punct', understand, []),
#  (Why, 'WRB', 'advmod', what, []),
#  (what, 'WP', 'ROOT', what, [Why, ?, "]),
#  (?, '.', 'punct', what, []),
#  (", "''", 'punct', what, []),
#  (``, '``', 'punct', To, []),
#  (To, 'IN', 'ROOT', To, [``, Severus, ,, perhaps, .]),
#  (Severus, 'NNP', 'pobj', To, [ ]),
#  ( , '', '', Severus, []),
#  (,, ',', 'punct', To, []),
#  (perhaps, 'RB', 'advmod', To, []),
#  (., '.', 'punct', To, []),
#  (Which, 'WDT', 'nsubj', means, []),
#  (means, 'VBZ', 'ROOT', means, [Which, ,, incidentally, ,, owes, ., '']),
#  (,, ',', 'punct', means, []),
#  (incidentally, 'RB', 'advmod', means, []),
#  (,, ',', 'punct', means, []),
#  (that, 'IN', 'mark', owes, []),
#  (James, 'NNP', 'nsubj', owes, [ ]),
#  ( , '', '', James, []),
#  (owes, 'VBZ', 'ccomp', means, [that, James, me, squids]),
#  (me, 'PRP', 'dative', owes, []),
#  (five, 'CD', 'nummod', squids, []),
#  (squids, 'NNS', 'dobj', owes, [five, ,, is]),
#  (,, ',', 'punct', squids, []),
#  (wherever, 'WRB', 'advmod', is, []),
#  (James, 'NNP', 'nsubj', is, [ ]),
#  ( , '', '', James, []),
#  (is, 'VBZ', 'advcl', squids, [wherever, James]),
#  (., '.', 'punct', means, []),
#  ('', "''", 'punct', means, []),
#  (James, 'NNP', 'nsubj', ignored, [ ]),
#  ( , '', '', James, []),
#  (ignored, 'VBD', 'ccomp', was, [James, issue, altogether]),
#  (the, 'DT', 'det', issue, []),
#  (werewolf, 'NN', 'compound', issue, []),
#  (issue, 'NN', 'dobj', ignored, [the, werewolf]),
#  (altogether, 'RB', 'advmod', ignored, []),
#  (;, ':', 'punct', was, []),
#  (Remus, 'NN', 'nsubj', was, []),
#  (was, 'VBD', 'ROOT', was, [ignored, ;, Remus, human, .]),
#  (as, 'RB', 'advmod', human, []),
#  (human, 'JJ', 'acomp', was, [as, as]),
#  (as, 'IN', 'prep', human, [James]),
#  (James, 'NNP', 'pobj', as, [ ]),
#  ( , '', '', James, []),
#  (., '.', 'punct', was, []),
#  (Sirius, 'NNP', 'nsubj', consulted, [ ]),
#  ( , '', '', Sirius, []),
#  (briefly, 'NN', 'advmod', consulted, []),
#  (consulted, 'VBD', 'ROOT', consulted, [Sirius, briefly, space, in, again, .]),
#  (the, 'DT', 'det', space, []),
#  (space, 'NN', 'dobj', consulted, [the]),
#  (in, 'IN', 'prep', consulted, [front]),
#  (front, 'NN', 'pobj', in, [of]),
#  (of, 'IN', 'prep', front, [eyes]),
#  (James, 'NNP', 'poss', eyes, [ ]),
#  ( , '', '', James, []),
#  (eyes, 'NNS', 'pobj', of, [James]),
#  (again, 'RB', 'advmod', consulted, []),
#  (., '.', 'punct', consulted, []),
#  (``, '``', 'punct', fit, []),
#  (We, 'PRP', 'nsubj', fit, []),
#  (..., 'NFP', 'punct', fit, []),
#  (fit, 'JJ', 'ROOT', fit, [``, We, ..., .]),
#  (., '.', 'punct', fit, []),
#  (We, 'PRP', 'nsubjpass', attracted, []),
#  (were, 'VBD', 'auxpass', attracted, []),
#  (attracted, 'VBN', 'ROOT', attracted, [We, were, to, .]),
#  (to, 'IN', 'prep', attracted, [other]),
#  (each, 'DT', 'det', other, []),
#  (other, 'JJ', 'pobj', to, [each]),
#  (., '.', 'punct', attracted, []),
#  (James, 'NNP', 'nsubj', understood, [ ]),
#  ( , '', '', James, []),
#  (understood, 'VBD', 'ccomp', understood, [James, me]),
#  (me, 'PRP', 'dobj', understood, []),
#  (,, ',', 'punct', understood, []),
#  (I, 'PRP', 'nsubj', understood, []),
#  (understood, 'VBD', 'ROOT', understood, [understood, ,, I, James, ., '']),
#  (James, 'NNP', 'dobj', understood, [ ]),
#  ( , '', '', James, []),
#  (., '.', 'punct', understood, []),
#  ('', "''", 'punct', understood, []),
#  (``, '``', 'punct', know, []),
#  (We, 'PRP', 'nsubj', know, []),
#  (know, 'VBP', 'ROOT', know, [``, We, turned, ,, '']),
#  (James, 'NNP', 'nsubj', turned, [ ]),
#  ( , '', '', James, []),
#  (turned, 'VBD', 'ccomp', know, [James, coat, for]),
#  (coat, 'NN', 'oprd', turned, []),
#  (for, 'IN', 'prep', turned, [us]),
#  (us, 'PRP', 'pobj', for, []),
#  (,, ',', 'punct', know, []),
#  ('', "''", 'punct', know, []),
#  (James, 'NNP', 'nsubj', said, [ ]),
#  ( , '', '', James, []),
#  (said, 'VBD', 'ROOT', said, [James, then, .]),
#  (then, 'RB', 'advmod', said, []),
#  (., '.', 'punct', said, []),
#  (``, '``', 'punct', means, []),
#  (Which, 'WDT', 'nsubj', means, []),
#  (means, 'VBZ', 'ROOT', means, [``, Which, was, ., '']),
#  (James, 'NNP', 'nmod', loyalty, [ ]),
#  ( , '', '', James, []),
#  (first, 'JJ', 'amod', loyalty, []),
#  (loyalty, 'NN', 'nsubj', was, [James, first]),
#  (was, 'VBD', 'ccomp', means, [loyalty, to]),
#  (to, 'IN', 'prep', was, [them]),
#  (them, 'PRP', 'pobj', to, []),
#  (., '.', 'punct', means, []),
#  ('', "''", 'punct', means, []),
#  (Eyes, 'NNS', 'nsubj', narrowed, []),
#  (narrowed, 'VBD', 'ROOT', narrowed, [Eyes, ,, drew, .]),
#  (,, ',', 'punct', narrowed, []),
#  (James, 'NNP', 'nsubj', drew, [ ]),
#  ( , '', '', James, []),
#  (drew, 'VBD', 'ccomp', narrowed, [James, out, cigarette]),
#  (out, 'RP', 'prt', drew, []),
#  (a, 'DT', 'det', cigarette, []),
#  (cigarette, 'NN', 'dobj', drew, [a]),
#  (., '.', 'punct', narrowed, []),
#  (``, "''", 'punct', said, []),
#  (James, 'NNP', 'ccomp', said, [ ]),
#  ( , '', '', James, []),
#  (,, ',', 'punct', said, []),
#  ('', "''", 'punct', said, []),
#  (James, 'NNP', 'nsubj', said, [ ]),
#  ( , '', '', James, []),
#  (said,
#   'VBD',
#   'parataxis',
#   participated,
#   [``, James, ,, '', James, ,, pausing, ,]),
#  (,, ',', 'punct', said, []),
#  (pausing, 'VBG', 'advcl', said, [spark]),
#  (to, 'TO', 'aux', spark, []),
#  (spark, 'VB', 'advcl', pausing, [to, it, on]),
#  (it, 'PRP', 'dobj', spark, []),
#  (on, 'IN', 'prep', spark, [knuckle]),
#  (James, 'NNP', 'nmod', knuckle, [ ]),
#  ( , '', '', James, []),
#  (knuckle, 'NN', 'pobj', on, [James]),
#  (,, ',', 'punct', said, []),
#  ('', "''", 'punct', participated, []),
#  (participated, 'VBD', 'ROOT', participated, [said, '', .]),
#  (., '.', 'punct', participated, []),
#  (Willingly, 'RB', 'ROOT', Willingly, [.]),
#  (., '.', 'punct', Willingly, []),
#  (", '``', 'punct', was, []),
#  (It, 'PRP', 'nsubj', was, []),
#  (was, 'VBD', 'ROOT', was, [", It, clear, Sirius, forgive, sharing, .]),
#  (clear, 'JJ', 'acomp', was, []),
#  (Sirius, 'NNP', 'npadvmod', was, [ ]),
#  ( , '', '', Sirius, []),
#  (would, 'MD', 'aux', forgive, []),
#  (never, 'RB', 'neg', forgive, []),
#  (forgive, 'VB', 'ccomp', was, [would, never, James, for, ,]),
#  (James, 'NNP', 'dobj', forgive, [ ]),
#  ( , '', '', James, []),
#  (for, 'IN', 'prep', forgive, [it]),
#  (it, 'PRP', 'pobj', for, []),
#  (,, ',', 'punct', forgive, []),
#  (whatever, 'WDT', 'dobj', sharing, []),
#  (truths, 'NNS', 'compound', Sirius, []),
#  (Sirius, 'NNP', 'nsubj', sharing, [truths,  ]),
#  ( , '', '', Sirius, []),
#  (were, 'VBD', 'aux', sharing, []),
#  (sharing,
#   'VBG',
#   'ccomp',
#   was,
#   [whatever, Sirius, were, tonight, notwithstanding]),
#  (tonight, 'NN', 'npadvmod', sharing, []),
#  (notwithstanding, 'IN', 'advmod', sharing, []),
#  (., '.', 'punct', was, []),
#  (Sirius, 'NNP', 'nsubj', seemed, [ ]),
#  ( , '', '', Sirius, []),
#  (seemed, 'VBD', 'ROOT', seemed, [Sirius, regard, ,, but, smirked]),
#  (to, 'TO', 'aux', regard, []),
#  (regard, 'VB', 'xcomp', seemed, [to, Severus, with]),
#  (Severus, 'NNP', 'dobj', regard, [ ]),
#  ( , '', '', Severus, []),
#  (with, 'IN', 'prep', regard, [something]),
#  (something, 'NN', 'pobj', with, [like, for]),
#  (like, 'IN', 'prep', something, [sympathy]),
#  (sympathy, 'NN', 'pobj', like, [or, understanding]),
#  (or, 'CC', 'cc', sympathy, []),
#  (even, 'RB', 'advmod', understanding, []),
#  (understanding, 'VBG', 'conj', sympathy, [even]),
#  (for, 'IN', 'prep', something, [second]),
#  (a, 'DT', 'det', second, []),
#  (bare, 'JJ', 'amod', second, []),
#  (second, 'NN', 'pobj', for, [a, bare]),
#  (,, ',', 'punct', seemed, []),
#  (but, 'CC', 'cc', seemed, []),
#  (then, 'RB', 'advmod', smirked, []),
#  (Severus, 'NNP', 'nsubj', smirked, [ ]),
#  ( , '', '', Severus, []),
#  (smirked, 'VBD', 'conj', seemed, [then, Severus, ,, cruelly, .]),
#  (,, ',', 'punct', smirked, []),
#  (cruelly, 'RB', 'advmod', smirked, []),
#  (., '.', 'punct', smirked, []),
#  (``, '``', 'punct', was, []),
#  (James, 'NNP', 'nsubj', was, [ ]),
#  ( , '', '', James, []),
#  (was, 'VBD', 'ROOT', was, [``, James, pureblood, ,, like, .]),
#  (a, 'DT', 'det', pureblood, []),
#  (pureblood, 'NN', 'attr', was, [a]),
#  (,, ',', 'punct', was, []),
#  (just, 'RB', 'advmod', like, []),
#  (like, 'IN', 'prep', was, [just, me]),
#  (me, 'PRP', 'pobj', like, []),
#  (., '.', 'punct', was, []),
#  (You, 'PRP', 'nsubj', been, []),
#  (', "''", 'punct', been, []),
#  (ve, 'VBP', 'aux', been, []),
#  (been, 'VBN', 'ROOT', been, [You, ', ve, envious, along, ., '']),
#  (envious, 'JJ', 'acomp', been, []),
#  (all, 'RB', 'advmod', along, []),
#  (along, 'RB', 'advmod', been, [all]),
#  (., '.', 'punct', been, []),
#  ('', "''", 'punct', been, []),
#  (``, '``', 'punct', did, []),
#  (I, 'PRP', 'nsubj', did, []),
#  (did, 'VBD', 'ROOT', did, [``, I, same, ,, '', blurted, .]),
#  (the, 'DT', 'det', same, []),
#  (same, 'JJ', 'dobj', did, [the]),
#  (,, ',', 'punct', did, []),
#  ('', "''", 'punct', did, []),
#  (Sirius, 'NNP', 'nsubj', blurted, [ ]),
#  ( , '', '', Sirius, []),
#  (blurted, 'VBD', 'ccomp', did, [Sirius, around]),
#  (around, 'IN', 'prep', blurted, [filter]),
#  (the, 'DT', 'det', filter, []),
#  (filter, 'NN', 'pobj', around, [the, of]),
#  (of, 'IN', 'prep', filter, [cigarette]),
#  (Severus, 'NNP', 'compound', cigarette, [ ]),
#  ( , '', '', Severus, []),
#  (cigarette, 'NN', 'pobj', of, [Severus]),
#  (., '.', 'punct', did, []),
#  (``, '``', 'punct', at, []),
#  (That, 'DT', 'det', night, []),
#  (night, 'NN', 'npadvmod', at, [That]),
#  (,, ',', 'punct', at, []),
#  (at, 'IN', 'ROOT', at, [``, night, ,, willow, .]),
#  (the, 'DT', 'det', willow, []),
#  (willow, 'NN', 'pobj', at, [the]),
#  (., '.', 'punct', at, []),
#  (I, 'PRP', 'nsubj', tried, []),
#  (tried, 'VBD', 'ROOT', tried, [I, frighten, thought, .]),
#  (to, 'TO', 'aux', frighten, []),
#  (frighten, 'VB', 'xcomp', tried, [to, you]),
#  (you, 'PRP', 'dobj', frighten, []),
#  (because, 'IN', 'mark', thought, []),
#  (I, 'PRP', 'nsubj', thought, []),
#  ...]

# %%
test_toks = nlp('Ryan is a doofus')
[(tok, tok.dep_, tok.head, [c.text for c in tok.head.children]) for tok in test_toks]
# Out:
# [(Ryan, 'nsubj', is, ['Ryan', 'doofus']),
#  (is, 'ROOT', is, ['Ryan', 'doofus']),
#  (a, 'det', doofus, ['a']),
#  (doofus, 'attr', is, ['Ryan', 'doofus'])]

# %%
# [tok.text for tok in test_toks if tok.dep_=='attr' and tok.head.text=='is' and 'Ryan' in list(tok.head.children)]
[tok.text for tok in test_toks if tok.dep_=='attr' and tok.head.text=='is' and 'Ryan' in [c.text for c in tok.head.children]]
# Out:
# ['doofus']

# %%
test_toks = nlp('Ryan, a doofus, sat at the table')
[(tok, tok.dep_, tok.head) for tok in test_toks]
# Out:
# [(Ryan, 'nsubj', sat),
#  (,, 'punct', Ryan),
#  (a, 'det', doofus),
#  (doofus, 'appos', Ryan),
#  (,, 'punct', sat),
#  (sat, 'ROOT', sat),
#  (at, 'prep', sat),
#  (the, 'det', table),
#  (table, 'pobj', at)]

# %%
test_toks = nlp('The disheveled Ryan sat at the table')
[(tok, tok.dep_, tok.head) for tok in test_toks]
# Out:
# [(The, 'det', Ryan),
#  (disheveled, 'amod', Ryan),
#  (Ryan, 'nsubj', sat),
#  (sat, 'ROOT', sat),
#  (at, 'prep', sat),
#  (the, 'det', table),
#  (table, 'pobj', at)]

# %%
# Verbs where character was the subject
verbs_subj = [tok.head for tok in annotated if tok.text == 'Sirius' and (tok.dep_=='nsubj' or tok.dep_=='agent')]
verbs_subj
# Out:
# [took,
#  stared,
#  grumbled,
#  laughed,
#  got,
#  snapped,
#  asked,
#  pointed,
#  frowned,
#  asked,
#  drank,
#  said,
#  were,
#  were,
#  said,
#  paused,
#  consulted,
#  sharing,
#  seemed,
#  blurted,
#  drawled,
#  said,
#  observed,
#  shrugged,
#  nodded,
#  grinned,
#  pursed,
#  was,
#  overarched,
#  looked,
#  clarified,
#  nodded,
#  admitted]

# %%
# Verbs where character was the object
# verbs_obj = [tok.head for tok in annotated if tok.text == 'Sirius' and tok.dep_=='dobj']
verbs_obj = [tok.head for tok in annotated if tok.text == 'Sirius' and (tok.dep_=='dobj' or tok.dep_=='nsubjpass' or tok.dep_=='dative' or tok.dep_=='pobj')]
# verbs_obj = [tok.head for tok in annotated if tok.text == 'me' and tok.dep_=='dobj']
# verbs_obj = [tok.head for tok in annotated if tok.text == 'him' and tok.dep_=='dobj']
verbs_obj
# Out:
# [got, at, of, into]

# %%
# Adjectives that describe the character
adjs = [tok.text for tok in annotated if tok.head.text == 'Sirius' and (tok.dep_=='amod' or tok.dep_=='appos' or tok.dep_=='nsubj' or tok.dep_=='nmod')] \
    + [tok.text for tok in test_toks if tok.dep_=='attr' and (tok.head.text=='is' or tok.head.text=='was') and 'Sirius' in [c.text for c in tok.head.children]]
    
adjs
# Out:
# []

# %%
def name_from_char(charname):
    name = ' '.join([part for part in charname.split('_') if part[0].isupper()])
    if name.endswith(')'):
        name = name[:-1]
    return name

# %%
def normalize_names(text):
    text_split = text.split()
    
    for i, word in enumerate(text_split):
        if word.startswith('($_'):
            name = name_from_char(word)
            text_split[i-1] = name
            text_split[i] = ''

    return ' '.join(text_split)

# %%
# Process assertions
import spacy
nlp = spacy.load('en', disable=['ner'])

# %%
from tqdm import tqdm_notebook as tqdm
import json

char_features = {}

dataset_name = 'complete_en_1k-50k'
pipeline_output_path = f'/data/fanfiction_gender_roles/harrypotter_ao3/{dataset_name}/output/'

output_dirpath = os.path.join(pipeline_output_path, 'char_features')
if not os.path.exists(output_dirpath):
    os.mkdir(output_dirpath)

# for fic in list(char_assertions.keys())[:1]:
for fic in tqdm(char_assertions):
    for char in char_assertions[fic]:
        name = name_from_char(char)
            
        assertions = ' '.join(char_assertions[fic][char])
        
        # Replace pronouns with coref'ed names
        assertions = normalize_names(assertions)
        
        # postag and parse
        annotated = nlp(assertions)
        
        # Verbs where character was the subject
        verbs_subj = [tok.head.text.lower() for tok in annotated if tok.text == name and (tok.dep_=='nsubj' or tok.dep_=='agent')]
        verbs_subj
        
        # Verbs where character was the object
        verbs_obj = [tok.head.text.lower() for tok in annotated if tok.text == name and (tok.dep_=='dobj' or tok.dep_=='nsubjpass' or tok.dep_=='dative' or tok.dep_=='pobj')]
        
        # Adjectives that describe the character
        adjs = [tok.text.lower() for tok in annotated if tok.head.text == name and (tok.dep_=='amod' or tok.dep_=='appos' or tok.dep_=='nsubj' or tok.dep_=='nmod')] \
            + [tok.text.lower() for tok in test_toks if tok.dep_=='attr' and (tok.head.text=='is' or tok.head.text=='was') and name in [c.text for c in tok.head.children]]
        
        if not fic in char_features:
            char_features[fic] = {}
        if not name in char_features[fic]:
            char_features[fic][name] = []
            
        char_features[fic][name].extend(verbs_subj + verbs_obj + adjs)
        
    # Save out
    with open(os.path.join(output_dirpath, f'{fic}.json'), 'w') as f:
        json.dump(char_features[fic], f)
        
char_features
# Out:
# HBox(children=(IntProgress(value=0, max=14989), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-94-be97835ea8e0> in <module>
#      22
#      23         # postag and parse
# ---> 24         annotated = nlp(assertions)
#      25
#      26         # Verbs where character was the subject
#
# ~/anaconda/lib/python3.7/site-packages/spacy/language.py in __call__(self, text, disable)
#     350             if not hasattr(proc, '__call__'):
#     351                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 352             doc = proc(doc)
#     353             if doc is None:
#     354                 raise ValueError(Errors.E005.format(name=name))
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.__call__()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.parse_batch()
#
# KeyboardInterrupt:

# %%
# Test loading processed JSON files
os.listdir(output_dirpath)
# Out:
# ['183523.json',
#  '918622.json',
#  '309535.json',
#  '726061.json',
#  '16391837.json',
#  '11032020.json',
#  '5480774.json',
#  '4465862.json',
#  '4012087.json',
#  '7514581.json',
#  '4459220.json',
#  '8531686.json',
#  '54247.json']

# %%
with open(os.path.join(output_dirpath, os.listdir(output_dirpath)[0])) as f:
    test_dict = json.load(f)
    
test_dict
# Out:
# {'Valentines Day': [],
#  'Sirius': ['shakes', 'says', 'move'],
#  'Remus': ['does',
#   'makes',
#   'hate',
#   'sitting',
#   'inserts',
#   'remarks',
#   'wriggles',
#   'continues',
#   'is',
#   'with'],
#  'James': ['explains',
#   'concludes',
#   'glowers',
#   'finishes',
#   'buried',
#   'asks',
#   'jumps',
#   'endearing',
#   'pines',
#   'raced',
#   'fights',
#   'says',
#   'stop',
#   'behind',
#   'see',
#   'of',
#   'after'],
#  'Evans': ['had', 'into'],
#  'God Moony': [],
#  'Wormtail': ['got'],
#  'Lily': ['been', 'see', 'get', "'re", 'set', 'on', 'hate']}

# %% [markdown]
# # Turn processed txt files into csv

# %%
# Copy existing csv files over
for fname in tqdm(os.listdir(coref_output_dirpath)):
    
    if not fname.endswith('.txt'):
        outpath = os.path.join(os.path.dirname(coref_output_dirpath), 'char_coref_stories_csv', fname)
        shutil.copy(os.path.join(coref_output_dirpath, fname), outpath)
# Out:
# HBox(children=(IntProgress(value=0, max=23780), HTML(value='')))

# %%
import os
from tqdm import tqdm_notebook as tqdm
import csv
import sys
import shutil
from IPython.core.debugger import set_trace

csv.field_size_limit(sys.maxsize)
coref_output_dirpath = '/data/fanfiction_gender_roles/harrypotter_ao3/complete_en_1k-50k/output/char_coref_stories'
original_dirpath = '/data/fanfiction_gender_roles/harrypotter_ao3/complete_en_1k-50k/fics'

for fname in tqdm(os.listdir(coref_output_dirpath)):
    
    if not fname.endswith('.txt'):
        continue
        
    fic_id = fname[:-10]
        
    # Read in header from original CSV
    with open(os.path.join(original_dirpath, f'{fic_id}.csv')) as fin:
        reader = csv.reader(fin)
        header = next(reader)
        
        # Read in coreffed txt
        with open(os.path.join(coref_output_dirpath, fname)) as f:
            lines = f.readlines()

        # Output
        with open(os.path.join(coref_output_dirpath, f'{fic_id}.coref.csv'), 'w') as fout:
            writer = csv.writer(fout)
            writer.writerow(header)

            # Write content
            for row,text in zip(reader, lines):
                if not len(row) - 1 > 0:
                    continue
                row[len(row)-1]= text # fill in text in final position
                writer.writerow(row)
# Out:
# HBox(children=(IntProgress(value=0, max=94861), HTML(value='')))

# %%
# Original
f = open(output_dir+"/"+filename[:-4]+".coref.txt")
fin = open(test_csv_dir+filename)
reader = csv.reader(fin)                                                 │
 50             header = next(reader)                                                    │  1  [||       8.9%]   9  [||||    23.1%]   17 [|||||||100.0%]   25 [|||||   32.7%]
 51             #fout = open(output_dir+"/"+filename[:-4]+".coref.csv","w", encoding='cp1│  2  [|||     13.0%]   10 [||||    25.6%]   18 [|||||||100.0%]   26 [|||     12.9%]
    250')                                                                                │  3  [||||||||57.1%]   11 [||||||| 45.3%]   19 [|||||   30.7%]   27 [||||    21.1%]
 52             fout = open(output_dir+"/"+filename[:-4]+".coref.csv","w", encoding='utf8│  4  [|||     10.5%]   12 [|||||||100.0%]   20 [|||||||100.0%]   28 [|||     14.0%]
    ')                                                                                   │  5  [||||||||97.5%]   13 [|||||||100.0%]   21 [|||     12.3%]   29 [||       7.5%]
 53             writer = csv.writer(fout)                                                │  6  [||||||||96.9%]   14 [|||||||100.0%]   22 [|||     11.7%]   30 [|||      9.2%]
 54             lines = f.readlines()                                                    │  7  [||||||||87.7%]   15 [|||||||100.0%]   23 [|||     12.9%]   31 [|||     14.8%]
 55             writer.writerow(header)                                                  │  8  [|||||||100.0%]   16 [|||     14.2%]   24 [|||      9.3%]   32 [|||||||100.0%]
 56                                                                                      │  Mem[|||||||||||||||||||||||||193G/252G]   Tasks: 236, 1474 thr; 39 running
 57             for row,text in zip(reader, lines):                                      │  Swp[|||||||||||||||||||||||||128G/128G]   Load average: 20.66 22.19 22.91 
 58             #row["paragraph"] = text                                                 │                                            Uptime: 32 days, 23:14:02
 59             #print (row["paragraph"])                                                │
 60             #print (text)                                                            │  PID USER      PRI  NI  VIRT   RES   SHR S CPU% MEM%   TIME+  Command                   
 61                 row[len(row)-1]= text                                                │31768 mamille2   20   0  9.5G 5801M 16612 S 355.  2.2 16h16:59 java -Xmx5g -cp stanford-c
 62                 writer.writerow(row)                                                 │20318 mamille2   20   0 9651M 5735M 16656 S 135.  2.2 13h32:48 java -Xmx5g -cp stanford-c
 63             #print (row['paragraph'])                                                │32698 xinruyan   20   0 9643M 3483M 16600 S 123.  1.4  2:46.96 java -cp /usr0/home/xinruy
 64                                                                                      │18935 mamille2   20   0 9715M 5795M  9660 S 119.  2.2 76h10:31 java -Xmx5g -cp stanford-c
 65             fin.close()                                                              │32760 xinruyan   20   0 9643M 3339M 16868 R 104.  1.3  0:27.91 java -cp /usr0/home/xinruy
 66             f.close()                                                                │32759 xinruyan   20   0 9643M 3339M 16868 S 103.  1.3  2:07.80 java -cp /usr0/home/xinruy
 67             fout.close()

# %% [markdown]
# # Split data into smaller directories

# %%
import os
from collections import defaultdict
import numpy as np

dataset_name = 'complete_en_1k-50k'
# fic_dirpath = f'/data/fanfiction_gender_roles/harrypotter_ao3/{dataset_name}/fics'
fic_dirpath = f'/projects/fanfiction-nlp/{dataset_name}_fic_text'

fnames = os.listdir(fic_dirpath)

# Mock split
split100 = defaultdict(list)
for fname in fnames:
    split100[fname[:2]].append(fname)
    
# Figures on splits
split100_lengths = [len(subdir) for name, subdir in split100.items()]
print(sorted(split100_lengths))
print(np.mean(split100_lengths))
print(len(split100))
# Out:
# [304, 378, 395, 401, 408, 421, 443, 445, 449, 457, 459, 459, 467, 470, 473, 477, 482, 484, 488, 488, 490, 491, 497, 499, 504, 508, 509, 511, 518, 521, 526, 528, 535, 538, 541, 541, 553, 562, 566, 570, 572, 576, 584, 585, 586, 588, 589, 590, 591, 591, 592, 592, 605, 608, 608, 611, 619, 624, 628, 629, 630, 630, 639, 640, 644, 650, 654, 655, 658, 674, 675, 677, 680, 699, 699, 701, 710, 728, 756, 840, 883, 1100, 1433, 2559, 4031, 4240, 4643, 5603, 5972, 8723]
# 935.0
# 90

# %%
# Make split
from tqdm import tqdm_notebook as tqdm
import shutil

fic_split_dirpath = fic_dirpath+'_split'
os.mkdir(fic_split_dirpath)

for split, split_fnames in tqdm(split100.items()):
    split_dirpath = os.path.join(fic_split_dirpath, split)
    os.mkdir(split_dirpath)
    for fname in split_fnames:
        shutil.copy(os.path.join(fic_dirpath, fname), os.path.join(split_dirpath, fname))
# Out:
# HBox(children=(IntProgress(value=0, max=90), HTML(value='')))

# %% [markdown]
# # Sample HP data

# %%
# Load HP metadata
import pandas as pd

metadata_fpath = '/data/fanfiction_gender_roles/harrypotter_ao3/story_metadata.csv'

metadata = pd.read_csv(metadata_fpath)
metadata.columns
# Out:
# Index(['fic_id', 'title', 'author', 'author_key', 'rating', 'category',
#        'fandom', 'relationship', 'character', 'additional tags', 'language',
#        'published', 'status', 'status date', 'words', 'comments', 'kudos',
#        'bookmarks', 'hits', 'chapter_count', 'series', 'seriespart',
#        'seriesid', 'summary', 'preface_notes', 'afterword_notes'],
#       dtype='object')

# %%
# Filter to complete fics in English between 1k-50k words

filtered_metadata = metadata[(metadata['status']=='Completed') & \
                            (metadata['language'] == 'English') & \
                            (metadata['words']>=1000) & \
                            (metadata['words']<=50000)]

print(len(metadata))
print(len(filtered_metadata))
# Out:
# 179407
# 84150

# %%
# Load HP files
import os

# fic_dirpath = '/usr2/mamille2/fanfiction-project/data/ao3/harrypotter/fics_paras/'
fic_dirpath = '/data/fanfiction_gender_roles/harrypotter_ao3/preprocessed_paras/

fic_ids = []
for fname in os.listdir(fic_dirpath):
    if not fname.endswith('_tokenized_paras.txt'):
        fic_ids.append(int(fname[:-4]))
        
len(fic_ids)
# Out:
# 179407

# %%
selected_fic_ids = filtered_metadata['fic_id'].to_list()
len(selected_fic_ids)
# Out:
# 84150

# %%
# Copy fics over 
import shutil
from tqdm import tqdm_notebook as tqdm

for fic_id in tqdm(selected_fic_ids):
    shutil.copy(os.path.join(fic_dirpath, f'{fic_id}.txt'), 
                os.path.join(f'/data/fanfiction_gender_roles/harrypotter_ao3/selected/{fic_id}.txt')
               )
# Out:
# HBox(children=(IntProgress(value=0, max=86303), HTML(value='')))

# %%
# Construct dict of fics -> chapter names
import os
from collections import defaultdict
from tqdm import tqdm_notebook as tqdm

fic_dirpath = '/usr2/scratch/fanfic/ao3_harrypotter_text/stories/'
chap_names = os.listdir(fic_dirpath)
fic2chapter = defaultdict(list)

for chapter in tqdm(chap_names):
    fic,_ = chapter.split('_')
    fic2chapter[fic].append(chapter)
    
len(fic2chapter)
# Out:
# 179407

# %%
# Copy raw fic CSVs over
import shutil
from tqdm import tqdm_notebook as tqdm

problem_chars = [
    "\u2028",
    '\u0092',
    '\u0093',
    '\u0094',
]

dataset_name = 'complete_en_1k-50k'

for fic_id in tqdm(selected_fic_ids):
    # Combine chapters into fics
    fic_chapters = []

    for chapter in fic2chapter[str(fic_id)]:
        with open(os.path.join(fic_dirpath, chapter)) as f:
            data = f.read()
            for char in problem_chars:
                data = data.replace(char, ' ')
                    
#             fic_chapters.append('\n'.join(f.read().replace(, ' ').splitlines()[1:])) # Add all but first header line
            fic_chapters.append('\n'.join(data.splitlines()[1:])) # Add all but first header line
        
    with open(os.path.join(f'/data/fanfiction_gender_roles/harrypotter_ao3/{dataset_name}/fics/{fic_id}.csv'), 'w') as f:
        f.write('fic_id,chapter_id,para_id,text\n')
        f.write('\n'.join(fic_chapters))
# Out:
# HBox(children=(IntProgress(value=0, max=84150), HTML(value='')))
