# %% [markdown]
# # Examine LGBT news corpus

# %%
# Load news corpus
import pandas as pd

lgbt_data = pd.read_csv('/data/fanfiction_ao3/lgbt_news/lgbt_news_corpus.csv', encoding='latin-1')
# lgbt_data = pd.read_csv('/data/fanfiction_ao3/lgbt_news/lgbt_news_corpus.csv', encoding='cp1252')
lgbt_data
# Out:
# /usr0/home/mamille2/anaconda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (7,8,10,14,18) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                                     Text  \
# 0      Re ÛÏObama Alters Hospital Rules for Gay Righ...
# 1      You cannot have people who have no expertise i...
# 2      In an interview with Tracy Clark-Flory on Salo...
# 3      After we filed back out into the Tennessee sun...
# 4      ''Gays and lesbians are a very good group of p...
# ...                                                  ...
# 34615  Infection data are sparse. Estimates of the nu...
# 34616  The Council notes that throughout the history ...
# 34617  Another reason throws light on C.D.C. reluctan...
# 34618  The executive director of the National Gay and...
# 34619  The other complaint was prompted by the broadc...
#
# ...

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
lgbt_data.sample(100).loc[:, ['Title', 'Date', 'Category']]
# Out:
#                                                                                        Title  \
# 12234                               Gay Couples Also Need Economic Benefits; Indeed a Family
# 21717                                              AIDS Patients In Dire Need Finding Solace
# 13606                                     Out Magazine Acquired by The Advocate, a Key Rival
# 19401                                                                           NEWS SUMMARY
# 3934                                                      Ruling Signals More Fights to Come
# 2483                                               Buzzwords; Hello, Synergy, Begone, Crisis
# 16618                                                     Boies Schiller Dismisses 3 Lawyers
# 3572                                                             Corrections: For the Record
# 32139                                          Salvation Army Is More Than Christmas Kettles
# ...

# %%
lgbt_data['Date'].max()
# Out:
# '2015-12-29T18:28:05Z'

# %%
# View articles 2010-2020
decade2010 = lgbt_data[lgbt_data['Date'].str.startswith('201')]
decade2010.loc[:, ['Title', 'Date', 'Category', 'Text']]
# Out:
#                                                    Title  \
# 0         Hospital Visiting Rights for Same-Sex Partners
# 2      Why Asexuals DonÛªt Want to Be Invisible Anymore
# 3      Dollywood: A Little Bit Country, a Little Bit Gay
# 8                     Don't Ask, Don't Tell, Don't Think
# 12                 Biden 'Comfortable' With Gay Marriage
# ...                                                  ...
# 19679         Stealing a Page From the Boomers' Playbook
# 19683  A National Strategy Funds State Political Mono...
# 19689  Arguments Heard in Federal Challenge of Virgin...
# 19697   Seeking a Same-Sex Marriage Case Fit for History
# 19725      Boy Scout Troop Loses Charter Over Gay Leader
#
#                        Date Category  \
# 0      2010-04-26T00:00:00Z  Opinion
# 2      2014-09-24T15:44:50Z  Unknown
# 3      2014-08-24T00:00:00Z   Travel
# 8      2012-07-17T16:50:14Z  Opinion
# 12     2012-05-06T11:02:19Z     U.S.
# ...                     ...      ...
# ...
